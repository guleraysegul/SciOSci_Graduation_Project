# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %%
import requests
from bs4 import BeautifulSoup
import json
import time

# Base URL of the Austrian Academy website
base_url = "https://www.oeaw.ac.at"

# URL to the main members page
members_page_url = "https://www.oeaw.ac.at/en/members"

# Function to scrape all members from the main page
def scrape_members():
    members = []
    try:
        response = requests.get(members_page_url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")

        # Find all member entries in the list
        member_list = soup.find_all("li")
        for member_item in member_list:
            link_tag = member_item.find("a", class_="before-arrow-right-icon")
            if link_tag:
                profile_url = base_url + link_tag["href"]
                degree_tag = link_tag.find("span", class_="degree")
                name_tag = link_tag.find("span", class_="name text-bold")

                # Extract name and degree, fallback to "Not available" if missing
                name = name_tag.get_text(strip=True) if name_tag else "Not available"
                degree = degree_tag.get_text(strip=True) if degree_tag else "Not available"

                members.append({"name": name, "degree": degree, "profile_url": profile_url})
    except Exception as e:
        print(f"Error fetching members: {e}")
    return members

# Function to scrape additional details from the profile page
def scrape_profile_details(member):
    try:
        response = requests.get(member["profile_url"])
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")

        # Example: Scraping expertise or other details (update as per the profile page structure)
        expertise_tag = soup.find("div", class_="field-expertise")  # Update with actual class or ID
        affiliations_tag = soup.find("div", class_="field-affiliations")  # Update with actual class or ID

        # Extract text content
        member["expertise"] = expertise_tag.get_text(strip=True) if expertise_tag else "Not available"
        member["affiliations"] = affiliations_tag.get_text(strip=True) if affiliations_tag else "Not available"
    except Exception as e:
        print(f"Error fetching profile details for {member['name']}: {e}")

# Scrape all members
members_data = scrape_members()

# Scrape profile details for each member
for member in members_data:
    scrape_profile_details(member)
    time.sleep(1)  # Add delay to respect API rate limits

# Save as JSON
json_output_path = "austrian_academy_members.json"
with open(json_output_path, "w", encoding="utf-8") as json_file:
    json.dump(members_data, json_file, indent=4, ensure_ascii=False)

print(f"Data saved to {json_output_path}")
# Out:
# Data saved to austrian_academy_members.json

# %%
import json

# Path to your JSON file
file_path = "/content/austrian_academy_members.json"  # Replace with the actual path to your JSON file

# Load the JSON data
with open(file_path, "r", encoding="utf-8") as file:
    data = json.load(file)

# Count the number of members
number_of_members = len(data)

print(f"Total number of members: {number_of_members}")
# Out:
# Total number of members: 950

# %%
import requests
from bs4 import BeautifulSoup
import json
import time

# Load the JSON file containing member profile links
members_file_path = "/content/austrian_academy_members.json"  # Replace with your actual file path

# Read the JSON file
with open(members_file_path, "r", encoding="utf-8") as file:
    members_data = json.load(file)

base_url = "https://www.oeaw.ac.at"  # Ensure correct base URL

# List to store the enhanced member data
enhanced_members_data = []

for member in members_data:
    try:
        # Fix URL construction
        profile_url = member["profile_url"] if member["profile_url"].startswith("http") else f"{base_url}{member['profile_url']}"
        response = requests.get(profile_url)
        response.raise_for_status()  # Ensure the request was successful

        soup = BeautifulSoup(response.content, "html.parser")

        # Extract name
        name = soup.find("h1").get_text(strip=True) if soup.find("h1") else "N/A"

        # Extract title
        title = soup.find("span", class_="degree").get_text(strip=True) if soup.find("span", class_="degree") else "N/A"

        # Extract affiliation
        affiliation = soup.find("ul", class_="medium-space-between").get_text(strip=True) if soup.find("ul", class_="medium-space-between") else "N/A"

        # Extract membership type (expertise)
        membership_type = soup.find("p", class_="membertype-statement").get_text(strip=True) if soup.find("p", class_="membertype-statement") else "N/A"

        # Append the data
        enhanced_members_data.append({
            "name": name,
            "title": title,
            "affiliation": affiliation,
            "membership_type": membership_type,
            "profile_url": profile_url
        })

        print(f"Scraped data for: {name}")

        # Sleep to respect the server
        time.sleep(1)

    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for {member.get('name', 'Unknown')}: {e}")

# Save the enhanced data to a new JSON file in the current directory
output_file_name = "austrian_academy_members_enhanced.json"

with open(output_file_name, "w", encoding="utf-8") as output_file:
    json.dump(enhanced_members_data, output_file, indent=4, ensure_ascii=False)

print(f"Enhanced data saved to {output_file_name}")
# Out:
# Scraped data for: Rainer Abart
# Scraped data for: Karl Acham
# Scraped data for: Antal Ádám
# Scraped data for: Ludwig Adamovich
# Scraped data for: Timon Erik Adolph
# Scraped data for: Alícia Adserà
# Scraped data for: Adriano Aguzzi
# Scraped data for: Josef Aicher
# Scraped data for: Martin Aigner
# Scraped data for: Luciana Aigner-Foresti
# Scraped data for: Brenda Almond
# Scraped data for: Michael Alram
# Scraped data for: Eva Alram-Stern
# Scraped data for: Carlos Alvar Ezquerra
# Scraped data for: João Alves
# Scraped data for: Michel Amandry
# Scraped data for: Petra Amann
# Scraped data for: Brigitta Ammann
# Scraped data for: Angelika Amon
# Scraped data for: Bertil Andersson
# Scraped data for: Bernard Andreae
# Scraped data for: Anaïs  Angelo
# Scraped data for: Flavio Anselmetti
# Scraped data for: Leah Armstrong
# Scraped data for: Markus Arndt
# Scraped data for: Eduard Arzt
# Scraped data for: Alain Aspect
# Scraped data for: Markus Aspelmeyer
# Scraped data for: Aleida Assmann
# Scraped data for: Alice Auersperg
# Scraped data for: Hans Aurenhammer
# Scraped data for: Manuela Baccarini
# Scraped data for: Andrea Bachmaier
# Scraped data for: Auksė Balčytienė
# Scraped data for: Andrius Baltuška
# Scraped data for: Albert-László Barabási
# Scraped data for: Andrea Barta
# Scraped data for: Friedrich G. Barth
# Scraped data for: Hans Basbøll
# Scraped data for: Rainer Bauböck
# Scraped data for: Bernhard Bauer
# Scraped data for: Siegfried J. Bauer
# Scraped data for: Friedrich L. Bauer
# Scraped data for: Günther Bauer
# Scraped data for: Wolfgang Baumjohann
# Scraped data for: Zdeněk P. Bažant
# Scraped data for: Alexander K.  Belyaev
# Scraped data for: Robert John Bennett
# Scraped data for: Iván T. Berend
# Scraped data for: Walter Berka
# Scraped data for: Walter Berschin
# Scraped data for: Pier Marco Bertinetto
# Scraped data for: Reinhold Bichler
# Scraped data for: Manfred Bietak
# Scraped data for: Francesco C. Billari
# Scraped data for: Kurt Binder
# Scraped data for: Michal Biran
# Scraped data for: Helmut Birkhan
# Scraped data for: Paul Albert Blanz
# Scraped data for: Thomas Blaschke
# Scraped data for: Jean-Pierre Blaser
# Scraped data for: Rainer Blatt
# Scraped data for: Helen M. Blau
# Scraped data for: Horst Bleckmann
# Scraped data for: Günter Blöschl
# Scraped data for: Hans-Heinrich Blotevogel
# Scraped data for: Christoph Bock
# Scraped data for: Michael Joachim Bonell
# Scraped data for: Jürgen Borchhardt
# Scraped data for: Włodzimierz Borodziej
# Scraped data for: Axel Börsch-Supan
# Scraped data for: Axel Borsdorf
# Scraped data for: Richard Bösel
# Scraped data for: Jacques Bouveresse
# Scraped data for: John W. Boyer
# Scraped data for: Kaan Boztug
# Scraped data for: Karl Dietrich Bracher
# Scraped data for: Peter Brang
# Scraped data for: Georg Brasseur
# Scraped data for: Achim Brauer
# Scraped data for: Georg Peter Braulik
# Scraped data for: Jürgen Braunstein
# Scraped data for: Michel Breger
# Scraped data for: Gottfried Brem
# Scraped data for: Jan N. Bremmer
# Scraped data for: Wolfgang H. Breunlich
# Scraped data for: Wolfgang Brezinka
# Scraped data for: Hans Briegel
# Scraped data for: Günter Brucher
# Scraped data for: Gerhart Bruckmann
# Scraped data for: Ernst Bruckmüller
# Scraped data for: Wolfgang Brückner
# Scraped data for: Gerhard Budin
# Scraped data for: Julia Budka
# Scraped data for: Alejandro Raul Burga Ramos
# Scraped data for: Joachim Burgdörfer
# Scraped data for: Manfred Burgstaller
# Scraped data for: Otto Burkard
# Scraped data for: Walter Burkert
# Scraped data for: Meinrad Busslinger
# Scraped data for: Vladimír Bužek
# Scraped data for: Peter Bydlinski
# Scraped data for: Claus-Wilhelm Canaris
# Scraped data for: Carmen Cardelle de Hartmann
# Scraped data for: Louis Carlen
# Scraped data for: Giovanni Battista Castiglioni
# Scraped data for: Marina Cattaruzza
# Scraped data for: Federico Celestini
# Scraped data for: Komaravolu Chandrasekharan
# Scraped data for: Emmanuelle Charpentier
# Scraped data for: Mark W. Chase
# Scraped data for: Hai Cheng
# Scraped data for: Kenneth R. Chien
# Scraped data for: Maria Christakis
# Scraped data for: Enno Christophers
# Scraped data for: Evangelos Chrysos
# Scraped data for: Johann Cigler
# Scraped data for: Ignacio J. Cirac
# Scraped data for: Christopher M. Clark
# Scraped data for: Gary B. Cohen
# Scraped data for: Adrian Constantin
# Scraped data for: Michael P. Conzen
# Scraped data for: Paul Corkum
# Scraped data for: Thomas Corsten
# Scraped data for: Moritz Csáky
# Scraped data for: Christa Cuchiero
# Scraped data for: Yasin Dagdas
# Scraped data for: Falko Daim
# Scraped data for: Joachim Dalfen
# Scraped data for: Georg Danek
# Scraped data for: Robert Danzer
# Scraped data for: Lorraine Daston
# Scraped data for: Elisa  Davoli
# Scraped data for: Igor Bert Dawid
# Scraped data for: Patrizia de Bernardo Stempel
# Scraped data for: Gemma De les Coves
# Scraped data for: Bruno De Nicola
# Scraped data for: Nicla  De Zorzi
# Scraped data for: Peter Deetjen
# Scraped data for: Gerhard Dehm
# Scraped data for: Stefanie Dehnen
# Scraped data for: Manfred Deistler
# Scraped data for: Agnes Dellinger
# Scraped data for: Alexander Demandt
# Scraped data for: Helmut Denk
# Scraped data for: Barry J. Dickson
# Scraped data for: Ulrike Diebold
# Scraped data for: Egbert Dierker
# Scraped data for: Cora Dietl
# Scraped data for: Nina A. Dmitrieva
# Scraped data for: Gerhard Dobesch
# Scraped data for: Gabriele Doblhammer-Reiter
# Scraped data for: Liam Dolan
# Scraped data for: Rafael Domingo
# Scraped data for: Michael Doneus
# Scraped data for: Friedrich Dorner
# Scraped data for: Claudia Draxl
# Scraped data for: Wolfgang Ulrich Dressler
# Scraped data for: Michael Drmota
# Scraped data for: Ernst Peter Michael Dronke
# Scraped data for: Heinz Duchhardt
# Scraped data for: Klaus Düwel
# Scraped data for: Friedrich Dydak
# Scraped data for: Katarzyna Dziubalska-Kołaczyk
# Scraped data for: Josef Eberhardsteiner
# Scraped data for: Jürgen Eckert
# Scraped data for: Herbert Edelsbrunner
# Scraped data for: Hubert Christian Ehalt
# Scraped data for: Friedrich Ehrendorfer
# Scraped data for: Martin Ehrendorfer
# Scraped data for: Bernhard Ehrenzeller
# Scraped data for: Ludwig M. Eichinger
# Scraped data for: Michael Eichmair
# Scraped data for: Heiner Eichner
# Scraped data for: Manfred Eigen
# Scraped data for: Manfred Einsiedler
# Scraped data for: Thomas Eiter
# Scraped data for: Ivar Ekeland
# Scraped data for: Wilfried Ellmeier
# Scraped data for: Vincent Eltschinger
# Scraped data for: Heinz Engl
# Scraped data for: Johannes Erben
# Scraped data for: László Erdös
# Scraped data for: Gerhard Ertl
# Scraped data for: Maria J. Esteban
# Scraped data for: Richard John Evans
# Scraped data for: Robert John Weston Evans
# Scraped data for: Itamar Even-Zohar
# Scraped data for: Ludwig D. Faddeev
# Scraped data for: Heinz Falk
# Scraped data for: Gerda Falkner
# Scraped data for: Reinhard Fässler
# Scraped data for: Heinz Faßmann
# Scraped data for: Bénédicte Fauvarque-Cosson
# Scraped data for: Ernst Fehr
# Scraped data for: Gustav Feichtinger
# Scraped data for: Johannes Feichtinger
# Scraped data for: Martin S. Feldstein
# Scraped data for: Hannes A. Fellner
# Scraped data for: Sebastian Felten
# Scraped data for: Francesca Ferlaino
# Scraped data for: Günter Bernhard L. Fettweis
# Scraped data for: Ingeborg Fiala-Fürst
# Scraped data for: Wolfgang Fichtner
# Scraped data for: Hermann Fillitz
# Scraped data for: Jörg Finsinger
# Scraped data for: Andrea Fischer
# Scraped data for: Peter Fischer
# Scraped data for: Manfred M. Fischer
# Scraped data for: Hellmut F. Fischmeister
# Scraped data for: Jürgen Fleig
# Scraped data for: Konstanze Fliedl
# Scraped data for: August Florian
# Scraped data for: Rudolf Flotzinger
# Scraped data for: Monika Fludernik
# Scraped data for: Helmut Flügel
# Scraped data for: Franz Födermayr
# Scraped data for: Pál Fodor
# Scraped data for: Herbert Foltinek
# Scraped data for: Sebastian  Forster
# Scraped data for: Heinz G. Fortak
# Scraped data for: Bert Fragner
# Scraped data for: Wolfgang Frank
# Scraped data for: Peter Robert Franke
# Scraped data for: Peter Fratzl
# Scraped data for: Stefan Freunberger
# Scraped data for: Johannes Fried
# Scraped data for: Herwig Friesinger
# Scraped data for: Wolfgang Frisch
# Scraped data for: Sylvia Frühwirth-Schnatter
# Scraped data for: Erwin Führer
# Scraped data for: Alexia Fürnkranz-Prskawetz
# Scraped data for: Alois Fürstner
# Scraped data for: Helmut Gadner
# Scraped data for: Natalia Gagarina
# Scraped data for: Franz Gamillscheg
# Scraped data for: Thomas V. Gamkrelidze
# Scraped data for: Hans-Martin Gauger
# Scraped data for: Patrick J. Geary
# Scraped data for: Michael Gehler
# Scraped data for: Monika Gehrig-Merz
# Scraped data for: Johannes Geiss
# Scraped data for: Klaus Gersten
# Scraped data for: Martin H. Gerzabek
# Scraped data for: Michael Ghil
# Scraped data for: Patrizia Giampieri-Deutsch
# Scraped data for: Gerhard Giebisch
# Scraped data for: Oswald Giering
# Scraped data for: Simone Gingrich
# Scraped data for: Andre Gingrich
# Scraped data for: Karl-Heinz Alois Glaßmeier
# Scraped data for: Gerhard Glatzel
# Scraped data for: Claire F. Gmachl
# Scraped data for: Michael  Gnant
# Scraped data for: Helmut Gneuss
# Scraped data for: Hans Goebl
# Scraped data for: Ivan Golub
# Scraped data for: Leticia González
# Scraped data for: Maciej Górny
# Scraped data for: Georg Gottlob
# Scraped data for: Georg Grabherr
# Scraped data for: Sherrill Grace
# Scraped data for: Bernhard Grasemann
# Scraped data for: Manfred Grasserbauer
# Scraped data for: Daniel M. Greenberger
# Scraped data for: Wolfgang Greisenegger
# Scraped data for: Frantz Grenet
# Scraped data for: Herfried Griengl
# Scraped data for: Nicolas Grimal
# Scraped data for: Rudolf Grimm
# Scraped data for: Irmgard Griss
# Scraped data for: Jasmina Grković-Major
# Scraped data for: Rudolf Grosschedl
# Scraped data for: Peter Manfred Gruber
# Scraped data for: Gernot Gruber
# Scraped data for: Oskar Grün
# Scraped data for: Dieter Gutknecht
# Scraped data for: Giselher Guttmann
# Scraped data for: Mats Gyllenberg
# Scraped data for: Kálmán Györgyi
# Scraped data for: Rudolf Haag
# Scraped data for: Gerhard Haerendel
# Scraped data for: Stefan Hagel
# Scraped data for: Othmar Hageneder
# Scraped data for: Martin Hairer
# Scraped data for: Ivo Hajnal
# Scraped data for: John Haldon
# Scraped data for: Max Haller
# Scraped data for: Franz Halter-Koch
# Scraped data for: Ernst Hanisch
# Scraped data for: Ulf Hannerz
# Scraped data for: Edouard Hannezo
# Scraped data for: Christian Hannick
# Scraped data for: Aage A. Hansen-Löve
# Scraped data for: Michael Hantel
# Scraped data for: Jens-Uwe Hartmann
# Scraped data for: Maximilian Hartmuth
# Scraped data for: Mathias Harzhauser
# Scraped data for: Horst Haselsteiner
# Scraped data for: Günther Hasinger
# Scraped data for: Friederike Hassauer
# Scraped data for: Wolfgang Haubrichs
# Scraped data for: Gabriele Haug-Moritz
# Scraped data for: Hermann Franz Haupt
# Scraped data for: Uta Heil
# Scraped data for: Wolf-Dieter Heiss
# Scraped data for: Philipp U. Heitz
# Scraped data for: Christian Hellmich
# Scraped data for: Gilbert Helmberg
# Scraped data for: Monika Henzinger
# Scraped data for: Thomas A. Henzinger
# Scraped data for: Milan Herak
# Scraped data for: Gerhard Herndl
# Scraped data for: Marie Louise Herzfeld-Schild
# Scraped data for: Hans-Joachim Hinrichsen
# Scraped data for: Oskar v. Hinüber
# Scraped data for: Ivan Hlaváček
# Scraped data for: Milan Hlavačka
# Scraped data for: Claudia Höbartner
# Scraped data for: Erwin Hochmair
# Scraped data for: Ingeborg Hochmair-Desoyer
# Scraped data for: Sepp Hochreiter
# Scraped data for: Hartwig Höcker
# Scraped data for: Ivo Ludwig Hofacker
# Scraped data for: Barbara Hohn
# Scraped data for: Hans Höller
# Scraped data for: Gerald  Holton
# Scraped data for: Gerhard A. Holzapfel
# Scraped data for: Robert Holzmann
# Scraped data for: Heinrich Honsell
# Scraped data for: Barbara Horejs
# Scraped data for: Oleh Hornykiewicz
# Scraped data for: Konstantin-Alexander Hossmann
# Scraped data for: Yaroslav Hrytsak
# Scraped data for: Christoph Huber
# Scraped data for: Thomas J. R. Hughes
# Scraped data for: Pascale Hugon
# Scraped data for: Hermann Hunger
# Scraped data for: Nicola Hüsing
# Scraped data for: Reinhard Franz Josef Hüttl
# Scraped data for: Anthony A. Hyman
# Scraped data for: Ataç İmamoğlu
# Scraped data for: Christoph Irmscher
# Scraped data for: Hans Irschik
# Scraped data for: Shiro Ishii
# Scraped data for: Hans Peter Isler
# Scraped data for: Lisa Isola
# Scraped data for: Clemens Jabloner
# Scraped data for: Éva Jakab
# Scraped data for: Bernhard Jakoby
# Scraped data for: Sigrid Jalkotzy-Deger
# Scraped data for: Cecilia Jarlskog
# Scraped data for: Erik Jayme
# Scraped data for: Franz Jeglitsch
# Scraped data for: Thomas Jenuwein
# Scraped data for: Hans Joas
# Scraped data for: Werner Jobst
# Scraped data for: Zdenek Johan
# Scraped data for: Peter Johanek
# Scraped data for: Julian Johnson
# Scraped data for: Michael Jursa
# Scraped data for: Thede Kahl
# Scraped data for: Barbara Kaltenbacher
# Scraped data for: Manfred  Kaltenbacher
# Scraped data for: Eric R. Kandel
# Scraped data for: Andreas Kappeler
# Scraped data for: Vassos Karageorghis
# Scraped data for: Stevan Karamata
# Scraped data for: Matthias Karmasin
# Scraped data for: Martin Karplus
# Scraped data for: Georg Kaser
# Scraped data for: Daniel Kastler
# Scraped data for: Radoslav Katičić
# Scraped data for: Stephen Ira Katz
# Scraped data for: Hubert Kaufhold
# Scraped data for: Sylvia Kaufmann
# Scraped data for: Anke Rita Kaysser-Pyzalla
# Scraped data for: Katrin Keller
# Scraped data for: Birgit Kellner
# Scraped data for: Fritz Kelnhofer
# Scraped data for: Thomas Kenner
# Scraped data for: Manfred Kern
# Scraped data for: Eva Kernbauer
# Scraped data for: Ferenc Kiefer
# Scraped data for: Rudolf Kippenhahn
# Scraped data for: Gottfried Kirchengast
# Scraped data for: Britta Klagge
# Scraped data for: Michał Kleiber
# Scraped data for: Hans-Dieter Klein
# Scraped data for: Jürgen Kleine-Vehn
# Scraped data for: Nina Klimburg-Witjes
# Scraped data for: Bernd Ulrich Kluge
# Scraped data for: Alfred Kluwick
# Scraped data for: Fritz Peter Knapp
# Scraped data for: Sylvia Knapp
# Scraped data for: Jürgen Knoblich
# Scraped data for: Wolfgang Knoll
# Scraped data for: Christian Köberl
# Scraped data for: Walter Koch
# Scraped data for: Johannes Koder
# Scraped data for: Alfred Kohler
# Scraped data for: Alwin Köhler
# Scraped data for: Martin Kohli
# Scraped data for: Walter Kohn
# Scraped data for: Kurt L. Komarek
# Scraped data for: Robert Konrat
# Scraped data for: Hermann Kopetz
# Scraped data for: Hans-Georg Koppensteiner
# Scraped data for: Martin Korenjak
# Scraped data for: Karl Korinek
# Scraped data for: Christian Körner
# Scraped data for: Dušan Kováč
# Scraped data for: Helmut Koziol
# Scraped data for: Frauke Kraas
# Scraped data for: Dietrich Kraft
# Scraped data for: Ernst August Kramer
# Scraped data for: Christoph Kratky
# Scraped data for: Christian Krattenthaler
# Scraped data for: Ferenc Krausz
# Scraped data for: Bernhard Kräutler
# Scraped data for: Josef Kreiner
# Scraped data for: Georg Kresse
# Scraped data for: Otto Kresten
# Scraped data for: Friedrich Krinzinger
# Scraped data for: Guido Kroemer
# Scraped data for: Karl Kroeschell
# Scraped data for: Kurt Krolop
# Scraped data for: James Glenn Krueger
# Scraped data for: Hans-Henrik Krummacher
# Scraped data for: Andreas Kugi
# Scraped data for: Michael Kuhn
# Scraped data for: Richard Küng
# Scraped data for: Wilfried Kurz
# Scraped data for: Walter Kutschera
# Scraped data for: Jan Květ
# Scraped data for: Paul Alexander Kyrle
# Scraped data for: Anne L’Huillier
# Scraped data for: Johanna Laakso
# Scraped data for: Sabine Ladstätter
# Scraped data for: Christopher F. Laferl
# Scraped data for: Peter Laggner
# Scraped data for: Julia Lajta-Novak
# Scraped data for: Vasileios Lambrinoudakis
# Scraped data for: Claus Lamm
# Scraped data for: Irene Marthe Lang
# Scraped data for: Armin Lange
# Scraped data for: Robert S. Langer
# Scraped data for: Heinz Langer
# Scraped data for: Walter Larcher
# Scraped data for: Hans Lassmann
# Scraped data for: Reinhard Lauer
# Scraped data for: Jacques Le Rider
# Scraped data for: Klaus Lechner
# Scraped data for: Joseph Theodoor Leerssen
# Scraped data for: Gustav Adolf Lehmann
# Scraped data for: Marianne Johanna Lehmkuhl
# Scraped data for: Ursula Lehr
# Scraped data for: Helga Leitner
# Scraped data for: Mikhail Lemeshko
# Scraped data for: Alexandra N. Lenz
# Scraped data for: Silke Leopold
# Scraped data for: Johannes A. Lercher
# Scraped data for: Willem J. M. Levelt
# Scraped data for: Gary Libben
# Scraped data for: Elliott Lieb
# Scraped data for: Gene Elden Likens
# Scraped data for: Mandana E. Limbert
# Scraped data for: Andrea Lindmayr-Brandl
# Scraped data for: Thomas Lindner
# Scraped data for: Karl Lintner
# Scraped data for: Benjamin List
# Scraped data for: Birgit Lodes
# Scraped data for: Michele Loporcaro
# Scraped data for: Hellmut Lorenz
# Scraped data for: Martin Löschnigg
# Scraped data for: Peter Lucas
# Scraped data for: Monika Ludwig
# Scraped data for: Gerhard Luf
# Scraped data for: Thomas Luger
# Scraped data for: Helmut Lukesch
# Scraped data for: Reimar Lüst
# Scraped data for: Christina Lutter
# Scraped data for: Wolfgang Lutz
# Scraped data for: Marc Luy
# Scraped data for: Séamus Mac Mathúna
# Scraped data for: Thomas Magauer
# Scraped data for: Astrid Mager
# Scraped data for: Claudio Magris
# Scraped data for: Christian Mair
# Scraped data for: Melanie Malzahn
# Scraped data for: Herbert Mang
# Scraped data for: Wolfgang Mantl
# Scraped data for: Joseph Maran
# Scraped data for: Michael Marberger
# Scraped data for: Raimund Margreiter
# Scraped data for: Peter Markowich
# Scraped data for: James H. Marrow
# Scraped data for: Alberto Martino
# Scraped data for: Herbert Matis
# Scraped data for: Aleksandar Matković
# Scraped data for: Franz Matscher
# Scraped data for: Richard Viktor Mattessich
# Scraped data for: Hartmut  Matthäus
# Scraped data for: Paolo Matthiae
# Scraped data for: Marjori Ann Matzke
# Scraped data for: Nuno Maulide
# Scraped data for: Bernd Mayer
# Scraped data for: Henry M. R. E. Mayr-Harting
# Scraped data for: Paul Heinz Mayrhofer
# Scraped data for: Otto Mayrhofer-Krammel
# Scraped data for: Brigitte Mazohl
# Scraped data for: Rosamond McKitterick
# Scraped data for: Peter McMullen
# Scraped data for: Wolfgang F. G. Mecklenbräuker
# Scraped data for: Wolfgang Meid
# Scraped data for: Anne Sophie Meincke
# Scraped data for: Igor Mel'čuk
# Scraped data for: Fritz Melchers
# Scraped data for: Sarah Melzer
# Scraped data for: Günther Meschke
# Scraped data for: Bruno Messerli
# Scraped data for: Michael Metzeltin
# Scraped data for: Carola Metzner-Nebelsick
# Scraped data for: Ronald Micura
# Scraped data for: Gero Miesenböck
# Scraped data for: Hanno Millesi
# Scraped data for: Nina Mirnig
# Scraped data for: Diana Mishkova
# Scraped data for: Jürgen Mittelstraß
# Scraped data for: Christian  Mitterer
# Scraped data for: Fritz Mitthof
# Scraped data for: Kimberly Modic
# Scraped data for: Stephan Moebius
# Scraped data for: Helmuth Möhwald
# Scraped data for: Andreas F. Molisch
# Scraped data for: Hans Mommsen
# Scraped data for: Alessandro Montanari
# Scraped data for: Helmut Moritz
# Scraped data for: Cécile Morrisson
# Scraped data for: Gina E. Moseley
# Scraped data for: Helfried Mostler
# Scraped data for: Gérard A. Mourou
# Scraped data for: Nicolette Mout
# Scraped data for: Dennis C. Mueller
# Scraped data for: Wolfgang Mueller
# Scraped data for: Ivan I. Mueller
# Scraped data for: Sandra Müller
# Scraped data for: Ulrike Müller-Böker
# Scraped data for: Johann Mulzer
# Scraped data for: Ulrike Müßig
# Scraped data for: Karol Myśliwiec
# Scraped data for: Herta Nagl-Docekal
# Scraped data for: Norman M. Naimark
# Scraped data for: Rumi Nakamura
# Scraped data for: George (Gia) Sch. Nakhutsrishvili
# Scraped data for: Kim A. Nasmyth
# Scraped data for: David Natal Villazala
# Scraped data for: Adolf Neckel
# Scraped data for: Robert Nedoma
# Scraped data for: Wolfgang  Neubauer
# Scraped data for: Christine Neugebauer-Maresch
# Scraped data for: Winfried L. Neuhuber
# Scraped data for: Walter Neupert
# Scraped data for: Gerhard Neweklowsky
# Scraped data for: Stefan Michael Newerkla
# Scraped data for: Harald Niederreiter
# Scraped data for: Christian Roland Noe
# Scraped data for: Magnus Nordborg
# Scraped data for: Dieter Nörr
# Scraped data for: Marie-Louise Nosch
# Scraped data for: Sir Gustav Joseph Victor Nossal
# Scraped data for: Heinrich Nöth
# Scraped data for: Martin A. Nowak
# Scraped data for: Helga Nowotny
# Scraped data for: Onora O'Neill
# Scraped data for: Anna Christina Obenauf
# Scraped data for: Paul Oberhammer
# Scraped data for: Gerhard Oberhammer
# Scraped data for: Dieter Oesterhelt
# Scraped data for: Werner Ogris
# Scraped data for: Oskar Friedrich Olaj
# Scraped data for: Thomas Olechowski
# Scraped data for: Gerhard Opelz
# Scraped data for: Gherardo Ortalli
# Scraped data for: Marcus Ossiander
# Scraped data for: Jurij Sergejewitsch Ossipov
# Scraped data for: Jürgen Osterhammel
# Scraped data for: Jörg A. Ott
# Scraped data for: Alfred E. von Overbeck
# Scraped data for: Peter Palese
# Scraped data for: Herbert Palme
# Scraped data for: Bernhard Palme
# Scraped data for: Jian-Wei Pan
# Scraped data for: Oswald Panagl
# Scraped data for: Lucy Y. Pao
# Scraped data for: Fritz Paschke
# Scraped data for: Gernot Patzelt
# Scraped data for: Josef Penninger
# Scraped data for: Ernst Pernicka
# Scraped data for: Peter Pernthaler
# Scraped data for: Anne Peters
# Scraped data for: Jan-Michael Peters
# Scraped data for: Jillian Petersen
# Scraped data for: Hellmuth Petsche
# Scraped data for: Johann Pfanzagl
# Scraped data for: Gerhard Pferschy
# Scraped data for: Otto Pfersmann
# Scraped data for: Jörg Pfleiderer
# Scraped data for: Gert Pfurtscheller
# Scraped data for: Philip Ivanov Philippov
# Scraped data for: Gernot Piccottini
# Scraped data for: Helmut Pichler
# Scraped data for: Hannes Pichler
# Scraped data for: Pierre Jean Pichot
# Scraped data for: Herbert Pietschmann
# Scraped data for: Werner E. Piller
# Scraped data for: Renate Johanna Pillinger
# Scraped data for: Rudolf Pischinger
# Scraped data for: Clemens Plaschka
# Scraped data for: Carolina Plescia
# Scraped data for: Walter L. Pohl
# Scraped data for: Walter Pohl
# Scraped data for: Hryhoriy Polshyn
# Scraped data for: Marianne Popp
# Scraped data for: Magdalena Pöschl
# Scraped data for: Barbara Prainsack
# Scraped data for: Rudolf Preimesberger
# Scraped data for: Anton Preisinger
# Scraped data for: Friedrich B. Prinz
# Scraped data for: Manfred Prisching
# Scraped data for: Stephan  Procházka
# Scraped data for: Paolo Prodi
# Scraped data for: Walter Puchner
# Scraped data for: Andreas Pülz
# Scraped data for: Denise Pumain
# Scraped data for: Sonja Puntscher Riekmann
# Scraped data for: Gernot Rabeder
# Scraped data for: Ljiljana Radonić
# Scraped data for: Piero Rafanelli
# Scraped data for: Andrej Rahten
# Scraped data for: Franz Rainer
# Scraped data for: Ekkehard Ramm
# Scraped data for: Franz G. Rammerstorfer
# Scraped data for: Friederike Range
# Scraped data for: Claudia Rapp
# Scraped data for: Armando Rastelli
# Scraped data for: Gudrun Rath
# Scraped data for: Isabelle Ratié
# Scraped data for: Helmut Rauch
# Scraped data for: Peter H. Raven
# Scraped data for: Karl M. A. Rawer
# Scraped data for: Katharina Rebay-Salisbury
# Scraped data for: Anton Rebhan
# Scraped data for: Ludwig Reich
# Scraped data for: Ingo Reiffenstein
# Scraped data for: Wolf Uwe Reimold
# Scraped data for: Susanne Reindl-Krauskopf
# Scraped data for: August Reinisch
# Scraped data for: André Reis
# Scraped data for: Elmar R. Reiter
# Scraped data for: Reinhold Remmert
# Scraped data for: Andrew Colin Renfrew
# Scraped data for: Andrea Rentmeister
# Scraped data for: Fritz Resinger
# Scraped data for: Georg Ress
# Scraped data for: Keywan Riahi
# Scraped data for: James R. Rice
# Scraped data for: Kurt R. Richter
# Scraped data for: Norbert G. Riedel
# Scraped data for: Willibald Riedler
# Scraped data for: Josef Riedmann
# Scraped data for: Wolfgang Riehle
# Scraped data for: Gert Riethmüller
# Scraped data for: Wolfgang Rindler
# Scraped data for: Zsigmond Ritoók
# Scraped data for: Monika Ritsch-Marte
# Scraped data for: Olivia Fiona Robinson
# Scraped data for: Alexandra Rodler-Rørbo
# Scraped data for: Teresa Rodríguez de las Heras Ballell
# Scraped data for: Juan Gualterio Roederer
# Scraped data for: Herbert Walter Roesky
# Scraped data for: Robert Rollinger
# Scraped data for: José Luis Romero
# Scraped data for: Maria Grazia Roncarolo
# Scraped data for: Artur Rosenauer
# Scraped data for: Leopold Rosenmayr
# Scraped data for: Michael Rössner
# Scraped data for: Mathias Walter Rotach
# Scraped data for: Carlo Rubbia
# Scraped data for: Helmut O. Rucker
# Scraped data for: Helmut Rumpler
# Scraped data for: Hans Georg Ruppe
# Scraped data for: Günther Rupprechter
# Scraped data for: Eda Sagarra
# Scraped data for: Richard Salomon
# Scraped data for: Roman Sandgruber
# Scraped data for: Friedrich Sandhofer
# Scraped data for: Birgit Sandkaulen
# Scraped data for: Niyazi Serdar Sariçiftçi
# Scraped data for: Michael Sarnthein-Lotichius
# Scraped data for: Pasqualina Maria Sarro
# Scraped data for: Paolo Sartori
# Scraped data for: Friedrich Schaller
# Scraped data for: Gottfried Schatz
# Scraped data for: Philipp  Scheibelreiter
# Scraped data for: Walter Scheidel
# Scraped data for: Eva Schernhammer
# Scraped data for: Rudolf Schieffer
# Scraped data for: Sabine Schindler
# Scraped data for: Philipp Schindler
# Scraped data for: Andrzej Schinzel
# Scraped data for: Wolfgang Schlager
# Scraped data for: Wolfgang P. Schleich
# Scraped data for: Christa Schleper
# Scraped data for: Hermann Schmalzried
# Scraped data for: Klaus Schmidt
# Scraped data for: Wolfgang Schmidt
# Scraped data for: Matthias  Schmidt
# Scraped data for: Johannes Schmidt
# Scraped data for: Alfred Schmidt
# Scraped data for: Arnold Schmidt
# Scraped data for: Ernst August Schmidt
# Scraped data for: Philipp Schmidt-Dengler
# Scraped data for: Ursula Schmidt-Erfurth
# Scraped data for: Sabine Schmidtke
# Scraped data for: Jörg Schmiedmayer
# Scraped data for: Lambert Schmithausen
# Scraped data for: Rüdiger Schmitt
# Scraped data for: Oliver Jens Schmitt
# Scraped data for: Kurt Schmoller
# Scraped data for: Isabel Schnabel
# Scraped data for: Wilhelm Schneider
# Scraped data for: Albrecht Schöne
# Scraped data for: Hans Peter Schönlaub
# Scraped data for: Peter Schönswetter
# Scraped data for: Carl E. Schorske
# Scraped data for: Peter Schreiner
# Scraped data for: Ulrich Schubert
# Scraped data for: Gerold Schuler
# Scraped data for: Rolf Schulte-Hermann
# Scraped data for: Birgitta Schultze-Bernhardt
# Scraped data for: Winfried Schulze
# Scraped data for: Josef Schurz
# Scraped data for: Peter Schuster
# Scraped data for: Gerhard Schütz
# Scraped data for: Sebastian Schütze
# Scraped data for: Hans Schwabl
# Scraped data for: Karlheinz Schwarz
# Scraped data for: Florian Schwarz
# Scraped data for: Hans Georg Schwarzacher
# Scraped data for: Walther Schwarzacher
# Scraped data for: Günter C. Schweiger
# Scraped data for: Fritz Schweiger
# Scraped data for: Michael Schweitzer
# Scraped data for: Dieter Schweizer
# Scraped data for: Hugo Schwendenwein
# Scraped data for: Martin Seger
# Scraped data for: Christian Seidl
# Scraped data for: Horst Seidler
# Scraped data for: Stephan Johannes Seidlmayer
# Scraped data for: Robert  Seiringer
# Scraped data for: Ali Mehmet Celâl Şengör
# Scraped data for: Veronika Sexl
# Scraped data for: Demetra Sfendoni-Mentzou
# Scraped data for: Francesco Sferra
# Scraped data for: Danuta Shanzer
# Scraped data for: M. Rahim Shayegan
# Scraped data for: Ethan M. Shevach
# Scraped data for: Maria Sibilia
# Scraped data for: Susanne Sievers
# Scraped data for: Karl Sigmund
# Scraped data for: Petra Sijpesteijn
# Scraped data for: Oleg Simakov
# Scraped data for: Barry Simon
# Scraped data for: Nicholas Sims-Williams
# Scraped data for: Hans-Werner Sinn
# Scraped data for: Peter Sitte
# Scraped data for: Quentin R. D. Skinner
# Scraped data for: Uwe B. Sleytr
# Scraped data for: John Victor Small
# Scraped data for: Kurt Smolak
# Scraped data for: Josef Smolen
# Scraped data for: Werner Sollors
# Scraped data for: Éva Somogyi
# Scraped data for: Vera T. Sós
# Scraped data for: Nicola Spaldin
# Scraped data for: Katta Spiel
# Scraped data for: Christoph Spötl
# Scraped data for: Hellmuth Stachel
# Scraped data for: Saskia Stachowitsch
# Scraped data for: Peter F. Stadler
# Scraped data for: Lawrence E. Stager
# Scraped data for: Sigrid Stagl
# Scraped data for: André Stahl
# Scraped data for: Maria A. Stassinopoulou
# Scraped data for: Paul Stefanovits
# Scraped data for: Florian  Steger
# Scraped data for: Erwin Stein
# Scraped data for: Sybille Steinbacher
# Scraped data for: Peter Steinhauser
# Scraped data for: Friedrich Franz Steininger
# Scraped data for: Ernst Steinkellner
# Scraped data for: Hans-Peter Steinrück
# Scraped data for: Barbara Stelzl-Marx
# Scraped data for: Günter Stemberger
# Scraped data for: Stig T. Stenholm
# Scraped data for: Nikolaus K. Stephanidis
# Scraped data for: Peter Štih
# Scraped data for: Georg Stingl
# Scraped data for: Gerold Stoll
# Scraped data for: Barbara Stollberg-Rilinger
# Scraped data for: Gerald Stourzh
# Scraped data for: Helmut Strasser
# Scraped data for: Erich Wolfgang Streissler
# Scraped data for: Jörg Striessnig
# Scraped data for: Josef Strobl
# Scraped data for: Arno Strohmeyer
# Scraped data for: Tod F. Stuessy
# Scraped data for: Christian Sturmbauer
# Scraped data for: Robert Samuel Summers
# Scraped data for: Hans Sünkel
# Scraped data for: Giulio Superti-Furga
# Scraped data for: Arnold Suppan
# Scraped data for: Ernst Christoph Suttner
# Scraped data for: Gustav Andreas Tammann
# Scraped data for: Elly Tanaka
# Scraped data for: Éva Tardos
# Scraped data for: Ulrich Technau
# Scraped data for: Jaroslav Tejral
# Scraped data for: Werner Telesko
# Scraped data for: Heinz-Elmar Tenorth
# Scraped data for: Erich Thenius
# Scraped data for: Udo Thiel
# Scraped data for: Gerhard Thür
# Scraped data for: Robert F. Tichy
# Scraped data for: Klement Tockner
# Scraped data for: Theodor Tomandl
# Scraped data for: Erich Trapp
# Scraped data for: Dirk Trauner
# Scraped data for: Michael Trauner
# Scraped data for: Marko Trogrlić
# Scraped data for: Hans Tuppy
# Scraped data for: Franz-Josef Ulm
# Scraped data for: Melanie Unseld
# Scraped data for: Miriam M. Unterlass
# Scraped data for: Gerald Urban
# Scraped data for: Otto Helmut Urban
# Scraped data for: Boris A. Uspenskij
# Scraped data for: Gerd W. Utermann
# Scraped data for: Alice Vadrot
# Scraped data for: Rudolf Valenta
# Scraped data for: Peter van Nieuwenhuizen
# Scraped data for: Mihai-Cristian Vasile
# Scraped data for: Michael Johannes Vellekoop
# Scraped data for: Beatriz Vicoso
# Scraped data for: Karl Vodrazka
# Scraped data for: Thomas Vogl
# Scraped data for: Arndt von Haeseler
# Scraped data for: Klaus von Klitzing
# Scraped data for: Alfred Wagenhofer
# Scraped data for: Horst Wagner
# Scraped data for: Andreas  Wagner
# Scraped data for: Günter P. Wagner
# Scraped data for: Karl Wagner
# Scraped data for: Sigurd Wagner
# Scraped data for: Erwin F. Wagner
# Scraped data for: Michael Wagner
# Scraped data for: Birgit Wagner
# Scraped data for: Scott Waitukaitis
# Scraped data for: Wolfgang A. Wall
# Scraped data for: Grete Walter-Klingenstein
# Scraped data for: Heinrich Wänke
# Scraped data for: Graham Warren
# Scraped data for: Peter Michael Warren
# Scraped data for: Andrea Weber
# Scraped data for: Harald Wolfgang Weber
# Scraped data for: Gerhard Wegner
# Scraped data for: Rüdiger Wehner
# Scraped data for: Susanne Weigelin-Schwiedrzik
# Scraped data for: Stefan Weinfurter
# Scraped data for: Astrid Weiss
# Scraped data for: Günter Weiss
# Scraped data for: Werner Welzig
# Scraped data for: Emo Welzl
# Scraped data for: Christiane Wendehorst
# Scraped data for: Samuel A. Werner
# Scraped data for: Diter von Wettstein
# Scraped data for: Manfred Wicke
# Scraped data for: Gerhard Widmer
# Scraped data for: Ewald Wiederin
# Scraped data for: Maria Katharina  Wiedlack
# Scraped data for: Malcolm Hewitt Wiener
# Scraped data for: Josef Wiesehöfer
# Scraped data for: Wolfgang Wieser
# Scraped data for: Heinz Gregor Wieser
# Scraped data for: Michaela Wiesinger
# Scraped data for: Peter Wiesinger
# Scraped data for: Luzius Wildhaber
# Scraped data for: Günther Wilke
# Scraped data for: F. Ludwig Wilke
# Scraped data for: Jürgen Wilke
# Scraped data for: Harco Willems
# Scraped data for: Anouk Willemsen
# Scraped data for: Michaela Windischgrätz
# Scraped data for: Verena Winiwarter
# Scraped data for: Thomas Winkelbauer
# Scraped data for: Hans Winkler
# Scraped data for: Georg Winter
# Scraped data for: Renée Winter
# Scraped data for: Erich Winter
# Scraped data for: Irene J. Winter
# Scraped data for: Gerhard Wirth
# Scraped data for: Norbert Richard Wolf
# Scraped data for: Alois Wolf
# Scraped data for: Eckhard Wolf
# Scraped data for: Werner Wolf
# Scraped data for: Ulrich Wolf
# Scraped data for: Klaus Wolff
# Scraped data for: Herwig Wolfram
# Scraped data for: Bernhard Woytek
# Scraped data for: Dagmar Wujastyk
# Scraped data for: Keizô Yamamoto
# Scraped data for: Yeong-Bin Yang
# Scraped data for: William Edgar Yates
# Scraped data for: Bilge Yıldız
# Scraped data for: Stephen G. Young
# Scraped data for: Waldemar Zacharasiewicz
# Scraped data for: Hans Georg Zachau
# Scraped data for: Anatoly G. Zagorodny
# Scraped data for: Kurt Zatloukal
# Scraped data for: Josef Zechner
# Scraped data for: Rudolf Zechner
# Scraped data for: Anton Zeilinger
# Scraped data for: Josef Zemann
# Scraped data for: Wolfgang Zenker
# Scraped data for: Michael Zgurovsky
# Scraped data for: Yong-de Zhang
# Scraped data for: Shuguang Zhang
# Scraped data for: Franz Ziegler
# Scraped data for: Peter V. Zima
# Scraped data for: Reinhard Zimmermann
# Scraped data for: Harald Volkmar Zimmermann
# Scraped data for: Michel Zink
# Scraped data for: Ernst K. Zinner
# Scraped data for: Natalia A. Zinovieva
# Scraped data for: Theodore J. Ziolkowski
# Scraped data for: Jan M. Ziolkowski
# Scraped data for: Peter Zoller
# Scraped data for: Alessandro Zuccari
# Scraped data for: Paul Michael Zulehner
# Enhanced data saved to austrian_academy_members_enhanced.json

# %%
import requests
import json
import time

# Input: Austrian Academy Members JSON file
input_file_path = "/content/austrian_academy_members_enhanced.json"  # Replace with your actual file path

# Output file paths
output_file_path = "austrian_academy_members_author_ids.json"  # JSON output file

# Function to fetch OpenAlex data for an author by name
def fetch_openalex_data(name):
    try:
        url = f"https://api.openalex.org/authors?filter=display_name.search:{name}"
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        if "results" in data and data["results"]:
            author = data["results"][0]
            return {
                "openalex_id": author.get("id"),
                "works_count": author.get("works_count"),
                "cited_by_count": author.get("cited_by_count"),
                "h_index": author.get("h_index"),
                "i10_index": author.get("i10_index"),
            }
        else:
            return {
                "openalex_id": None,
                "works_count": None,
                "cited_by_count": None,
                "h_index": None,
                "i10_index": None,
            }
    except requests.exceptions.RequestException as e:
        print(f"Error fetching OpenAlex data for {name}: {e}")
        return {
            "openalex_id": None,
            "works_count": None,
            "cited_by_count": None,
            "h_index": None,
            "i10_index": None,
        }

# Read the input JSON file
with open(input_file_path, "r", encoding="utf-8") as file:
    members_data = json.load(file)

# List to store enriched member data
enriched_members_data = []

# Iterate through each member and fetch OpenAlex data
for member in members_data:
    name = member.get("name", "N/A")
    print(f"Fetching OpenAlex data for: {name}")

    # Fetch OpenAlex data
    openalex_data = fetch_openalex_data(name)

    # Append OpenAlex data to the member record
    enriched_member = {
        "name": name,
        "expertise": member.get("expertise", "N/A"),
        **openalex_data  # Merge OpenAlex data
    }
    enriched_members_data.append(enriched_member)

    # Respect API rate limits
    time.sleep(1)

# Save the enriched data to a new JSON file
with open(output_file_path, "w", encoding="utf-8") as output_file:
    json.dump(enriched_members_data, output_file, indent=4, ensure_ascii=False)

print(f"Data with OpenAlex details saved to {output_file_path}")
# Out:
# Fetching OpenAlex data for: Rainer Abart
# Fetching OpenAlex data for: Karl Acham
# Fetching OpenAlex data for: Antal Ádám
# Fetching OpenAlex data for: Ludwig Adamovich
# Fetching OpenAlex data for: Timon Erik Adolph
# Fetching OpenAlex data for: Alícia Adserà
# Fetching OpenAlex data for: Adriano Aguzzi
# Fetching OpenAlex data for: Josef Aicher
# Fetching OpenAlex data for: Martin Aigner
# Fetching OpenAlex data for: Luciana Aigner-Foresti
# Fetching OpenAlex data for: Brenda Almond
# Fetching OpenAlex data for: Michael Alram
# Fetching OpenAlex data for: Eva Alram-Stern
# Fetching OpenAlex data for: Carlos Alvar Ezquerra
# Fetching OpenAlex data for: João Alves
# Fetching OpenAlex data for: Michel Amandry
# Fetching OpenAlex data for: Petra Amann
# Fetching OpenAlex data for: Brigitta Ammann
# Fetching OpenAlex data for: Angelika Amon
# Fetching OpenAlex data for: Bertil Andersson
# Fetching OpenAlex data for: Bernard Andreae
# Fetching OpenAlex data for: Anaïs  Angelo
# Fetching OpenAlex data for: Flavio Anselmetti
# Fetching OpenAlex data for: Leah Armstrong
# Fetching OpenAlex data for: Markus Arndt
# Fetching OpenAlex data for: Eduard Arzt
# Fetching OpenAlex data for: Alain Aspect
# Fetching OpenAlex data for: Markus Aspelmeyer
# Fetching OpenAlex data for: Aleida Assmann
# Fetching OpenAlex data for: Alice Auersperg
# Fetching OpenAlex data for: Hans Aurenhammer
# Fetching OpenAlex data for: Manuela Baccarini
# Fetching OpenAlex data for: Andrea Bachmaier
# Fetching OpenAlex data for: Auksė Balčytienė
# Fetching OpenAlex data for: Andrius Baltuška
# Fetching OpenAlex data for: Albert-László Barabási
# Fetching OpenAlex data for: Andrea Barta
# Fetching OpenAlex data for: Friedrich G. Barth
# Fetching OpenAlex data for: Hans Basbøll
# Fetching OpenAlex data for: Rainer Bauböck
# Fetching OpenAlex data for: Bernhard Bauer
# Fetching OpenAlex data for: Siegfried J. Bauer
# Fetching OpenAlex data for: Friedrich L. Bauer
# Fetching OpenAlex data for: Günther Bauer
# Fetching OpenAlex data for: Wolfgang Baumjohann
# Fetching OpenAlex data for: Zdeněk P. Bažant
# Fetching OpenAlex data for: Alexander K.  Belyaev
# Fetching OpenAlex data for: Robert John Bennett
# Fetching OpenAlex data for: Iván T. Berend
# Fetching OpenAlex data for: Walter Berka
# Fetching OpenAlex data for: Walter Berschin
# Fetching OpenAlex data for: Pier Marco Bertinetto
# Fetching OpenAlex data for: Reinhold Bichler
# Fetching OpenAlex data for: Manfred Bietak
# Fetching OpenAlex data for: Francesco C. Billari
# Fetching OpenAlex data for: Kurt Binder
# Fetching OpenAlex data for: Michal Biran
# Fetching OpenAlex data for: Helmut Birkhan
# Fetching OpenAlex data for: Paul Albert Blanz
# Fetching OpenAlex data for: Thomas Blaschke
# Fetching OpenAlex data for: Jean-Pierre Blaser
# Fetching OpenAlex data for: Rainer Blatt
# Fetching OpenAlex data for: Helen M. Blau
# Fetching OpenAlex data for: Horst Bleckmann
# Fetching OpenAlex data for: Günter Blöschl
# Fetching OpenAlex data for: Hans-Heinrich Blotevogel
# Fetching OpenAlex data for: Christoph Bock
# Fetching OpenAlex data for: Michael Joachim Bonell
# Fetching OpenAlex data for: Jürgen Borchhardt
# Fetching OpenAlex data for: Włodzimierz Borodziej
# Fetching OpenAlex data for: Axel Börsch-Supan
# Fetching OpenAlex data for: Axel Borsdorf
# Fetching OpenAlex data for: Richard Bösel
# Fetching OpenAlex data for: Jacques Bouveresse
# Fetching OpenAlex data for: John W. Boyer
# Fetching OpenAlex data for: Kaan Boztug
# Fetching OpenAlex data for: Karl Dietrich Bracher
# Fetching OpenAlex data for: Peter Brang
# Fetching OpenAlex data for: Georg Brasseur
# Fetching OpenAlex data for: Achim Brauer
# Fetching OpenAlex data for: Georg Peter Braulik
# Fetching OpenAlex data for: Jürgen Braunstein
# Fetching OpenAlex data for: Michel Breger
# Fetching OpenAlex data for: Gottfried Brem
# Fetching OpenAlex data for: Jan N. Bremmer
# Fetching OpenAlex data for: Wolfgang H. Breunlich
# Fetching OpenAlex data for: Wolfgang Brezinka
# Fetching OpenAlex data for: Hans Briegel
# Fetching OpenAlex data for: Günter Brucher
# Fetching OpenAlex data for: Gerhart Bruckmann
# Fetching OpenAlex data for: Ernst Bruckmüller
# Fetching OpenAlex data for: Wolfgang Brückner
# Fetching OpenAlex data for: Gerhard Budin
# Fetching OpenAlex data for: Julia Budka
# Fetching OpenAlex data for: Alejandro Raul Burga Ramos
# Fetching OpenAlex data for: Joachim Burgdörfer
# Fetching OpenAlex data for: Manfred Burgstaller
# Fetching OpenAlex data for: Otto Burkard
# Fetching OpenAlex data for: Walter Burkert
# Fetching OpenAlex data for: Meinrad Busslinger
# Fetching OpenAlex data for: Vladimír Bužek
# Fetching OpenAlex data for: Peter Bydlinski
# Fetching OpenAlex data for: Claus-Wilhelm Canaris
# Fetching OpenAlex data for: Carmen Cardelle de Hartmann
# Fetching OpenAlex data for: Louis Carlen
# Fetching OpenAlex data for: Giovanni Battista Castiglioni
# Fetching OpenAlex data for: Marina Cattaruzza
# Fetching OpenAlex data for: Federico Celestini
# Fetching OpenAlex data for: Komaravolu Chandrasekharan
# Fetching OpenAlex data for: Emmanuelle Charpentier
# Fetching OpenAlex data for: Mark W. Chase
# Fetching OpenAlex data for: Hai Cheng
# Fetching OpenAlex data for: Kenneth R. Chien
# Fetching OpenAlex data for: Maria Christakis
# Fetching OpenAlex data for: Enno Christophers
# Fetching OpenAlex data for: Evangelos Chrysos
# Fetching OpenAlex data for: Johann Cigler
# Fetching OpenAlex data for: Ignacio J. Cirac
# Fetching OpenAlex data for: Christopher M. Clark
# Fetching OpenAlex data for: Gary B. Cohen
# Fetching OpenAlex data for: Adrian Constantin
# Fetching OpenAlex data for: Michael P. Conzen
# Fetching OpenAlex data for: Paul Corkum
# Fetching OpenAlex data for: Thomas Corsten
# Fetching OpenAlex data for: Moritz Csáky
# Fetching OpenAlex data for: Christa Cuchiero
# Fetching OpenAlex data for: Yasin Dagdas
# Fetching OpenAlex data for: Falko Daim
# Fetching OpenAlex data for: Joachim Dalfen
# Fetching OpenAlex data for: Georg Danek
# Fetching OpenAlex data for: Robert Danzer
# Fetching OpenAlex data for: Lorraine Daston
# Fetching OpenAlex data for: Elisa  Davoli
# Fetching OpenAlex data for: Igor Bert Dawid
# Fetching OpenAlex data for: Patrizia de Bernardo Stempel
# Fetching OpenAlex data for: Gemma De les Coves
# Fetching OpenAlex data for: Bruno De Nicola
# Fetching OpenAlex data for: Nicla  De Zorzi
# Fetching OpenAlex data for: Peter Deetjen
# Fetching OpenAlex data for: Gerhard Dehm
# Fetching OpenAlex data for: Stefanie Dehnen
# Fetching OpenAlex data for: Manfred Deistler
# Fetching OpenAlex data for: Agnes Dellinger
# Fetching OpenAlex data for: Alexander Demandt
# Fetching OpenAlex data for: Helmut Denk
# Fetching OpenAlex data for: Barry J. Dickson
# Fetching OpenAlex data for: Ulrike Diebold
# Fetching OpenAlex data for: Egbert Dierker
# Fetching OpenAlex data for: Cora Dietl
# Fetching OpenAlex data for: Nina A. Dmitrieva
# Fetching OpenAlex data for: Gerhard Dobesch
# Fetching OpenAlex data for: Gabriele Doblhammer-Reiter
# Fetching OpenAlex data for: Liam Dolan
# Fetching OpenAlex data for: Rafael Domingo
# Fetching OpenAlex data for: Michael Doneus
# Fetching OpenAlex data for: Friedrich Dorner
# Fetching OpenAlex data for: Claudia Draxl
# Fetching OpenAlex data for: Wolfgang Ulrich Dressler
# Fetching OpenAlex data for: Michael Drmota
# Fetching OpenAlex data for: Ernst Peter Michael Dronke
# Fetching OpenAlex data for: Heinz Duchhardt
# Fetching OpenAlex data for: Klaus Düwel
# Fetching OpenAlex data for: Friedrich Dydak
# Fetching OpenAlex data for: Katarzyna Dziubalska-Kołaczyk
# Fetching OpenAlex data for: Josef Eberhardsteiner
# Fetching OpenAlex data for: Jürgen Eckert
# Fetching OpenAlex data for: Herbert Edelsbrunner
# Fetching OpenAlex data for: Hubert Christian Ehalt
# Fetching OpenAlex data for: Friedrich Ehrendorfer
# Fetching OpenAlex data for: Martin Ehrendorfer
# Fetching OpenAlex data for: Bernhard Ehrenzeller
# Fetching OpenAlex data for: Ludwig M. Eichinger
# Fetching OpenAlex data for: Michael Eichmair
# Fetching OpenAlex data for: Heiner Eichner
# Fetching OpenAlex data for: Manfred Eigen
# Fetching OpenAlex data for: Manfred Einsiedler
# Fetching OpenAlex data for: Thomas Eiter
# Fetching OpenAlex data for: Ivar Ekeland
# Fetching OpenAlex data for: Wilfried Ellmeier
# Fetching OpenAlex data for: Vincent Eltschinger
# Fetching OpenAlex data for: Heinz Engl
# Fetching OpenAlex data for: Johannes Erben
# Fetching OpenAlex data for: László Erdös
# Fetching OpenAlex data for: Gerhard Ertl
# Fetching OpenAlex data for: Maria J. Esteban
# Fetching OpenAlex data for: Richard John Evans
# Fetching OpenAlex data for: Robert John Weston Evans
# Fetching OpenAlex data for: Itamar Even-Zohar
# Fetching OpenAlex data for: Ludwig D. Faddeev
# Fetching OpenAlex data for: Heinz Falk
# Fetching OpenAlex data for: Gerda Falkner
# Fetching OpenAlex data for: Reinhard Fässler
# Fetching OpenAlex data for: Heinz Faßmann
# Fetching OpenAlex data for: Bénédicte Fauvarque-Cosson
# Fetching OpenAlex data for: Ernst Fehr
# Fetching OpenAlex data for: Gustav Feichtinger
# Fetching OpenAlex data for: Johannes Feichtinger
# Fetching OpenAlex data for: Martin S. Feldstein
# Fetching OpenAlex data for: Hannes A. Fellner
# Fetching OpenAlex data for: Sebastian Felten
# Fetching OpenAlex data for: Francesca Ferlaino
# Fetching OpenAlex data for: Günter Bernhard L. Fettweis
# Fetching OpenAlex data for: Ingeborg Fiala-Fürst
# Fetching OpenAlex data for: Wolfgang Fichtner
# Fetching OpenAlex data for: Hermann Fillitz
# Fetching OpenAlex data for: Jörg Finsinger
# Fetching OpenAlex data for: Andrea Fischer
# Fetching OpenAlex data for: Peter Fischer
# Fetching OpenAlex data for: Manfred M. Fischer
# Fetching OpenAlex data for: Hellmut F. Fischmeister
# Fetching OpenAlex data for: Jürgen Fleig
# Fetching OpenAlex data for: Konstanze Fliedl
# Fetching OpenAlex data for: August Florian
# Fetching OpenAlex data for: Rudolf Flotzinger
# Fetching OpenAlex data for: Monika Fludernik
# Fetching OpenAlex data for: Helmut Flügel
# Fetching OpenAlex data for: Franz Födermayr
# Fetching OpenAlex data for: Pál Fodor
# Fetching OpenAlex data for: Herbert Foltinek
# Fetching OpenAlex data for: Sebastian  Forster
# Fetching OpenAlex data for: Heinz G. Fortak
# Fetching OpenAlex data for: Bert Fragner
# Fetching OpenAlex data for: Wolfgang Frank
# Fetching OpenAlex data for: Peter Robert Franke
# Fetching OpenAlex data for: Peter Fratzl
# Fetching OpenAlex data for: Stefan Freunberger
# Fetching OpenAlex data for: Johannes Fried
# Fetching OpenAlex data for: Herwig Friesinger
# Fetching OpenAlex data for: Wolfgang Frisch
# Fetching OpenAlex data for: Sylvia Frühwirth-Schnatter
# Fetching OpenAlex data for: Erwin Führer
# Fetching OpenAlex data for: Alexia Fürnkranz-Prskawetz
# Fetching OpenAlex data for: Alois Fürstner
# Fetching OpenAlex data for: Helmut Gadner
# Fetching OpenAlex data for: Natalia Gagarina
# Fetching OpenAlex data for: Franz Gamillscheg
# Fetching OpenAlex data for: Thomas V. Gamkrelidze
# Fetching OpenAlex data for: Hans-Martin Gauger
# Fetching OpenAlex data for: Patrick J. Geary
# Fetching OpenAlex data for: Michael Gehler
# Fetching OpenAlex data for: Monika Gehrig-Merz
# Fetching OpenAlex data for: Johannes Geiss
# Fetching OpenAlex data for: Klaus Gersten
# Fetching OpenAlex data for: Martin H. Gerzabek
# Fetching OpenAlex data for: Michael Ghil
# Fetching OpenAlex data for: Patrizia Giampieri-Deutsch
# Fetching OpenAlex data for: Gerhard Giebisch
# Fetching OpenAlex data for: Oswald Giering
# Fetching OpenAlex data for: Simone Gingrich
# Fetching OpenAlex data for: Andre Gingrich
# Fetching OpenAlex data for: Karl-Heinz Alois Glaßmeier
# Fetching OpenAlex data for: Gerhard Glatzel
# Fetching OpenAlex data for: Claire F. Gmachl
# Fetching OpenAlex data for: Michael  Gnant
# Fetching OpenAlex data for: Helmut Gneuss
# Fetching OpenAlex data for: Hans Goebl
# Fetching OpenAlex data for: Ivan Golub
# Fetching OpenAlex data for: Leticia González
# Fetching OpenAlex data for: Maciej Górny
# Fetching OpenAlex data for: Georg Gottlob
# Fetching OpenAlex data for: Georg Grabherr
# Fetching OpenAlex data for: Sherrill Grace
# Fetching OpenAlex data for: Bernhard Grasemann
# Fetching OpenAlex data for: Manfred Grasserbauer
# Fetching OpenAlex data for: Daniel M. Greenberger
# Fetching OpenAlex data for: Wolfgang Greisenegger
# Fetching OpenAlex data for: Frantz Grenet
# Fetching OpenAlex data for: Herfried Griengl
# Fetching OpenAlex data for: Nicolas Grimal
# Fetching OpenAlex data for: Rudolf Grimm
# Fetching OpenAlex data for: Irmgard Griss
# Fetching OpenAlex data for: Jasmina Grković-Major
# Fetching OpenAlex data for: Rudolf Grosschedl
# Fetching OpenAlex data for: Peter Manfred Gruber
# Fetching OpenAlex data for: Gernot Gruber
# Fetching OpenAlex data for: Oskar Grün
# Fetching OpenAlex data for: Dieter Gutknecht
# Fetching OpenAlex data for: Giselher Guttmann
# Fetching OpenAlex data for: Mats Gyllenberg
# Fetching OpenAlex data for: Kálmán Györgyi
# Fetching OpenAlex data for: Rudolf Haag
# Fetching OpenAlex data for: Gerhard Haerendel
# Fetching OpenAlex data for: Stefan Hagel
# Fetching OpenAlex data for: Othmar Hageneder
# Fetching OpenAlex data for: Martin Hairer
# Fetching OpenAlex data for: Ivo Hajnal
# Fetching OpenAlex data for: John Haldon
# Fetching OpenAlex data for: Max Haller
# Fetching OpenAlex data for: Franz Halter-Koch
# Fetching OpenAlex data for: Ernst Hanisch
# Fetching OpenAlex data for: Ulf Hannerz
# Fetching OpenAlex data for: Edouard Hannezo
# Fetching OpenAlex data for: Christian Hannick
# Fetching OpenAlex data for: Aage A. Hansen-Löve
# Fetching OpenAlex data for: Michael Hantel
# Fetching OpenAlex data for: Jens-Uwe Hartmann
# Fetching OpenAlex data for: Maximilian Hartmuth
# Fetching OpenAlex data for: Mathias Harzhauser
# Fetching OpenAlex data for: Horst Haselsteiner
# Fetching OpenAlex data for: Günther Hasinger
# Fetching OpenAlex data for: Friederike Hassauer
# Fetching OpenAlex data for: Wolfgang Haubrichs
# Fetching OpenAlex data for: Gabriele Haug-Moritz
# Fetching OpenAlex data for: Hermann Franz Haupt
# Fetching OpenAlex data for: Uta Heil
# Fetching OpenAlex data for: Wolf-Dieter Heiss
# Fetching OpenAlex data for: Philipp U. Heitz
# Fetching OpenAlex data for: Christian Hellmich
# Fetching OpenAlex data for: Gilbert Helmberg
# Fetching OpenAlex data for: Monika Henzinger
# Fetching OpenAlex data for: Thomas A. Henzinger
# Fetching OpenAlex data for: Milan Herak
# Fetching OpenAlex data for: Gerhard Herndl
# Fetching OpenAlex data for: Marie Louise Herzfeld-Schild
# Fetching OpenAlex data for: Hans-Joachim Hinrichsen
# Fetching OpenAlex data for: Oskar v. Hinüber
# Fetching OpenAlex data for: Ivan Hlaváček
# Fetching OpenAlex data for: Milan Hlavačka
# Fetching OpenAlex data for: Claudia Höbartner
# Fetching OpenAlex data for: Erwin Hochmair
# Fetching OpenAlex data for: Ingeborg Hochmair-Desoyer
# Fetching OpenAlex data for: Sepp Hochreiter
# Fetching OpenAlex data for: Hartwig Höcker
# Fetching OpenAlex data for: Ivo Ludwig Hofacker
# Fetching OpenAlex data for: Barbara Hohn
# Fetching OpenAlex data for: Hans Höller
# Fetching OpenAlex data for: Gerald  Holton
# Fetching OpenAlex data for: Gerhard A. Holzapfel
# Fetching OpenAlex data for: Robert Holzmann
# Fetching OpenAlex data for: Heinrich Honsell
# Fetching OpenAlex data for: Barbara Horejs
# Fetching OpenAlex data for: Oleh Hornykiewicz
# Fetching OpenAlex data for: Konstantin-Alexander Hossmann
# Fetching OpenAlex data for: Yaroslav Hrytsak
# Fetching OpenAlex data for: Christoph Huber
# Fetching OpenAlex data for: Thomas J. R. Hughes
# Fetching OpenAlex data for: Pascale Hugon
# Fetching OpenAlex data for: Hermann Hunger
# Fetching OpenAlex data for: Nicola Hüsing
# Fetching OpenAlex data for: Reinhard Franz Josef Hüttl
# Fetching OpenAlex data for: Anthony A. Hyman
# Fetching OpenAlex data for: Ataç İmamoğlu
# Fetching OpenAlex data for: Christoph Irmscher
# Fetching OpenAlex data for: Hans Irschik
# Fetching OpenAlex data for: Shiro Ishii
# Fetching OpenAlex data for: Hans Peter Isler
# Fetching OpenAlex data for: Lisa Isola
# Fetching OpenAlex data for: Clemens Jabloner
# Fetching OpenAlex data for: Éva Jakab
# Fetching OpenAlex data for: Bernhard Jakoby
# Fetching OpenAlex data for: Sigrid Jalkotzy-Deger
# Fetching OpenAlex data for: Cecilia Jarlskog
# Fetching OpenAlex data for: Erik Jayme
# Fetching OpenAlex data for: Franz Jeglitsch
# Fetching OpenAlex data for: Thomas Jenuwein
# Fetching OpenAlex data for: Hans Joas
# Fetching OpenAlex data for: Werner Jobst
# Fetching OpenAlex data for: Zdenek Johan
# Fetching OpenAlex data for: Peter Johanek
# Fetching OpenAlex data for: Julian Johnson
# Fetching OpenAlex data for: Michael Jursa
# Fetching OpenAlex data for: Thede Kahl
# Fetching OpenAlex data for: Barbara Kaltenbacher
# Fetching OpenAlex data for: Manfred  Kaltenbacher
# Fetching OpenAlex data for: Eric R. Kandel
# Fetching OpenAlex data for: Andreas Kappeler
# Fetching OpenAlex data for: Vassos Karageorghis
# Fetching OpenAlex data for: Stevan Karamata
# Fetching OpenAlex data for: Matthias Karmasin
# Fetching OpenAlex data for: Martin Karplus
# Fetching OpenAlex data for: Georg Kaser
# Fetching OpenAlex data for: Daniel Kastler
# Fetching OpenAlex data for: Radoslav Katičić
# Fetching OpenAlex data for: Stephen Ira Katz
# Fetching OpenAlex data for: Hubert Kaufhold
# Fetching OpenAlex data for: Sylvia Kaufmann
# Fetching OpenAlex data for: Anke Rita Kaysser-Pyzalla
# Fetching OpenAlex data for: Katrin Keller
# Fetching OpenAlex data for: Birgit Kellner
# Fetching OpenAlex data for: Fritz Kelnhofer
# Fetching OpenAlex data for: Thomas Kenner
# Fetching OpenAlex data for: Manfred Kern
# Fetching OpenAlex data for: Eva Kernbauer
# Fetching OpenAlex data for: Ferenc Kiefer
# Fetching OpenAlex data for: Rudolf Kippenhahn
# Fetching OpenAlex data for: Gottfried Kirchengast
# Fetching OpenAlex data for: Britta Klagge
# Fetching OpenAlex data for: Michał Kleiber
# Fetching OpenAlex data for: Hans-Dieter Klein
# Fetching OpenAlex data for: Jürgen Kleine-Vehn
# Fetching OpenAlex data for: Nina Klimburg-Witjes
# Fetching OpenAlex data for: Bernd Ulrich Kluge
# Fetching OpenAlex data for: Alfred Kluwick
# Fetching OpenAlex data for: Fritz Peter Knapp
# Fetching OpenAlex data for: Sylvia Knapp
# Fetching OpenAlex data for: Jürgen Knoblich
# Fetching OpenAlex data for: Wolfgang Knoll
# Fetching OpenAlex data for: Christian Köberl
# Fetching OpenAlex data for: Walter Koch
# Fetching OpenAlex data for: Johannes Koder
# Fetching OpenAlex data for: Alfred Kohler
# Fetching OpenAlex data for: Alwin Köhler
# Fetching OpenAlex data for: Martin Kohli
# Fetching OpenAlex data for: Walter Kohn
# Fetching OpenAlex data for: Kurt L. Komarek
# Fetching OpenAlex data for: Robert Konrat
# Fetching OpenAlex data for: Hermann Kopetz
# Fetching OpenAlex data for: Hans-Georg Koppensteiner
# Fetching OpenAlex data for: Martin Korenjak
# Fetching OpenAlex data for: Karl Korinek
# Fetching OpenAlex data for: Christian Körner
# Fetching OpenAlex data for: Dušan Kováč
# Fetching OpenAlex data for: Helmut Koziol
# Fetching OpenAlex data for: Frauke Kraas
# Fetching OpenAlex data for: Dietrich Kraft
# Fetching OpenAlex data for: Ernst August Kramer
# Fetching OpenAlex data for: Christoph Kratky
# Fetching OpenAlex data for: Christian Krattenthaler
# Fetching OpenAlex data for: Ferenc Krausz
# Fetching OpenAlex data for: Bernhard Kräutler
# Fetching OpenAlex data for: Josef Kreiner
# Fetching OpenAlex data for: Georg Kresse
# Fetching OpenAlex data for: Otto Kresten
# Fetching OpenAlex data for: Friedrich Krinzinger
# Fetching OpenAlex data for: Guido Kroemer
# Fetching OpenAlex data for: Karl Kroeschell
# Fetching OpenAlex data for: Kurt Krolop
# Fetching OpenAlex data for: James Glenn Krueger
# Fetching OpenAlex data for: Hans-Henrik Krummacher
# Fetching OpenAlex data for: Andreas Kugi
# Fetching OpenAlex data for: Michael Kuhn
# Fetching OpenAlex data for: Richard Küng
# Fetching OpenAlex data for: Wilfried Kurz
# Fetching OpenAlex data for: Walter Kutschera
# Fetching OpenAlex data for: Jan Květ
# Fetching OpenAlex data for: Paul Alexander Kyrle
# Fetching OpenAlex data for: Anne L’Huillier
# Fetching OpenAlex data for: Johanna Laakso
# Fetching OpenAlex data for: Sabine Ladstätter
# Fetching OpenAlex data for: Christopher F. Laferl
# Fetching OpenAlex data for: Peter Laggner
# Fetching OpenAlex data for: Julia Lajta-Novak
# Fetching OpenAlex data for: Vasileios Lambrinoudakis
# Fetching OpenAlex data for: Claus Lamm
# Fetching OpenAlex data for: Irene Marthe Lang
# Fetching OpenAlex data for: Armin Lange
# Fetching OpenAlex data for: Robert S. Langer
# Fetching OpenAlex data for: Heinz Langer
# Fetching OpenAlex data for: Walter Larcher
# Fetching OpenAlex data for: Hans Lassmann
# Fetching OpenAlex data for: Reinhard Lauer
# Fetching OpenAlex data for: Jacques Le Rider
# Fetching OpenAlex data for: Klaus Lechner
# Fetching OpenAlex data for: Joseph Theodoor Leerssen
# Fetching OpenAlex data for: Gustav Adolf Lehmann
# Fetching OpenAlex data for: Marianne Johanna Lehmkuhl
# Fetching OpenAlex data for: Ursula Lehr
# Fetching OpenAlex data for: Helga Leitner
# Fetching OpenAlex data for: Mikhail Lemeshko
# Fetching OpenAlex data for: Alexandra N. Lenz
# Fetching OpenAlex data for: Silke Leopold
# Fetching OpenAlex data for: Johannes A. Lercher
# Fetching OpenAlex data for: Willem J. M. Levelt
# Fetching OpenAlex data for: Gary Libben
# Fetching OpenAlex data for: Elliott Lieb
# Fetching OpenAlex data for: Gene Elden Likens
# Fetching OpenAlex data for: Mandana E. Limbert
# Fetching OpenAlex data for: Andrea Lindmayr-Brandl
# Fetching OpenAlex data for: Thomas Lindner
# Fetching OpenAlex data for: Karl Lintner
# Fetching OpenAlex data for: Benjamin List
# Fetching OpenAlex data for: Birgit Lodes
# Fetching OpenAlex data for: Michele Loporcaro
# Fetching OpenAlex data for: Hellmut Lorenz
# Fetching OpenAlex data for: Martin Löschnigg
# Fetching OpenAlex data for: Peter Lucas
# Fetching OpenAlex data for: Monika Ludwig
# Fetching OpenAlex data for: Gerhard Luf
# Fetching OpenAlex data for: Thomas Luger
# Fetching OpenAlex data for: Helmut Lukesch
# Fetching OpenAlex data for: Reimar Lüst
# Fetching OpenAlex data for: Christina Lutter
# Fetching OpenAlex data for: Wolfgang Lutz
# Fetching OpenAlex data for: Marc Luy
# Fetching OpenAlex data for: Séamus Mac Mathúna
# Fetching OpenAlex data for: Thomas Magauer
# Fetching OpenAlex data for: Astrid Mager
# Fetching OpenAlex data for: Claudio Magris
# Fetching OpenAlex data for: Christian Mair
# Fetching OpenAlex data for: Melanie Malzahn
# Fetching OpenAlex data for: Herbert Mang
# Fetching OpenAlex data for: Wolfgang Mantl
# Fetching OpenAlex data for: Joseph Maran
# Fetching OpenAlex data for: Michael Marberger
# Fetching OpenAlex data for: Raimund Margreiter
# Fetching OpenAlex data for: Peter Markowich
# Fetching OpenAlex data for: James H. Marrow
# Fetching OpenAlex data for: Alberto Martino
# Fetching OpenAlex data for: Herbert Matis
# Fetching OpenAlex data for: Aleksandar Matković
# Fetching OpenAlex data for: Franz Matscher
# Fetching OpenAlex data for: Richard Viktor Mattessich
# Fetching OpenAlex data for: Hartmut  Matthäus
# Fetching OpenAlex data for: Paolo Matthiae
# Fetching OpenAlex data for: Marjori Ann Matzke
# Fetching OpenAlex data for: Nuno Maulide
# Fetching OpenAlex data for: Bernd Mayer
# Fetching OpenAlex data for: Henry M. R. E. Mayr-Harting
# Fetching OpenAlex data for: Paul Heinz Mayrhofer
# Fetching OpenAlex data for: Otto Mayrhofer-Krammel
# Fetching OpenAlex data for: Brigitte Mazohl
# Fetching OpenAlex data for: Rosamond McKitterick
# Fetching OpenAlex data for: Peter McMullen
# Fetching OpenAlex data for: Wolfgang F. G. Mecklenbräuker
# Fetching OpenAlex data for: Wolfgang Meid
# Fetching OpenAlex data for: Anne Sophie Meincke
# Fetching OpenAlex data for: Igor Mel'čuk
# Fetching OpenAlex data for: Fritz Melchers
# Fetching OpenAlex data for: Sarah Melzer
# Fetching OpenAlex data for: Günther Meschke
# Fetching OpenAlex data for: Bruno Messerli
# Fetching OpenAlex data for: Michael Metzeltin
# Fetching OpenAlex data for: Carola Metzner-Nebelsick
# Fetching OpenAlex data for: Ronald Micura
# Fetching OpenAlex data for: Gero Miesenböck
# Fetching OpenAlex data for: Hanno Millesi
# Fetching OpenAlex data for: Nina Mirnig
# Fetching OpenAlex data for: Diana Mishkova
# Fetching OpenAlex data for: Jürgen Mittelstraß
# Fetching OpenAlex data for: Christian  Mitterer
# Fetching OpenAlex data for: Fritz Mitthof
# Fetching OpenAlex data for: Kimberly Modic
# Fetching OpenAlex data for: Stephan Moebius
# Fetching OpenAlex data for: Helmuth Möhwald
# Fetching OpenAlex data for: Andreas F. Molisch
# Fetching OpenAlex data for: Hans Mommsen
# Fetching OpenAlex data for: Alessandro Montanari
# Fetching OpenAlex data for: Helmut Moritz
# Fetching OpenAlex data for: Cécile Morrisson
# Fetching OpenAlex data for: Gina E. Moseley
# Fetching OpenAlex data for: Helfried Mostler
# Fetching OpenAlex data for: Gérard A. Mourou
# Fetching OpenAlex data for: Nicolette Mout
# Fetching OpenAlex data for: Dennis C. Mueller
# Fetching OpenAlex data for: Wolfgang Mueller
# Fetching OpenAlex data for: Ivan I. Mueller
# Fetching OpenAlex data for: Sandra Müller
# Fetching OpenAlex data for: Ulrike Müller-Böker
# Fetching OpenAlex data for: Johann Mulzer
# Fetching OpenAlex data for: Ulrike Müßig
# Fetching OpenAlex data for: Karol Myśliwiec
# Fetching OpenAlex data for: Herta Nagl-Docekal
# Fetching OpenAlex data for: Norman M. Naimark
# Fetching OpenAlex data for: Rumi Nakamura
# Fetching OpenAlex data for: George (Gia) Sch. Nakhutsrishvili
# Fetching OpenAlex data for: Kim A. Nasmyth
# Fetching OpenAlex data for: David Natal Villazala
# Fetching OpenAlex data for: Adolf Neckel
# Fetching OpenAlex data for: Robert Nedoma
# Fetching OpenAlex data for: Wolfgang  Neubauer
# Fetching OpenAlex data for: Christine Neugebauer-Maresch
# Fetching OpenAlex data for: Winfried L. Neuhuber
# Fetching OpenAlex data for: Walter Neupert
# Fetching OpenAlex data for: Gerhard Neweklowsky
# Fetching OpenAlex data for: Stefan Michael Newerkla
# Fetching OpenAlex data for: Harald Niederreiter
# Fetching OpenAlex data for: Christian Roland Noe
# Fetching OpenAlex data for: Magnus Nordborg
# Fetching OpenAlex data for: Dieter Nörr
# Fetching OpenAlex data for: Marie-Louise Nosch
# Fetching OpenAlex data for: Sir Gustav Joseph Victor Nossal
# Fetching OpenAlex data for: Heinrich Nöth
# Fetching OpenAlex data for: Martin A. Nowak
# Fetching OpenAlex data for: Helga Nowotny
# Fetching OpenAlex data for: Onora O'Neill
# Fetching OpenAlex data for: Anna Christina Obenauf
# Fetching OpenAlex data for: Paul Oberhammer
# Fetching OpenAlex data for: Gerhard Oberhammer
# Fetching OpenAlex data for: Dieter Oesterhelt
# Fetching OpenAlex data for: Werner Ogris
# Fetching OpenAlex data for: Oskar Friedrich Olaj
# Fetching OpenAlex data for: Thomas Olechowski
# Fetching OpenAlex data for: Gerhard Opelz
# Fetching OpenAlex data for: Gherardo Ortalli
# Fetching OpenAlex data for: Marcus Ossiander
# Fetching OpenAlex data for: Jurij Sergejewitsch Ossipov
# Fetching OpenAlex data for: Jürgen Osterhammel
# Fetching OpenAlex data for: Jörg A. Ott
# Fetching OpenAlex data for: Alfred E. von Overbeck
# Fetching OpenAlex data for: Peter Palese
# Fetching OpenAlex data for: Herbert Palme
# Fetching OpenAlex data for: Bernhard Palme
# Fetching OpenAlex data for: Jian-Wei Pan
# Fetching OpenAlex data for: Oswald Panagl
# Fetching OpenAlex data for: Lucy Y. Pao
# Fetching OpenAlex data for: Fritz Paschke
# Fetching OpenAlex data for: Gernot Patzelt
# Fetching OpenAlex data for: Josef Penninger
# Fetching OpenAlex data for: Ernst Pernicka
# Fetching OpenAlex data for: Peter Pernthaler
# Fetching OpenAlex data for: Anne Peters
# Fetching OpenAlex data for: Jan-Michael Peters
# Fetching OpenAlex data for: Jillian Petersen
# Fetching OpenAlex data for: Hellmuth Petsche
# Fetching OpenAlex data for: Johann Pfanzagl
# Fetching OpenAlex data for: Gerhard Pferschy
# Fetching OpenAlex data for: Otto Pfersmann
# Fetching OpenAlex data for: Jörg Pfleiderer
# Fetching OpenAlex data for: Gert Pfurtscheller
# Fetching OpenAlex data for: Philip Ivanov Philippov
# Fetching OpenAlex data for: Gernot Piccottini
# Fetching OpenAlex data for: Helmut Pichler
# Fetching OpenAlex data for: Hannes Pichler
# Fetching OpenAlex data for: Pierre Jean Pichot
# Fetching OpenAlex data for: Herbert Pietschmann
# Fetching OpenAlex data for: Werner E. Piller
# Fetching OpenAlex data for: Renate Johanna Pillinger
# Fetching OpenAlex data for: Rudolf Pischinger
# Fetching OpenAlex data for: Clemens Plaschka
# Fetching OpenAlex data for: Carolina Plescia
# Fetching OpenAlex data for: Walter L. Pohl
# Fetching OpenAlex data for: Walter Pohl
# Fetching OpenAlex data for: Hryhoriy Polshyn
# Fetching OpenAlex data for: Marianne Popp
# Fetching OpenAlex data for: Magdalena Pöschl
# Fetching OpenAlex data for: Barbara Prainsack
# Fetching OpenAlex data for: Rudolf Preimesberger
# Fetching OpenAlex data for: Anton Preisinger
# Fetching OpenAlex data for: Friedrich B. Prinz
# Fetching OpenAlex data for: Manfred Prisching
# Fetching OpenAlex data for: Stephan  Procházka
# Fetching OpenAlex data for: Paolo Prodi
# Fetching OpenAlex data for: Walter Puchner
# Fetching OpenAlex data for: Andreas Pülz
# Fetching OpenAlex data for: Denise Pumain
# Fetching OpenAlex data for: Sonja Puntscher Riekmann
# Fetching OpenAlex data for: Gernot Rabeder
# Fetching OpenAlex data for: Ljiljana Radonić
# Fetching OpenAlex data for: Piero Rafanelli
# Fetching OpenAlex data for: Andrej Rahten
# Fetching OpenAlex data for: Franz Rainer
# Fetching OpenAlex data for: Ekkehard Ramm
# Fetching OpenAlex data for: Franz G. Rammerstorfer
# Fetching OpenAlex data for: Friederike Range
# Fetching OpenAlex data for: Claudia Rapp
# Fetching OpenAlex data for: Armando Rastelli
# Fetching OpenAlex data for: Gudrun Rath
# Fetching OpenAlex data for: Isabelle Ratié
# Fetching OpenAlex data for: Helmut Rauch
# Fetching OpenAlex data for: Peter H. Raven
# Fetching OpenAlex data for: Karl M. A. Rawer
# Fetching OpenAlex data for: Katharina Rebay-Salisbury
# Fetching OpenAlex data for: Anton Rebhan
# Fetching OpenAlex data for: Ludwig Reich
# Fetching OpenAlex data for: Ingo Reiffenstein
# Fetching OpenAlex data for: Wolf Uwe Reimold
# Fetching OpenAlex data for: Susanne Reindl-Krauskopf
# Fetching OpenAlex data for: August Reinisch
# Fetching OpenAlex data for: André Reis
# Fetching OpenAlex data for: Elmar R. Reiter
# Fetching OpenAlex data for: Reinhold Remmert
# Fetching OpenAlex data for: Andrew Colin Renfrew
# Fetching OpenAlex data for: Andrea Rentmeister
# Fetching OpenAlex data for: Fritz Resinger
# Fetching OpenAlex data for: Georg Ress
# Fetching OpenAlex data for: Keywan Riahi
# Fetching OpenAlex data for: James R. Rice
# Fetching OpenAlex data for: Kurt R. Richter
# Fetching OpenAlex data for: Norbert G. Riedel
# Fetching OpenAlex data for: Willibald Riedler
# Fetching OpenAlex data for: Josef Riedmann
# Fetching OpenAlex data for: Wolfgang Riehle
# Fetching OpenAlex data for: Gert Riethmüller
# Fetching OpenAlex data for: Wolfgang Rindler
# Fetching OpenAlex data for: Zsigmond Ritoók
# Fetching OpenAlex data for: Monika Ritsch-Marte
# Fetching OpenAlex data for: Olivia Fiona Robinson
# Fetching OpenAlex data for: Alexandra Rodler-Rørbo
# Fetching OpenAlex data for: Teresa Rodríguez de las Heras Ballell
# Fetching OpenAlex data for: Juan Gualterio Roederer
# Fetching OpenAlex data for: Herbert Walter Roesky
# Fetching OpenAlex data for: Robert Rollinger
# Fetching OpenAlex data for: José Luis Romero
# Fetching OpenAlex data for: Maria Grazia Roncarolo
# Fetching OpenAlex data for: Artur Rosenauer
# Fetching OpenAlex data for: Leopold Rosenmayr
# Fetching OpenAlex data for: Michael Rössner
# Fetching OpenAlex data for: Mathias Walter Rotach
# Fetching OpenAlex data for: Carlo Rubbia
# Fetching OpenAlex data for: Helmut O. Rucker
# Fetching OpenAlex data for: Helmut Rumpler
# Fetching OpenAlex data for: Hans Georg Ruppe
# Fetching OpenAlex data for: Günther Rupprechter
# Fetching OpenAlex data for: Eda Sagarra
# Fetching OpenAlex data for: Richard Salomon
# Fetching OpenAlex data for: Roman Sandgruber
# Fetching OpenAlex data for: Friedrich Sandhofer
# Fetching OpenAlex data for: Birgit Sandkaulen
# Fetching OpenAlex data for: Niyazi Serdar Sariçiftçi
# Fetching OpenAlex data for: Michael Sarnthein-Lotichius
# Fetching OpenAlex data for: Pasqualina Maria Sarro
# Fetching OpenAlex data for: Paolo Sartori
# Fetching OpenAlex data for: Friedrich Schaller
# Fetching OpenAlex data for: Gottfried Schatz
# Fetching OpenAlex data for: Philipp  Scheibelreiter
# Fetching OpenAlex data for: Walter Scheidel
# Fetching OpenAlex data for: Eva Schernhammer
# Fetching OpenAlex data for: Rudolf Schieffer
# Fetching OpenAlex data for: Sabine Schindler
# Fetching OpenAlex data for: Philipp Schindler
# Fetching OpenAlex data for: Andrzej Schinzel
# Fetching OpenAlex data for: Wolfgang Schlager
# Fetching OpenAlex data for: Wolfgang P. Schleich
# Fetching OpenAlex data for: Christa Schleper
# Fetching OpenAlex data for: Hermann Schmalzried
# Fetching OpenAlex data for: Klaus Schmidt
# Fetching OpenAlex data for: Wolfgang Schmidt
# Fetching OpenAlex data for: Matthias  Schmidt
# Fetching OpenAlex data for: Johannes Schmidt
# Fetching OpenAlex data for: Alfred Schmidt
# Fetching OpenAlex data for: Arnold Schmidt
# Fetching OpenAlex data for: Ernst August Schmidt
# Fetching OpenAlex data for: Philipp Schmidt-Dengler
# Fetching OpenAlex data for: Ursula Schmidt-Erfurth
# Fetching OpenAlex data for: Sabine Schmidtke
# Fetching OpenAlex data for: Jörg Schmiedmayer
# Fetching OpenAlex data for: Lambert Schmithausen
# Fetching OpenAlex data for: Rüdiger Schmitt
# Fetching OpenAlex data for: Oliver Jens Schmitt
# Fetching OpenAlex data for: Kurt Schmoller
# Fetching OpenAlex data for: Isabel Schnabel
# Fetching OpenAlex data for: Wilhelm Schneider
# Fetching OpenAlex data for: Albrecht Schöne
# Fetching OpenAlex data for: Hans Peter Schönlaub
# Fetching OpenAlex data for: Peter Schönswetter
# Fetching OpenAlex data for: Carl E. Schorske
# Fetching OpenAlex data for: Peter Schreiner
# Fetching OpenAlex data for: Ulrich Schubert
# Fetching OpenAlex data for: Gerold Schuler
# Fetching OpenAlex data for: Rolf Schulte-Hermann
# Fetching OpenAlex data for: Birgitta Schultze-Bernhardt
# Fetching OpenAlex data for: Winfried Schulze
# Fetching OpenAlex data for: Josef Schurz
# Fetching OpenAlex data for: Peter Schuster
# Fetching OpenAlex data for: Gerhard Schütz
# Fetching OpenAlex data for: Sebastian Schütze
# Fetching OpenAlex data for: Hans Schwabl
# Fetching OpenAlex data for: Karlheinz Schwarz
# Fetching OpenAlex data for: Florian Schwarz
# Fetching OpenAlex data for: Hans Georg Schwarzacher
# Fetching OpenAlex data for: Walther Schwarzacher
# Fetching OpenAlex data for: Günter C. Schweiger
# Fetching OpenAlex data for: Fritz Schweiger
# Fetching OpenAlex data for: Michael Schweitzer
# Fetching OpenAlex data for: Dieter Schweizer
# Fetching OpenAlex data for: Hugo Schwendenwein
# Fetching OpenAlex data for: Martin Seger
# Fetching OpenAlex data for: Christian Seidl
# Fetching OpenAlex data for: Horst Seidler
# Fetching OpenAlex data for: Stephan Johannes Seidlmayer
# Fetching OpenAlex data for: Robert  Seiringer
# Fetching OpenAlex data for: Ali Mehmet Celâl Şengör
# Fetching OpenAlex data for: Veronika Sexl
# Fetching OpenAlex data for: Demetra Sfendoni-Mentzou
# Fetching OpenAlex data for: Francesco Sferra
# Fetching OpenAlex data for: Danuta Shanzer
# Fetching OpenAlex data for: M. Rahim Shayegan
# Fetching OpenAlex data for: Ethan M. Shevach
# Fetching OpenAlex data for: Maria Sibilia
# Fetching OpenAlex data for: Susanne Sievers
# Fetching OpenAlex data for: Karl Sigmund
# Fetching OpenAlex data for: Petra Sijpesteijn
# Fetching OpenAlex data for: Oleg Simakov
# Fetching OpenAlex data for: Barry Simon
# Fetching OpenAlex data for: Nicholas Sims-Williams
# Fetching OpenAlex data for: Hans-Werner Sinn
# Fetching OpenAlex data for: Peter Sitte
# Fetching OpenAlex data for: Quentin R. D. Skinner
# Fetching OpenAlex data for: Uwe B. Sleytr
# Fetching OpenAlex data for: John Victor Small
# Fetching OpenAlex data for: Kurt Smolak
# Fetching OpenAlex data for: Josef Smolen
# Fetching OpenAlex data for: Werner Sollors
# Fetching OpenAlex data for: Éva Somogyi
# Fetching OpenAlex data for: Vera T. Sós
# Fetching OpenAlex data for: Nicola Spaldin
# Fetching OpenAlex data for: Katta Spiel
# Fetching OpenAlex data for: Christoph Spötl
# Fetching OpenAlex data for: Hellmuth Stachel
# Fetching OpenAlex data for: Saskia Stachowitsch
# Fetching OpenAlex data for: Peter F. Stadler
# Fetching OpenAlex data for: Lawrence E. Stager
# Fetching OpenAlex data for: Sigrid Stagl
# Fetching OpenAlex data for: André Stahl
# Fetching OpenAlex data for: Maria A. Stassinopoulou
# Fetching OpenAlex data for: Paul Stefanovits
# Fetching OpenAlex data for: Florian  Steger
# Fetching OpenAlex data for: Erwin Stein
# Fetching OpenAlex data for: Sybille Steinbacher
# Fetching OpenAlex data for: Peter Steinhauser
# Fetching OpenAlex data for: Friedrich Franz Steininger
# Fetching OpenAlex data for: Ernst Steinkellner
# Fetching OpenAlex data for: Hans-Peter Steinrück
# Fetching OpenAlex data for: Barbara Stelzl-Marx
# Fetching OpenAlex data for: Günter Stemberger
# Fetching OpenAlex data for: Stig T. Stenholm
# Fetching OpenAlex data for: Nikolaus K. Stephanidis
# Fetching OpenAlex data for: Peter Štih
# Fetching OpenAlex data for: Georg Stingl
# Fetching OpenAlex data for: Gerold Stoll
# Fetching OpenAlex data for: Barbara Stollberg-Rilinger
# Fetching OpenAlex data for: Gerald Stourzh
# Fetching OpenAlex data for: Helmut Strasser
# Fetching OpenAlex data for: Erich Wolfgang Streissler
# Fetching OpenAlex data for: Jörg Striessnig
# Fetching OpenAlex data for: Josef Strobl
# Fetching OpenAlex data for: Arno Strohmeyer
# Fetching OpenAlex data for: Tod F. Stuessy
# Fetching OpenAlex data for: Christian Sturmbauer
# Fetching OpenAlex data for: Robert Samuel Summers
# Fetching OpenAlex data for: Hans Sünkel
# Fetching OpenAlex data for: Giulio Superti-Furga
# Fetching OpenAlex data for: Arnold Suppan
# Fetching OpenAlex data for: Ernst Christoph Suttner
# Fetching OpenAlex data for: Gustav Andreas Tammann
# Fetching OpenAlex data for: Elly Tanaka
# Fetching OpenAlex data for: Éva Tardos
# Fetching OpenAlex data for: Ulrich Technau
# Fetching OpenAlex data for: Jaroslav Tejral
# Fetching OpenAlex data for: Werner Telesko
# Fetching OpenAlex data for: Heinz-Elmar Tenorth
# Fetching OpenAlex data for: Erich Thenius
# Fetching OpenAlex data for: Udo Thiel
# Fetching OpenAlex data for: Gerhard Thür
# Fetching OpenAlex data for: Robert F. Tichy
# Fetching OpenAlex data for: Klement Tockner
# Fetching OpenAlex data for: Theodor Tomandl
# Fetching OpenAlex data for: Erich Trapp
# Fetching OpenAlex data for: Dirk Trauner
# Fetching OpenAlex data for: Michael Trauner
# Fetching OpenAlex data for: Marko Trogrlić
# Fetching OpenAlex data for: Hans Tuppy
# Fetching OpenAlex data for: Franz-Josef Ulm
# Fetching OpenAlex data for: Melanie Unseld
# Fetching OpenAlex data for: Miriam M. Unterlass
# Fetching OpenAlex data for: Gerald Urban
# Fetching OpenAlex data for: Otto Helmut Urban
# Fetching OpenAlex data for: Boris A. Uspenskij
# Fetching OpenAlex data for: Gerd W. Utermann
# Fetching OpenAlex data for: Alice Vadrot
# Fetching OpenAlex data for: Rudolf Valenta
# Fetching OpenAlex data for: Peter van Nieuwenhuizen
# Fetching OpenAlex data for: Mihai-Cristian Vasile
# Fetching OpenAlex data for: Michael Johannes Vellekoop
# Fetching OpenAlex data for: Beatriz Vicoso
# Fetching OpenAlex data for: Karl Vodrazka
# Fetching OpenAlex data for: Thomas Vogl
# Fetching OpenAlex data for: Arndt von Haeseler
# Fetching OpenAlex data for: Klaus von Klitzing
# Fetching OpenAlex data for: Alfred Wagenhofer
# Fetching OpenAlex data for: Horst Wagner
# Fetching OpenAlex data for: Andreas  Wagner
# Fetching OpenAlex data for: Günter P. Wagner
# Fetching OpenAlex data for: Karl Wagner
# Fetching OpenAlex data for: Sigurd Wagner
# Fetching OpenAlex data for: Erwin F. Wagner
# Fetching OpenAlex data for: Michael Wagner
# Fetching OpenAlex data for: Birgit Wagner
# Fetching OpenAlex data for: Scott Waitukaitis
# Fetching OpenAlex data for: Wolfgang A. Wall
# Fetching OpenAlex data for: Grete Walter-Klingenstein
# Fetching OpenAlex data for: Heinrich Wänke
# Fetching OpenAlex data for: Graham Warren
# Fetching OpenAlex data for: Peter Michael Warren
# Fetching OpenAlex data for: Andrea Weber
# Fetching OpenAlex data for: Harald Wolfgang Weber
# Fetching OpenAlex data for: Gerhard Wegner
# Fetching OpenAlex data for: Rüdiger Wehner
# Fetching OpenAlex data for: Susanne Weigelin-Schwiedrzik
# Fetching OpenAlex data for: Stefan Weinfurter
# Fetching OpenAlex data for: Astrid Weiss
# Fetching OpenAlex data for: Günter Weiss
# Fetching OpenAlex data for: Werner Welzig
# Fetching OpenAlex data for: Emo Welzl
# Fetching OpenAlex data for: Christiane Wendehorst
# Fetching OpenAlex data for: Samuel A. Werner
# Fetching OpenAlex data for: Diter von Wettstein
# Fetching OpenAlex data for: Manfred Wicke
# Fetching OpenAlex data for: Gerhard Widmer
# Fetching OpenAlex data for: Ewald Wiederin
# Fetching OpenAlex data for: Maria Katharina  Wiedlack
# Fetching OpenAlex data for: Malcolm Hewitt Wiener
# Fetching OpenAlex data for: Josef Wiesehöfer
# Fetching OpenAlex data for: Wolfgang Wieser
# Fetching OpenAlex data for: Heinz Gregor Wieser
# Fetching OpenAlex data for: Michaela Wiesinger
# Fetching OpenAlex data for: Peter Wiesinger
# Fetching OpenAlex data for: Luzius Wildhaber
# Fetching OpenAlex data for: Günther Wilke
# Fetching OpenAlex data for: F. Ludwig Wilke
# Fetching OpenAlex data for: Jürgen Wilke
# Fetching OpenAlex data for: Harco Willems
# Fetching OpenAlex data for: Anouk Willemsen
# Fetching OpenAlex data for: Michaela Windischgrätz
# Fetching OpenAlex data for: Verena Winiwarter
# Fetching OpenAlex data for: Thomas Winkelbauer
# Fetching OpenAlex data for: Hans Winkler
# Fetching OpenAlex data for: Georg Winter
# Fetching OpenAlex data for: Renée Winter
# Fetching OpenAlex data for: Erich Winter
# Fetching OpenAlex data for: Irene J. Winter
# Fetching OpenAlex data for: Gerhard Wirth
# Fetching OpenAlex data for: Norbert Richard Wolf
# Fetching OpenAlex data for: Alois Wolf
# Fetching OpenAlex data for: Eckhard Wolf
# Fetching OpenAlex data for: Werner Wolf
# Fetching OpenAlex data for: Ulrich Wolf
# Fetching OpenAlex data for: Klaus Wolff
# Fetching OpenAlex data for: Herwig Wolfram
# Fetching OpenAlex data for: Bernhard Woytek
# Fetching OpenAlex data for: Dagmar Wujastyk
# Fetching OpenAlex data for: Keizô Yamamoto
# Fetching OpenAlex data for: Yeong-Bin Yang
# Fetching OpenAlex data for: William Edgar Yates
# Fetching OpenAlex data for: Bilge Yıldız
# Fetching OpenAlex data for: Stephen G. Young
# Fetching OpenAlex data for: Waldemar Zacharasiewicz
# Fetching OpenAlex data for: Hans Georg Zachau
# Fetching OpenAlex data for: Anatoly G. Zagorodny
# Fetching OpenAlex data for: Kurt Zatloukal
# Fetching OpenAlex data for: Josef Zechner
# Fetching OpenAlex data for: Rudolf Zechner
# Fetching OpenAlex data for: Anton Zeilinger
# Fetching OpenAlex data for: Josef Zemann
# Fetching OpenAlex data for: Wolfgang Zenker
# Fetching OpenAlex data for: Michael Zgurovsky
# Fetching OpenAlex data for: Yong-de Zhang
# Fetching OpenAlex data for: Shuguang Zhang
# Fetching OpenAlex data for: Franz Ziegler
# Fetching OpenAlex data for: Peter V. Zima
# Fetching OpenAlex data for: Reinhard Zimmermann
# Fetching OpenAlex data for: Harald Volkmar Zimmermann
# Fetching OpenAlex data for: Michel Zink
# Fetching OpenAlex data for: Ernst K. Zinner
# Fetching OpenAlex data for: Natalia A. Zinovieva
# Fetching OpenAlex data for: Theodore J. Ziolkowski
# Fetching OpenAlex data for: Jan M. Ziolkowski
# Fetching OpenAlex data for: Peter Zoller
# Fetching OpenAlex data for: Alessandro Zuccari
# Fetching OpenAlex data for: Paul Michael Zulehner
# Data with OpenAlex details saved to austrian_academy_members_author_ids.json

# %%
import requests
import json
import time

# Input and output file paths
input_file_path = "/content/austrian_academy_members_enhanced.json"  # Replace with your actual file path
output_file_path = "austrian_academy_members_author_ids_enhanced.json"

# OpenAlex API endpoint
openalex_base_url = "https://api.openalex.org/authors"

# Function to fetch OpenAlex data
def get_openalex_metrics(name):
    try:
        # Query OpenAlex API to find the author
        response = requests.get(openalex_base_url, params={"search": name})
        response.raise_for_status()
        results = response.json()

        if "results" in results and results["results"]:
            # Take the first match (or apply additional filters if necessary)
            author = results["results"][0]
            return {
                "openalex_id": author.get("id"),
                "works_count": author.get("works_count", 0),
                "cited_by_count": author.get("cited_by_count", 0),
                "h_index": author.get("h_index", 0),
                "i10_index": author.get("i10_index", 0)  # Extract i10_index if available
            }
        else:
            return {
                "openalex_id": None,
                "works_count": None,
                "cited_by_count": None,
                "h_index": None,
                "i10_index": None
            }
    except Exception as e:
        print(f"Error fetching OpenAlex data for {name}: {e}")
        return {
            "openalex_id": None,
            "works_count": None,
            "cited_by_count": None,
            "h_index": None,
            "i10_index": None
        }

# Load the initial JSON file
with open(input_file_path, "r", encoding="utf-8") as file:
    members_data = json.load(file)

# Enrich the data with OpenAlex metrics
enriched_data = []

for member in members_data:
    print(f"Fetching OpenAlex data for {member['name']}...")
    openalex_metrics = get_openalex_metrics(member["name"])

    # Combine the existing member info with OpenAlex metrics
    enriched_member = {
        "name": member.get("name"),
        "title": member.get("title"),
        "affiliation": member.get("affiliation"),
        "membership_type": member.get("membership_type"),
        "works_count": openalex_metrics["works_count"],
        "cited_by_count": openalex_metrics["cited_by_count"],
        "h_index": openalex_metrics["h_index"],
        "i10_index": openalex_metrics["i10_index"],
        "openalex_id": openalex_metrics["openalex_id"]
    }

    enriched_data.append(enriched_member)
    time.sleep(1)  # Respect API rate limits

# Save the enriched data to a new JSON file
with open(output_file_path, "w", encoding="utf-8") as output_file:
    json.dump(enriched_data, output_file, indent=4, ensure_ascii=False)

print(f"Enriched data saved to {output_file_path}")
# Out:
# Fetching OpenAlex data for Rainer Abart...
# Fetching OpenAlex data for Karl Acham...
# Fetching OpenAlex data for Antal Ádám...
# Fetching OpenAlex data for Ludwig Adamovich...
# Fetching OpenAlex data for Timon Erik Adolph...
# Fetching OpenAlex data for Alícia Adserà...
# Fetching OpenAlex data for Adriano Aguzzi...
# Fetching OpenAlex data for Josef Aicher...
# Fetching OpenAlex data for Martin Aigner...
# Fetching OpenAlex data for Luciana Aigner-Foresti...
# Fetching OpenAlex data for Brenda Almond...
# Fetching OpenAlex data for Michael Alram...
# Fetching OpenAlex data for Eva Alram-Stern...
# Fetching OpenAlex data for Carlos Alvar Ezquerra...
# Fetching OpenAlex data for João Alves...
# Fetching OpenAlex data for Michel Amandry...
# Fetching OpenAlex data for Petra Amann...
# Fetching OpenAlex data for Brigitta Ammann...
# Fetching OpenAlex data for Angelika Amon...
# Fetching OpenAlex data for Bertil Andersson...
# Fetching OpenAlex data for Bernard Andreae...
# Fetching OpenAlex data for Anaïs  Angelo...
# Fetching OpenAlex data for Flavio Anselmetti...
# Fetching OpenAlex data for Leah Armstrong...
# Fetching OpenAlex data for Markus Arndt...
# Fetching OpenAlex data for Eduard Arzt...
# Fetching OpenAlex data for Alain Aspect...
# Fetching OpenAlex data for Markus Aspelmeyer...
# Fetching OpenAlex data for Aleida Assmann...
# Fetching OpenAlex data for Alice Auersperg...
# Fetching OpenAlex data for Hans Aurenhammer...
# Fetching OpenAlex data for Manuela Baccarini...
# Fetching OpenAlex data for Andrea Bachmaier...
# Fetching OpenAlex data for Auksė Balčytienė...
# Fetching OpenAlex data for Andrius Baltuška...
# Fetching OpenAlex data for Albert-László Barabási...
# Fetching OpenAlex data for Andrea Barta...
# Fetching OpenAlex data for Friedrich G. Barth...
# Fetching OpenAlex data for Hans Basbøll...
# Fetching OpenAlex data for Rainer Bauböck...
# Fetching OpenAlex data for Bernhard Bauer...
# Fetching OpenAlex data for Siegfried J. Bauer...
# Fetching OpenAlex data for Friedrich L. Bauer...
# Fetching OpenAlex data for Günther Bauer...
# Fetching OpenAlex data for Wolfgang Baumjohann...
# Fetching OpenAlex data for Zdeněk P. Bažant...
# Fetching OpenAlex data for Alexander K.  Belyaev...
# Fetching OpenAlex data for Robert John Bennett...
# Fetching OpenAlex data for Iván T. Berend...
# Fetching OpenAlex data for Walter Berka...
# Fetching OpenAlex data for Walter Berschin...
# Fetching OpenAlex data for Pier Marco Bertinetto...
# Fetching OpenAlex data for Reinhold Bichler...
# Fetching OpenAlex data for Manfred Bietak...
# Fetching OpenAlex data for Francesco C. Billari...
# Fetching OpenAlex data for Kurt Binder...
# Fetching OpenAlex data for Michal Biran...
# Fetching OpenAlex data for Helmut Birkhan...
# Fetching OpenAlex data for Paul Albert Blanz...
# Fetching OpenAlex data for Thomas Blaschke...
# Fetching OpenAlex data for Jean-Pierre Blaser...
# Fetching OpenAlex data for Rainer Blatt...
# Fetching OpenAlex data for Helen M. Blau...
# Fetching OpenAlex data for Horst Bleckmann...
# Fetching OpenAlex data for Günter Blöschl...
# Fetching OpenAlex data for Hans-Heinrich Blotevogel...
# Fetching OpenAlex data for Christoph Bock...
# Fetching OpenAlex data for Michael Joachim Bonell...
# Fetching OpenAlex data for Jürgen Borchhardt...
# Fetching OpenAlex data for Włodzimierz Borodziej...
# Fetching OpenAlex data for Axel Börsch-Supan...
# Fetching OpenAlex data for Axel Borsdorf...
# Fetching OpenAlex data for Richard Bösel...
# Fetching OpenAlex data for Jacques Bouveresse...
# Fetching OpenAlex data for John W. Boyer...
# Fetching OpenAlex data for Kaan Boztug...
# Fetching OpenAlex data for Karl Dietrich Bracher...
# Fetching OpenAlex data for Peter Brang...
# Fetching OpenAlex data for Georg Brasseur...
# Fetching OpenAlex data for Achim Brauer...
# Fetching OpenAlex data for Georg Peter Braulik...
# Fetching OpenAlex data for Jürgen Braunstein...
# Fetching OpenAlex data for Michel Breger...
# Fetching OpenAlex data for Gottfried Brem...
# Fetching OpenAlex data for Jan N. Bremmer...
# Fetching OpenAlex data for Wolfgang H. Breunlich...
# Fetching OpenAlex data for Wolfgang Brezinka...
# Fetching OpenAlex data for Hans Briegel...
# Fetching OpenAlex data for Günter Brucher...
# Fetching OpenAlex data for Gerhart Bruckmann...
# Fetching OpenAlex data for Ernst Bruckmüller...
# Fetching OpenAlex data for Wolfgang Brückner...
# Fetching OpenAlex data for Gerhard Budin...
# Fetching OpenAlex data for Julia Budka...
# Fetching OpenAlex data for Alejandro Raul Burga Ramos...
# Fetching OpenAlex data for Joachim Burgdörfer...
# Fetching OpenAlex data for Manfred Burgstaller...
# Fetching OpenAlex data for Otto Burkard...
# Fetching OpenAlex data for Walter Burkert...
# Fetching OpenAlex data for Meinrad Busslinger...
# Fetching OpenAlex data for Vladimír Bužek...
# Fetching OpenAlex data for Peter Bydlinski...
# Fetching OpenAlex data for Claus-Wilhelm Canaris...
# Fetching OpenAlex data for Carmen Cardelle de Hartmann...
# Fetching OpenAlex data for Louis Carlen...
# Fetching OpenAlex data for Giovanni Battista Castiglioni...
# Fetching OpenAlex data for Marina Cattaruzza...
# Fetching OpenAlex data for Federico Celestini...
# Fetching OpenAlex data for Komaravolu Chandrasekharan...
# Fetching OpenAlex data for Emmanuelle Charpentier...
# Fetching OpenAlex data for Mark W. Chase...
# Fetching OpenAlex data for Hai Cheng...
# Fetching OpenAlex data for Kenneth R. Chien...
# Fetching OpenAlex data for Maria Christakis...
# Fetching OpenAlex data for Enno Christophers...
# Fetching OpenAlex data for Evangelos Chrysos...
# Fetching OpenAlex data for Johann Cigler...
# Fetching OpenAlex data for Ignacio J. Cirac...
# Fetching OpenAlex data for Christopher M. Clark...
# Fetching OpenAlex data for Gary B. Cohen...
# Fetching OpenAlex data for Adrian Constantin...
# Fetching OpenAlex data for Michael P. Conzen...
# Fetching OpenAlex data for Paul Corkum...
# Fetching OpenAlex data for Thomas Corsten...
# Fetching OpenAlex data for Moritz Csáky...
# Fetching OpenAlex data for Christa Cuchiero...
# Fetching OpenAlex data for Yasin Dagdas...
# Fetching OpenAlex data for Falko Daim...
# Fetching OpenAlex data for Joachim Dalfen...
# Fetching OpenAlex data for Georg Danek...
# Fetching OpenAlex data for Robert Danzer...
# Fetching OpenAlex data for Lorraine Daston...
# Fetching OpenAlex data for Elisa  Davoli...
# Fetching OpenAlex data for Igor Bert Dawid...
# Fetching OpenAlex data for Patrizia de Bernardo Stempel...
# Fetching OpenAlex data for Gemma De les Coves...
# Fetching OpenAlex data for Bruno De Nicola...
# Fetching OpenAlex data for Nicla  De Zorzi...
# Fetching OpenAlex data for Peter Deetjen...
# Fetching OpenAlex data for Gerhard Dehm...
# Fetching OpenAlex data for Stefanie Dehnen...
# Fetching OpenAlex data for Manfred Deistler...
# Fetching OpenAlex data for Agnes Dellinger...
# Fetching OpenAlex data for Alexander Demandt...
# Fetching OpenAlex data for Helmut Denk...
# Fetching OpenAlex data for Barry J. Dickson...
# Fetching OpenAlex data for Ulrike Diebold...
# Fetching OpenAlex data for Egbert Dierker...
# Fetching OpenAlex data for Cora Dietl...
# Fetching OpenAlex data for Nina A. Dmitrieva...
# Fetching OpenAlex data for Gerhard Dobesch...
# Fetching OpenAlex data for Gabriele Doblhammer-Reiter...
# Fetching OpenAlex data for Liam Dolan...
# Fetching OpenAlex data for Rafael Domingo...
# Fetching OpenAlex data for Michael Doneus...
# Fetching OpenAlex data for Friedrich Dorner...
# Fetching OpenAlex data for Claudia Draxl...
# Fetching OpenAlex data for Wolfgang Ulrich Dressler...
# Fetching OpenAlex data for Michael Drmota...
# Fetching OpenAlex data for Ernst Peter Michael Dronke...
# Fetching OpenAlex data for Heinz Duchhardt...
# Fetching OpenAlex data for Klaus Düwel...
# Fetching OpenAlex data for Friedrich Dydak...
# Fetching OpenAlex data for Katarzyna Dziubalska-Kołaczyk...
# Fetching OpenAlex data for Josef Eberhardsteiner...
# Fetching OpenAlex data for Jürgen Eckert...
# Fetching OpenAlex data for Herbert Edelsbrunner...
# Fetching OpenAlex data for Hubert Christian Ehalt...
# Fetching OpenAlex data for Friedrich Ehrendorfer...
# Fetching OpenAlex data for Martin Ehrendorfer...
# Fetching OpenAlex data for Bernhard Ehrenzeller...
# Fetching OpenAlex data for Ludwig M. Eichinger...
# Fetching OpenAlex data for Michael Eichmair...
# Fetching OpenAlex data for Heiner Eichner...
# Fetching OpenAlex data for Manfred Eigen...
# Fetching OpenAlex data for Manfred Einsiedler...
# Fetching OpenAlex data for Thomas Eiter...
# Fetching OpenAlex data for Ivar Ekeland...
# Fetching OpenAlex data for Wilfried Ellmeier...
# Fetching OpenAlex data for Vincent Eltschinger...
# Fetching OpenAlex data for Heinz Engl...
# Fetching OpenAlex data for Johannes Erben...
# Fetching OpenAlex data for László Erdös...
# Fetching OpenAlex data for Gerhard Ertl...
# Fetching OpenAlex data for Maria J. Esteban...
# Fetching OpenAlex data for Richard John Evans...
# Fetching OpenAlex data for Robert John Weston Evans...
# Fetching OpenAlex data for Itamar Even-Zohar...
# Fetching OpenAlex data for Ludwig D. Faddeev...
# Fetching OpenAlex data for Heinz Falk...
# Fetching OpenAlex data for Gerda Falkner...
# Fetching OpenAlex data for Reinhard Fässler...
# Fetching OpenAlex data for Heinz Faßmann...
# Fetching OpenAlex data for Bénédicte Fauvarque-Cosson...
# Fetching OpenAlex data for Ernst Fehr...
# Fetching OpenAlex data for Gustav Feichtinger...
# Fetching OpenAlex data for Johannes Feichtinger...
# Fetching OpenAlex data for Martin S. Feldstein...
# Fetching OpenAlex data for Hannes A. Fellner...
# Fetching OpenAlex data for Sebastian Felten...
# Fetching OpenAlex data for Francesca Ferlaino...
# Fetching OpenAlex data for Günter Bernhard L. Fettweis...
# Fetching OpenAlex data for Ingeborg Fiala-Fürst...
# Fetching OpenAlex data for Wolfgang Fichtner...
# Fetching OpenAlex data for Hermann Fillitz...
# Fetching OpenAlex data for Jörg Finsinger...
# Fetching OpenAlex data for Andrea Fischer...
# Fetching OpenAlex data for Peter Fischer...
# Fetching OpenAlex data for Manfred M. Fischer...
# Fetching OpenAlex data for Hellmut F. Fischmeister...
# Fetching OpenAlex data for Jürgen Fleig...
# Fetching OpenAlex data for Konstanze Fliedl...
# Fetching OpenAlex data for August Florian...
# Fetching OpenAlex data for Rudolf Flotzinger...
# Fetching OpenAlex data for Monika Fludernik...
# Fetching OpenAlex data for Helmut Flügel...
# Fetching OpenAlex data for Franz Födermayr...
# Fetching OpenAlex data for Pál Fodor...
# Fetching OpenAlex data for Herbert Foltinek...
# Fetching OpenAlex data for Sebastian  Forster...
# Fetching OpenAlex data for Heinz G. Fortak...
# Fetching OpenAlex data for Bert Fragner...
# Fetching OpenAlex data for Wolfgang Frank...
# Fetching OpenAlex data for Peter Robert Franke...
# Fetching OpenAlex data for Peter Fratzl...
# Fetching OpenAlex data for Stefan Freunberger...
# Fetching OpenAlex data for Johannes Fried...
# Fetching OpenAlex data for Herwig Friesinger...
# Fetching OpenAlex data for Wolfgang Frisch...
# Fetching OpenAlex data for Sylvia Frühwirth-Schnatter...
# Fetching OpenAlex data for Erwin Führer...
# Fetching OpenAlex data for Alexia Fürnkranz-Prskawetz...
# Fetching OpenAlex data for Alois Fürstner...
# Fetching OpenAlex data for Helmut Gadner...
# Fetching OpenAlex data for Natalia Gagarina...
# Fetching OpenAlex data for Franz Gamillscheg...
# Fetching OpenAlex data for Thomas V. Gamkrelidze...
# Fetching OpenAlex data for Hans-Martin Gauger...
# Fetching OpenAlex data for Patrick J. Geary...
# Fetching OpenAlex data for Michael Gehler...
# Fetching OpenAlex data for Monika Gehrig-Merz...
# Fetching OpenAlex data for Johannes Geiss...
# Fetching OpenAlex data for Klaus Gersten...
# Fetching OpenAlex data for Martin H. Gerzabek...
# Fetching OpenAlex data for Michael Ghil...
# Fetching OpenAlex data for Patrizia Giampieri-Deutsch...
# Fetching OpenAlex data for Gerhard Giebisch...
# Fetching OpenAlex data for Oswald Giering...
# Fetching OpenAlex data for Simone Gingrich...
# Fetching OpenAlex data for Andre Gingrich...
# Fetching OpenAlex data for Karl-Heinz Alois Glaßmeier...
# Fetching OpenAlex data for Gerhard Glatzel...
# Fetching OpenAlex data for Claire F. Gmachl...
# Fetching OpenAlex data for Michael  Gnant...
# Fetching OpenAlex data for Helmut Gneuss...
# Fetching OpenAlex data for Hans Goebl...
# Fetching OpenAlex data for Ivan Golub...
# Fetching OpenAlex data for Leticia González...
# Fetching OpenAlex data for Maciej Górny...
# Fetching OpenAlex data for Georg Gottlob...
# Fetching OpenAlex data for Georg Grabherr...
# Fetching OpenAlex data for Sherrill Grace...
# Fetching OpenAlex data for Bernhard Grasemann...
# Fetching OpenAlex data for Manfred Grasserbauer...
# Fetching OpenAlex data for Daniel M. Greenberger...
# Fetching OpenAlex data for Wolfgang Greisenegger...
# Fetching OpenAlex data for Frantz Grenet...
# Fetching OpenAlex data for Herfried Griengl...
# Fetching OpenAlex data for Nicolas Grimal...
# Fetching OpenAlex data for Rudolf Grimm...
# Fetching OpenAlex data for Irmgard Griss...
# Fetching OpenAlex data for Jasmina Grković-Major...
# Fetching OpenAlex data for Rudolf Grosschedl...
# Fetching OpenAlex data for Peter Manfred Gruber...
# Fetching OpenAlex data for Gernot Gruber...
# Fetching OpenAlex data for Oskar Grün...
# Fetching OpenAlex data for Dieter Gutknecht...
# Fetching OpenAlex data for Giselher Guttmann...
# Fetching OpenAlex data for Mats Gyllenberg...
# Fetching OpenAlex data for Kálmán Györgyi...
# Fetching OpenAlex data for Rudolf Haag...
# Fetching OpenAlex data for Gerhard Haerendel...
# Fetching OpenAlex data for Stefan Hagel...
# Fetching OpenAlex data for Othmar Hageneder...
# Fetching OpenAlex data for Martin Hairer...
# Fetching OpenAlex data for Ivo Hajnal...
# Fetching OpenAlex data for John Haldon...
# Fetching OpenAlex data for Max Haller...
# Fetching OpenAlex data for Franz Halter-Koch...
# Fetching OpenAlex data for Ernst Hanisch...
# Fetching OpenAlex data for Ulf Hannerz...
# Fetching OpenAlex data for Edouard Hannezo...
# Fetching OpenAlex data for Christian Hannick...
# Fetching OpenAlex data for Aage A. Hansen-Löve...
# Fetching OpenAlex data for Michael Hantel...
# Fetching OpenAlex data for Jens-Uwe Hartmann...
# Fetching OpenAlex data for Maximilian Hartmuth...
# Fetching OpenAlex data for Mathias Harzhauser...
# Fetching OpenAlex data for Horst Haselsteiner...
# Fetching OpenAlex data for Günther Hasinger...
# Fetching OpenAlex data for Friederike Hassauer...
# Fetching OpenAlex data for Wolfgang Haubrichs...
# Fetching OpenAlex data for Gabriele Haug-Moritz...
# Fetching OpenAlex data for Hermann Franz Haupt...
# Fetching OpenAlex data for Uta Heil...
# Fetching OpenAlex data for Wolf-Dieter Heiss...
# Fetching OpenAlex data for Philipp U. Heitz...
# Fetching OpenAlex data for Christian Hellmich...
# Fetching OpenAlex data for Gilbert Helmberg...
# Fetching OpenAlex data for Monika Henzinger...
# Fetching OpenAlex data for Thomas A. Henzinger...
# Fetching OpenAlex data for Milan Herak...
# Fetching OpenAlex data for Gerhard Herndl...
# Fetching OpenAlex data for Marie Louise Herzfeld-Schild...
# Fetching OpenAlex data for Hans-Joachim Hinrichsen...
# Fetching OpenAlex data for Oskar v. Hinüber...
# Fetching OpenAlex data for Ivan Hlaváček...
# Fetching OpenAlex data for Milan Hlavačka...
# Fetching OpenAlex data for Claudia Höbartner...
# Fetching OpenAlex data for Erwin Hochmair...
# Fetching OpenAlex data for Ingeborg Hochmair-Desoyer...
# Fetching OpenAlex data for Sepp Hochreiter...
# Fetching OpenAlex data for Hartwig Höcker...
# Fetching OpenAlex data for Ivo Ludwig Hofacker...
# Fetching OpenAlex data for Barbara Hohn...
# Fetching OpenAlex data for Hans Höller...
# Fetching OpenAlex data for Gerald  Holton...
# Fetching OpenAlex data for Gerhard A. Holzapfel...
# Fetching OpenAlex data for Robert Holzmann...
# Fetching OpenAlex data for Heinrich Honsell...
# Fetching OpenAlex data for Barbara Horejs...
# Fetching OpenAlex data for Oleh Hornykiewicz...
# Fetching OpenAlex data for Konstantin-Alexander Hossmann...
# Fetching OpenAlex data for Yaroslav Hrytsak...
# Fetching OpenAlex data for Christoph Huber...
# Fetching OpenAlex data for Thomas J. R. Hughes...
# Fetching OpenAlex data for Pascale Hugon...
# Fetching OpenAlex data for Hermann Hunger...
# Fetching OpenAlex data for Nicola Hüsing...
# Fetching OpenAlex data for Reinhard Franz Josef Hüttl...
# Fetching OpenAlex data for Anthony A. Hyman...
# Fetching OpenAlex data for Ataç İmamoğlu...
# Fetching OpenAlex data for Christoph Irmscher...
# Fetching OpenAlex data for Hans Irschik...
# Fetching OpenAlex data for Shiro Ishii...
# Fetching OpenAlex data for Hans Peter Isler...
# Fetching OpenAlex data for Lisa Isola...
# Fetching OpenAlex data for Clemens Jabloner...
# Fetching OpenAlex data for Éva Jakab...
# Fetching OpenAlex data for Bernhard Jakoby...
# Fetching OpenAlex data for Sigrid Jalkotzy-Deger...
# Fetching OpenAlex data for Cecilia Jarlskog...
# Fetching OpenAlex data for Erik Jayme...
# Fetching OpenAlex data for Franz Jeglitsch...
# Fetching OpenAlex data for Thomas Jenuwein...
# Fetching OpenAlex data for Hans Joas...
# Fetching OpenAlex data for Werner Jobst...
# Fetching OpenAlex data for Zdenek Johan...
# Fetching OpenAlex data for Peter Johanek...
# Fetching OpenAlex data for Julian Johnson...
# Fetching OpenAlex data for Michael Jursa...
# Fetching OpenAlex data for Thede Kahl...
# Fetching OpenAlex data for Barbara Kaltenbacher...
# Fetching OpenAlex data for Manfred  Kaltenbacher...
# Fetching OpenAlex data for Eric R. Kandel...
# Fetching OpenAlex data for Andreas Kappeler...
# Fetching OpenAlex data for Vassos Karageorghis...
# Fetching OpenAlex data for Stevan Karamata...
# Fetching OpenAlex data for Matthias Karmasin...
# Fetching OpenAlex data for Martin Karplus...
# Fetching OpenAlex data for Georg Kaser...
# Fetching OpenAlex data for Daniel Kastler...
# Fetching OpenAlex data for Radoslav Katičić...
# Fetching OpenAlex data for Stephen Ira Katz...
# Fetching OpenAlex data for Hubert Kaufhold...
# Fetching OpenAlex data for Sylvia Kaufmann...
# Fetching OpenAlex data for Anke Rita Kaysser-Pyzalla...
# Fetching OpenAlex data for Katrin Keller...
# Fetching OpenAlex data for Birgit Kellner...
# Fetching OpenAlex data for Fritz Kelnhofer...
# Fetching OpenAlex data for Thomas Kenner...
# Fetching OpenAlex data for Manfred Kern...
# Fetching OpenAlex data for Eva Kernbauer...
# Fetching OpenAlex data for Ferenc Kiefer...
# Fetching OpenAlex data for Rudolf Kippenhahn...
# Fetching OpenAlex data for Gottfried Kirchengast...
# Fetching OpenAlex data for Britta Klagge...
# Fetching OpenAlex data for Michał Kleiber...
# Fetching OpenAlex data for Hans-Dieter Klein...
# Fetching OpenAlex data for Jürgen Kleine-Vehn...
# Fetching OpenAlex data for Nina Klimburg-Witjes...
# Fetching OpenAlex data for Bernd Ulrich Kluge...
# Fetching OpenAlex data for Alfred Kluwick...
# Fetching OpenAlex data for Fritz Peter Knapp...
# Fetching OpenAlex data for Sylvia Knapp...
# Fetching OpenAlex data for Jürgen Knoblich...
# Fetching OpenAlex data for Wolfgang Knoll...
# Fetching OpenAlex data for Christian Köberl...
# Fetching OpenAlex data for Walter Koch...
# Fetching OpenAlex data for Johannes Koder...
# Fetching OpenAlex data for Alfred Kohler...
# Fetching OpenAlex data for Alwin Köhler...
# Fetching OpenAlex data for Martin Kohli...
# Fetching OpenAlex data for Walter Kohn...
# Fetching OpenAlex data for Kurt L. Komarek...
# Fetching OpenAlex data for Robert Konrat...
# Fetching OpenAlex data for Hermann Kopetz...
# Fetching OpenAlex data for Hans-Georg Koppensteiner...
# Fetching OpenAlex data for Martin Korenjak...
# Fetching OpenAlex data for Karl Korinek...
# Fetching OpenAlex data for Christian Körner...
# Fetching OpenAlex data for Dušan Kováč...
# Fetching OpenAlex data for Helmut Koziol...
# Fetching OpenAlex data for Frauke Kraas...
# Fetching OpenAlex data for Dietrich Kraft...
# Fetching OpenAlex data for Ernst August Kramer...
# Fetching OpenAlex data for Christoph Kratky...
# Fetching OpenAlex data for Christian Krattenthaler...
# Fetching OpenAlex data for Ferenc Krausz...
# Fetching OpenAlex data for Bernhard Kräutler...
# Fetching OpenAlex data for Josef Kreiner...
# Fetching OpenAlex data for Georg Kresse...
# Fetching OpenAlex data for Otto Kresten...
# Fetching OpenAlex data for Friedrich Krinzinger...
# Fetching OpenAlex data for Guido Kroemer...
# Fetching OpenAlex data for Karl Kroeschell...
# Fetching OpenAlex data for Kurt Krolop...
# Fetching OpenAlex data for James Glenn Krueger...
# Fetching OpenAlex data for Hans-Henrik Krummacher...
# Fetching OpenAlex data for Andreas Kugi...
# Fetching OpenAlex data for Michael Kuhn...
# Fetching OpenAlex data for Richard Küng...
# Fetching OpenAlex data for Wilfried Kurz...
# Fetching OpenAlex data for Walter Kutschera...
# Fetching OpenAlex data for Jan Květ...
# Fetching OpenAlex data for Paul Alexander Kyrle...
# Fetching OpenAlex data for Anne L’Huillier...
# Fetching OpenAlex data for Johanna Laakso...
# Fetching OpenAlex data for Sabine Ladstätter...
# Fetching OpenAlex data for Christopher F. Laferl...
# Fetching OpenAlex data for Peter Laggner...
# Fetching OpenAlex data for Julia Lajta-Novak...
# Fetching OpenAlex data for Vasileios Lambrinoudakis...
# Fetching OpenAlex data for Claus Lamm...
# Fetching OpenAlex data for Irene Marthe Lang...
# Fetching OpenAlex data for Armin Lange...
# Fetching OpenAlex data for Robert S. Langer...
# Fetching OpenAlex data for Heinz Langer...
# Fetching OpenAlex data for Walter Larcher...
# Fetching OpenAlex data for Hans Lassmann...
# Fetching OpenAlex data for Reinhard Lauer...
# Fetching OpenAlex data for Jacques Le Rider...
# Fetching OpenAlex data for Klaus Lechner...
# Fetching OpenAlex data for Joseph Theodoor Leerssen...
# Fetching OpenAlex data for Gustav Adolf Lehmann...
# Fetching OpenAlex data for Marianne Johanna Lehmkuhl...
# Fetching OpenAlex data for Ursula Lehr...
# Fetching OpenAlex data for Helga Leitner...
# Fetching OpenAlex data for Mikhail Lemeshko...
# Fetching OpenAlex data for Alexandra N. Lenz...
# Fetching OpenAlex data for Silke Leopold...
# Fetching OpenAlex data for Johannes A. Lercher...
# Fetching OpenAlex data for Willem J. M. Levelt...
# Fetching OpenAlex data for Gary Libben...
# Fetching OpenAlex data for Elliott Lieb...
# Fetching OpenAlex data for Gene Elden Likens...
# Fetching OpenAlex data for Mandana E. Limbert...
# Fetching OpenAlex data for Andrea Lindmayr-Brandl...
# Fetching OpenAlex data for Thomas Lindner...
# Fetching OpenAlex data for Karl Lintner...
# Fetching OpenAlex data for Benjamin List...
# Fetching OpenAlex data for Birgit Lodes...
# Fetching OpenAlex data for Michele Loporcaro...
# Fetching OpenAlex data for Hellmut Lorenz...
# Fetching OpenAlex data for Martin Löschnigg...
# Fetching OpenAlex data for Peter Lucas...
# Fetching OpenAlex data for Monika Ludwig...
# Fetching OpenAlex data for Gerhard Luf...
# Fetching OpenAlex data for Thomas Luger...
# Fetching OpenAlex data for Helmut Lukesch...
# Fetching OpenAlex data for Reimar Lüst...
# Fetching OpenAlex data for Christina Lutter...
# Fetching OpenAlex data for Wolfgang Lutz...
# Fetching OpenAlex data for Marc Luy...
# Fetching OpenAlex data for Séamus Mac Mathúna...
# Fetching OpenAlex data for Thomas Magauer...
# Fetching OpenAlex data for Astrid Mager...
# Fetching OpenAlex data for Claudio Magris...
# Fetching OpenAlex data for Christian Mair...
# Fetching OpenAlex data for Melanie Malzahn...
# Fetching OpenAlex data for Herbert Mang...
# Fetching OpenAlex data for Wolfgang Mantl...
# Fetching OpenAlex data for Joseph Maran...
# Fetching OpenAlex data for Michael Marberger...
# Fetching OpenAlex data for Raimund Margreiter...
# Fetching OpenAlex data for Peter Markowich...
# Fetching OpenAlex data for James H. Marrow...
# Fetching OpenAlex data for Alberto Martino...
# Fetching OpenAlex data for Herbert Matis...
# Fetching OpenAlex data for Aleksandar Matković...
# Fetching OpenAlex data for Franz Matscher...
# Fetching OpenAlex data for Richard Viktor Mattessich...
# Fetching OpenAlex data for Hartmut  Matthäus...
# Fetching OpenAlex data for Paolo Matthiae...
# Fetching OpenAlex data for Marjori Ann Matzke...
# Fetching OpenAlex data for Nuno Maulide...
# Fetching OpenAlex data for Bernd Mayer...
# Fetching OpenAlex data for Henry M. R. E. Mayr-Harting...
# Fetching OpenAlex data for Paul Heinz Mayrhofer...
# Fetching OpenAlex data for Otto Mayrhofer-Krammel...
# Fetching OpenAlex data for Brigitte Mazohl...
# Fetching OpenAlex data for Rosamond McKitterick...
# Fetching OpenAlex data for Peter McMullen...
# Fetching OpenAlex data for Wolfgang F. G. Mecklenbräuker...
# Fetching OpenAlex data for Wolfgang Meid...
# Fetching OpenAlex data for Anne Sophie Meincke...
# Fetching OpenAlex data for Igor Mel'čuk...
# Fetching OpenAlex data for Fritz Melchers...
# Fetching OpenAlex data for Sarah Melzer...
# Fetching OpenAlex data for Günther Meschke...
# Fetching OpenAlex data for Bruno Messerli...
# Fetching OpenAlex data for Michael Metzeltin...
# Fetching OpenAlex data for Carola Metzner-Nebelsick...
# Fetching OpenAlex data for Ronald Micura...
# Fetching OpenAlex data for Gero Miesenböck...
# Fetching OpenAlex data for Hanno Millesi...
# Fetching OpenAlex data for Nina Mirnig...
# Fetching OpenAlex data for Diana Mishkova...
# Fetching OpenAlex data for Jürgen Mittelstraß...
# Fetching OpenAlex data for Christian  Mitterer...
# Fetching OpenAlex data for Fritz Mitthof...
# Fetching OpenAlex data for Kimberly Modic...
# Fetching OpenAlex data for Stephan Moebius...
# Fetching OpenAlex data for Helmuth Möhwald...
# Fetching OpenAlex data for Andreas F. Molisch...
# Fetching OpenAlex data for Hans Mommsen...
# Fetching OpenAlex data for Alessandro Montanari...
# Fetching OpenAlex data for Helmut Moritz...
# Fetching OpenAlex data for Cécile Morrisson...
# Fetching OpenAlex data for Gina E. Moseley...
# Fetching OpenAlex data for Helfried Mostler...
# Fetching OpenAlex data for Gérard A. Mourou...
# Fetching OpenAlex data for Nicolette Mout...
# Fetching OpenAlex data for Dennis C. Mueller...
# Fetching OpenAlex data for Wolfgang Mueller...
# Fetching OpenAlex data for Ivan I. Mueller...
# Fetching OpenAlex data for Sandra Müller...
# Fetching OpenAlex data for Ulrike Müller-Böker...
# Fetching OpenAlex data for Johann Mulzer...
# Fetching OpenAlex data for Ulrike Müßig...
# Fetching OpenAlex data for Karol Myśliwiec...
# Fetching OpenAlex data for Herta Nagl-Docekal...
# Fetching OpenAlex data for Norman M. Naimark...
# Fetching OpenAlex data for Rumi Nakamura...
# Fetching OpenAlex data for George (Gia) Sch. Nakhutsrishvili...
# Fetching OpenAlex data for Kim A. Nasmyth...
# Fetching OpenAlex data for David Natal Villazala...
# Fetching OpenAlex data for Adolf Neckel...
# Fetching OpenAlex data for Robert Nedoma...
# Fetching OpenAlex data for Wolfgang  Neubauer...
# Fetching OpenAlex data for Christine Neugebauer-Maresch...
# Fetching OpenAlex data for Winfried L. Neuhuber...
# Fetching OpenAlex data for Walter Neupert...
# Fetching OpenAlex data for Gerhard Neweklowsky...
# Fetching OpenAlex data for Stefan Michael Newerkla...
# Fetching OpenAlex data for Harald Niederreiter...
# Fetching OpenAlex data for Christian Roland Noe...
# Fetching OpenAlex data for Magnus Nordborg...
# Fetching OpenAlex data for Dieter Nörr...
# Fetching OpenAlex data for Marie-Louise Nosch...
# Fetching OpenAlex data for Sir Gustav Joseph Victor Nossal...
# Fetching OpenAlex data for Heinrich Nöth...
# Fetching OpenAlex data for Martin A. Nowak...
# Fetching OpenAlex data for Helga Nowotny...
# Fetching OpenAlex data for Onora O'Neill...
# Fetching OpenAlex data for Anna Christina Obenauf...
# Fetching OpenAlex data for Paul Oberhammer...
# Fetching OpenAlex data for Gerhard Oberhammer...
# Fetching OpenAlex data for Dieter Oesterhelt...
# Fetching OpenAlex data for Werner Ogris...
# Fetching OpenAlex data for Oskar Friedrich Olaj...
# Fetching OpenAlex data for Thomas Olechowski...
# Fetching OpenAlex data for Gerhard Opelz...
# Fetching OpenAlex data for Gherardo Ortalli...
# Fetching OpenAlex data for Marcus Ossiander...
# Fetching OpenAlex data for Jurij Sergejewitsch Ossipov...
# Fetching OpenAlex data for Jürgen Osterhammel...
# Fetching OpenAlex data for Jörg A. Ott...
# Fetching OpenAlex data for Alfred E. von Overbeck...
# Fetching OpenAlex data for Peter Palese...
# Fetching OpenAlex data for Herbert Palme...
# Fetching OpenAlex data for Bernhard Palme...
# Fetching OpenAlex data for Jian-Wei Pan...
# Fetching OpenAlex data for Oswald Panagl...
# Fetching OpenAlex data for Lucy Y. Pao...
# Fetching OpenAlex data for Fritz Paschke...
# Fetching OpenAlex data for Gernot Patzelt...
# Fetching OpenAlex data for Josef Penninger...
# Fetching OpenAlex data for Ernst Pernicka...
# Fetching OpenAlex data for Peter Pernthaler...
# Fetching OpenAlex data for Anne Peters...
# Fetching OpenAlex data for Jan-Michael Peters...
# Fetching OpenAlex data for Jillian Petersen...
# Fetching OpenAlex data for Hellmuth Petsche...
# Fetching OpenAlex data for Johann Pfanzagl...
# Fetching OpenAlex data for Gerhard Pferschy...
# Fetching OpenAlex data for Otto Pfersmann...
# Fetching OpenAlex data for Jörg Pfleiderer...
# Fetching OpenAlex data for Gert Pfurtscheller...
# Fetching OpenAlex data for Philip Ivanov Philippov...
# Fetching OpenAlex data for Gernot Piccottini...
# Fetching OpenAlex data for Helmut Pichler...
# Fetching OpenAlex data for Hannes Pichler...
# Fetching OpenAlex data for Pierre Jean Pichot...
# Fetching OpenAlex data for Herbert Pietschmann...
# Fetching OpenAlex data for Werner E. Piller...
# Fetching OpenAlex data for Renate Johanna Pillinger...
# Fetching OpenAlex data for Rudolf Pischinger...
# Fetching OpenAlex data for Clemens Plaschka...
# Fetching OpenAlex data for Carolina Plescia...
# Fetching OpenAlex data for Walter L. Pohl...
# Fetching OpenAlex data for Walter Pohl...
# Fetching OpenAlex data for Hryhoriy Polshyn...
# Fetching OpenAlex data for Marianne Popp...
# Fetching OpenAlex data for Magdalena Pöschl...
# Fetching OpenAlex data for Barbara Prainsack...
# Fetching OpenAlex data for Rudolf Preimesberger...
# Fetching OpenAlex data for Anton Preisinger...
# Fetching OpenAlex data for Friedrich B. Prinz...
# Fetching OpenAlex data for Manfred Prisching...
# Fetching OpenAlex data for Stephan  Procházka...
# Fetching OpenAlex data for Paolo Prodi...
# Fetching OpenAlex data for Walter Puchner...
# Fetching OpenAlex data for Andreas Pülz...
# Fetching OpenAlex data for Denise Pumain...
# Fetching OpenAlex data for Sonja Puntscher Riekmann...
# Fetching OpenAlex data for Gernot Rabeder...
# Fetching OpenAlex data for Ljiljana Radonić...
# Fetching OpenAlex data for Piero Rafanelli...
# Fetching OpenAlex data for Andrej Rahten...
# Fetching OpenAlex data for Franz Rainer...
# Fetching OpenAlex data for Ekkehard Ramm...
# Fetching OpenAlex data for Franz G. Rammerstorfer...
# Fetching OpenAlex data for Friederike Range...
# Fetching OpenAlex data for Claudia Rapp...
# Fetching OpenAlex data for Armando Rastelli...
# Fetching OpenAlex data for Gudrun Rath...
# Fetching OpenAlex data for Isabelle Ratié...
# Fetching OpenAlex data for Helmut Rauch...
# Fetching OpenAlex data for Peter H. Raven...
# Fetching OpenAlex data for Karl M. A. Rawer...
# Fetching OpenAlex data for Katharina Rebay-Salisbury...
# Fetching OpenAlex data for Anton Rebhan...
# Fetching OpenAlex data for Ludwig Reich...
# Fetching OpenAlex data for Ingo Reiffenstein...
# Fetching OpenAlex data for Wolf Uwe Reimold...
# Fetching OpenAlex data for Susanne Reindl-Krauskopf...
# Fetching OpenAlex data for August Reinisch...
# Fetching OpenAlex data for André Reis...
# Fetching OpenAlex data for Elmar R. Reiter...
# Fetching OpenAlex data for Reinhold Remmert...
# Fetching OpenAlex data for Andrew Colin Renfrew...
# Fetching OpenAlex data for Andrea Rentmeister...
# Fetching OpenAlex data for Fritz Resinger...
# Fetching OpenAlex data for Georg Ress...
# Fetching OpenAlex data for Keywan Riahi...
# Fetching OpenAlex data for James R. Rice...
# Fetching OpenAlex data for Kurt R. Richter...
# Fetching OpenAlex data for Norbert G. Riedel...
# Fetching OpenAlex data for Willibald Riedler...
# Fetching OpenAlex data for Josef Riedmann...
# Fetching OpenAlex data for Wolfgang Riehle...
# Fetching OpenAlex data for Gert Riethmüller...
# Fetching OpenAlex data for Wolfgang Rindler...
# Fetching OpenAlex data for Zsigmond Ritoók...
# Fetching OpenAlex data for Monika Ritsch-Marte...
# Fetching OpenAlex data for Olivia Fiona Robinson...
# Fetching OpenAlex data for Alexandra Rodler-Rørbo...
# Fetching OpenAlex data for Teresa Rodríguez de las Heras Ballell...
# Fetching OpenAlex data for Juan Gualterio Roederer...
# Fetching OpenAlex data for Herbert Walter Roesky...
# Fetching OpenAlex data for Robert Rollinger...
# Fetching OpenAlex data for José Luis Romero...
# Fetching OpenAlex data for Maria Grazia Roncarolo...
# Fetching OpenAlex data for Artur Rosenauer...
# Fetching OpenAlex data for Leopold Rosenmayr...
# Fetching OpenAlex data for Michael Rössner...
# Fetching OpenAlex data for Mathias Walter Rotach...
# Fetching OpenAlex data for Carlo Rubbia...
# Fetching OpenAlex data for Helmut O. Rucker...
# Fetching OpenAlex data for Helmut Rumpler...
# Fetching OpenAlex data for Hans Georg Ruppe...
# Fetching OpenAlex data for Günther Rupprechter...
# Fetching OpenAlex data for Eda Sagarra...
# Fetching OpenAlex data for Richard Salomon...
# Fetching OpenAlex data for Roman Sandgruber...
# Fetching OpenAlex data for Friedrich Sandhofer...
# Fetching OpenAlex data for Birgit Sandkaulen...
# Fetching OpenAlex data for Niyazi Serdar Sariçiftçi...
# Fetching OpenAlex data for Michael Sarnthein-Lotichius...
# Fetching OpenAlex data for Pasqualina Maria Sarro...
# Fetching OpenAlex data for Paolo Sartori...
# Fetching OpenAlex data for Friedrich Schaller...
# Fetching OpenAlex data for Gottfried Schatz...
# Fetching OpenAlex data for Philipp  Scheibelreiter...
# Fetching OpenAlex data for Walter Scheidel...
# Fetching OpenAlex data for Eva Schernhammer...
# Fetching OpenAlex data for Rudolf Schieffer...
# Fetching OpenAlex data for Sabine Schindler...
# Fetching OpenAlex data for Philipp Schindler...
# Fetching OpenAlex data for Andrzej Schinzel...
# Fetching OpenAlex data for Wolfgang Schlager...
# Fetching OpenAlex data for Wolfgang P. Schleich...
# Fetching OpenAlex data for Christa Schleper...
# Fetching OpenAlex data for Hermann Schmalzried...
# Fetching OpenAlex data for Klaus Schmidt...
# Fetching OpenAlex data for Wolfgang Schmidt...
# Fetching OpenAlex data for Matthias  Schmidt...
# Fetching OpenAlex data for Johannes Schmidt...
# Fetching OpenAlex data for Alfred Schmidt...
# Fetching OpenAlex data for Arnold Schmidt...
# Fetching OpenAlex data for Ernst August Schmidt...
# Fetching OpenAlex data for Philipp Schmidt-Dengler...
# Fetching OpenAlex data for Ursula Schmidt-Erfurth...
# Fetching OpenAlex data for Sabine Schmidtke...
# Fetching OpenAlex data for Jörg Schmiedmayer...
# Fetching OpenAlex data for Lambert Schmithausen...
# Fetching OpenAlex data for Rüdiger Schmitt...
# Fetching OpenAlex data for Oliver Jens Schmitt...
# Fetching OpenAlex data for Kurt Schmoller...
# Fetching OpenAlex data for Isabel Schnabel...
# Fetching OpenAlex data for Wilhelm Schneider...
# Fetching OpenAlex data for Albrecht Schöne...
# Fetching OpenAlex data for Hans Peter Schönlaub...
# Fetching OpenAlex data for Peter Schönswetter...
# Fetching OpenAlex data for Carl E. Schorske...
# Fetching OpenAlex data for Peter Schreiner...
# Fetching OpenAlex data for Ulrich Schubert...
# Fetching OpenAlex data for Gerold Schuler...
# Fetching OpenAlex data for Rolf Schulte-Hermann...
# Fetching OpenAlex data for Birgitta Schultze-Bernhardt...
# Fetching OpenAlex data for Winfried Schulze...
# Fetching OpenAlex data for Josef Schurz...
# Fetching OpenAlex data for Peter Schuster...
# Fetching OpenAlex data for Gerhard Schütz...
# Fetching OpenAlex data for Sebastian Schütze...
# Fetching OpenAlex data for Hans Schwabl...
# Fetching OpenAlex data for Karlheinz Schwarz...
# Fetching OpenAlex data for Florian Schwarz...
# Fetching OpenAlex data for Hans Georg Schwarzacher...
# Fetching OpenAlex data for Walther Schwarzacher...
# Fetching OpenAlex data for Günter C. Schweiger...
# Fetching OpenAlex data for Fritz Schweiger...
# Fetching OpenAlex data for Michael Schweitzer...
# Fetching OpenAlex data for Dieter Schweizer...
# Fetching OpenAlex data for Hugo Schwendenwein...
# Fetching OpenAlex data for Martin Seger...
# Fetching OpenAlex data for Christian Seidl...
# Fetching OpenAlex data for Horst Seidler...
# Fetching OpenAlex data for Stephan Johannes Seidlmayer...
# Fetching OpenAlex data for Robert  Seiringer...
# Fetching OpenAlex data for Ali Mehmet Celâl Şengör...
# Fetching OpenAlex data for Veronika Sexl...
# Fetching OpenAlex data for Demetra Sfendoni-Mentzou...
# Fetching OpenAlex data for Francesco Sferra...
# Fetching OpenAlex data for Danuta Shanzer...
# Fetching OpenAlex data for M. Rahim Shayegan...
# Fetching OpenAlex data for Ethan M. Shevach...
# Fetching OpenAlex data for Maria Sibilia...
# Fetching OpenAlex data for Susanne Sievers...
# Fetching OpenAlex data for Karl Sigmund...
# Fetching OpenAlex data for Petra Sijpesteijn...
# Fetching OpenAlex data for Oleg Simakov...
# Fetching OpenAlex data for Barry Simon...
# Fetching OpenAlex data for Nicholas Sims-Williams...
# Fetching OpenAlex data for Hans-Werner Sinn...
# Fetching OpenAlex data for Peter Sitte...
# Fetching OpenAlex data for Quentin R. D. Skinner...
# Fetching OpenAlex data for Uwe B. Sleytr...
# Fetching OpenAlex data for John Victor Small...
# Fetching OpenAlex data for Kurt Smolak...
# Fetching OpenAlex data for Josef Smolen...
# Fetching OpenAlex data for Werner Sollors...
# Fetching OpenAlex data for Éva Somogyi...
# Fetching OpenAlex data for Vera T. Sós...
# Fetching OpenAlex data for Nicola Spaldin...
# Fetching OpenAlex data for Katta Spiel...
# Fetching OpenAlex data for Christoph Spötl...
# Fetching OpenAlex data for Hellmuth Stachel...
# Fetching OpenAlex data for Saskia Stachowitsch...
# Fetching OpenAlex data for Peter F. Stadler...
# Fetching OpenAlex data for Lawrence E. Stager...
# Fetching OpenAlex data for Sigrid Stagl...
# Fetching OpenAlex data for André Stahl...
# Fetching OpenAlex data for Maria A. Stassinopoulou...
# Fetching OpenAlex data for Paul Stefanovits...
# Fetching OpenAlex data for Florian  Steger...
# Fetching OpenAlex data for Erwin Stein...
# Fetching OpenAlex data for Sybille Steinbacher...
# Fetching OpenAlex data for Peter Steinhauser...
# Fetching OpenAlex data for Friedrich Franz Steininger...
# Fetching OpenAlex data for Ernst Steinkellner...
# Fetching OpenAlex data for Hans-Peter Steinrück...
# Fetching OpenAlex data for Barbara Stelzl-Marx...
# Fetching OpenAlex data for Günter Stemberger...
# Fetching OpenAlex data for Stig T. Stenholm...
# Fetching OpenAlex data for Nikolaus K. Stephanidis...
# Fetching OpenAlex data for Peter Štih...
# Fetching OpenAlex data for Georg Stingl...
# Fetching OpenAlex data for Gerold Stoll...
# Fetching OpenAlex data for Barbara Stollberg-Rilinger...
# Fetching OpenAlex data for Gerald Stourzh...
# Fetching OpenAlex data for Helmut Strasser...
# Fetching OpenAlex data for Erich Wolfgang Streissler...
# Fetching OpenAlex data for Jörg Striessnig...
# Fetching OpenAlex data for Josef Strobl...
# Fetching OpenAlex data for Arno Strohmeyer...
# Fetching OpenAlex data for Tod F. Stuessy...
# Fetching OpenAlex data for Christian Sturmbauer...
# Fetching OpenAlex data for Robert Samuel Summers...
# Fetching OpenAlex data for Hans Sünkel...
# Fetching OpenAlex data for Giulio Superti-Furga...
# Fetching OpenAlex data for Arnold Suppan...
# Fetching OpenAlex data for Ernst Christoph Suttner...
# Fetching OpenAlex data for Gustav Andreas Tammann...
# Fetching OpenAlex data for Elly Tanaka...
# Fetching OpenAlex data for Éva Tardos...
# Fetching OpenAlex data for Ulrich Technau...
# Fetching OpenAlex data for Jaroslav Tejral...
# Fetching OpenAlex data for Werner Telesko...
# Fetching OpenAlex data for Heinz-Elmar Tenorth...
# Fetching OpenAlex data for Erich Thenius...
# Fetching OpenAlex data for Udo Thiel...
# Fetching OpenAlex data for Gerhard Thür...
# Fetching OpenAlex data for Robert F. Tichy...
# Fetching OpenAlex data for Klement Tockner...
# Fetching OpenAlex data for Theodor Tomandl...
# Fetching OpenAlex data for Erich Trapp...
# Fetching OpenAlex data for Dirk Trauner...
# Fetching OpenAlex data for Michael Trauner...
# Fetching OpenAlex data for Marko Trogrlić...
# Fetching OpenAlex data for Hans Tuppy...
# Fetching OpenAlex data for Franz-Josef Ulm...
# Fetching OpenAlex data for Melanie Unseld...
# Fetching OpenAlex data for Miriam M. Unterlass...
# Fetching OpenAlex data for Gerald Urban...
# Fetching OpenAlex data for Otto Helmut Urban...
# Fetching OpenAlex data for Boris A. Uspenskij...
# Fetching OpenAlex data for Gerd W. Utermann...
# Fetching OpenAlex data for Alice Vadrot...
# Fetching OpenAlex data for Rudolf Valenta...
# Fetching OpenAlex data for Peter van Nieuwenhuizen...
# Fetching OpenAlex data for Mihai-Cristian Vasile...
# Fetching OpenAlex data for Michael Johannes Vellekoop...
# Fetching OpenAlex data for Beatriz Vicoso...
# Fetching OpenAlex data for Karl Vodrazka...
# Fetching OpenAlex data for Thomas Vogl...
# Fetching OpenAlex data for Arndt von Haeseler...
# Fetching OpenAlex data for Klaus von Klitzing...
# Fetching OpenAlex data for Alfred Wagenhofer...
# Fetching OpenAlex data for Horst Wagner...
# Fetching OpenAlex data for Andreas  Wagner...
# Fetching OpenAlex data for Günter P. Wagner...
# Fetching OpenAlex data for Karl Wagner...
# Fetching OpenAlex data for Sigurd Wagner...
# Fetching OpenAlex data for Erwin F. Wagner...
# Fetching OpenAlex data for Michael Wagner...
# Fetching OpenAlex data for Birgit Wagner...
# Fetching OpenAlex data for Scott Waitukaitis...
# Fetching OpenAlex data for Wolfgang A. Wall...
# Fetching OpenAlex data for Grete Walter-Klingenstein...
# Fetching OpenAlex data for Heinrich Wänke...
# Fetching OpenAlex data for Graham Warren...
# Fetching OpenAlex data for Peter Michael Warren...
# Fetching OpenAlex data for Andrea Weber...
# Fetching OpenAlex data for Harald Wolfgang Weber...
# Fetching OpenAlex data for Gerhard Wegner...
# Fetching OpenAlex data for Rüdiger Wehner...
# Fetching OpenAlex data for Susanne Weigelin-Schwiedrzik...
# Fetching OpenAlex data for Stefan Weinfurter...
# Fetching OpenAlex data for Astrid Weiss...
# Fetching OpenAlex data for Günter Weiss...
# Fetching OpenAlex data for Werner Welzig...
# Fetching OpenAlex data for Emo Welzl...
# Fetching OpenAlex data for Christiane Wendehorst...
# Fetching OpenAlex data for Samuel A. Werner...
# Fetching OpenAlex data for Diter von Wettstein...
# Fetching OpenAlex data for Manfred Wicke...
# Fetching OpenAlex data for Gerhard Widmer...
# Fetching OpenAlex data for Ewald Wiederin...
# Fetching OpenAlex data for Maria Katharina  Wiedlack...
# Fetching OpenAlex data for Malcolm Hewitt Wiener...
# Fetching OpenAlex data for Josef Wiesehöfer...
# Fetching OpenAlex data for Wolfgang Wieser...
# Fetching OpenAlex data for Heinz Gregor Wieser...
# Fetching OpenAlex data for Michaela Wiesinger...
# Fetching OpenAlex data for Peter Wiesinger...
# Fetching OpenAlex data for Luzius Wildhaber...
# Fetching OpenAlex data for Günther Wilke...
# Fetching OpenAlex data for F. Ludwig Wilke...
# Fetching OpenAlex data for Jürgen Wilke...
# Fetching OpenAlex data for Harco Willems...
# Fetching OpenAlex data for Anouk Willemsen...
# Fetching OpenAlex data for Michaela Windischgrätz...
# Fetching OpenAlex data for Verena Winiwarter...
# Fetching OpenAlex data for Thomas Winkelbauer...
# Fetching OpenAlex data for Hans Winkler...
# Fetching OpenAlex data for Georg Winter...
# Fetching OpenAlex data for Renée Winter...
# Fetching OpenAlex data for Erich Winter...
# Fetching OpenAlex data for Irene J. Winter...
# Fetching OpenAlex data for Gerhard Wirth...
# Fetching OpenAlex data for Norbert Richard Wolf...
# Fetching OpenAlex data for Alois Wolf...
# Fetching OpenAlex data for Eckhard Wolf...
# Fetching OpenAlex data for Werner Wolf...
# Fetching OpenAlex data for Ulrich Wolf...
# Fetching OpenAlex data for Klaus Wolff...
# Fetching OpenAlex data for Herwig Wolfram...
# Fetching OpenAlex data for Bernhard Woytek...
# Fetching OpenAlex data for Dagmar Wujastyk...
# Fetching OpenAlex data for Keizô Yamamoto...
# Fetching OpenAlex data for Yeong-Bin Yang...
# Fetching OpenAlex data for William Edgar Yates...
# Fetching OpenAlex data for Bilge Yıldız...
# Fetching OpenAlex data for Stephen G. Young...
# Fetching OpenAlex data for Waldemar Zacharasiewicz...
# Fetching OpenAlex data for Hans Georg Zachau...
# Fetching OpenAlex data for Anatoly G. Zagorodny...
# Fetching OpenAlex data for Kurt Zatloukal...
# Fetching OpenAlex data for Josef Zechner...
# Fetching OpenAlex data for Rudolf Zechner...
# Fetching OpenAlex data for Anton Zeilinger...
# Fetching OpenAlex data for Josef Zemann...
# Fetching OpenAlex data for Wolfgang Zenker...
# Fetching OpenAlex data for Michael Zgurovsky...
# Fetching OpenAlex data for Yong-de Zhang...
# Fetching OpenAlex data for Shuguang Zhang...
# Fetching OpenAlex data for Franz Ziegler...
# Fetching OpenAlex data for Peter V. Zima...
# Fetching OpenAlex data for Reinhard Zimmermann...
# Fetching OpenAlex data for Harald Volkmar Zimmermann...
# Fetching OpenAlex data for Michel Zink...
# Fetching OpenAlex data for Ernst K. Zinner...
# Fetching OpenAlex data for Natalia A. Zinovieva...
# Fetching OpenAlex data for Theodore J. Ziolkowski...
# Fetching OpenAlex data for Jan M. Ziolkowski...
# Fetching OpenAlex data for Peter Zoller...
# Fetching OpenAlex data for Alessandro Zuccari...
# Fetching OpenAlex data for Paul Michael Zulehner...
# Enriched data saved to austrian_academy_members_author_ids_enhanced.json

# %%
import requests
import json
import time
import pandas as pd

# Input and output file paths
input_file_path = "/content/austrian_academy_members_enhanced.json"  # Replace with actual file path
output_file_path = "austrian_academy_author_ids.json"

# Load members JSON
with open(input_file_path, 'r', encoding='utf-8') as file:
    members = json.load(file)

# OpenAlex API endpoint
openalex_base_url = "https://api.openalex.org/authors"

# Function to query OpenAlex
def get_openalex_author_id(name):
    try:
        response = requests.get(openalex_base_url, params={"search": name})
        response.raise_for_status()  # Raise an exception for HTTP errors
        results = response.json()

        if "results" in results and results["results"]:
            # Take the first match (or apply more filters if needed)
            first_result = results["results"][0]
            return {
                "author_id": first_result.get("id"),
                "name": first_result.get("display_name"),
                "works_count": first_result.get("works_count", 0),
                "cited_by_count": first_result.get("cited_by_count", 0),
            }
        else:
            return None  # No match found
    except Exception as e:
        print(f"Error fetching author ID for {name}: {e}")
        return None

# Process each member to fetch OpenAlex Author ID
results = []
for member in members:
    print(f"Fetching OpenAlex Author ID for {member['name']}...")
    author_data = get_openalex_author_id(member["name"])
    if author_data:
        results.append({
            "name": member["name"],
            "title": member.get("title", None),
            "affiliation": member.get("affiliation", None),
            "membership_type": member.get("membership_type", None),
            "profile_url": member.get("profile_url", None),
            "openalex_id": author_data["author_id"],
            "works_count": author_data["works_count"],
            "cited_by_count": author_data["cited_by_count"],
        })
    else:
        results.append({
            "name": member["name"],
            "title": member.get("title", None),
            "affiliation": member.get("affiliation", None),
            "membership_type": member.get("membership_type", None),
            "profile_url": member.get("profile_url", None),
            "openalex_id": None,
            "works_count": None,
            "cited_by_count": None,
        })
    # Respect API rate limits
    time.sleep(1)  # Adjust delay if needed

# Save the results to a JSON file
with open(output_file_path, 'w', encoding='utf-8') as file:
    json.dump(results, file, ensure_ascii=False, indent=4)

print(f"Author IDs saved to '{output_file_path}'.")

# Optionally, save to CSV for easier inspection
pd.DataFrame(results).to_csv("austrian_academy_author_ids.csv", index=False)
print("Author IDs also saved to 'austrian_academy_author_ids.csv'.")
# Out:
# Fetching OpenAlex Author ID for Rainer Abart...
# Fetching OpenAlex Author ID for Karl Acham...
# Fetching OpenAlex Author ID for Antal Ádám...
# Fetching OpenAlex Author ID for Ludwig Adamovich...
# Fetching OpenAlex Author ID for Timon Erik Adolph...
# Fetching OpenAlex Author ID for Alícia Adserà...
# Fetching OpenAlex Author ID for Adriano Aguzzi...
# Fetching OpenAlex Author ID for Josef Aicher...
# Fetching OpenAlex Author ID for Martin Aigner...
# Fetching OpenAlex Author ID for Luciana Aigner-Foresti...
# Fetching OpenAlex Author ID for Brenda Almond...
# Fetching OpenAlex Author ID for Michael Alram...
# Fetching OpenAlex Author ID for Eva Alram-Stern...
# Fetching OpenAlex Author ID for Carlos Alvar Ezquerra...
# Fetching OpenAlex Author ID for João Alves...
# Fetching OpenAlex Author ID for Michel Amandry...
# Fetching OpenAlex Author ID for Petra Amann...
# Fetching OpenAlex Author ID for Brigitta Ammann...
# Fetching OpenAlex Author ID for Angelika Amon...
# Fetching OpenAlex Author ID for Bertil Andersson...
# Fetching OpenAlex Author ID for Bernard Andreae...
# Fetching OpenAlex Author ID for Anaïs  Angelo...
# Fetching OpenAlex Author ID for Flavio Anselmetti...
# Fetching OpenAlex Author ID for Leah Armstrong...
# Fetching OpenAlex Author ID for Markus Arndt...
# Fetching OpenAlex Author ID for Eduard Arzt...
# Fetching OpenAlex Author ID for Alain Aspect...
# Fetching OpenAlex Author ID for Markus Aspelmeyer...
# Fetching OpenAlex Author ID for Aleida Assmann...
# Fetching OpenAlex Author ID for Alice Auersperg...
# Fetching OpenAlex Author ID for Hans Aurenhammer...
# Fetching OpenAlex Author ID for Manuela Baccarini...
# Fetching OpenAlex Author ID for Andrea Bachmaier...
# Fetching OpenAlex Author ID for Auksė Balčytienė...
# Fetching OpenAlex Author ID for Andrius Baltuška...
# Fetching OpenAlex Author ID for Albert-László Barabási...
# Fetching OpenAlex Author ID for Andrea Barta...
# Fetching OpenAlex Author ID for Friedrich G. Barth...
# Fetching OpenAlex Author ID for Hans Basbøll...
# Fetching OpenAlex Author ID for Rainer Bauböck...
# Fetching OpenAlex Author ID for Bernhard Bauer...
# Fetching OpenAlex Author ID for Siegfried J. Bauer...
# Fetching OpenAlex Author ID for Friedrich L. Bauer...
# Fetching OpenAlex Author ID for Günther Bauer...
# Fetching OpenAlex Author ID for Wolfgang Baumjohann...
# Fetching OpenAlex Author ID for Zdeněk P. Bažant...
# Fetching OpenAlex Author ID for Alexander K.  Belyaev...
# Fetching OpenAlex Author ID for Robert John Bennett...
# Fetching OpenAlex Author ID for Iván T. Berend...
# Fetching OpenAlex Author ID for Walter Berka...
# Fetching OpenAlex Author ID for Walter Berschin...
# Fetching OpenAlex Author ID for Pier Marco Bertinetto...
# Fetching OpenAlex Author ID for Reinhold Bichler...
# Fetching OpenAlex Author ID for Manfred Bietak...
# Fetching OpenAlex Author ID for Francesco C. Billari...
# Fetching OpenAlex Author ID for Kurt Binder...
# Fetching OpenAlex Author ID for Michal Biran...
# Fetching OpenAlex Author ID for Helmut Birkhan...
# Fetching OpenAlex Author ID for Paul Albert Blanz...
# Fetching OpenAlex Author ID for Thomas Blaschke...
# Fetching OpenAlex Author ID for Jean-Pierre Blaser...
# Fetching OpenAlex Author ID for Rainer Blatt...
# Fetching OpenAlex Author ID for Helen M. Blau...
# Fetching OpenAlex Author ID for Horst Bleckmann...
# Fetching OpenAlex Author ID for Günter Blöschl...
# Fetching OpenAlex Author ID for Hans-Heinrich Blotevogel...
# Fetching OpenAlex Author ID for Christoph Bock...
# Fetching OpenAlex Author ID for Michael Joachim Bonell...
# Fetching OpenAlex Author ID for Jürgen Borchhardt...
# Fetching OpenAlex Author ID for Włodzimierz Borodziej...
# Fetching OpenAlex Author ID for Axel Börsch-Supan...
# Fetching OpenAlex Author ID for Axel Borsdorf...
# Fetching OpenAlex Author ID for Richard Bösel...
# Fetching OpenAlex Author ID for Jacques Bouveresse...
# Fetching OpenAlex Author ID for John W. Boyer...
# Fetching OpenAlex Author ID for Kaan Boztug...
# Fetching OpenAlex Author ID for Karl Dietrich Bracher...
# Fetching OpenAlex Author ID for Peter Brang...
# Fetching OpenAlex Author ID for Georg Brasseur...
# Fetching OpenAlex Author ID for Achim Brauer...
# Fetching OpenAlex Author ID for Georg Peter Braulik...
# Fetching OpenAlex Author ID for Jürgen Braunstein...
# Fetching OpenAlex Author ID for Michel Breger...
# Fetching OpenAlex Author ID for Gottfried Brem...
# Fetching OpenAlex Author ID for Jan N. Bremmer...
# Fetching OpenAlex Author ID for Wolfgang H. Breunlich...
# Fetching OpenAlex Author ID for Wolfgang Brezinka...
# Fetching OpenAlex Author ID for Hans Briegel...
# Fetching OpenAlex Author ID for Günter Brucher...
# Fetching OpenAlex Author ID for Gerhart Bruckmann...
# Fetching OpenAlex Author ID for Ernst Bruckmüller...
# Fetching OpenAlex Author ID for Wolfgang Brückner...
# Fetching OpenAlex Author ID for Gerhard Budin...
# Fetching OpenAlex Author ID for Julia Budka...
# Fetching OpenAlex Author ID for Alejandro Raul Burga Ramos...
# Fetching OpenAlex Author ID for Joachim Burgdörfer...
# Fetching OpenAlex Author ID for Manfred Burgstaller...
# Fetching OpenAlex Author ID for Otto Burkard...
# Fetching OpenAlex Author ID for Walter Burkert...
# Fetching OpenAlex Author ID for Meinrad Busslinger...
# Fetching OpenAlex Author ID for Vladimír Bužek...
# Fetching OpenAlex Author ID for Peter Bydlinski...
# Fetching OpenAlex Author ID for Claus-Wilhelm Canaris...
# Fetching OpenAlex Author ID for Carmen Cardelle de Hartmann...
# Fetching OpenAlex Author ID for Louis Carlen...
# Fetching OpenAlex Author ID for Giovanni Battista Castiglioni...
# Fetching OpenAlex Author ID for Marina Cattaruzza...
# Fetching OpenAlex Author ID for Federico Celestini...
# Fetching OpenAlex Author ID for Komaravolu Chandrasekharan...
# Fetching OpenAlex Author ID for Emmanuelle Charpentier...
# Fetching OpenAlex Author ID for Mark W. Chase...
# Fetching OpenAlex Author ID for Hai Cheng...
# Fetching OpenAlex Author ID for Kenneth R. Chien...
# Fetching OpenAlex Author ID for Maria Christakis...
# Fetching OpenAlex Author ID for Enno Christophers...
# Fetching OpenAlex Author ID for Evangelos Chrysos...
# Fetching OpenAlex Author ID for Johann Cigler...
# Fetching OpenAlex Author ID for Ignacio J. Cirac...
# Fetching OpenAlex Author ID for Christopher M. Clark...
# Fetching OpenAlex Author ID for Gary B. Cohen...
# Fetching OpenAlex Author ID for Adrian Constantin...
# Fetching OpenAlex Author ID for Michael P. Conzen...
# Fetching OpenAlex Author ID for Paul Corkum...
# Fetching OpenAlex Author ID for Thomas Corsten...
# Fetching OpenAlex Author ID for Moritz Csáky...
# Fetching OpenAlex Author ID for Christa Cuchiero...
# Fetching OpenAlex Author ID for Yasin Dagdas...
# Fetching OpenAlex Author ID for Falko Daim...
# Fetching OpenAlex Author ID for Joachim Dalfen...
# Fetching OpenAlex Author ID for Georg Danek...
# Fetching OpenAlex Author ID for Robert Danzer...
# Fetching OpenAlex Author ID for Lorraine Daston...
# Fetching OpenAlex Author ID for Elisa  Davoli...
# Fetching OpenAlex Author ID for Igor Bert Dawid...
# Fetching OpenAlex Author ID for Patrizia de Bernardo Stempel...
# Fetching OpenAlex Author ID for Gemma De les Coves...
# Fetching OpenAlex Author ID for Bruno De Nicola...
# Fetching OpenAlex Author ID for Nicla  De Zorzi...
# Fetching OpenAlex Author ID for Peter Deetjen...
# Fetching OpenAlex Author ID for Gerhard Dehm...
# Fetching OpenAlex Author ID for Stefanie Dehnen...
# Fetching OpenAlex Author ID for Manfred Deistler...
# Fetching OpenAlex Author ID for Agnes Dellinger...
# Fetching OpenAlex Author ID for Alexander Demandt...
# Fetching OpenAlex Author ID for Helmut Denk...
# Fetching OpenAlex Author ID for Barry J. Dickson...
# Fetching OpenAlex Author ID for Ulrike Diebold...
# Fetching OpenAlex Author ID for Egbert Dierker...
# Fetching OpenAlex Author ID for Cora Dietl...
# Fetching OpenAlex Author ID for Nina A. Dmitrieva...
# Fetching OpenAlex Author ID for Gerhard Dobesch...
# Fetching OpenAlex Author ID for Gabriele Doblhammer-Reiter...
# Fetching OpenAlex Author ID for Liam Dolan...
# Fetching OpenAlex Author ID for Rafael Domingo...
# Fetching OpenAlex Author ID for Michael Doneus...
# Fetching OpenAlex Author ID for Friedrich Dorner...
# Fetching OpenAlex Author ID for Claudia Draxl...
# Fetching OpenAlex Author ID for Wolfgang Ulrich Dressler...
# Fetching OpenAlex Author ID for Michael Drmota...
# Fetching OpenAlex Author ID for Ernst Peter Michael Dronke...
# Fetching OpenAlex Author ID for Heinz Duchhardt...
# Fetching OpenAlex Author ID for Klaus Düwel...
# Fetching OpenAlex Author ID for Friedrich Dydak...
# Fetching OpenAlex Author ID for Katarzyna Dziubalska-Kołaczyk...
# Fetching OpenAlex Author ID for Josef Eberhardsteiner...
# Fetching OpenAlex Author ID for Jürgen Eckert...
# Fetching OpenAlex Author ID for Herbert Edelsbrunner...
# Fetching OpenAlex Author ID for Hubert Christian Ehalt...
# Fetching OpenAlex Author ID for Friedrich Ehrendorfer...
# Fetching OpenAlex Author ID for Martin Ehrendorfer...
# Fetching OpenAlex Author ID for Bernhard Ehrenzeller...
# Fetching OpenAlex Author ID for Ludwig M. Eichinger...
# Fetching OpenAlex Author ID for Michael Eichmair...
# Fetching OpenAlex Author ID for Heiner Eichner...
# Fetching OpenAlex Author ID for Manfred Eigen...
# Fetching OpenAlex Author ID for Manfred Einsiedler...
# Fetching OpenAlex Author ID for Thomas Eiter...
# Fetching OpenAlex Author ID for Ivar Ekeland...
# Fetching OpenAlex Author ID for Wilfried Ellmeier...
# Fetching OpenAlex Author ID for Vincent Eltschinger...
# Fetching OpenAlex Author ID for Heinz Engl...
# Fetching OpenAlex Author ID for Johannes Erben...
# Fetching OpenAlex Author ID for László Erdös...
# Fetching OpenAlex Author ID for Gerhard Ertl...
# Fetching OpenAlex Author ID for Maria J. Esteban...
# Fetching OpenAlex Author ID for Richard John Evans...
# Fetching OpenAlex Author ID for Robert John Weston Evans...
# Fetching OpenAlex Author ID for Itamar Even-Zohar...
# Fetching OpenAlex Author ID for Ludwig D. Faddeev...
# Fetching OpenAlex Author ID for Heinz Falk...
# Fetching OpenAlex Author ID for Gerda Falkner...
# Fetching OpenAlex Author ID for Reinhard Fässler...
# Fetching OpenAlex Author ID for Heinz Faßmann...
# Fetching OpenAlex Author ID for Bénédicte Fauvarque-Cosson...
# Fetching OpenAlex Author ID for Ernst Fehr...
# Fetching OpenAlex Author ID for Gustav Feichtinger...
# Fetching OpenAlex Author ID for Johannes Feichtinger...
# Fetching OpenAlex Author ID for Martin S. Feldstein...
# Fetching OpenAlex Author ID for Hannes A. Fellner...
# Fetching OpenAlex Author ID for Sebastian Felten...
# Fetching OpenAlex Author ID for Francesca Ferlaino...
# Fetching OpenAlex Author ID for Günter Bernhard L. Fettweis...
# Fetching OpenAlex Author ID for Ingeborg Fiala-Fürst...
# Fetching OpenAlex Author ID for Wolfgang Fichtner...
# Fetching OpenAlex Author ID for Hermann Fillitz...
# Fetching OpenAlex Author ID for Jörg Finsinger...
# Fetching OpenAlex Author ID for Andrea Fischer...
# Fetching OpenAlex Author ID for Peter Fischer...
# Fetching OpenAlex Author ID for Manfred M. Fischer...
# Fetching OpenAlex Author ID for Hellmut F. Fischmeister...
# Fetching OpenAlex Author ID for Jürgen Fleig...
# Fetching OpenAlex Author ID for Konstanze Fliedl...
# Fetching OpenAlex Author ID for August Florian...
# Fetching OpenAlex Author ID for Rudolf Flotzinger...
# Fetching OpenAlex Author ID for Monika Fludernik...
# Fetching OpenAlex Author ID for Helmut Flügel...
# Fetching OpenAlex Author ID for Franz Födermayr...
# Fetching OpenAlex Author ID for Pál Fodor...
# Fetching OpenAlex Author ID for Herbert Foltinek...
# Fetching OpenAlex Author ID for Sebastian  Forster...
# Fetching OpenAlex Author ID for Heinz G. Fortak...
# Fetching OpenAlex Author ID for Bert Fragner...
# Fetching OpenAlex Author ID for Wolfgang Frank...
# Fetching OpenAlex Author ID for Peter Robert Franke...
# Fetching OpenAlex Author ID for Peter Fratzl...
# Fetching OpenAlex Author ID for Stefan Freunberger...
# Fetching OpenAlex Author ID for Johannes Fried...
# Fetching OpenAlex Author ID for Herwig Friesinger...
# Fetching OpenAlex Author ID for Wolfgang Frisch...
# Fetching OpenAlex Author ID for Sylvia Frühwirth-Schnatter...
# Fetching OpenAlex Author ID for Erwin Führer...
# Fetching OpenAlex Author ID for Alexia Fürnkranz-Prskawetz...
# Fetching OpenAlex Author ID for Alois Fürstner...
# Fetching OpenAlex Author ID for Helmut Gadner...
# Fetching OpenAlex Author ID for Natalia Gagarina...
# Fetching OpenAlex Author ID for Franz Gamillscheg...
# Fetching OpenAlex Author ID for Thomas V. Gamkrelidze...
# Fetching OpenAlex Author ID for Hans-Martin Gauger...
# Fetching OpenAlex Author ID for Patrick J. Geary...
# Fetching OpenAlex Author ID for Michael Gehler...
# Fetching OpenAlex Author ID for Monika Gehrig-Merz...
# Fetching OpenAlex Author ID for Johannes Geiss...
# Fetching OpenAlex Author ID for Klaus Gersten...
# Fetching OpenAlex Author ID for Martin H. Gerzabek...
# Fetching OpenAlex Author ID for Michael Ghil...
# Fetching OpenAlex Author ID for Patrizia Giampieri-Deutsch...
# Fetching OpenAlex Author ID for Gerhard Giebisch...
# Fetching OpenAlex Author ID for Oswald Giering...
# Fetching OpenAlex Author ID for Simone Gingrich...
# Fetching OpenAlex Author ID for Andre Gingrich...
# Fetching OpenAlex Author ID for Karl-Heinz Alois Glaßmeier...
# Fetching OpenAlex Author ID for Gerhard Glatzel...
# Fetching OpenAlex Author ID for Claire F. Gmachl...
# Fetching OpenAlex Author ID for Michael  Gnant...
# Fetching OpenAlex Author ID for Helmut Gneuss...
# Fetching OpenAlex Author ID for Hans Goebl...
# Fetching OpenAlex Author ID for Ivan Golub...
# Fetching OpenAlex Author ID for Leticia González...
# Fetching OpenAlex Author ID for Maciej Górny...
# Fetching OpenAlex Author ID for Georg Gottlob...
# Fetching OpenAlex Author ID for Georg Grabherr...
# Fetching OpenAlex Author ID for Sherrill Grace...
# Fetching OpenAlex Author ID for Bernhard Grasemann...
# Fetching OpenAlex Author ID for Manfred Grasserbauer...
# Fetching OpenAlex Author ID for Daniel M. Greenberger...
# Fetching OpenAlex Author ID for Wolfgang Greisenegger...
# Fetching OpenAlex Author ID for Frantz Grenet...
# Fetching OpenAlex Author ID for Herfried Griengl...
# Fetching OpenAlex Author ID for Nicolas Grimal...
# Fetching OpenAlex Author ID for Rudolf Grimm...
# Fetching OpenAlex Author ID for Irmgard Griss...
# Fetching OpenAlex Author ID for Jasmina Grković-Major...
# Fetching OpenAlex Author ID for Rudolf Grosschedl...
# Fetching OpenAlex Author ID for Peter Manfred Gruber...
# Fetching OpenAlex Author ID for Gernot Gruber...
# Fetching OpenAlex Author ID for Oskar Grün...
# Fetching OpenAlex Author ID for Dieter Gutknecht...
# Fetching OpenAlex Author ID for Giselher Guttmann...
# Fetching OpenAlex Author ID for Mats Gyllenberg...
# Fetching OpenAlex Author ID for Kálmán Györgyi...
# Fetching OpenAlex Author ID for Rudolf Haag...
# Fetching OpenAlex Author ID for Gerhard Haerendel...
# Fetching OpenAlex Author ID for Stefan Hagel...
# Fetching OpenAlex Author ID for Othmar Hageneder...
# Fetching OpenAlex Author ID for Martin Hairer...
# Fetching OpenAlex Author ID for Ivo Hajnal...
# Fetching OpenAlex Author ID for John Haldon...
# Fetching OpenAlex Author ID for Max Haller...
# Fetching OpenAlex Author ID for Franz Halter-Koch...
# Fetching OpenAlex Author ID for Ernst Hanisch...
# Fetching OpenAlex Author ID for Ulf Hannerz...
# Fetching OpenAlex Author ID for Edouard Hannezo...
# Fetching OpenAlex Author ID for Christian Hannick...
# Fetching OpenAlex Author ID for Aage A. Hansen-Löve...
# Fetching OpenAlex Author ID for Michael Hantel...
# Fetching OpenAlex Author ID for Jens-Uwe Hartmann...
# Fetching OpenAlex Author ID for Maximilian Hartmuth...
# Fetching OpenAlex Author ID for Mathias Harzhauser...
# Fetching OpenAlex Author ID for Horst Haselsteiner...
# Fetching OpenAlex Author ID for Günther Hasinger...
# Fetching OpenAlex Author ID for Friederike Hassauer...
# Fetching OpenAlex Author ID for Wolfgang Haubrichs...
# Fetching OpenAlex Author ID for Gabriele Haug-Moritz...
# Fetching OpenAlex Author ID for Hermann Franz Haupt...
# Fetching OpenAlex Author ID for Uta Heil...
# Fetching OpenAlex Author ID for Wolf-Dieter Heiss...
# Fetching OpenAlex Author ID for Philipp U. Heitz...
# Fetching OpenAlex Author ID for Christian Hellmich...
# Fetching OpenAlex Author ID for Gilbert Helmberg...
# Fetching OpenAlex Author ID for Monika Henzinger...
# Fetching OpenAlex Author ID for Thomas A. Henzinger...
# Fetching OpenAlex Author ID for Milan Herak...
# Fetching OpenAlex Author ID for Gerhard Herndl...
# Fetching OpenAlex Author ID for Marie Louise Herzfeld-Schild...
# Fetching OpenAlex Author ID for Hans-Joachim Hinrichsen...
# Fetching OpenAlex Author ID for Oskar v. Hinüber...
# Fetching OpenAlex Author ID for Ivan Hlaváček...
# Fetching OpenAlex Author ID for Milan Hlavačka...
# Fetching OpenAlex Author ID for Claudia Höbartner...
# Fetching OpenAlex Author ID for Erwin Hochmair...
# Fetching OpenAlex Author ID for Ingeborg Hochmair-Desoyer...
# Fetching OpenAlex Author ID for Sepp Hochreiter...
# Fetching OpenAlex Author ID for Hartwig Höcker...
# Fetching OpenAlex Author ID for Ivo Ludwig Hofacker...
# Fetching OpenAlex Author ID for Barbara Hohn...
# Fetching OpenAlex Author ID for Hans Höller...
# Fetching OpenAlex Author ID for Gerald  Holton...
# Fetching OpenAlex Author ID for Gerhard A. Holzapfel...
# Fetching OpenAlex Author ID for Robert Holzmann...
# Fetching OpenAlex Author ID for Heinrich Honsell...
# Fetching OpenAlex Author ID for Barbara Horejs...
# Fetching OpenAlex Author ID for Oleh Hornykiewicz...
# Fetching OpenAlex Author ID for Konstantin-Alexander Hossmann...
# Fetching OpenAlex Author ID for Yaroslav Hrytsak...
# Fetching OpenAlex Author ID for Christoph Huber...
# Fetching OpenAlex Author ID for Thomas J. R. Hughes...
# Fetching OpenAlex Author ID for Pascale Hugon...
# Fetching OpenAlex Author ID for Hermann Hunger...
# Fetching OpenAlex Author ID for Nicola Hüsing...
# Fetching OpenAlex Author ID for Reinhard Franz Josef Hüttl...
# Fetching OpenAlex Author ID for Anthony A. Hyman...
# Fetching OpenAlex Author ID for Ataç İmamoğlu...
# Fetching OpenAlex Author ID for Christoph Irmscher...
# Fetching OpenAlex Author ID for Hans Irschik...
# Fetching OpenAlex Author ID for Shiro Ishii...
# Fetching OpenAlex Author ID for Hans Peter Isler...
# Fetching OpenAlex Author ID for Lisa Isola...
# Fetching OpenAlex Author ID for Clemens Jabloner...
# Fetching OpenAlex Author ID for Éva Jakab...
# Fetching OpenAlex Author ID for Bernhard Jakoby...
# Fetching OpenAlex Author ID for Sigrid Jalkotzy-Deger...
# Fetching OpenAlex Author ID for Cecilia Jarlskog...
# Fetching OpenAlex Author ID for Erik Jayme...
# Fetching OpenAlex Author ID for Franz Jeglitsch...
# Fetching OpenAlex Author ID for Thomas Jenuwein...
# Fetching OpenAlex Author ID for Hans Joas...
# Fetching OpenAlex Author ID for Werner Jobst...
# Fetching OpenAlex Author ID for Zdenek Johan...
# Fetching OpenAlex Author ID for Peter Johanek...
# Fetching OpenAlex Author ID for Julian Johnson...
# Fetching OpenAlex Author ID for Michael Jursa...
# Fetching OpenAlex Author ID for Thede Kahl...
# Fetching OpenAlex Author ID for Barbara Kaltenbacher...
# Fetching OpenAlex Author ID for Manfred  Kaltenbacher...
# Fetching OpenAlex Author ID for Eric R. Kandel...
# Fetching OpenAlex Author ID for Andreas Kappeler...
# Fetching OpenAlex Author ID for Vassos Karageorghis...
# Fetching OpenAlex Author ID for Stevan Karamata...
# Fetching OpenAlex Author ID for Matthias Karmasin...
# Fetching OpenAlex Author ID for Martin Karplus...
# Fetching OpenAlex Author ID for Georg Kaser...
# Fetching OpenAlex Author ID for Daniel Kastler...
# Fetching OpenAlex Author ID for Radoslav Katičić...
# Fetching OpenAlex Author ID for Stephen Ira Katz...
# Fetching OpenAlex Author ID for Hubert Kaufhold...
# Fetching OpenAlex Author ID for Sylvia Kaufmann...
# Fetching OpenAlex Author ID for Anke Rita Kaysser-Pyzalla...
# Fetching OpenAlex Author ID for Katrin Keller...
# Fetching OpenAlex Author ID for Birgit Kellner...
# Fetching OpenAlex Author ID for Fritz Kelnhofer...
# Fetching OpenAlex Author ID for Thomas Kenner...
# Fetching OpenAlex Author ID for Manfred Kern...
# Fetching OpenAlex Author ID for Eva Kernbauer...
# Fetching OpenAlex Author ID for Ferenc Kiefer...
# Fetching OpenAlex Author ID for Rudolf Kippenhahn...
# Fetching OpenAlex Author ID for Gottfried Kirchengast...
# Fetching OpenAlex Author ID for Britta Klagge...
# Fetching OpenAlex Author ID for Michał Kleiber...
# Fetching OpenAlex Author ID for Hans-Dieter Klein...
# Fetching OpenAlex Author ID for Jürgen Kleine-Vehn...
# Fetching OpenAlex Author ID for Nina Klimburg-Witjes...
# Fetching OpenAlex Author ID for Bernd Ulrich Kluge...
# Fetching OpenAlex Author ID for Alfred Kluwick...
# Fetching OpenAlex Author ID for Fritz Peter Knapp...
# Fetching OpenAlex Author ID for Sylvia Knapp...
# Fetching OpenAlex Author ID for Jürgen Knoblich...
# Fetching OpenAlex Author ID for Wolfgang Knoll...
# Fetching OpenAlex Author ID for Christian Köberl...
# Fetching OpenAlex Author ID for Walter Koch...
# Fetching OpenAlex Author ID for Johannes Koder...
# Fetching OpenAlex Author ID for Alfred Kohler...
# Fetching OpenAlex Author ID for Alwin Köhler...
# Fetching OpenAlex Author ID for Martin Kohli...
# Fetching OpenAlex Author ID for Walter Kohn...
# Fetching OpenAlex Author ID for Kurt L. Komarek...
# Fetching OpenAlex Author ID for Robert Konrat...
# Fetching OpenAlex Author ID for Hermann Kopetz...
# Fetching OpenAlex Author ID for Hans-Georg Koppensteiner...
# Fetching OpenAlex Author ID for Martin Korenjak...
# Fetching OpenAlex Author ID for Karl Korinek...
# Fetching OpenAlex Author ID for Christian Körner...
# Fetching OpenAlex Author ID for Dušan Kováč...
# Fetching OpenAlex Author ID for Helmut Koziol...
# Fetching OpenAlex Author ID for Frauke Kraas...
# Fetching OpenAlex Author ID for Dietrich Kraft...
# Fetching OpenAlex Author ID for Ernst August Kramer...
# Fetching OpenAlex Author ID for Christoph Kratky...
# Fetching OpenAlex Author ID for Christian Krattenthaler...
# Fetching OpenAlex Author ID for Ferenc Krausz...
# Fetching OpenAlex Author ID for Bernhard Kräutler...
# Fetching OpenAlex Author ID for Josef Kreiner...
# Fetching OpenAlex Author ID for Georg Kresse...
# Fetching OpenAlex Author ID for Otto Kresten...
# Fetching OpenAlex Author ID for Friedrich Krinzinger...
# Fetching OpenAlex Author ID for Guido Kroemer...
# Fetching OpenAlex Author ID for Karl Kroeschell...
# Fetching OpenAlex Author ID for Kurt Krolop...
# Fetching OpenAlex Author ID for James Glenn Krueger...
# Fetching OpenAlex Author ID for Hans-Henrik Krummacher...
# Fetching OpenAlex Author ID for Andreas Kugi...
# Fetching OpenAlex Author ID for Michael Kuhn...
# Fetching OpenAlex Author ID for Richard Küng...
# Fetching OpenAlex Author ID for Wilfried Kurz...
# Fetching OpenAlex Author ID for Walter Kutschera...
# Fetching OpenAlex Author ID for Jan Květ...
# Fetching OpenAlex Author ID for Paul Alexander Kyrle...
# Fetching OpenAlex Author ID for Anne L’Huillier...
# Fetching OpenAlex Author ID for Johanna Laakso...
# Fetching OpenAlex Author ID for Sabine Ladstätter...
# Fetching OpenAlex Author ID for Christopher F. Laferl...
# Fetching OpenAlex Author ID for Peter Laggner...
# Fetching OpenAlex Author ID for Julia Lajta-Novak...
# Fetching OpenAlex Author ID for Vasileios Lambrinoudakis...
# Fetching OpenAlex Author ID for Claus Lamm...
# Fetching OpenAlex Author ID for Irene Marthe Lang...
# Fetching OpenAlex Author ID for Armin Lange...
# Fetching OpenAlex Author ID for Robert S. Langer...
# Fetching OpenAlex Author ID for Heinz Langer...
# Fetching OpenAlex Author ID for Walter Larcher...
# Fetching OpenAlex Author ID for Hans Lassmann...
# Fetching OpenAlex Author ID for Reinhard Lauer...
# Fetching OpenAlex Author ID for Jacques Le Rider...
# Fetching OpenAlex Author ID for Klaus Lechner...
# Fetching OpenAlex Author ID for Joseph Theodoor Leerssen...
# Fetching OpenAlex Author ID for Gustav Adolf Lehmann...
# Fetching OpenAlex Author ID for Marianne Johanna Lehmkuhl...
# Fetching OpenAlex Author ID for Ursula Lehr...
# Fetching OpenAlex Author ID for Helga Leitner...
# Fetching OpenAlex Author ID for Mikhail Lemeshko...
# Fetching OpenAlex Author ID for Alexandra N. Lenz...
# Fetching OpenAlex Author ID for Silke Leopold...
# Fetching OpenAlex Author ID for Johannes A. Lercher...
# Fetching OpenAlex Author ID for Willem J. M. Levelt...
# Fetching OpenAlex Author ID for Gary Libben...
# Fetching OpenAlex Author ID for Elliott Lieb...
# Fetching OpenAlex Author ID for Gene Elden Likens...
# Fetching OpenAlex Author ID for Mandana E. Limbert...
# Fetching OpenAlex Author ID for Andrea Lindmayr-Brandl...
# Fetching OpenAlex Author ID for Thomas Lindner...
# Fetching OpenAlex Author ID for Karl Lintner...
# Fetching OpenAlex Author ID for Benjamin List...
# Fetching OpenAlex Author ID for Birgit Lodes...
# Fetching OpenAlex Author ID for Michele Loporcaro...
# Fetching OpenAlex Author ID for Hellmut Lorenz...
# Fetching OpenAlex Author ID for Martin Löschnigg...
# Fetching OpenAlex Author ID for Peter Lucas...
# Fetching OpenAlex Author ID for Monika Ludwig...
# Fetching OpenAlex Author ID for Gerhard Luf...
# Fetching OpenAlex Author ID for Thomas Luger...
# Fetching OpenAlex Author ID for Helmut Lukesch...
# Fetching OpenAlex Author ID for Reimar Lüst...
# Fetching OpenAlex Author ID for Christina Lutter...
# Fetching OpenAlex Author ID for Wolfgang Lutz...
# Fetching OpenAlex Author ID for Marc Luy...
# Fetching OpenAlex Author ID for Séamus Mac Mathúna...
# Fetching OpenAlex Author ID for Thomas Magauer...
# Fetching OpenAlex Author ID for Astrid Mager...
# Fetching OpenAlex Author ID for Claudio Magris...
# Fetching OpenAlex Author ID for Christian Mair...
# Fetching OpenAlex Author ID for Melanie Malzahn...
# Fetching OpenAlex Author ID for Herbert Mang...
# Fetching OpenAlex Author ID for Wolfgang Mantl...
# Fetching OpenAlex Author ID for Joseph Maran...
# Fetching OpenAlex Author ID for Michael Marberger...
# Fetching OpenAlex Author ID for Raimund Margreiter...
# Fetching OpenAlex Author ID for Peter Markowich...
# Fetching OpenAlex Author ID for James H. Marrow...
# Fetching OpenAlex Author ID for Alberto Martino...
# Fetching OpenAlex Author ID for Herbert Matis...
# Fetching OpenAlex Author ID for Aleksandar Matković...
# Fetching OpenAlex Author ID for Franz Matscher...
# Fetching OpenAlex Author ID for Richard Viktor Mattessich...
# Fetching OpenAlex Author ID for Hartmut  Matthäus...
# Fetching OpenAlex Author ID for Paolo Matthiae...
# Fetching OpenAlex Author ID for Marjori Ann Matzke...
# Fetching OpenAlex Author ID for Nuno Maulide...
# Fetching OpenAlex Author ID for Bernd Mayer...
# Fetching OpenAlex Author ID for Henry M. R. E. Mayr-Harting...
# Fetching OpenAlex Author ID for Paul Heinz Mayrhofer...
# Fetching OpenAlex Author ID for Otto Mayrhofer-Krammel...
# Fetching OpenAlex Author ID for Brigitte Mazohl...
# Fetching OpenAlex Author ID for Rosamond McKitterick...
# Fetching OpenAlex Author ID for Peter McMullen...
# Fetching OpenAlex Author ID for Wolfgang F. G. Mecklenbräuker...
# Fetching OpenAlex Author ID for Wolfgang Meid...
# Fetching OpenAlex Author ID for Anne Sophie Meincke...
# Fetching OpenAlex Author ID for Igor Mel'čuk...
# Fetching OpenAlex Author ID for Fritz Melchers...
# Fetching OpenAlex Author ID for Sarah Melzer...
# Fetching OpenAlex Author ID for Günther Meschke...
# Fetching OpenAlex Author ID for Bruno Messerli...
# Fetching OpenAlex Author ID for Michael Metzeltin...
# Fetching OpenAlex Author ID for Carola Metzner-Nebelsick...
# Fetching OpenAlex Author ID for Ronald Micura...
# Fetching OpenAlex Author ID for Gero Miesenböck...
# Fetching OpenAlex Author ID for Hanno Millesi...
# Fetching OpenAlex Author ID for Nina Mirnig...
# Fetching OpenAlex Author ID for Diana Mishkova...
# Fetching OpenAlex Author ID for Jürgen Mittelstraß...
# Fetching OpenAlex Author ID for Christian  Mitterer...
# Fetching OpenAlex Author ID for Fritz Mitthof...
# Fetching OpenAlex Author ID for Kimberly Modic...
# Fetching OpenAlex Author ID for Stephan Moebius...
# Fetching OpenAlex Author ID for Helmuth Möhwald...
# Fetching OpenAlex Author ID for Andreas F. Molisch...
# Fetching OpenAlex Author ID for Hans Mommsen...
# Fetching OpenAlex Author ID for Alessandro Montanari...
# Fetching OpenAlex Author ID for Helmut Moritz...
# Fetching OpenAlex Author ID for Cécile Morrisson...
# Fetching OpenAlex Author ID for Gina E. Moseley...
# Fetching OpenAlex Author ID for Helfried Mostler...
# Fetching OpenAlex Author ID for Gérard A. Mourou...
# Fetching OpenAlex Author ID for Nicolette Mout...
# Fetching OpenAlex Author ID for Dennis C. Mueller...
# Fetching OpenAlex Author ID for Wolfgang Mueller...
# Fetching OpenAlex Author ID for Ivan I. Mueller...
# Fetching OpenAlex Author ID for Sandra Müller...
# Fetching OpenAlex Author ID for Ulrike Müller-Böker...
# Fetching OpenAlex Author ID for Johann Mulzer...
# Fetching OpenAlex Author ID for Ulrike Müßig...
# Fetching OpenAlex Author ID for Karol Myśliwiec...
# Fetching OpenAlex Author ID for Herta Nagl-Docekal...
# Fetching OpenAlex Author ID for Norman M. Naimark...
# Fetching OpenAlex Author ID for Rumi Nakamura...
# Fetching OpenAlex Author ID for George (Gia) Sch. Nakhutsrishvili...
# Fetching OpenAlex Author ID for Kim A. Nasmyth...
# Fetching OpenAlex Author ID for David Natal Villazala...
# Fetching OpenAlex Author ID for Adolf Neckel...
# Fetching OpenAlex Author ID for Robert Nedoma...
# Fetching OpenAlex Author ID for Wolfgang  Neubauer...
# Fetching OpenAlex Author ID for Christine Neugebauer-Maresch...
# Fetching OpenAlex Author ID for Winfried L. Neuhuber...
# Fetching OpenAlex Author ID for Walter Neupert...
# Fetching OpenAlex Author ID for Gerhard Neweklowsky...
# Fetching OpenAlex Author ID for Stefan Michael Newerkla...
# Fetching OpenAlex Author ID for Harald Niederreiter...
# Fetching OpenAlex Author ID for Christian Roland Noe...
# Fetching OpenAlex Author ID for Magnus Nordborg...
# Fetching OpenAlex Author ID for Dieter Nörr...
# Fetching OpenAlex Author ID for Marie-Louise Nosch...
# Fetching OpenAlex Author ID for Sir Gustav Joseph Victor Nossal...
# Fetching OpenAlex Author ID for Heinrich Nöth...
# Fetching OpenAlex Author ID for Martin A. Nowak...
# Fetching OpenAlex Author ID for Helga Nowotny...
# Fetching OpenAlex Author ID for Onora O'Neill...
# Fetching OpenAlex Author ID for Anna Christina Obenauf...
# Fetching OpenAlex Author ID for Paul Oberhammer...
# Fetching OpenAlex Author ID for Gerhard Oberhammer...
# Fetching OpenAlex Author ID for Dieter Oesterhelt...
# Fetching OpenAlex Author ID for Werner Ogris...
# Fetching OpenAlex Author ID for Oskar Friedrich Olaj...
# Fetching OpenAlex Author ID for Thomas Olechowski...
# Fetching OpenAlex Author ID for Gerhard Opelz...
# Fetching OpenAlex Author ID for Gherardo Ortalli...
# Fetching OpenAlex Author ID for Marcus Ossiander...
# Fetching OpenAlex Author ID for Jurij Sergejewitsch Ossipov...
# Fetching OpenAlex Author ID for Jürgen Osterhammel...
# Fetching OpenAlex Author ID for Jörg A. Ott...
# Fetching OpenAlex Author ID for Alfred E. von Overbeck...
# Fetching OpenAlex Author ID for Peter Palese...
# Fetching OpenAlex Author ID for Herbert Palme...
# Fetching OpenAlex Author ID for Bernhard Palme...
# Fetching OpenAlex Author ID for Jian-Wei Pan...
# Fetching OpenAlex Author ID for Oswald Panagl...
# Fetching OpenAlex Author ID for Lucy Y. Pao...
# Fetching OpenAlex Author ID for Fritz Paschke...
# Fetching OpenAlex Author ID for Gernot Patzelt...
# Fetching OpenAlex Author ID for Josef Penninger...
# Fetching OpenAlex Author ID for Ernst Pernicka...
# Fetching OpenAlex Author ID for Peter Pernthaler...
# Fetching OpenAlex Author ID for Anne Peters...
# Fetching OpenAlex Author ID for Jan-Michael Peters...
# Fetching OpenAlex Author ID for Jillian Petersen...
# Fetching OpenAlex Author ID for Hellmuth Petsche...
# Fetching OpenAlex Author ID for Johann Pfanzagl...
# Fetching OpenAlex Author ID for Gerhard Pferschy...
# Fetching OpenAlex Author ID for Otto Pfersmann...
# Fetching OpenAlex Author ID for Jörg Pfleiderer...
# Fetching OpenAlex Author ID for Gert Pfurtscheller...
# Fetching OpenAlex Author ID for Philip Ivanov Philippov...
# Fetching OpenAlex Author ID for Gernot Piccottini...
# Fetching OpenAlex Author ID for Helmut Pichler...
# Fetching OpenAlex Author ID for Hannes Pichler...
# Fetching OpenAlex Author ID for Pierre Jean Pichot...
# Fetching OpenAlex Author ID for Herbert Pietschmann...
# Fetching OpenAlex Author ID for Werner E. Piller...
# Fetching OpenAlex Author ID for Renate Johanna Pillinger...
# Fetching OpenAlex Author ID for Rudolf Pischinger...
# Fetching OpenAlex Author ID for Clemens Plaschka...
# Fetching OpenAlex Author ID for Carolina Plescia...
# Fetching OpenAlex Author ID for Walter L. Pohl...
# Fetching OpenAlex Author ID for Walter Pohl...
# Fetching OpenAlex Author ID for Hryhoriy Polshyn...
# Fetching OpenAlex Author ID for Marianne Popp...
# Fetching OpenAlex Author ID for Magdalena Pöschl...
# Fetching OpenAlex Author ID for Barbara Prainsack...
# Fetching OpenAlex Author ID for Rudolf Preimesberger...
# Fetching OpenAlex Author ID for Anton Preisinger...
# Fetching OpenAlex Author ID for Friedrich B. Prinz...
# Fetching OpenAlex Author ID for Manfred Prisching...
# Fetching OpenAlex Author ID for Stephan  Procházka...
# Fetching OpenAlex Author ID for Paolo Prodi...
# Fetching OpenAlex Author ID for Walter Puchner...
# Fetching OpenAlex Author ID for Andreas Pülz...
# Fetching OpenAlex Author ID for Denise Pumain...
# Fetching OpenAlex Author ID for Sonja Puntscher Riekmann...
# Fetching OpenAlex Author ID for Gernot Rabeder...
# Fetching OpenAlex Author ID for Ljiljana Radonić...
# Fetching OpenAlex Author ID for Piero Rafanelli...
# Fetching OpenAlex Author ID for Andrej Rahten...
# Fetching OpenAlex Author ID for Franz Rainer...
# Fetching OpenAlex Author ID for Ekkehard Ramm...
# Fetching OpenAlex Author ID for Franz G. Rammerstorfer...
# Fetching OpenAlex Author ID for Friederike Range...
# Fetching OpenAlex Author ID for Claudia Rapp...
# Fetching OpenAlex Author ID for Armando Rastelli...
# Fetching OpenAlex Author ID for Gudrun Rath...
# Fetching OpenAlex Author ID for Isabelle Ratié...
# Fetching OpenAlex Author ID for Helmut Rauch...
# Fetching OpenAlex Author ID for Peter H. Raven...
# Fetching OpenAlex Author ID for Karl M. A. Rawer...
# Fetching OpenAlex Author ID for Katharina Rebay-Salisbury...
# Fetching OpenAlex Author ID for Anton Rebhan...
# Fetching OpenAlex Author ID for Ludwig Reich...
# Fetching OpenAlex Author ID for Ingo Reiffenstein...
# Fetching OpenAlex Author ID for Wolf Uwe Reimold...
# Fetching OpenAlex Author ID for Susanne Reindl-Krauskopf...
# Fetching OpenAlex Author ID for August Reinisch...
# Fetching OpenAlex Author ID for André Reis...
# Fetching OpenAlex Author ID for Elmar R. Reiter...
# Fetching OpenAlex Author ID for Reinhold Remmert...
# Fetching OpenAlex Author ID for Andrew Colin Renfrew...
# Fetching OpenAlex Author ID for Andrea Rentmeister...
# Fetching OpenAlex Author ID for Fritz Resinger...
# Fetching OpenAlex Author ID for Georg Ress...
# Fetching OpenAlex Author ID for Keywan Riahi...
# Fetching OpenAlex Author ID for James R. Rice...
# Fetching OpenAlex Author ID for Kurt R. Richter...
# Fetching OpenAlex Author ID for Norbert G. Riedel...
# Fetching OpenAlex Author ID for Willibald Riedler...
# Fetching OpenAlex Author ID for Josef Riedmann...
# Fetching OpenAlex Author ID for Wolfgang Riehle...
# Fetching OpenAlex Author ID for Gert Riethmüller...
# Fetching OpenAlex Author ID for Wolfgang Rindler...
# Fetching OpenAlex Author ID for Zsigmond Ritoók...
# Fetching OpenAlex Author ID for Monika Ritsch-Marte...
# Fetching OpenAlex Author ID for Olivia Fiona Robinson...
# Fetching OpenAlex Author ID for Alexandra Rodler-Rørbo...
# Fetching OpenAlex Author ID for Teresa Rodríguez de las Heras Ballell...
# Fetching OpenAlex Author ID for Juan Gualterio Roederer...
# Fetching OpenAlex Author ID for Herbert Walter Roesky...
# Fetching OpenAlex Author ID for Robert Rollinger...
# Fetching OpenAlex Author ID for José Luis Romero...
# Fetching OpenAlex Author ID for Maria Grazia Roncarolo...
# Fetching OpenAlex Author ID for Artur Rosenauer...
# Fetching OpenAlex Author ID for Leopold Rosenmayr...
# Fetching OpenAlex Author ID for Michael Rössner...
# Fetching OpenAlex Author ID for Mathias Walter Rotach...
# Fetching OpenAlex Author ID for Carlo Rubbia...
# Fetching OpenAlex Author ID for Helmut O. Rucker...
# Fetching OpenAlex Author ID for Helmut Rumpler...
# Fetching OpenAlex Author ID for Hans Georg Ruppe...
# Fetching OpenAlex Author ID for Günther Rupprechter...
# Fetching OpenAlex Author ID for Eda Sagarra...
# Fetching OpenAlex Author ID for Richard Salomon...
# Fetching OpenAlex Author ID for Roman Sandgruber...
# Fetching OpenAlex Author ID for Friedrich Sandhofer...
# Fetching OpenAlex Author ID for Birgit Sandkaulen...
# Fetching OpenAlex Author ID for Niyazi Serdar Sariçiftçi...
# Fetching OpenAlex Author ID for Michael Sarnthein-Lotichius...
# Fetching OpenAlex Author ID for Pasqualina Maria Sarro...
# Fetching OpenAlex Author ID for Paolo Sartori...
# Fetching OpenAlex Author ID for Friedrich Schaller...
# Fetching OpenAlex Author ID for Gottfried Schatz...
# Fetching OpenAlex Author ID for Philipp  Scheibelreiter...
# Fetching OpenAlex Author ID for Walter Scheidel...
# Fetching OpenAlex Author ID for Eva Schernhammer...
# Fetching OpenAlex Author ID for Rudolf Schieffer...
# Fetching OpenAlex Author ID for Sabine Schindler...
# Fetching OpenAlex Author ID for Philipp Schindler...
# Fetching OpenAlex Author ID for Andrzej Schinzel...
# Fetching OpenAlex Author ID for Wolfgang Schlager...
# Fetching OpenAlex Author ID for Wolfgang P. Schleich...
# Fetching OpenAlex Author ID for Christa Schleper...
# Fetching OpenAlex Author ID for Hermann Schmalzried...
# Fetching OpenAlex Author ID for Klaus Schmidt...
# Fetching OpenAlex Author ID for Wolfgang Schmidt...
# Fetching OpenAlex Author ID for Matthias  Schmidt...
# Fetching OpenAlex Author ID for Johannes Schmidt...
# Fetching OpenAlex Author ID for Alfred Schmidt...
# Fetching OpenAlex Author ID for Arnold Schmidt...
# Fetching OpenAlex Author ID for Ernst August Schmidt...
# Fetching OpenAlex Author ID for Philipp Schmidt-Dengler...
# Fetching OpenAlex Author ID for Ursula Schmidt-Erfurth...
# Fetching OpenAlex Author ID for Sabine Schmidtke...
# Fetching OpenAlex Author ID for Jörg Schmiedmayer...
# Fetching OpenAlex Author ID for Lambert Schmithausen...
# Fetching OpenAlex Author ID for Rüdiger Schmitt...
# Fetching OpenAlex Author ID for Oliver Jens Schmitt...
# Fetching OpenAlex Author ID for Kurt Schmoller...
# Fetching OpenAlex Author ID for Isabel Schnabel...
# Fetching OpenAlex Author ID for Wilhelm Schneider...
# Fetching OpenAlex Author ID for Albrecht Schöne...
# Fetching OpenAlex Author ID for Hans Peter Schönlaub...
# Fetching OpenAlex Author ID for Peter Schönswetter...
# Fetching OpenAlex Author ID for Carl E. Schorske...
# Fetching OpenAlex Author ID for Peter Schreiner...
# Fetching OpenAlex Author ID for Ulrich Schubert...
# Fetching OpenAlex Author ID for Gerold Schuler...
# Fetching OpenAlex Author ID for Rolf Schulte-Hermann...
# Fetching OpenAlex Author ID for Birgitta Schultze-Bernhardt...
# Fetching OpenAlex Author ID for Winfried Schulze...
# Fetching OpenAlex Author ID for Josef Schurz...
# Fetching OpenAlex Author ID for Peter Schuster...
# Fetching OpenAlex Author ID for Gerhard Schütz...
# Fetching OpenAlex Author ID for Sebastian Schütze...
# Fetching OpenAlex Author ID for Hans Schwabl...
# Fetching OpenAlex Author ID for Karlheinz Schwarz...
# Fetching OpenAlex Author ID for Florian Schwarz...
# Fetching OpenAlex Author ID for Hans Georg Schwarzacher...
# Fetching OpenAlex Author ID for Walther Schwarzacher...
# Fetching OpenAlex Author ID for Günter C. Schweiger...
# Fetching OpenAlex Author ID for Fritz Schweiger...
# Fetching OpenAlex Author ID for Michael Schweitzer...
# Fetching OpenAlex Author ID for Dieter Schweizer...
# Fetching OpenAlex Author ID for Hugo Schwendenwein...
# Fetching OpenAlex Author ID for Martin Seger...
# Fetching OpenAlex Author ID for Christian Seidl...
# Fetching OpenAlex Author ID for Horst Seidler...
# Fetching OpenAlex Author ID for Stephan Johannes Seidlmayer...
# Fetching OpenAlex Author ID for Robert  Seiringer...
# Fetching OpenAlex Author ID for Ali Mehmet Celâl Şengör...
# Fetching OpenAlex Author ID for Veronika Sexl...
# Fetching OpenAlex Author ID for Demetra Sfendoni-Mentzou...
# Fetching OpenAlex Author ID for Francesco Sferra...
# Fetching OpenAlex Author ID for Danuta Shanzer...
# Fetching OpenAlex Author ID for M. Rahim Shayegan...
# Fetching OpenAlex Author ID for Ethan M. Shevach...
# Fetching OpenAlex Author ID for Maria Sibilia...
# Fetching OpenAlex Author ID for Susanne Sievers...
# Fetching OpenAlex Author ID for Karl Sigmund...
# Fetching OpenAlex Author ID for Petra Sijpesteijn...
# Fetching OpenAlex Author ID for Oleg Simakov...
# Fetching OpenAlex Author ID for Barry Simon...
# Fetching OpenAlex Author ID for Nicholas Sims-Williams...
# Fetching OpenAlex Author ID for Hans-Werner Sinn...
# Fetching OpenAlex Author ID for Peter Sitte...
# Fetching OpenAlex Author ID for Quentin R. D. Skinner...
# Fetching OpenAlex Author ID for Uwe B. Sleytr...
# Fetching OpenAlex Author ID for John Victor Small...
# Fetching OpenAlex Author ID for Kurt Smolak...
# Fetching OpenAlex Author ID for Josef Smolen...
# Fetching OpenAlex Author ID for Werner Sollors...
# Fetching OpenAlex Author ID for Éva Somogyi...
# Fetching OpenAlex Author ID for Vera T. Sós...
# Fetching OpenAlex Author ID for Nicola Spaldin...
# Fetching OpenAlex Author ID for Katta Spiel...
# Fetching OpenAlex Author ID for Christoph Spötl...
# Fetching OpenAlex Author ID for Hellmuth Stachel...
# Fetching OpenAlex Author ID for Saskia Stachowitsch...
# Fetching OpenAlex Author ID for Peter F. Stadler...
# Fetching OpenAlex Author ID for Lawrence E. Stager...
# Fetching OpenAlex Author ID for Sigrid Stagl...
# Fetching OpenAlex Author ID for André Stahl...
# Fetching OpenAlex Author ID for Maria A. Stassinopoulou...
# Fetching OpenAlex Author ID for Paul Stefanovits...
# Fetching OpenAlex Author ID for Florian  Steger...
# Fetching OpenAlex Author ID for Erwin Stein...
# Fetching OpenAlex Author ID for Sybille Steinbacher...
# Fetching OpenAlex Author ID for Peter Steinhauser...
# Fetching OpenAlex Author ID for Friedrich Franz Steininger...
# Fetching OpenAlex Author ID for Ernst Steinkellner...
# Fetching OpenAlex Author ID for Hans-Peter Steinrück...
# Fetching OpenAlex Author ID for Barbara Stelzl-Marx...
# Fetching OpenAlex Author ID for Günter Stemberger...
# Fetching OpenAlex Author ID for Stig T. Stenholm...
# Fetching OpenAlex Author ID for Nikolaus K. Stephanidis...
# Fetching OpenAlex Author ID for Peter Štih...
# Fetching OpenAlex Author ID for Georg Stingl...
# Fetching OpenAlex Author ID for Gerold Stoll...
# Fetching OpenAlex Author ID for Barbara Stollberg-Rilinger...
# Fetching OpenAlex Author ID for Gerald Stourzh...
# Fetching OpenAlex Author ID for Helmut Strasser...
# Fetching OpenAlex Author ID for Erich Wolfgang Streissler...
# Fetching OpenAlex Author ID for Jörg Striessnig...
# Fetching OpenAlex Author ID for Josef Strobl...
# Fetching OpenAlex Author ID for Arno Strohmeyer...
# Fetching OpenAlex Author ID for Tod F. Stuessy...
# Fetching OpenAlex Author ID for Christian Sturmbauer...
# Fetching OpenAlex Author ID for Robert Samuel Summers...
# Fetching OpenAlex Author ID for Hans Sünkel...
# Fetching OpenAlex Author ID for Giulio Superti-Furga...
# Fetching OpenAlex Author ID for Arnold Suppan...
# Fetching OpenAlex Author ID for Ernst Christoph Suttner...
# Fetching OpenAlex Author ID for Gustav Andreas Tammann...
# Fetching OpenAlex Author ID for Elly Tanaka...
# Fetching OpenAlex Author ID for Éva Tardos...
# Fetching OpenAlex Author ID for Ulrich Technau...
# Fetching OpenAlex Author ID for Jaroslav Tejral...
# Fetching OpenAlex Author ID for Werner Telesko...
# Fetching OpenAlex Author ID for Heinz-Elmar Tenorth...
# Fetching OpenAlex Author ID for Erich Thenius...
# Fetching OpenAlex Author ID for Udo Thiel...
# Fetching OpenAlex Author ID for Gerhard Thür...
# Fetching OpenAlex Author ID for Robert F. Tichy...
# Fetching OpenAlex Author ID for Klement Tockner...
# Fetching OpenAlex Author ID for Theodor Tomandl...
# Fetching OpenAlex Author ID for Erich Trapp...
# Fetching OpenAlex Author ID for Dirk Trauner...
# Fetching OpenAlex Author ID for Michael Trauner...
# Fetching OpenAlex Author ID for Marko Trogrlić...
# Fetching OpenAlex Author ID for Hans Tuppy...
# Fetching OpenAlex Author ID for Franz-Josef Ulm...
# Fetching OpenAlex Author ID for Melanie Unseld...
# Fetching OpenAlex Author ID for Miriam M. Unterlass...
# Fetching OpenAlex Author ID for Gerald Urban...
# Fetching OpenAlex Author ID for Otto Helmut Urban...
# Fetching OpenAlex Author ID for Boris A. Uspenskij...
# Fetching OpenAlex Author ID for Gerd W. Utermann...
# Fetching OpenAlex Author ID for Alice Vadrot...
# Fetching OpenAlex Author ID for Rudolf Valenta...
# Fetching OpenAlex Author ID for Peter van Nieuwenhuizen...
# Fetching OpenAlex Author ID for Mihai-Cristian Vasile...
# Fetching OpenAlex Author ID for Michael Johannes Vellekoop...
# Fetching OpenAlex Author ID for Beatriz Vicoso...
# Fetching OpenAlex Author ID for Karl Vodrazka...
# Fetching OpenAlex Author ID for Thomas Vogl...
# Fetching OpenAlex Author ID for Arndt von Haeseler...
# Fetching OpenAlex Author ID for Klaus von Klitzing...
# Fetching OpenAlex Author ID for Alfred Wagenhofer...
# Fetching OpenAlex Author ID for Horst Wagner...
# Fetching OpenAlex Author ID for Andreas  Wagner...
# Fetching OpenAlex Author ID for Günter P. Wagner...
# Fetching OpenAlex Author ID for Karl Wagner...
# Fetching OpenAlex Author ID for Sigurd Wagner...
# Fetching OpenAlex Author ID for Erwin F. Wagner...
# Fetching OpenAlex Author ID for Michael Wagner...
# Fetching OpenAlex Author ID for Birgit Wagner...
# Fetching OpenAlex Author ID for Scott Waitukaitis...
# Fetching OpenAlex Author ID for Wolfgang A. Wall...
# Fetching OpenAlex Author ID for Grete Walter-Klingenstein...
# Fetching OpenAlex Author ID for Heinrich Wänke...
# Fetching OpenAlex Author ID for Graham Warren...
# Fetching OpenAlex Author ID for Peter Michael Warren...
# Fetching OpenAlex Author ID for Andrea Weber...
# Fetching OpenAlex Author ID for Harald Wolfgang Weber...
# Fetching OpenAlex Author ID for Gerhard Wegner...
# Fetching OpenAlex Author ID for Rüdiger Wehner...
# Fetching OpenAlex Author ID for Susanne Weigelin-Schwiedrzik...
# Fetching OpenAlex Author ID for Stefan Weinfurter...
# Fetching OpenAlex Author ID for Astrid Weiss...
# Fetching OpenAlex Author ID for Günter Weiss...
# Fetching OpenAlex Author ID for Werner Welzig...
# Fetching OpenAlex Author ID for Emo Welzl...
# Fetching OpenAlex Author ID for Christiane Wendehorst...
# Fetching OpenAlex Author ID for Samuel A. Werner...
# Fetching OpenAlex Author ID for Diter von Wettstein...
# Fetching OpenAlex Author ID for Manfred Wicke...
# Fetching OpenAlex Author ID for Gerhard Widmer...
# Fetching OpenAlex Author ID for Ewald Wiederin...
# Fetching OpenAlex Author ID for Maria Katharina  Wiedlack...
# Fetching OpenAlex Author ID for Malcolm Hewitt Wiener...
# Fetching OpenAlex Author ID for Josef Wiesehöfer...
# Fetching OpenAlex Author ID for Wolfgang Wieser...
# Fetching OpenAlex Author ID for Heinz Gregor Wieser...
# Fetching OpenAlex Author ID for Michaela Wiesinger...
# Fetching OpenAlex Author ID for Peter Wiesinger...
# Fetching OpenAlex Author ID for Luzius Wildhaber...
# Fetching OpenAlex Author ID for Günther Wilke...
# Fetching OpenAlex Author ID for F. Ludwig Wilke...
# Fetching OpenAlex Author ID for Jürgen Wilke...
# Fetching OpenAlex Author ID for Harco Willems...
# Fetching OpenAlex Author ID for Anouk Willemsen...
# Fetching OpenAlex Author ID for Michaela Windischgrätz...
# Fetching OpenAlex Author ID for Verena Winiwarter...
# Fetching OpenAlex Author ID for Thomas Winkelbauer...
# Fetching OpenAlex Author ID for Hans Winkler...
# Fetching OpenAlex Author ID for Georg Winter...
# Fetching OpenAlex Author ID for Renée Winter...
# Fetching OpenAlex Author ID for Erich Winter...
# Fetching OpenAlex Author ID for Irene J. Winter...
# Fetching OpenAlex Author ID for Gerhard Wirth...
# Fetching OpenAlex Author ID for Norbert Richard Wolf...
# Fetching OpenAlex Author ID for Alois Wolf...
# Fetching OpenAlex Author ID for Eckhard Wolf...
# Fetching OpenAlex Author ID for Werner Wolf...
# Fetching OpenAlex Author ID for Ulrich Wolf...
# Fetching OpenAlex Author ID for Klaus Wolff...
# Fetching OpenAlex Author ID for Herwig Wolfram...
# Fetching OpenAlex Author ID for Bernhard Woytek...
# Fetching OpenAlex Author ID for Dagmar Wujastyk...
# Fetching OpenAlex Author ID for Keizô Yamamoto...
# Fetching OpenAlex Author ID for Yeong-Bin Yang...
# Fetching OpenAlex Author ID for William Edgar Yates...
# Fetching OpenAlex Author ID for Bilge Yıldız...
# Fetching OpenAlex Author ID for Stephen G. Young...
# Fetching OpenAlex Author ID for Waldemar Zacharasiewicz...
# Fetching OpenAlex Author ID for Hans Georg Zachau...
# Fetching OpenAlex Author ID for Anatoly G. Zagorodny...
# Fetching OpenAlex Author ID for Kurt Zatloukal...
# Fetching OpenAlex Author ID for Josef Zechner...
# Fetching OpenAlex Author ID for Rudolf Zechner...
# Fetching OpenAlex Author ID for Anton Zeilinger...
# Fetching OpenAlex Author ID for Josef Zemann...
# Fetching OpenAlex Author ID for Wolfgang Zenker...
# Fetching OpenAlex Author ID for Michael Zgurovsky...
# Fetching OpenAlex Author ID for Yong-de Zhang...
# Fetching OpenAlex Author ID for Shuguang Zhang...
# Fetching OpenAlex Author ID for Franz Ziegler...
# Fetching OpenAlex Author ID for Peter V. Zima...
# Fetching OpenAlex Author ID for Reinhard Zimmermann...
# Fetching OpenAlex Author ID for Harald Volkmar Zimmermann...
# Fetching OpenAlex Author ID for Michel Zink...
# Fetching OpenAlex Author ID for Ernst K. Zinner...
# Fetching OpenAlex Author ID for Natalia A. Zinovieva...
# Fetching OpenAlex Author ID for Theodore J. Ziolkowski...
# Fetching OpenAlex Author ID for Jan M. Ziolkowski...
# Fetching OpenAlex Author ID for Peter Zoller...
# Fetching OpenAlex Author ID for Alessandro Zuccari...
# Fetching OpenAlex Author ID for Paul Michael Zulehner...
# Author IDs saved to 'austrian_academy_author_ids.json'.
# Author IDs also saved to 'austrian_academy_author_ids.csv'.

# %%
import requests
import json
import time

# Input and output file paths
input_file = "/content/austrian_academy_author_ids.json"  # Replace with your actual file path
output_file = "austrian_academy_members_with_indices.json"  # File to save the updated data

# OpenAlex base API URL
openalex_base_url = "https://api.openalex.org"

# Function to fetch H-index and I10-index for an author
def fetch_author_metrics(author_id):
    url = f"{openalex_base_url}/authors/{author_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        h_index = data.get("summary_stats", {}).get("h_index", None)
        i10_index = data.get("summary_stats", {}).get("i10_index", None)
        return h_index, i10_index
    else:
        print(f"Error fetching data for author {author_id}: {response.status_code}")
        return None, None

# Load the existing JSON file
with open(input_file, "r") as infile:
    members = json.load(infile)

# Process each member and fetch H-index and I10-index
for member in members:
    openalex_ids = member.get("openalex_id")
    if isinstance(openalex_ids, list):
        # Initialize variables to aggregate metrics
        h_indices = []
        i10_indices = []
        for openalex_id in openalex_ids:
            author_id = openalex_id.split("/")[-1]  # Extract author ID
            h_index, i10_index = fetch_author_metrics(author_id)
            if h_index is not None:
                h_indices.append(h_index)
            if i10_index is not None:
                i10_indices.append(i10_index)
            time.sleep(1)  # Respect API rate limits

        # Aggregate indices (e.g., take maximum values)
        member["h_index"] = max(h_indices) if h_indices else None
        member["i10_index"] = max(i10_indices) if i10_indices else None

    elif isinstance(openalex_ids, str):
        author_id = openalex_ids.split("/")[-1]  # Extract author ID
        h_index, i10_index = fetch_author_metrics(author_id)
        member["h_index"] = h_index
        member["i10_index"] = i10_index
        time.sleep(1)  # Respect API rate limits
    else:
        print(f"No OpenAlex ID for {member['name']}. Skipping...")
        member["h_index"] = None
        member["i10_index"] = None

# Save the updated JSON with indices
with open(output_file, "w") as outfile:
    json.dump(members, outfile, indent=4)

print(f"H-index and I10-index added and saved to {output_file}")
# Out:
# No OpenAlex ID for Paul Albert Blanz. Skipping...
# No OpenAlex ID for Georg Peter Braulik. Skipping...
# No OpenAlex ID for Alejandro Raul Burga Ramos. Skipping...
# No OpenAlex ID for Igor Bert Dawid. Skipping...
# No OpenAlex ID for Ernst Peter Michael Dronke. Skipping...
# No OpenAlex ID for Günter Bernhard L. Fettweis. Skipping...
# No OpenAlex ID for Monika Gehrig-Merz. Skipping...
# No OpenAlex ID for Karl-Heinz Alois Glaßmeier. Skipping...
# No OpenAlex ID for Hermann Franz Haupt. Skipping...
# No OpenAlex ID for Ivo Ludwig Hofacker. Skipping...
# No OpenAlex ID for Reinhard Franz Josef Hüttl. Skipping...
# No OpenAlex ID for Stephen Ira Katz. Skipping...
# No OpenAlex ID for Anke Rita Kaysser-Pyzalla. Skipping...
# No OpenAlex ID for Bernd Ulrich Kluge. Skipping...
# No OpenAlex ID for Ernst August Kramer. Skipping...
# No OpenAlex ID for Vasileios Lambrinoudakis. Skipping...
# No OpenAlex ID for Gene Elden Likens. Skipping...
# No OpenAlex ID for Richard Viktor Mattessich. Skipping...
# No OpenAlex ID for George (Gia) Sch. Nakhutsrishvili. Skipping...
# No OpenAlex ID for Sir Gustav Joseph Victor Nossal. Skipping...
# No OpenAlex ID for Jurij Sergejewitsch Ossipov. Skipping...
# No OpenAlex ID for Karl M. A. Rawer. Skipping...
# No OpenAlex ID for Fritz Resinger. Skipping...
# No OpenAlex ID for Olivia Fiona Robinson. Skipping...
# No OpenAlex ID for Herbert Walter Roesky. Skipping...
# No OpenAlex ID for Michael Sarnthein-Lotichius. Skipping...
# No OpenAlex ID for Birgitta Schultze-Bernhardt. Skipping...
# No OpenAlex ID for Günter C. Schweiger. Skipping...
# No OpenAlex ID for Paul Stefanovits. Skipping...
# No OpenAlex ID for Friedrich Franz Steininger. Skipping...
# No OpenAlex ID for Erich Wolfgang Streissler. Skipping...
# No OpenAlex ID for Gerd W. Utermann. Skipping...
# No OpenAlex ID for Mihai-Cristian Vasile. Skipping...
# No OpenAlex ID for Grete Walter-Klingenstein. Skipping...
# No OpenAlex ID for Peter Michael Warren. Skipping...
# No OpenAlex ID for Harald Wolfgang Weber. Skipping...
# No OpenAlex ID for Malcolm Hewitt Wiener. Skipping...
# No OpenAlex ID for Michaela Windischgrätz. Skipping...
# No OpenAlex ID for William Edgar Yates. Skipping...
# No OpenAlex ID for Harald Volkmar Zimmermann. Skipping...
# H-index and I10-index added and saved to austrian_academy_members_with_indices.json

# %%
import requests
import json
import time
import os

# Input and output file paths
input_file = "/content/austrian_academy_members_with_indices.json"  # Replace with your actual file path
output_file = "austrian_academy_works.json"  # File to save the detailed works data
progress_file = "progress_log2.json"  # Save progress to resume if interrupted

# OpenAlex base API URL
openalex_base_url = "https://api.openalex.org"

# Function to fetch works for an author
def fetch_author_works(author_id):
    works = []
    page = 1
    while True:
        try:
            url = f"{openalex_base_url}/works?filter=author.id:{author_id}&per-page=200&page={page}"
            response = requests.get(url, timeout=30)
            response.raise_for_status()  # Raise an exception for HTTP errors
            data = response.json()

            works.extend(data.get("results", []))
            if "next" not in data.get("meta", {}):
                break

            page += 1
            time.sleep(1)  # Respect API rate limits
        except requests.exceptions.RequestException as e:
            print(f"Error fetching works for author {author_id} on page {page}: {e}")
            break
    return works

# Resume or start fresh
if os.path.exists(progress_file):
    with open(progress_file, "r") as file:
        processed_authors = json.load(file)
else:
    processed_authors = {}

# Load the existing JSON file
with open(input_file, "r") as infile:
    members = json.load(infile)

# Fetch works for each author
all_works = []
for member in members:
    openalex_ids = member.get("openalex_id")
    if isinstance(openalex_ids, list):
        for openalex_id in openalex_ids:
            author_id = openalex_id.split("/")[-1]  # Extract author ID
            if author_id not in processed_authors:
                print(f"Fetching works for {member['name']} ({author_id})...")
                works = fetch_author_works(author_id)
                all_works.extend(works)
                processed_authors[author_id] = True
                # Save progress after each author
                with open(progress_file, "w") as file:
                    json.dump(processed_authors, file, indent=4)
    elif isinstance(openalex_ids, str):
        author_id = openalex_ids.split("/")[-1]  # Extract author ID
        if author_id not in processed_authors:
            print(f"Fetching works for {member['name']} ({author_id})...")
            works = fetch_author_works(author_id)
            all_works.extend(works)
            processed_authors[author_id] = True
            # Save progress after each author
            with open(progress_file, "w") as file:
                json.dump(processed_authors, file, indent=4)
    else:
        print(f"No OpenAlex ID for {member['name']}. Skipping...")

# Save the works data to a JSON file
with open(output_file, "w") as outfile:
    json.dump(all_works, outfile, indent=4)

print(f"Works data with full details saved to {output_file}.")

# Clean up the progress log file if processing is complete
if len(processed_authors) == len(members):
    os.remove(progress_file)
# Out:
# Fetching works for Rainer Abart (A5011048858)...
# Fetching works for Karl Acham (A5033657966)...
# Fetching works for Antal Ádám (A5112833742)...
# Fetching works for Ludwig Adamovich (A5023385566)...
# Fetching works for Timon Erik Adolph (A5036264788)...
# Fetching works for Alícia Adserà (A5041559404)...
# Fetching works for Adriano Aguzzi (A5026438561)...
# Fetching works for Josef Aicher (A5051024997)...
# Fetching works for Martin Aigner (A5012929183)...
# Fetching works for Luciana Aigner-Foresti (A5002107112)...
# Fetching works for Brenda Almond (A5113839426)...
# Fetching works for Michael Alram (A5000633744)...
# Fetching works for Eva Alram-Stern (A5006887627)...
# Fetching works for Carlos Alvar Ezquerra (A5051009435)...
# Fetching works for João Alves (A5015547149)...
# Fetching works for Michel Amandry (A5001874471)...
# Fetching works for Petra Amann (A5071971627)...
# Fetching works for Brigitta Ammann (A5073355683)...
# Fetching works for Angelika Amon (A5006607755)...
# Fetching works for Bertil Andersson (A5110020851)...
# Fetching works for Bernard Andreae (A5072970731)...
# Fetching works for Anaïs  Angelo (A5063424732)...
# Fetching works for Flavio Anselmetti (A5046101937)...
# Fetching works for Leah Armstrong (A5035831793)...
# Fetching works for Markus Arndt (A5024069530)...
# Fetching works for Eduard Arzt (A5083348656)...
# Fetching works for Alain Aspect (A5046427077)...
# Fetching works for Markus Aspelmeyer (A5073463154)...
# Fetching works for Aleida Assmann (A5023553870)...
# Fetching works for Alice Auersperg (A5052062558)...
# Fetching works for Hans Aurenhammer (A5090448541)...
# Fetching works for Manuela Baccarini (A5034688668)...
# Fetching works for Andrea Bachmaier (A5017010102)...
# Fetching works for Auksė Balčytienė (A5011426144)...
# Fetching works for Andrius Baltuška (A5054560855)...
# Fetching works for Albert-László Barabási (A5038976962)...
# Fetching works for Andrea Barta (A5053377425)...
# Fetching works for Friedrich G. Barth (A5044378994)...
# Fetching works for Hans Basbøll (A5110280659)...
# Fetching works for Rainer Bauböck (A5065528439)...
# Fetching works for Bernhard Bauer (A5033747033)...
# Fetching works for Siegfried J. Bauer (A5015767289)...
# Fetching works for Friedrich L. Bauer (A5110048520)...
# Fetching works for Günther Bauer (A5061419535)...
# Fetching works for Wolfgang Baumjohann (A5070639192)...
# Fetching works for Zdeněk P. Bažant (A5111409797)...
# Fetching works for Alexander K.  Belyaev (A5066340431)...
# Fetching works for Robert John Bennett (A5018761236)...
# Fetching works for Iván T. Berend (A5060381012)...
# Fetching works for Walter Berka (A5086994708)...
# Fetching works for Walter Berschin (A5014354488)...
# Fetching works for Pier Marco Bertinetto (A5006927662)...
# Fetching works for Reinhold Bichler (A5009583024)...
# Fetching works for Manfred Bietak (A5051816874)...
# Fetching works for Francesco C. Billari (A5050698435)...
# Fetching works for Kurt Binder (A5037753080)...
# Fetching works for Michal Biran (A5024036616)...
# Fetching works for Helmut Birkhan (A5090647574)...
# Fetching works for Paul Albert Blanz (A5110405968)...
# Fetching works for Thomas Blaschke (A5056842687)...
# Fetching works for Jean-Pierre Blaser (A5051650028)...
# Fetching works for Rainer Blatt (A5040977712)...
# Fetching works for Helen M. Blau (A5081185233)...
# Fetching works for Horst Bleckmann (A5010446731)...
# Fetching works for Günter Blöschl (A5015678021)...
# Fetching works for Hans-Heinrich Blotevogel (A5038611288)...
# Fetching works for Christoph Bock (A5059183480)...
# Fetching works for Michael Joachim Bonell (A5112719621)...
# Fetching works for Jürgen Borchhardt (A5112815939)...
# Fetching works for Włodzimierz Borodziej (A5058429606)...
# Fetching works for Axel Börsch-Supan (A5074054769)...
# Fetching works for Axel Borsdorf (A5054561217)...
# Fetching works for Richard Bösel (A5046817711)...
# Fetching works for Jacques Bouveresse (A5065599990)...
# Fetching works for John W. Boyer (A5044223487)...
# Fetching works for Kaan Boztug (A5048616194)...
# Fetching works for Karl Dietrich Bracher (A5065715048)...
# Fetching works for Peter Brang (A5001103795)...
# Fetching works for Georg Brasseur (A5112819986)...
# Fetching works for Achim Brauer (A5002738445)...
# Fetching works for Georg Peter Braulik (A5082040297)...
# Fetching works for Jürgen Braunstein (A5110044432)...
# Fetching works for Michel Breger (A5050076167)...
# Fetching works for Gottfried Brem (A5074484140)...
# Fetching works for Jan N. Bremmer (A5067279502)...
# Fetching works for Wolfgang H. Breunlich (A5043730147)...
# Fetching works for Wolfgang Brezinka (A5080463894)...
# Fetching works for Hans Briegel (A5009007803)...
# Fetching works for Günter Brucher (A5067148351)...
# Fetching works for Gerhart Bruckmann (A5029293747)...
# Fetching works for Ernst Bruckmüller (A5018325459)...
# Fetching works for Wolfgang Brückner (A5007349500)...
# Fetching works for Gerhard Budin (A5088546447)...
# Fetching works for Julia Budka (A5044265620)...
# Fetching works for Alejandro Raul Burga Ramos (A5082494880)...
# Fetching works for Joachim Burgdörfer (A5022205449)...
# Fetching works for Manfred Burgstaller (A5033621282)...
# Fetching works for Otto Burkard (A5027250076)...
# Fetching works for Walter Burkert (A5077244902)...
# Fetching works for Meinrad Busslinger (A5062558133)...
# Fetching works for Vladimír Bužek (A5061320944)...
# Fetching works for Peter Bydlinski (A5028938703)...
# Fetching works for Claus-Wilhelm Canaris (A5049437732)...
# Fetching works for Carmen Cardelle de Hartmann (A5026885877)...
# Fetching works for Louis Carlen (A5044113968)...
# Fetching works for Giovanni Battista Castiglioni (A5014314620)...
# Fetching works for Marina Cattaruzza (A5103784143)...
# Fetching works for Federico Celestini (A5088674166)...
# Fetching works for Komaravolu Chandrasekharan (A5108186695)...
# Fetching works for Emmanuelle Charpentier (A5074743574)...
# Fetching works for Mark W. Chase (A5084143562)...
# Fetching works for Hai Cheng (A5023065107)...
# Fetching works for Kenneth R. Chien (A5107559060)...
# Fetching works for Maria Christakis (A5064181052)...
# Fetching works for Enno Christophers (A5010643311)...
# Fetching works for Evangelos Chrysos (A5020457358)...
# Fetching works for Johann Cigler (A5000249606)...
# Fetching works for Ignacio J. Cirac (A5083228566)...
# Fetching works for Christopher M. Clark (A5101652614)...
# Fetching works for Gary B. Cohen (A5109397234)...
# Fetching works for Adrian Constantin (A5010200247)...
# Fetching works for Michael P. Conzen (A5058087176)...
# Fetching works for Paul Corkum (A5057695025)...
# Fetching works for Thomas Corsten (A5067189322)...
# Fetching works for Moritz Csáky (A5037737600)...
# Fetching works for Christa Cuchiero (A5069510245)...
# Fetching works for Yasin Dagdas (A5015661318)...
# Fetching works for Falko Daim (A5073894814)...
# Fetching works for Joachim Dalfen (A5028071404)...
# Fetching works for Georg Danek (A5091826093)...
# Fetching works for Robert Danzer (A5033867562)...
# Fetching works for Lorraine Daston (A5059333899)...
# Fetching works for Elisa  Davoli (A5006393097)...
# Fetching works for Igor Bert Dawid (A5064390918)...
# Fetching works for Patrizia de Bernardo Stempel (A5015518076)...
# Fetching works for Gemma De les Coves (A5048415705)...
# Fetching works for Bruno De Nicola (A5039397968)...
# Fetching works for Nicla  De Zorzi (A5043334177)...
# Fetching works for Peter Deetjen (A5070703850)...
# Fetching works for Gerhard Dehm (A5075439885)...
# Fetching works for Stefanie Dehnen (A5076273697)...
# Fetching works for Manfred Deistler (A5087072346)...
# Fetching works for Agnes Dellinger (A5035649657)...
# Fetching works for Alexander Demandt (A5003675158)...
# Fetching works for Helmut Denk (A5072719639)...
# Fetching works for Barry J. Dickson (A5039360877)...
# Fetching works for Ulrike Diebold (A5084801808)...
# Fetching works for Egbert Dierker (A5023075841)...
# Fetching works for Cora Dietl (A5079869449)...
# Fetching works for Nina A. Dmitrieva (A5040432560)...
# Fetching works for Gerhard Dobesch (A5072149251)...
# Fetching works for Gabriele Doblhammer-Reiter (A5010854987)...
# Fetching works for Liam Dolan (A5010683652)...
# Fetching works for Rafael Domingo (A5016220971)...
# Fetching works for Michael Doneus (A5080871742)...
# Fetching works for Friedrich Dorner (A5108403840)...
# Fetching works for Claudia Draxl (A5053264793)...
# Fetching works for Wolfgang Ulrich Dressler (A5019847073)...
# Fetching works for Michael Drmota (A5107303472)...
# Fetching works for Ernst Peter Michael Dronke (A5069325251)...
# Fetching works for Heinz Duchhardt (A5023238896)...
# Fetching works for Klaus Düwel (A5037545408)...
# Fetching works for Friedrich Dydak (A5112048983)...
# Fetching works for Katarzyna Dziubalska-Kołaczyk (A5005084025)...
# Fetching works for Josef Eberhardsteiner (A5005567486)...
# Fetching works for Jürgen Eckert (A5028967959)...
# Fetching works for Herbert Edelsbrunner (A5069999967)...
# Fetching works for Hubert Christian Ehalt (A5010552047)...
# Fetching works for Friedrich Ehrendorfer (A5087434648)...
# Fetching works for Martin Ehrendorfer (A5015481845)...
# Fetching works for Bernhard Ehrenzeller (A5076929521)...
# Fetching works for Ludwig M. Eichinger (A5105784249)...
# Fetching works for Michael Eichmair (A5060571568)...
# Fetching works for Heiner Eichner (A5009194033)...
# Fetching works for Manfred Eigen (A5086771096)...
# Fetching works for Manfred Einsiedler (A5009126028)...
# Fetching works for Thomas Eiter (A5082178480)...
# Fetching works for Ivar Ekeland (A5081322539)...
# Fetching works for Wilfried Ellmeier (A5015207334)...
# Fetching works for Vincent Eltschinger (A5048018970)...
# Fetching works for Heinz Engl (A5001179074)...
# Fetching works for Johannes Erben (A5089748701)...
# Fetching works for László Erdös (A5087712027)...
# Fetching works for Gerhard Ertl (A5010170160)...
# Fetching works for Maria J. Esteban (A5102782834)...
# Fetching works for Richard John Evans (A5040359852)...
# Fetching works for Robert John Weston Evans (A5057897302)...
# Fetching works for Itamar Even-Zohar (A5082196497)...
# Fetching works for Ludwig D. Faddeev (A5113503178)...
# Fetching works for Heinz Falk (A5083247823)...
# Fetching works for Gerda Falkner (A5108076938)...
# Fetching works for Reinhard Fässler (A5112467058)...
# Fetching works for Heinz Faßmann (A5000197903)...
# Fetching works for Bénédicte Fauvarque-Cosson (A5040418630)...
# Fetching works for Ernst Fehr (A5023874785)...
# Fetching works for Gustav Feichtinger (A5046894948)...
# Fetching works for Johannes Feichtinger (A5110433364)...
# Fetching works for Martin S. Feldstein (A5108406018)...
# Fetching works for Hannes A. Fellner (A5018982632)...
# Fetching works for Sebastian Felten (A5051839083)...
# Fetching works for Francesca Ferlaino (A5055944638)...
# Fetching works for Günter Bernhard L. Fettweis (A5062333504)...
# Fetching works for Günter Bernhard L. Fettweis (A5007736247)...
# Fetching works for Ingeborg Fiala-Fürst (A5066132147)...
# Fetching works for Wolfgang Fichtner (A5103643964)...
# Fetching works for Hermann Fillitz (A5027319860)...
# Fetching works for Jörg Finsinger (A5019229324)...
# Fetching works for Andrea Fischer (A5008014164)...
# Fetching works for Peter Fischer (A5085560065)...
# Fetching works for Manfred M. Fischer (A5037982517)...
# Fetching works for Hellmut F. Fischmeister (A5044545272)...
# Fetching works for Jürgen Fleig (A5058689847)...
# Fetching works for Konstanze Fliedl (A5060940674)...
# Fetching works for August Florian (A5108801860)...
# Fetching works for Rudolf Flotzinger (A5083914270)...
# Fetching works for Monika Fludernik (A5001755929)...
# Fetching works for Helmut Flügel (A5007811388)...
# Fetching works for Franz Födermayr (A5069713872)...
# Fetching works for Pál Fodor (A5047614074)...
# Fetching works for Herbert Foltinek (A5057193607)...
# Fetching works for Sebastian  Forster (A5053481668)...
# Fetching works for Heinz G. Fortak (A5060671173)...
# Fetching works for Bert Fragner (A5035125792)...
# Fetching works for Wolfgang Frank (A5049859337)...
# Fetching works for Peter Robert Franke (A5049228679)...
# Fetching works for Peter Fratzl (A5025231754)...
# Fetching works for Stefan Freunberger (A5039467561)...
# Fetching works for Johannes Fried (A5112728154)...
# Fetching works for Herwig Friesinger (A5017104930)...
# Fetching works for Wolfgang Frisch (A5034708066)...
# Fetching works for Sylvia Frühwirth-Schnatter (A5051060321)...
# Fetching works for Erwin Führer (A5045381873)...
# Fetching works for Alexia Fürnkranz-Prskawetz (A5040666917)...
# Fetching works for Alois Fürstner (A5054667122)...
# Fetching works for Helmut Gadner (A5012680652)...
# Fetching works for Natalia Gagarina (A5018953834)...
# Fetching works for Franz Gamillscheg (A5028231237)...
# Fetching works for Thomas V. Gamkrelidze (A5073036578)...
# Fetching works for Hans-Martin Gauger (A5034906925)...
# Fetching works for Patrick J. Geary (A5022605300)...
# Fetching works for Michael Gehler (A5073388044)...
# Fetching works for Monika Gehrig-Merz (A5016991951)...
# Fetching works for Johannes Geiss (A5112518716)...
# Fetching works for Klaus Gersten (A5034299629)...
# Fetching works for Martin H. Gerzabek (A5067373281)...
# Fetching works for Michael Ghil (A5045772011)...
# Fetching works for Patrizia Giampieri-Deutsch (A5086462839)...
# Fetching works for Gerhard Giebisch (A5021311035)...
# Fetching works for Oswald Giering (A5005360266)...
# Fetching works for Simone Gingrich (A5003541186)...
# Fetching works for Andre Gingrich (A5112801293)...
# Fetching works for Karl-Heinz Alois Glaßmeier (A5050972930)...
# Fetching works for Gerhard Glatzel (A5081161618)...
# Fetching works for Claire F. Gmachl (A5061195967)...
# Fetching works for Michael  Gnant (A5025718393)...
# Fetching works for Helmut Gneuss (A5050626745)...
# Fetching works for Hans Goebl (A5044859717)...
# Fetching works for Ivan Golub (A5000416530)...
# Fetching works for Leticia González (A5008682258)...
# Fetching works for Maciej Górny (A5024512518)...
# Fetching works for Georg Gottlob (A5050151740)...
# Fetching works for Georg Grabherr (A5054669595)...
# Fetching works for Sherrill Grace (A5035502862)...
# Fetching works for Bernhard Grasemann (A5004948928)...
# Fetching works for Manfred Grasserbauer (A5012370997)...
# Fetching works for Daniel M. Greenberger (A5072498937)...
# Fetching works for Wolfgang Greisenegger (A5098167548)...
# Fetching works for Frantz Grenet (A5082942764)...
# Fetching works for Herfried Griengl (A5066680924)...
# Fetching works for Nicolas Grimal (A5026500312)...
# Fetching works for Rudolf Grimm (A5070127639)...
# Fetching works for Irmgard Griss (A5089861688)...
# Fetching works for Jasmina Grković-Major (A5069680740)...
# Fetching works for Rudolf Grosschedl (A5022682784)...
# Fetching works for Peter Manfred Gruber (A5110086698)...
# Fetching works for Gernot Gruber (A5112895353)...
# Fetching works for Oskar Grün (A5041528241)...
# Fetching works for Dieter Gutknecht (A5027476532)...
# Fetching works for Giselher Guttmann (A5031999577)...
# Fetching works for Mats Gyllenberg (A5054771020)...
# Fetching works for Kálmán Györgyi (A5075872476)...
# Fetching works for Rudolf Haag (A5072387672)...
# Fetching works for Gerhard Haerendel (A5038781444)...
# Fetching works for Stefan Hagel (A5063157240)...
# Fetching works for Othmar Hageneder (A5051669853)...
# Fetching works for Martin Hairer (A5016315238)...
# Fetching works for Ivo Hajnal (A5018332836)...
# Fetching works for John Haldon (A5090719333)...
# Fetching works for Max Haller (A5015201390)...
# Fetching works for Franz Halter-Koch (A5048462844)...
# Fetching works for Ernst Hanisch (A5088706023)...
# Fetching works for Ulf Hannerz (A5062218718)...
# Fetching works for Edouard Hannezo (A5027982101)...
# Fetching works for Christian Hannick (A5086264901)...
# Fetching works for Aage A. Hansen-Löve (A5016001862)...
# Fetching works for Michael Hantel (A5091865248)...
# Fetching works for Jens-Uwe Hartmann (A5052562050)...
# Fetching works for Maximilian Hartmuth (A5019924075)...
# Fetching works for Mathias Harzhauser (A5020527084)...
# Fetching works for Horst Haselsteiner (A5077025518)...
# Fetching works for Günther Hasinger (A5046987116)...
# Fetching works for Friederike Hassauer (A5078668006)...
# Fetching works for Wolfgang Haubrichs (A5012677480)...
# Fetching works for Gabriele Haug-Moritz (A5007133550)...
# Fetching works for Hermann Franz Haupt (A5049310670)...
# Fetching works for Uta Heil (A5000768937)...
# Fetching works for Wolf-Dieter Heiss (A5103054193)...
# Fetching works for Philipp U. Heitz (A5108231597)...
# Fetching works for Christian Hellmich (A5001867769)...
# Fetching works for Gilbert Helmberg (A5048560104)...
# Fetching works for Monika Henzinger (A5003641345)...
# Fetching works for Thomas A. Henzinger (A5080555605)...
# Fetching works for Milan Herak (A5088834932)...
# Fetching works for Gerhard Herndl (A5030545362)...
# Fetching works for Marie Louise Herzfeld-Schild (A5079922191)...
# Fetching works for Hans-Joachim Hinrichsen (A5061085251)...
# Fetching works for Oskar v. Hinüber (A5069736848)...
# Fetching works for Ivan Hlaváček (A5070194200)...
# Fetching works for Milan Hlavačka (A5024523082)...
# Fetching works for Claudia Höbartner (A5021290270)...
# Fetching works for Erwin Hochmair (A5010725048)...
# Fetching works for Ingeborg Hochmair-Desoyer (A5069697180)...
# Fetching works for Sepp Hochreiter (A5053148274)...
# Fetching works for Hartwig Höcker (A5084164316)...
# Fetching works for Ivo Ludwig Hofacker (A5011771355)...
# Fetching works for Barbara Hohn (A5111525633)...
# Fetching works for Hans Höller (A5090581061)...
# Fetching works for Gerald  Holton (A5064275660)...
# Fetching works for Gerhard A. Holzapfel (A5006819872)...
# Fetching works for Robert Holzmann (A5022381070)...
# Fetching works for Heinrich Honsell (A5046145665)...
# Fetching works for Barbara Horejs (A5056373999)...
# Fetching works for Oleh Hornykiewicz (A5073433019)...
# Fetching works for Konstantin-Alexander Hossmann (A5113442069)...
# Fetching works for Yaroslav Hrytsak (A5083725812)...
# Fetching works for Christoph Huber (A5103738941)...
# Fetching works for Thomas J. R. Hughes (A5031451887)...
# Fetching works for Pascale Hugon (A5052169723)...
# Fetching works for Hermann Hunger (A5027979086)...
# Fetching works for Nicola Hüsing (A5108606270)...
# Fetching works for Reinhard Franz Josef Hüttl (A5029856260)...
# Fetching works for Anthony A. Hyman (A5006441261)...
# Fetching works for Ataç İmamoğlu (A5008938191)...
# Fetching works for Christoph Irmscher (A5032160708)...
# Fetching works for Hans Irschik (A5079426146)...
# Fetching works for Shiro Ishii (A5028276763)...
# Fetching works for Hans Peter Isler (A5035435549)...
# Fetching works for Lisa Isola (A5042779769)...
# Fetching works for Clemens Jabloner (A5053393760)...
# Fetching works for Éva Jakab (A5004194022)...
# Fetching works for Bernhard Jakoby (A5085874325)...
# Fetching works for Sigrid Jalkotzy-Deger (A5018769425)...
# Fetching works for Cecilia Jarlskog (A5069097871)...
# Fetching works for Erik Jayme (A5085467599)...
# Fetching works for Franz Jeglitsch (A5075597745)...
# Fetching works for Thomas Jenuwein (A5040681676)...
# Fetching works for Hans Joas (A5053009274)...
# Fetching works for Werner Jobst (A5050835019)...
# Fetching works for Zdenek Johan (A5108081589)...
# Fetching works for Peter Johanek (A5013726244)...
# Fetching works for Julian Johnson (A5113531912)...
# Fetching works for Michael Jursa (A5077079618)...
# Fetching works for Thede Kahl (A5066371781)...
# Fetching works for Barbara Kaltenbacher (A5011058927)...
# Fetching works for Manfred  Kaltenbacher (A5013341461)...
# Fetching works for Eric R. Kandel (A5034071817)...
# Fetching works for Andreas Kappeler (A5080415667)...
# Fetching works for Vassos Karageorghis (A5022780486)...
# Fetching works for Stevan Karamata (A5069536107)...
# Fetching works for Matthias Karmasin (A5052602631)...
# Fetching works for Martin Karplus (A5076499540)...
# Fetching works for Georg Kaser (A5078805223)...
# Fetching works for Daniel Kastler (A5046704318)...
# Fetching works for Radoslav Katičić (A5021934691)...
# Fetching works for Stephen Ira Katz (A5111843374)...
# Fetching works for Stephen Ira Katz (A5111621701)...
# Fetching works for Stephen Ira Katz (A5105934290)...
# Fetching works for Hubert Kaufhold (A5065170700)...
# Fetching works for Sylvia Kaufmann (A5090370596)...
# Fetching works for Anke Rita Kaysser-Pyzalla (A5044178224)...
# Fetching works for Katrin Keller (A5111577652)...
# Fetching works for Birgit Kellner (A5037786450)...
# Fetching works for Fritz Kelnhofer (A5058071244)...
# Fetching works for Thomas Kenner (A5112277537)...
# Fetching works for Manfred Kern (A5109866173)...
# Fetching works for Eva Kernbauer (A5053337754)...
# Fetching works for Ferenc Kiefer (A5042304274)...
# Fetching works for Rudolf Kippenhahn (A5057889412)...
# Fetching works for Gottfried Kirchengast (A5026471003)...
# Fetching works for Britta Klagge (A5005604828)...
# Fetching works for Michał Kleiber (A5112787612)...
# Fetching works for Hans-Dieter Klein (A5036821405)...
# Fetching works for Jürgen Kleine-Vehn (A5030974588)...
# Fetching works for Nina Klimburg-Witjes (A5027253459)...
# Fetching works for Bernd Ulrich Kluge (A5043191218)...
# Fetching works for Alfred Kluwick (A5026758614)...
# Fetching works for Fritz Peter Knapp (A5084323543)...
# Fetching works for Sylvia Knapp (A5051970381)...
# Fetching works for Jürgen Knoblich (A5008803187)...
# Fetching works for Wolfgang Knoll (A5050381331)...
# Fetching works for Christian Köberl (A5023659295)...
# Fetching works for Walter Koch (A5075648082)...
# Fetching works for Johannes Koder (A5076203749)...
# Fetching works for Alfred Kohler (A5059576548)...
# Fetching works for Alwin Köhler (A5051857909)...
# Fetching works for Martin Kohli (A5109140470)...
# Fetching works for Walter Kohn (A5015070406)...
# Fetching works for Kurt L. Komarek (A5017835715)...
# Fetching works for Robert Konrat (A5077702058)...
# Fetching works for Hermann Kopetz (A5076712033)...
# Fetching works for Hans-Georg Koppensteiner (A5043494222)...
# Fetching works for Martin Korenjak (A5036034676)...
# Fetching works for Karl Korinek (A5074539498)...
# Fetching works for Christian Körner (A5075149019)...
# Fetching works for Dušan Kováč (A5087869480)...
# Fetching works for Helmut Koziol (A5008144702)...
# Fetching works for Frauke Kraas (A5066984150)...
# Fetching works for Dietrich Kraft (A5105181846)...
# Fetching works for Ernst August Kramer (A5062335813)...
# Fetching works for Christoph Kratky (A5114163665)...
# Fetching works for Christian Krattenthaler (A5040427357)...
# Fetching works for Ferenc Krausz (A5049801219)...
# Fetching works for Bernhard Kräutler (A5073612482)...
# Fetching works for Josef Kreiner (A5030131348)...
# Fetching works for Georg Kresse (A5019751186)...
# Fetching works for Otto Kresten (A5022962464)...
# Fetching works for Friedrich Krinzinger (A5026120717)...
# Fetching works for Guido Kroemer (A5075296559)...
# Fetching works for Karl Kroeschell (A5110886782)...
# Fetching works for Kurt Krolop (A5050968401)...
# Fetching works for James Glenn Krueger (A5080337749)...
# Fetching works for Hans-Henrik Krummacher (A5055358575)...
# Fetching works for Andreas Kugi (A5014193427)...
# Fetching works for Michael Kuhn (A5083798629)...
# Fetching works for Richard Küng (A5042021550)...
# Fetching works for Wilfried Kurz (A5055751954)...
# Fetching works for Walter Kutschera (A5071145976)...
# Fetching works for Jan Květ (A5112556265)...
# Fetching works for Paul Alexander Kyrle (A5060041875)...
# Fetching works for Anne L’Huillier (A5087194862)...
# Fetching works for Johanna Laakso (A5078532788)...
# Fetching works for Sabine Ladstätter (A5010728995)...
# Fetching works for Christopher F. Laferl (A5018108611)...
# Fetching works for Peter Laggner (A5113646781)...
# Fetching works for Julia Lajta-Novak (A5068650473)...
# Fetching works for Vasileios Lambrinoudakis (A5018909036)...
# Fetching works for Claus Lamm (A5089529725)...
# Fetching works for Irene Marthe Lang (A5077212270)...
# Fetching works for Armin Lange (A5087819137)...
# Fetching works for Robert S. Langer (A5042597057)...
# Fetching works for Heinz Langer (A5037712722)...
# Fetching works for Walter Larcher (A5034511572)...
# Fetching works for Hans Lassmann (A5050861407)...
# Fetching works for Reinhard Lauer (A5031372285)...
# Fetching works for Jacques Le Rider (A5074136813)...
# Fetching works for Klaus Lechner (A5107845763)...
# Fetching works for Joseph Theodoor Leerssen (A5039162630)...
# Fetching works for Gustav Adolf Lehmann (A5087733868)...
# Fetching works for Marianne Johanna Lehmkuhl (A5055448810)...
# Fetching works for Ursula Lehr (A5043400897)...
# Fetching works for Helga Leitner (A5011376543)...
# Fetching works for Mikhail Lemeshko (A5051104098)...
# Fetching works for Alexandra N. Lenz (A5028924804)...
# Fetching works for Silke Leopold (A5066779893)...
# Fetching works for Johannes A. Lercher (A5057378771)...
# Fetching works for Willem J. M. Levelt (A5109436410)...
# Fetching works for Gary Libben (A5012760070)...
# Fetching works for Elliott Lieb (A5072851506)...
# Fetching works for Gene Elden Likens (A5027576315)...
# Fetching works for Mandana E. Limbert (A5027024852)...
# Fetching works for Andrea Lindmayr-Brandl (A5078990284)...
# Fetching works for Thomas Lindner (A5101769806)...
# Fetching works for Karl Lintner (A5018402970)...
# Fetching works for Benjamin List (A5040055598)...
# Fetching works for Birgit Lodes (A5097056182)...
# Fetching works for Michele Loporcaro (A5047046643)...
# Fetching works for Hellmut Lorenz (A5005461727)...
# Fetching works for Martin Löschnigg (A5002890420)...
# Fetching works for Peter Lucas (A5012252416)...
# Fetching works for Monika Ludwig (A5007430256)...
# Fetching works for Gerhard Luf (A5082411729)...
# Fetching works for Thomas Luger (A5079571425)...
# Fetching works for Helmut Lukesch (A5026107052)...
# Fetching works for Reimar Lüst (A5111687944)...
# Fetching works for Christina Lutter (A5078405982)...
# Fetching works for Wolfgang Lutz (A5066664298)...
# Fetching works for Marc Luy (A5090508615)...
# Fetching works for Séamus Mac Mathúna (A5023446923)...
# Fetching works for Thomas Magauer (A5062792519)...
# Fetching works for Astrid Mager (A5006636117)...
# Fetching works for Claudio Magris (A5112628338)...
# Fetching works for Christian Mair (A5082889749)...
# Fetching works for Melanie Malzahn (A5073746291)...
# Fetching works for Herbert Mang (A5017724600)...
# Fetching works for Wolfgang Mantl (A5048059493)...
# Fetching works for Joseph Maran (A5037742602)...
# Fetching works for Michael Marberger (A5090946201)...
# Fetching works for Raimund Margreiter (A5111587694)...
# Fetching works for Peter Markowich (A5110260067)...
# Fetching works for James H. Marrow (A5070475344)...
# Fetching works for Alberto Martino (A5103038207)...
# Fetching works for Herbert Matis (A5013378132)...
# Fetching works for Aleksandar Matković (A5015457527)...
# Fetching works for Franz Matscher (A5059491935)...
# Fetching works for Richard Viktor Mattessich (A5000219288)...
# Fetching works for Hartmut  Matthäus (A5067139962)...
# Fetching works for Paolo Matthiae (A5031366579)...
# Fetching works for Marjori Ann Matzke (A5019957343)...
# Fetching works for Nuno Maulide (A5084246998)...
# Fetching works for Bernd Mayer (A5022599009)...
# Fetching works for Henry M. R. E. Mayr-Harting (A5042610646)...
# Fetching works for Paul Heinz Mayrhofer (A5052993744)...
# Fetching works for Otto Mayrhofer-Krammel (A5080544316)...
# Fetching works for Brigitte Mazohl (A5049679467)...
# Fetching works for Rosamond McKitterick (A5090805770)...
# Fetching works for Peter McMullen (A5069372898)...
# Fetching works for Wolfgang F. G. Mecklenbräuker (A5065435717)...
# Fetching works for Wolfgang Meid (A5000664730)...
# Fetching works for Anne Sophie Meincke (A5060705482)...
# Fetching works for Igor Mel'čuk (A5058443586)...
# Fetching works for Fritz Melchers (A5026967613)...
# Fetching works for Sarah Melzer (A5036522459)...
# Fetching works for Günther Meschke (A5033663151)...
# Fetching works for Bruno Messerli (A5108499648)...
# Fetching works for Michael Metzeltin (A5056068306)...
# Fetching works for Carola Metzner-Nebelsick (A5008621981)...
# Fetching works for Ronald Micura (A5058574119)...
# Fetching works for Gero Miesenböck (A5109272997)...
# Fetching works for Hanno Millesi (A5031424612)...
# Fetching works for Nina Mirnig (A5022986176)...
# Fetching works for Diana Mishkova (A5038960543)...
# Fetching works for Jürgen Mittelstraß (A5112766045)...
# Fetching works for Christian  Mitterer (A5001677654)...
# Fetching works for Fritz Mitthof (A5068391562)...
# Fetching works for Kimberly Modic (A5053342545)...
# Fetching works for Stephan Moebius (A5090605157)...
# Fetching works for Helmuth Möhwald (A5111573777)...
# Fetching works for Andreas F. Molisch (A5071725365)...
# Fetching works for Hans Mommsen (A5069700487)...
# Fetching works for Alessandro Montanari (A5024712421)...
# Fetching works for Helmut Moritz (A5058176159)...
# Fetching works for Cécile Morrisson (A5070169796)...
# Fetching works for Gina E. Moseley (A5000776839)...
# Fetching works for Helfried Mostler (A5066967055)...
# Fetching works for Gérard A. Mourou (A5057252770)...
# Fetching works for Nicolette Mout (A5072756639)...
# Fetching works for Dennis C. Mueller (A5058478092)...
# Fetching works for Wolfgang Mueller (A5109214001)...
# Fetching works for Ivan I. Mueller (A5109452519)...
# Fetching works for Sandra Müller (A5000898524)...
# Fetching works for Ulrike Müller-Böker (A5058682421)...
# Fetching works for Johann Mulzer (A5040626820)...
# Fetching works for Ulrike Müßig (A5045372636)...
# Fetching works for Karol Myśliwiec (A5087281369)...
# Fetching works for Herta Nagl-Docekal (A5031171570)...
# Fetching works for Norman M. Naimark (A5031032822)...
# Fetching works for Rumi Nakamura (A5068766098)...
# Fetching works for George (Gia) Sch. Nakhutsrishvili (A5006529627)...
# Fetching works for George (Gia) Sch. Nakhutsrishvili (A5049806063)...
# Fetching works for Kim A. Nasmyth (A5025297651)...
# Fetching works for David Natal Villazala (A5055770221)...
# Fetching works for Adolf Neckel (A5052237067)...
# Fetching works for Robert Nedoma (A5063943457)...
# Fetching works for Wolfgang  Neubauer (A5044115932)...
# Fetching works for Christine Neugebauer-Maresch (A5025441058)...
# Fetching works for Winfried L. Neuhuber (A5018505044)...
# Fetching works for Walter Neupert (A5046289240)...
# Fetching works for Gerhard Neweklowsky (A5078367858)...
# Fetching works for Stefan Michael Newerkla (A5015000388)...
# Fetching works for Harald Niederreiter (A5086124758)...
# Fetching works for Christian Roland Noe (A5110529965)...
# Fetching works for Magnus Nordborg (A5001507986)...
# Fetching works for Dieter Nörr (A5036496643)...
# Fetching works for Marie-Louise Nosch (A5065968042)...
# Fetching works for Sir Gustav Joseph Victor Nossal (A5110120064)...
# Fetching works for Heinrich Nöth (A5085011812)...
# Fetching works for Martin A. Nowak (A5081956768)...
# Fetching works for Helga Nowotny (A5000945637)...
# Fetching works for Onora O'Neill (A5109011388)...
# Fetching works for Anna Christina Obenauf (A5078729702)...
# Fetching works for Paul Oberhammer (A5030112200)...
# Fetching works for Gerhard Oberhammer (A5022261680)...
# Fetching works for Dieter Oesterhelt (A5077404586)...
# Fetching works for Werner Ogris (A5050489121)...
# Fetching works for Oskar Friedrich Olaj (A5111552045)...
# Fetching works for Thomas Olechowski (A5048783928)...
# Fetching works for Gerhard Opelz (A5111845951)...
# Fetching works for Gherardo Ortalli (A5026697158)...
# Fetching works for Marcus Ossiander (A5046938852)...
# Fetching works for Jurij Sergejewitsch Ossipov (A5030386630)...
# Fetching works for Jürgen Osterhammel (A5050720944)...
# Fetching works for Jörg A. Ott (A5022220687)...
# Fetching works for Alfred E. von Overbeck (A5079955846)...
# Fetching works for Peter Palese (A5004404612)...
# Fetching works for Herbert Palme (A5083650358)...
# Fetching works for Bernhard Palme (A5078722802)...
# Fetching works for Jian-Wei Pan (A5042449260)...
# Fetching works for Oswald Panagl (A5068780837)...
# Fetching works for Lucy Y. Pao (A5062050694)...
# Fetching works for Fritz Paschke (A5083496985)...
# Fetching works for Gernot Patzelt (A5112024632)...
# Fetching works for Josef Penninger (A5059310975)...
# Fetching works for Ernst Pernicka (A5019335918)...
# Fetching works for Peter Pernthaler (A5052412065)...
# Fetching works for Anne Peters (A5001347850)...
# Fetching works for Jan-Michael Peters (A5055191083)...
# Fetching works for Jillian Petersen (A5063678252)...
# Fetching works for Hellmuth Petsche (A5111599735)...
# Fetching works for Johann Pfanzagl (A5021413455)...
# Fetching works for Gerhard Pferschy (A5064015755)...
# Fetching works for Otto Pfersmann (A5085258118)...
# Fetching works for Jörg Pfleiderer (A5112793651)...
# Fetching works for Gert Pfurtscheller (A5106687523)...
# Fetching works for Philip Ivanov Philippov (A5113693421)...
# Fetching works for Gernot Piccottini (A5022552696)...
# Fetching works for Helmut Pichler (A5028244283)...
# Fetching works for Hannes Pichler (A5041692282)...
# Fetching works for Pierre Jean Pichot (A5082079945)...
# Fetching works for Herbert Pietschmann (A5031358209)...
# Fetching works for Werner E. Piller (A5000096344)...
# Fetching works for Renate Johanna Pillinger (A5041014540)...
# Fetching works for Rudolf Pischinger (A5072508700)...
# Fetching works for Clemens Plaschka (A5006479386)...
# Fetching works for Carolina Plescia (A5091423038)...
# Fetching works for Walter L. Pohl (A5050868680)...
# Fetching works for Walter Pohl (A5088327753)...
# Fetching works for Hryhoriy Polshyn (A5001175999)...
# Fetching works for Marianne Popp (A5108228334)...
# Fetching works for Magdalena Pöschl (A5061028260)...
# Fetching works for Barbara Prainsack (A5023800625)...
# Fetching works for Rudolf Preimesberger (A5012574738)...
# Fetching works for Anton Preisinger (A5012268114)...
# Fetching works for Friedrich B. Prinz (A5110463073)...
# Fetching works for Manfred Prisching (A5017984918)...
# Fetching works for Stephan  Procházka (A5080731429)...
# Fetching works for Paolo Prodi (A5100866826)...
# Fetching works for Walter Puchner (A5050897849)...
# Fetching works for Andreas Pülz (A5018474315)...
# Fetching works for Denise Pumain (A5040713816)...
# Fetching works for Sonja Puntscher Riekmann (A5060363358)...
# Fetching works for Gernot Rabeder (A5066261557)...
# Fetching works for Ljiljana Radonić (A5010244430)...
# Fetching works for Piero Rafanelli (A5046946736)...
# Fetching works for Andrej Rahten (A5028159557)...
# Fetching works for Franz Rainer (A5110261565)...
# Fetching works for Ekkehard Ramm (A5109418827)...
# Fetching works for Franz G. Rammerstorfer (A5026821096)...
# Fetching works for Friederike Range (A5076854956)...
# Fetching works for Claudia Rapp (A5033245425)...
# Fetching works for Armando Rastelli (A5009890802)...
# Fetching works for Gudrun Rath (A5065584019)...
# Fetching works for Isabelle Ratié (A5091403507)...
# Fetching works for Helmut Rauch (A5112388743)...
# Fetching works for Peter H. Raven (A5075532537)...
# Fetching works for Karl M. A. Rawer (A5040900433)...
# Fetching works for Katharina Rebay-Salisbury (A5014424938)...
# Fetching works for Anton Rebhan (A5025921670)...
# Fetching works for Ludwig Reich (A5022718947)...
# Fetching works for Ingo Reiffenstein (A5075330094)...
# Fetching works for Wolf Uwe Reimold (A5076871437)...
# Fetching works for Susanne Reindl-Krauskopf (A5054852413)...
# Fetching works for August Reinisch (A5000755997)...
# Fetching works for André Reis (A5082130600)...
# Fetching works for Elmar R. Reiter (A5112814075)...
# Fetching works for Reinhold Remmert (A5027363950)...
# Fetching works for Andrew Colin Renfrew (A5041836606)...
# Fetching works for Andrea Rentmeister (A5063961340)...
# Fetching works for Fritz Resinger (A5083059379)...
# Fetching works for Georg Ress (A5007786962)...
# Fetching works for Keywan Riahi (A5035238849)...
# Fetching works for James R. Rice (A5012093892)...
# Fetching works for Kurt R. Richter (A5108221980)...
# Fetching works for Norbert G. Riedel (A5007034159)...
# Fetching works for Willibald Riedler (A5110764898)...
# Fetching works for Josef Riedmann (A5084105731)...
# Fetching works for Wolfgang Riehle (A5015343549)...
# Fetching works for Gert Riethmüller (A5109952453)...
# Fetching works for Wolfgang Rindler (A5049664584)...
# Fetching works for Zsigmond Ritoók (A5053771278)...
# Fetching works for Monika Ritsch-Marte (A5005239403)...
# Fetching works for Olivia Fiona Robinson (A5103189987)...
# Fetching works for Alexandra Rodler-Rørbo (A5072443815)...
# Fetching works for Teresa Rodríguez de las Heras Ballell (A5048629605)...
# Fetching works for Juan Gualterio Roederer (A5089665955)...
# Fetching works for Herbert Walter Roesky (A5081316842)...
# Fetching works for Robert Rollinger (A5112808941)...
# Fetching works for José Luis Romero (A5100721537)...
# Fetching works for Maria Grazia Roncarolo (A5006672507)...
# Fetching works for Artur Rosenauer (A5057456839)...
# Fetching works for Leopold Rosenmayr (A5060374542)...
# Fetching works for Michael Rössner (A5033894962)...
# Fetching works for Mathias Walter Rotach (A5025613199)...
# Fetching works for Carlo Rubbia (A5105889392)...
# Fetching works for Helmut O. Rucker (A5030714055)...
# Fetching works for Helmut Rumpler (A5068576748)...
# Fetching works for Hans Georg Ruppe (A5000587715)...
# Fetching works for Günther Rupprechter (A5088541152)...
# Fetching works for Eda Sagarra (A5016759215)...
# Fetching works for Richard Salomon (A5059006561)...
# Fetching works for Roman Sandgruber (A5002094345)...
# Fetching works for Friedrich Sandhofer (A5048861133)...
# Fetching works for Birgit Sandkaulen (A5053146471)...
# Fetching works for Niyazi Serdar Sariçiftçi (A5036842921)...
# Fetching works for Michael Sarnthein-Lotichius (A5030185564)...
# Fetching works for Pasqualina Maria Sarro (A5064630364)...
# Fetching works for Paolo Sartori (A5043935592)...
# Fetching works for Friedrich Schaller (A5109944860)...
# Fetching works for Gottfried Schatz (A5025917067)...
# Fetching works for Philipp  Scheibelreiter (A5030426972)...
# Fetching works for Walter Scheidel (A5054855249)...
# Fetching works for Eva Schernhammer (A5018699045)...
# Fetching works for Rudolf Schieffer (A5015374665)...
# Fetching works for Sabine Schindler (A5054533208)...
# Fetching works for Philipp Schindler (A5033654155)...
# Fetching works for Andrzej Schinzel (A5010455224)...
# Fetching works for Wolfgang Schlager (A5029897371)...
# Fetching works for Wolfgang P. Schleich (A5047214535)...
# Fetching works for Christa Schleper (A5002281587)...
# Fetching works for Hermann Schmalzried (A5109910555)...
# Fetching works for Klaus Schmidt (A5058372080)...
# Fetching works for Wolfgang Schmidt (A5000740252)...
# Fetching works for Matthias  Schmidt (A5047596078)...
# Fetching works for Johannes Schmidt (A5103195750)...
# Fetching works for Alfred Schmidt (A5008347776)...
# Fetching works for Arnold Schmidt (A5101956235)...
# Fetching works for Ernst August Schmidt (A5098983988)...
# Fetching works for Philipp Schmidt-Dengler (A5049421358)...
# Fetching works for Ursula Schmidt-Erfurth (A5053563726)...
# Fetching works for Sabine Schmidtke (A5067247484)...
# Fetching works for Jörg Schmiedmayer (A5001996038)...
# Fetching works for Lambert Schmithausen (A5060263145)...
# Fetching works for Rüdiger Schmitt (A5108535171)...
# Fetching works for Oliver Jens Schmitt (A5001160764)...
# Fetching works for Kurt Schmoller (A5080584860)...
# Fetching works for Isabel Schnabel (A5062592345)...
# Fetching works for Wilhelm Schneider (A5077567178)...
# Fetching works for Albrecht Schöne (A5081687752)...
# Fetching works for Hans Peter Schönlaub (A5112564522)...
# Fetching works for Peter Schönswetter (A5029080887)...
# Fetching works for Carl E. Schorske (A5109160691)...
# Fetching works for Peter Schreiner (A5027412086)...
# Fetching works for Ulrich Schubert (A5075012306)...
# Fetching works for Gerold Schuler (A5064778812)...
# Fetching works for Rolf Schulte-Hermann (A5079301073)...
# Fetching works for Birgitta Schultze-Bernhardt (A5055113260)...
# Fetching works for Winfried Schulze (A5111371059)...
# Fetching works for Josef Schurz (A5010142000)...
# Fetching works for Peter Schuster (A5101404538)...
# Fetching works for Gerhard Schütz (A5109094279)...
# Fetching works for Sebastian Schütze (A5030266621)...
# Fetching works for Hans Schwabl (A5043928076)...
# Fetching works for Karlheinz Schwarz (A5038840462)...
# Fetching works for Florian Schwarz (A5048723309)...
# Fetching works for Hans Georg Schwarzacher (A5110433013)...
# Fetching works for Walther Schwarzacher (A5010372008)...
# Fetching works for Günter C. Schweiger (A5031577544)...
# Fetching works for Fritz Schweiger (A5029697153)...
# Fetching works for Michael Schweitzer (A5103241209)...
# Fetching works for Dieter Schweizer (A5031098201)...
# Fetching works for Hugo Schwendenwein (A5009805567)...
# Fetching works for Martin Seger (A5087456733)...
# Fetching works for Christian Seidl (A5090427354)...
# Fetching works for Horst Seidler (A5047920871)...
# Fetching works for Stephan Johannes Seidlmayer (A5034661952)...
# Fetching works for Robert  Seiringer (A5044393614)...
# Fetching works for Ali Mehmet Celâl Şengör (A5011255872)...
# Fetching works for Veronika Sexl (A5079620940)...
# Fetching works for Demetra Sfendoni-Mentzou (A5050966394)...
# Fetching works for Francesco Sferra (A5045429518)...
# Fetching works for Danuta Shanzer (A5057721502)...
# Fetching works for M. Rahim Shayegan (A5089568867)...
# Fetching works for Ethan M. Shevach (A5005119540)...
# Fetching works for Maria Sibilia (A5044726648)...
# Fetching works for Susanne Sievers (A5049241129)...
# Fetching works for Karl Sigmund (A5052442989)...
# Fetching works for Petra Sijpesteijn (A5008066033)...
# Fetching works for Oleg Simakov (A5041816560)...
# Fetching works for Barry Simon (A5038838154)...
# Fetching works for Nicholas Sims-Williams (A5012314102)...
# Fetching works for Hans-Werner Sinn (A5078488097)...
# Fetching works for Peter Sitte (A5031437752)...
# Fetching works for Quentin R. D. Skinner (A5109255683)...
# Fetching works for Uwe B. Sleytr (A5020717643)...
# Fetching works for John Victor Small (A5111615845)...
# Fetching works for Kurt Smolak (A5072337891)...
# Fetching works for Josef Smolen (A5111657027)...
# Fetching works for Werner Sollors (A5079107189)...
# Fetching works for Éva Somogyi (A5004695017)...
# Fetching works for Vera T. Sós (A5029190676)...
# Fetching works for Nicola Spaldin (A5079173175)...
# Fetching works for Katta Spiel (A5078686145)...
# Fetching works for Christoph Spötl (A5015889339)...
# Fetching works for Hellmuth Stachel (A5010425711)...
# Fetching works for Saskia Stachowitsch (A5034893803)...
# Fetching works for Peter F. Stadler (A5016104736)...
# Fetching works for Lawrence E. Stager (A5036875012)...
# Fetching works for Sigrid Stagl (A5033135314)...
# Fetching works for André Stahl (A5113765818)...
# Fetching works for Maria A. Stassinopoulou (A5065652992)...
# Fetching works for Paul Stefanovits (A5020421769)...
# Fetching works for Florian  Steger (A5061177559)...
# Fetching works for Erwin Stein (A5105714072)...
# Fetching works for Sybille Steinbacher (A5078571040)...
# Fetching works for Peter Steinhauser (A5110860875)...
# Fetching works for Friedrich Franz Steininger (A5104016281)...
# Fetching works for Ernst Steinkellner (A5052264653)...
# Fetching works for Hans-Peter Steinrück (A5035111702)...
# Fetching works for Barbara Stelzl-Marx (A5035627497)...
# Fetching works for Günter Stemberger (A5027006133)...
# Fetching works for Stig T. Stenholm (A5108223331)...
# Fetching works for Nikolaus K. Stephanidis (A5028020606)...
# Fetching works for Peter Štih (A5079543398)...
# Fetching works for Georg Stingl (A5090252753)...
# Fetching works for Gerold Stoll (A5026706910)...
# Fetching works for Barbara Stollberg-Rilinger (A5060539319)...
# Fetching works for Gerald Stourzh (A5041222966)...
# Fetching works for Helmut Strasser (A5048252341)...
# Fetching works for Erich Wolfgang Streissler (A5067273787)...
# Fetching works for Jörg Striessnig (A5064224098)...
# Fetching works for Josef Strobl (A5023815396)...
# Fetching works for Arno Strohmeyer (A5031071994)...
# Fetching works for Tod F. Stuessy (A5030382052)...
# Fetching works for Christian Sturmbauer (A5037235156)...
# Fetching works for Robert Samuel Summers (A5029960592)...
# Fetching works for Hans Sünkel (A5046865345)...
# Fetching works for Giulio Superti-Furga (A5069216326)...
# Fetching works for Arnold Suppan (A5084904023)...
# Fetching works for Ernst Christoph Suttner (A5064557880)...
# Fetching works for Gustav Andreas Tammann (A5110123790)...
# Fetching works for Elly Tanaka (A5038687254)...
# Fetching works for Éva Tardos (A5025175846)...
# Fetching works for Ulrich Technau (A5015343725)...
# Fetching works for Jaroslav Tejral (A5023961369)...
# Fetching works for Werner Telesko (A5047551236)...
# Fetching works for Heinz-Elmar Tenorth (A5112532047)...
# Fetching works for Erich Thenius (A5075804439)...
# Fetching works for Udo Thiel (A5058342782)...
# Fetching works for Gerhard Thür (A5003289926)...
# Fetching works for Robert F. Tichy (A5114021729)...
# Fetching works for Klement Tockner (A5085901023)...
# Fetching works for Theodor Tomandl (A5080306486)...
# Fetching works for Erich Trapp (A5073596905)...
# Fetching works for Dirk Trauner (A5042433434)...
# Fetching works for Michael Trauner (A5084197662)...
# Fetching works for Marko Trogrlić (A5048453620)...
# Fetching works for Hans Tuppy (A5110162542)...
# Fetching works for Franz-Josef Ulm (A5009860121)...
# Fetching works for Melanie Unseld (A5036931420)...
# Fetching works for Miriam M. Unterlass (A5007420543)...
# Fetching works for Gerald Urban (A5044520105)...
# Fetching works for Otto Helmut Urban (A5086242105)...
# Fetching works for Boris A. Uspenskij (A5003201502)...
# Fetching works for Gerd W. Utermann (A5056429133)...
# Fetching works for Alice Vadrot (A5005429444)...
# Fetching works for Rudolf Valenta (A5050048947)...
# Fetching works for Peter van Nieuwenhuizen (A5002694782)...
# Fetching works for Mihai-Cristian Vasile (A5079605571)...
# Fetching works for Michael Johannes Vellekoop (A5070747612)...
# Fetching works for Beatriz Vicoso (A5066962220)...
# Fetching works for Karl Vodrazka (A5011285514)...
# Fetching works for Thomas Vogl (A5035318279)...
# Fetching works for Arndt von Haeseler (A5085983122)...
# Fetching works for Klaus von Klitzing (A5056170134)...
# Fetching works for Alfred Wagenhofer (A5017310581)...
# Fetching works for Horst Wagner (A5028107211)...
# Fetching works for Andreas  Wagner (A5079730045)...
# Fetching works for Günter P. Wagner (A5072327308)...
# Fetching works for Karl Wagner (A5101760386)...
# Fetching works for Sigurd Wagner (A5032133587)...
# Fetching works for Erwin F. Wagner (A5004832527)...
# Fetching works for Michael Wagner (A5013993834)...
# Fetching works for Birgit Wagner (A5017342460)...
# Fetching works for Scott Waitukaitis (A5029302369)...
# Fetching works for Wolfgang A. Wall (A5053323760)...
# Fetching works for Grete Walter-Klingenstein (A5086403795)...
# Fetching works for Heinrich Wänke (A5010262811)...
# Fetching works for Graham Warren (A5073719453)...
# Fetching works for Peter Michael Warren (A5074719589)...
# Fetching works for Andrea Weber (A5065292179)...
# Fetching works for Harald Wolfgang Weber (A5107868475)...
# Fetching works for Gerhard Wegner (A5060413144)...
# Fetching works for Rüdiger Wehner (A5023074552)...
# Fetching works for Susanne Weigelin-Schwiedrzik (A5071699131)...
# Fetching works for Stefan Weinfurter (A5020713986)...
# Fetching works for Astrid Weiss (A5071826560)...
# Fetching works for Günter Weiss (A5003462114)...
# Fetching works for Werner Welzig (A5007866229)...
# Fetching works for Emo Welzl (A5107336010)...
# Fetching works for Christiane Wendehorst (A5081561741)...
# Fetching works for Samuel A. Werner (A5114025647)...
# Fetching works for Diter von Wettstein (A5008951787)...
# Fetching works for Manfred Wicke (A5069189353)...
# Fetching works for Gerhard Widmer (A5003768123)...
# Fetching works for Ewald Wiederin (A5053107857)...
# Fetching works for Maria Katharina  Wiedlack (A5009448764)...
# Fetching works for Malcolm Hewitt Wiener (A5069427120)...
# Fetching works for Josef Wiesehöfer (A5025309011)...
# Fetching works for Wolfgang Wieser (A5032578422)...
# Fetching works for Heinz Gregor Wieser (A5006411265)...
# Fetching works for Michaela Wiesinger (A5033847472)...
# Fetching works for Peter Wiesinger (A5002146991)...
# Fetching works for Luzius Wildhaber (A5079186588)...
# Fetching works for Günther Wilke (A5108796864)...
# Fetching works for F. Ludwig Wilke (A5104044766)...
# Fetching works for Jürgen Wilke (A5109539998)...
# Fetching works for Harco Willems (A5061661090)...
# Fetching works for Anouk Willemsen (A5062966075)...
# Fetching works for Michaela Windischgrätz (A5051270586)...
# Fetching works for Michaela Windischgrätz (A5015414961)...
# Fetching works for Verena Winiwarter (A5044819597)...
# Fetching works for Thomas Winkelbauer (A5023951889)...
# Fetching works for Hans Winkler (A5109285295)...
# Fetching works for Georg Winter (A5002922655)...
# Fetching works for Renée Winter (A5008100827)...
# Fetching works for Erich Winter (A5056828867)...
# Fetching works for Irene J. Winter (A5109802929)...
# Fetching works for Gerhard Wirth (A5068827798)...
# Fetching works for Norbert Richard Wolf (A5035519090)...
# Fetching works for Alois Wolf (A5068372057)...
# Fetching works for Eckhard Wolf (A5025136768)...
# Fetching works for Werner Wolf (A5107276416)...
# Fetching works for Ulrich Wolf (A5002527889)...
# Fetching works for Klaus Wolff (A5111363790)...
# Fetching works for Herwig Wolfram (A5041930053)...
# Fetching works for Bernhard Woytek (A5082812927)...
# Fetching works for Dagmar Wujastyk (A5063317485)...
# Fetching works for Keizô Yamamoto (A5100926237)...
# Fetching works for Yeong-Bin Yang (A5100758454)...
# Fetching works for William Edgar Yates (A5063283832)...
# Fetching works for Bilge Yıldız (A5111505303)...
# Fetching works for Stephen G. Young (A5085755071)...
# Fetching works for Waldemar Zacharasiewicz (A5009459206)...
# Fetching works for Hans Georg Zachau (A5111769777)...
# Fetching works for Anatoly G. Zagorodny (A5067805425)...
# Fetching works for Kurt Zatloukal (A5032058761)...
# Fetching works for Josef Zechner (A5072220755)...
# Fetching works for Rudolf Zechner (A5051973789)...
# Fetching works for Anton Zeilinger (A5001105113)...
# Fetching works for Josef Zemann (A5063964700)...
# Fetching works for Wolfgang Zenker (A5068438749)...
# Fetching works for Michael Zgurovsky (A5064586240)...
# Fetching works for Yong-de Zhang (A5100322864)...
# Fetching works for Shuguang Zhang (A5061928018)...
# Fetching works for Franz Ziegler (A5028544419)...
# Fetching works for Peter V. Zima (A5004418392)...
# Fetching works for Reinhard Zimmermann (A5108092666)...
# Fetching works for Harald Volkmar Zimmermann (A5067298818)...
# Fetching works for Michel Zink (A5113842846)...
# Fetching works for Ernst K. Zinner (A5079423016)...
# Fetching works for Natalia A. Zinovieva (A5048631259)...
# Fetching works for Theodore J. Ziolkowski (A5014609770)...
# Fetching works for Jan M. Ziolkowski (A5011199666)...
# Fetching works for Peter Zoller (A5016282235)...
# Fetching works for Alessandro Zuccari (A5057322393)...
# Fetching works for Paul Michael Zulehner (A5032046748)...
# Works data with full details saved to austrian_academy_works.json.

# %%
import json

# Input and output file paths
input_file = "/content/austrian_academy_members_with_indices.json"  # Replace with your distorted JSON file path
output_file = "austrian_academy_members_with_indices_restored.json"  # Restored output file

# Load the distorted JSON file
with open(input_file, "r", encoding="utf-8") as infile:
    data = json.load(infile)

# Decode Unicode escape sequences
def decode_unicode(data):
    if isinstance(data, dict):
        return {key: decode_unicode(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [decode_unicode(item) for item in data]
    elif isinstance(data, str):
        try:
            # Attempt to decode the string
            return data.encode('latin1').decode('utf-8')
        except (UnicodeEncodeError, UnicodeDecodeError):
            # Return the original string if decoding fails
            return data
    else:
        return data

restored_data = decode_unicode(data)

# Save the restored JSON file
with open(output_file, "w", encoding="utf-8") as outfile:
    json.dump(restored_data, outfile, ensure_ascii=False, indent=4)

print(f"Restored file saved to {output_file}")
# Out:
# Restored file saved to austrian_academy_members_with_indices_restored.json

# %%
import requests
import json
import time
import pandas as pd

# Input and output file paths
input_file = "/content/austrian_academy_members_with_indices_restored.json"  # Replace with your actual file path
output_json_file = "austrian_academy_works_filtered.json"  # JSON file output
output_csv_file = "austrian_academy_works_filtered.csv"  # CSV file output
progress_log_file = "progress_log2.json"  # Log file to track progress

# OpenAlex base API URL
openalex_base_url = "https://api.openalex.org"

# Function to fetch works for an author
def fetch_author_works(author_id):
    works = []
    page = 1
    while True:
        url = f"{openalex_base_url}/works?filter=author.id:{author_id}&per-page=200&page={page}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            for work in data.get("results", []):  # Handle missing 'results'
                filtered_work = {
                    "id": work.get("id", ""),
                    "title": work.get("title", ""),
                    "doi": work.get("doi", ""),
                    "publication_year": work.get("publication_year", ""),
                    "cited_by_count": work.get("cited_by_count", 0),
                    "authorships": [
                        {
                            "author": {
                                "id": auth.get("author", {}).get("id", ""),
                                "display_name": auth.get("author", {}).get("display_name", "")
                            },
                            "institutions": [
                                {
                                    "id": inst.get("id", ""),
                                    "display_name": inst.get("display_name", ""),
                                    "country_code": inst.get("country_code", ""),
                                    "type": inst.get("type", "")  # Safely handle missing type
                                }
                                for inst in auth.get("institutions", []) if inst
                            ]
                        }
                        for auth in work.get("authorships", []) if auth
                    ],
                    "primary_topic": {
                        "id": work.get("primary_topic", {}).get("id", ""),
                        "display_name": work.get("primary_topic", {}).get("display_name", ""),
                        "score": work.get("primary_topic", {}).get("score", 0),
                        "field": {
                            "id": work.get("primary_topic", {}).get("field", {}).get("id", ""),
                            "display_name": work.get("primary_topic", {}).get("field", {}).get("display_name", "")
                        } if work.get("primary_topic", {}).get("field") else {},
                        "subfield": {
                            "id": work.get("primary_topic", {}).get("subfield", {}).get("id", ""),
                            "display_name": work.get("primary_topic", {}).get("subfield", {}).get("display_name", "")
                        } if work.get("primary_topic", {}).get("subfield") else {},
                        "domain": {
                            "id": work.get("primary_topic", {}).get("domain", {}).get("id", ""),
                            "display_name": work.get("primary_topic", {}).get("domain", {}).get("display_name", "")
                        } if work.get("primary_topic", {}).get("domain") else {}
                    } if work.get("primary_topic") else {},  # Handle missing primary_topic
                    "concepts": [
                        {
                            "id": concept.get("id", ""),
                            "display_name": concept.get("display_name", ""),
                            "level": concept.get("level", 0),
                            "score": concept.get("score", 0)
                        }
                        for concept in work.get("concepts", []) if concept
                    ],
                    "open_access": work.get("open_access", {}),
                    "sustainable_development_goals": [
                        {
                            "id": sdg.get("id", ""),
                            "score": sdg.get("score", 0),
                            "display_name": sdg.get("display_name", "")
                        }
                        for sdg in work.get("sustainable_development_goals", []) if sdg
                    ],
                    "referenced_works": work.get("referenced_works", [])
                }
                works.append(filtered_work)
            if "next" not in data.get("meta", {}):  # Handle missing 'meta'
                break
            page += 1
            time.sleep(1)  # Respect API rate limits
        else:
            print(f"Error fetching works for author {author_id}: {response.status_code}")
            break
    return works

# Load the existing JSON file
with open(input_file, "r") as infile:
    members = json.load(infile)

# Load or initialize the progress log
try:
    with open(progress_log_file, "r") as log_file:
        progress_log = json.load(log_file)
except FileNotFoundError:
    progress_log = {}

# Fetch works for each author and organize them under authors
authors_with_works = []
for member in members:
    name = member["name"]
    openalex_ids = member.get("openalex_id")
    all_works = []

    if name in progress_log and progress_log[name]:
        print(f"Skipping {name}, already completed.")
        continue

    print(f"Fetching works for {name}...")

    try:
        if isinstance(openalex_ids, list):
            for openalex_id in openalex_ids:
                author_id = openalex_id.split("/")[-1]  # Extract author ID
                all_works.extend(fetch_author_works(author_id))
        elif isinstance(openalex_ids, str):
            author_id = openalex_ids.split("/")[-1]
            all_works.extend(fetch_author_works(author_id))

        authors_with_works.append({
            "name": name,
            "openalex_id": openalex_ids,
            "works": all_works
        })

        # Mark the author as successfully processed
        progress_log[name] = True

    except Exception as e:
        print(f"Error processing {name}: {e}")
        progress_log[name] = False  # Mark as failed

    # Save progress after each author
    with open(progress_log_file, "w") as log_file:
        json.dump(progress_log, log_file, indent=4)

# Save the filtered data to a JSON file
with open(output_json_file, "w") as outfile:
    json.dump(authors_with_works, outfile, indent=4)
print(f"Filtered works data saved to JSON: {output_json_file}")

# Convert to CSV for easier inspection
csv_data = []
for author in authors_with_works:
    for work in author["works"]:
        csv_data.append({
            "author_name": author["name"],
            "author_openalex_id": author["openalex_id"],
            "work_id": work["id"],
            "work_title": work["title"],
            "doi": work["doi"],
            "publication_year": work["publication_year"],
            "cited_by_count": work["cited_by_count"],
            "field": work["primary_topic"].get("field", {}).get("display_name", ""),
            "subfield": work["primary_topic"].get("subfield", {}).get("display_name", ""),
            "domain": work["primary_topic"].get("domain", {}).get("display_name", ""),
            "concepts": ", ".join([concept["display_name"] for concept in work["concepts"]]),
            "open_access_status": work.get("open_access", {}).get("oa_status", ""),
            "sustainable_development_goals": ", ".join([sdg["display_name"] for sdg in work.get("sustainable_development_goals", [])]),
            "referenced_works_count": len(work.get("referenced_works", []))
        })

pd.DataFrame(csv_data).to_csv(output_csv_file, index=False)
print(f"Filtered works data saved to CSV: {output_csv_file}")
# Out:
# Fetching works for Rainer Abart...
# Fetching works for Karl Acham...
# Fetching works for Antal Ádám...
# Fetching works for Ludwig Adamovich...
# Fetching works for Timon Erik Adolph...
# Fetching works for Alícia Adserà...
# Fetching works for Adriano Aguzzi...
# Fetching works for Josef Aicher...
# Fetching works for Martin Aigner...
# Fetching works for Luciana Aigner-Foresti...
# Fetching works for Brenda Almond...
# Fetching works for Michael Alram...
# Fetching works for Eva Alram-Stern...
# Fetching works for Carlos Alvar Ezquerra...
# Fetching works for João Alves...
# Fetching works for Michel Amandry...
# Fetching works for Petra Amann...
# Fetching works for Brigitta Ammann...
# Fetching works for Angelika Amon...
# Fetching works for Bertil Andersson...
# Fetching works for Bernard Andreae...
# Fetching works for Anaïs  Angelo...
# Fetching works for Flavio Anselmetti...
# Fetching works for Leah Armstrong...
# Fetching works for Markus Arndt...
# Fetching works for Eduard Arzt...
# Fetching works for Alain Aspect...
# Fetching works for Markus Aspelmeyer...
# Fetching works for Aleida Assmann...
# Fetching works for Alice Auersperg...
# Fetching works for Hans Aurenhammer...
# Fetching works for Manuela Baccarini...
# Fetching works for Andrea Bachmaier...
# Fetching works for Auksė Balčytienė...
# Fetching works for Andrius Baltuška...
# Fetching works for Albert-László Barabási...
# Fetching works for Andrea Barta...
# Fetching works for Friedrich G. Barth...
# Fetching works for Hans Basbøll...
# Fetching works for Rainer Bauböck...
# Fetching works for Bernhard Bauer...
# Fetching works for Siegfried J. Bauer...
# Fetching works for Friedrich L. Bauer...
# Fetching works for Günther Bauer...
# Fetching works for Wolfgang Baumjohann...
# Fetching works for Zdeněk P. Bažant...
# Fetching works for Alexander K.  Belyaev...
# Fetching works for Robert John Bennett...
# Fetching works for Iván T. Berend...
# Fetching works for Walter Berka...
# Fetching works for Walter Berschin...
# Fetching works for Pier Marco Bertinetto...
# Fetching works for Reinhold Bichler...
# Fetching works for Manfred Bietak...
# Fetching works for Francesco C. Billari...
# Fetching works for Kurt Binder...
# Fetching works for Michal Biran...
# Fetching works for Helmut Birkhan...
# Fetching works for Paul Albert Blanz...
# Fetching works for Thomas Blaschke...
# Fetching works for Jean-Pierre Blaser...
# Fetching works for Rainer Blatt...
# Fetching works for Helen M. Blau...
# Fetching works for Horst Bleckmann...
# Fetching works for Günter Blöschl...
# Fetching works for Hans-Heinrich Blotevogel...
# Fetching works for Christoph Bock...
# Fetching works for Michael Joachim Bonell...
# Fetching works for Jürgen Borchhardt...
# Fetching works for Włodzimierz Borodziej...
# Fetching works for Axel Börsch-Supan...
# Fetching works for Axel Borsdorf...
# Fetching works for Richard Bösel...
# Fetching works for Jacques Bouveresse...
# Fetching works for John W. Boyer...
# Fetching works for Kaan Boztug...
# Fetching works for Karl Dietrich Bracher...
# Fetching works for Peter Brang...
# Fetching works for Georg Brasseur...
# Fetching works for Achim Brauer...
# Fetching works for Georg Peter Braulik...
# Fetching works for Jürgen Braunstein...
# Fetching works for Michel Breger...
# Fetching works for Gottfried Brem...
# Fetching works for Jan N. Bremmer...
# Fetching works for Wolfgang H. Breunlich...
# Fetching works for Wolfgang Brezinka...
# Fetching works for Hans Briegel...
# Fetching works for Günter Brucher...
# Fetching works for Gerhart Bruckmann...
# Fetching works for Ernst Bruckmüller...
# Fetching works for Wolfgang Brückner...
# Fetching works for Gerhard Budin...
# Fetching works for Julia Budka...
# Fetching works for Alejandro Raul Burga Ramos...
# Fetching works for Joachim Burgdörfer...
# Fetching works for Manfred Burgstaller...
# Fetching works for Otto Burkard...
# Fetching works for Walter Burkert...
# Fetching works for Meinrad Busslinger...
# Fetching works for Vladimír Bužek...
# Fetching works for Peter Bydlinski...
# Fetching works for Claus-Wilhelm Canaris...
# Fetching works for Carmen Cardelle de Hartmann...
# Fetching works for Louis Carlen...
# Fetching works for Giovanni Battista Castiglioni...
# Fetching works for Marina Cattaruzza...
# Fetching works for Federico Celestini...
# Fetching works for Komaravolu Chandrasekharan...
# Fetching works for Emmanuelle Charpentier...
# Fetching works for Mark W. Chase...
# Fetching works for Hai Cheng...
# Fetching works for Kenneth R. Chien...
# Fetching works for Maria Christakis...
# Fetching works for Enno Christophers...
# Fetching works for Evangelos Chrysos...
# Fetching works for Johann Cigler...
# Fetching works for Ignacio J. Cirac...
# Fetching works for Christopher M. Clark...
# Fetching works for Gary B. Cohen...
# Fetching works for Adrian Constantin...
# Fetching works for Michael P. Conzen...
# Fetching works for Paul Corkum...
# Fetching works for Thomas Corsten...
# Fetching works for Moritz Csáky...
# Fetching works for Christa Cuchiero...
# Fetching works for Yasin Dagdas...
# Fetching works for Falko Daim...
# Fetching works for Joachim Dalfen...
# Fetching works for Georg Danek...
# Fetching works for Robert Danzer...
# Fetching works for Lorraine Daston...
# Fetching works for Elisa  Davoli...
# Fetching works for Igor Bert Dawid...
# Fetching works for Patrizia de Bernardo Stempel...
# Fetching works for Gemma De les Coves...
# Fetching works for Bruno De Nicola...
# Fetching works for Nicla  De Zorzi...
# Fetching works for Peter Deetjen...
# Fetching works for Gerhard Dehm...
# Fetching works for Stefanie Dehnen...
# Fetching works for Manfred Deistler...
# Fetching works for Agnes Dellinger...
# Fetching works for Alexander Demandt...
# Fetching works for Helmut Denk...
# Fetching works for Barry J. Dickson...
# Fetching works for Ulrike Diebold...
# Fetching works for Egbert Dierker...
# Fetching works for Cora Dietl...
# Fetching works for Nina A. Dmitrieva...
# Fetching works for Gerhard Dobesch...
# Fetching works for Gabriele Doblhammer-Reiter...
# Fetching works for Liam Dolan...
# Fetching works for Rafael Domingo...
# Fetching works for Michael Doneus...
# Fetching works for Friedrich Dorner...
# Fetching works for Claudia Draxl...
# Fetching works for Wolfgang Ulrich Dressler...
# Fetching works for Michael Drmota...
# Fetching works for Ernst Peter Michael Dronke...
# Fetching works for Heinz Duchhardt...
# Fetching works for Klaus Düwel...
# Fetching works for Friedrich Dydak...
# Fetching works for Katarzyna Dziubalska-Kołaczyk...
# Fetching works for Josef Eberhardsteiner...
# Fetching works for Jürgen Eckert...
# Fetching works for Herbert Edelsbrunner...
# Fetching works for Hubert Christian Ehalt...
# Fetching works for Friedrich Ehrendorfer...
# Fetching works for Martin Ehrendorfer...
# Fetching works for Bernhard Ehrenzeller...
# Fetching works for Ludwig M. Eichinger...
# Fetching works for Michael Eichmair...
# Fetching works for Heiner Eichner...
# Fetching works for Manfred Eigen...
# Fetching works for Manfred Einsiedler...
# Fetching works for Thomas Eiter...
# Fetching works for Ivar Ekeland...
# Fetching works for Wilfried Ellmeier...
# Fetching works for Vincent Eltschinger...
# Fetching works for Heinz Engl...
# Fetching works for Johannes Erben...
# Fetching works for László Erdös...
# Fetching works for Gerhard Ertl...
# Fetching works for Maria J. Esteban...
# Fetching works for Richard John Evans...
# Fetching works for Robert John Weston Evans...
# Fetching works for Itamar Even-Zohar...
# Fetching works for Ludwig D. Faddeev...
# Fetching works for Heinz Falk...
# Fetching works for Gerda Falkner...
# Fetching works for Reinhard Fässler...
# Fetching works for Heinz Faßmann...
# Fetching works for Bénédicte Fauvarque-Cosson...
# Fetching works for Ernst Fehr...
# Fetching works for Gustav Feichtinger...
# Fetching works for Johannes Feichtinger...
# Fetching works for Martin S. Feldstein...
# Fetching works for Hannes A. Fellner...
# Fetching works for Sebastian Felten...
# Fetching works for Francesca Ferlaino...
# Fetching works for Günter Bernhard L. Fettweis...
# Fetching works for Ingeborg Fiala-Fürst...
# Fetching works for Wolfgang Fichtner...
# Fetching works for Hermann Fillitz...
# Fetching works for Jörg Finsinger...
# Fetching works for Andrea Fischer...
# Fetching works for Peter Fischer...
# Fetching works for Manfred M. Fischer...
# Fetching works for Hellmut F. Fischmeister...
# Fetching works for Jürgen Fleig...
# Fetching works for Konstanze Fliedl...
# Fetching works for August Florian...
# Fetching works for Rudolf Flotzinger...
# Fetching works for Monika Fludernik...
# Fetching works for Helmut Flügel...
# Fetching works for Franz Födermayr...
# Fetching works for Pál Fodor...
# Fetching works for Herbert Foltinek...
# Fetching works for Sebastian  Forster...
# Fetching works for Heinz G. Fortak...
# Fetching works for Bert Fragner...
# Fetching works for Wolfgang Frank...
# Fetching works for Peter Robert Franke...
# Fetching works for Peter Fratzl...
# Fetching works for Stefan Freunberger...
# Fetching works for Johannes Fried...
# Fetching works for Herwig Friesinger...
# Fetching works for Wolfgang Frisch...
# Fetching works for Sylvia Frühwirth-Schnatter...
# Fetching works for Erwin Führer...
# Fetching works for Alexia Fürnkranz-Prskawetz...
# Fetching works for Alois Fürstner...
# Fetching works for Helmut Gadner...
# Fetching works for Natalia Gagarina...
# Fetching works for Franz Gamillscheg...
# Fetching works for Thomas V. Gamkrelidze...
# Fetching works for Hans-Martin Gauger...
# Fetching works for Patrick J. Geary...
# Fetching works for Michael Gehler...
# Fetching works for Monika Gehrig-Merz...
# Fetching works for Johannes Geiss...
# Fetching works for Klaus Gersten...
# Fetching works for Martin H. Gerzabek...
# Fetching works for Michael Ghil...
# Fetching works for Patrizia Giampieri-Deutsch...
# Fetching works for Gerhard Giebisch...
# Fetching works for Oswald Giering...
# Fetching works for Simone Gingrich...
# Fetching works for Andre Gingrich...
# Fetching works for Karl-Heinz Alois Glaßmeier...
# Fetching works for Gerhard Glatzel...
# Fetching works for Claire F. Gmachl...
# Fetching works for Michael  Gnant...
# Fetching works for Helmut Gneuss...
# Fetching works for Hans Goebl...
# Fetching works for Ivan Golub...
# Fetching works for Leticia González...
# Fetching works for Maciej Górny...
# Fetching works for Georg Gottlob...
# Fetching works for Georg Grabherr...
# Fetching works for Sherrill Grace...
# Fetching works for Bernhard Grasemann...
# Fetching works for Manfred Grasserbauer...
# Fetching works for Daniel M. Greenberger...
# Fetching works for Wolfgang Greisenegger...
# Fetching works for Frantz Grenet...
# Fetching works for Herfried Griengl...
# Fetching works for Nicolas Grimal...
# Fetching works for Rudolf Grimm...
# Fetching works for Irmgard Griss...
# Fetching works for Jasmina Grković-Major...
# Fetching works for Rudolf Grosschedl...
# Fetching works for Peter Manfred Gruber...
# Fetching works for Gernot Gruber...
# Fetching works for Oskar Grün...
# Fetching works for Dieter Gutknecht...
# Fetching works for Giselher Guttmann...
# Fetching works for Mats Gyllenberg...
# Fetching works for Kálmán Györgyi...
# Fetching works for Rudolf Haag...
# Fetching works for Gerhard Haerendel...
# Fetching works for Stefan Hagel...
# Fetching works for Othmar Hageneder...
# Fetching works for Martin Hairer...
# Fetching works for Ivo Hajnal...
# Fetching works for John Haldon...
# Fetching works for Max Haller...
# Fetching works for Franz Halter-Koch...
# Fetching works for Ernst Hanisch...
# Fetching works for Ulf Hannerz...
# Fetching works for Edouard Hannezo...
# Fetching works for Christian Hannick...
# Fetching works for Aage A. Hansen-Löve...
# Fetching works for Michael Hantel...
# Fetching works for Jens-Uwe Hartmann...
# Fetching works for Maximilian Hartmuth...
# Fetching works for Mathias Harzhauser...
# Fetching works for Horst Haselsteiner...
# Fetching works for Günther Hasinger...
# Fetching works for Friederike Hassauer...
# Fetching works for Wolfgang Haubrichs...
# Fetching works for Gabriele Haug-Moritz...
# Fetching works for Hermann Franz Haupt...
# Fetching works for Uta Heil...
# Fetching works for Wolf-Dieter Heiss...
# Fetching works for Philipp U. Heitz...
# Fetching works for Christian Hellmich...
# Fetching works for Gilbert Helmberg...
# Fetching works for Monika Henzinger...
# Fetching works for Thomas A. Henzinger...
# Fetching works for Milan Herak...
# Fetching works for Gerhard Herndl...
# Fetching works for Marie Louise Herzfeld-Schild...
# Fetching works for Hans-Joachim Hinrichsen...
# Fetching works for Oskar v. Hinüber...
# Fetching works for Ivan Hlaváček...
# Fetching works for Milan Hlavačka...
# Fetching works for Claudia Höbartner...
# Fetching works for Erwin Hochmair...
# Fetching works for Ingeborg Hochmair-Desoyer...
# Fetching works for Sepp Hochreiter...
# Fetching works for Hartwig Höcker...
# Fetching works for Ivo Ludwig Hofacker...
# Fetching works for Barbara Hohn...
# Fetching works for Hans Höller...
# Fetching works for Gerald  Holton...
# Fetching works for Gerhard A. Holzapfel...
# Fetching works for Robert Holzmann...
# Fetching works for Heinrich Honsell...
# Fetching works for Barbara Horejs...
# Fetching works for Oleh Hornykiewicz...
# Fetching works for Konstantin-Alexander Hossmann...
# Fetching works for Yaroslav Hrytsak...
# Fetching works for Christoph Huber...
# Fetching works for Thomas J. R. Hughes...
# Fetching works for Pascale Hugon...
# Fetching works for Hermann Hunger...
# Fetching works for Nicola Hüsing...
# Fetching works for Reinhard Franz Josef Hüttl...
# Fetching works for Anthony A. Hyman...
# Fetching works for Ataç İmamoğlu...
# Fetching works for Christoph Irmscher...
# Fetching works for Hans Irschik...
# Fetching works for Shiro Ishii...
# Fetching works for Hans Peter Isler...
# Fetching works for Lisa Isola...
# Fetching works for Clemens Jabloner...
# Fetching works for Éva Jakab...
# Fetching works for Bernhard Jakoby...
# Fetching works for Sigrid Jalkotzy-Deger...
# Fetching works for Cecilia Jarlskog...
# Fetching works for Erik Jayme...
# Fetching works for Franz Jeglitsch...
# Fetching works for Thomas Jenuwein...
# Fetching works for Hans Joas...
# Fetching works for Werner Jobst...
# Fetching works for Zdenek Johan...
# Fetching works for Peter Johanek...
# Fetching works for Julian Johnson...
# Fetching works for Michael Jursa...
# Fetching works for Thede Kahl...
# Fetching works for Barbara Kaltenbacher...
# Fetching works for Manfred  Kaltenbacher...
# Fetching works for Eric R. Kandel...
# Fetching works for Andreas Kappeler...
# Fetching works for Vassos Karageorghis...
# Fetching works for Stevan Karamata...
# Fetching works for Matthias Karmasin...
# Fetching works for Martin Karplus...
# Fetching works for Georg Kaser...
# Fetching works for Daniel Kastler...
# Fetching works for Radoslav Katičić...
# Fetching works for Stephen Ira Katz...
# Fetching works for Hubert Kaufhold...
# Fetching works for Sylvia Kaufmann...
# Fetching works for Anke Rita Kaysser-Pyzalla...
# Fetching works for Katrin Keller...
# Fetching works for Birgit Kellner...
# Fetching works for Fritz Kelnhofer...
# Fetching works for Thomas Kenner...
# Fetching works for Manfred Kern...
# Fetching works for Eva Kernbauer...
# Fetching works for Ferenc Kiefer...
# Fetching works for Rudolf Kippenhahn...
# Fetching works for Gottfried Kirchengast...
# Fetching works for Britta Klagge...
# Fetching works for Michał Kleiber...
# Fetching works for Hans-Dieter Klein...
# Fetching works for Jürgen Kleine-Vehn...
# Fetching works for Nina Klimburg-Witjes...
# Fetching works for Bernd Ulrich Kluge...
# Fetching works for Alfred Kluwick...
# Fetching works for Fritz Peter Knapp...
# Fetching works for Sylvia Knapp...
# Fetching works for Jürgen Knoblich...
# Fetching works for Wolfgang Knoll...
# Fetching works for Christian Köberl...
# Fetching works for Walter Koch...
# Fetching works for Johannes Koder...
# Fetching works for Alfred Kohler...
# Fetching works for Alwin Köhler...
# Fetching works for Martin Kohli...
# Fetching works for Walter Kohn...
# Fetching works for Kurt L. Komarek...
# Fetching works for Robert Konrat...
# Fetching works for Hermann Kopetz...
# Fetching works for Hans-Georg Koppensteiner...
# Fetching works for Martin Korenjak...
# Fetching works for Karl Korinek...
# Fetching works for Christian Körner...
# Fetching works for Dušan Kováč...
# Fetching works for Helmut Koziol...
# Fetching works for Frauke Kraas...
# Fetching works for Dietrich Kraft...
# Fetching works for Ernst August Kramer...
# Fetching works for Christoph Kratky...
# Fetching works for Christian Krattenthaler...
# Fetching works for Ferenc Krausz...
# Fetching works for Bernhard Kräutler...
# Fetching works for Josef Kreiner...
# Fetching works for Georg Kresse...
# Fetching works for Otto Kresten...
# Fetching works for Friedrich Krinzinger...
# Fetching works for Guido Kroemer...
# Fetching works for Karl Kroeschell...
# Fetching works for Kurt Krolop...
# Fetching works for James Glenn Krueger...
# Fetching works for Hans-Henrik Krummacher...
# Fetching works for Andreas Kugi...
# Fetching works for Michael Kuhn...
# Fetching works for Richard Küng...
# Fetching works for Wilfried Kurz...
# Fetching works for Walter Kutschera...
# Fetching works for Jan Květ...
# Fetching works for Paul Alexander Kyrle...
# Fetching works for Anne L’Huillier...
# Fetching works for Johanna Laakso...
# Fetching works for Sabine Ladstätter...
# Fetching works for Christopher F. Laferl...
# Fetching works for Peter Laggner...
# Fetching works for Julia Lajta-Novak...
# Fetching works for Vasileios Lambrinoudakis...
# Fetching works for Claus Lamm...
# Fetching works for Irene Marthe Lang...
# Fetching works for Armin Lange...
# Fetching works for Robert S. Langer...
# Fetching works for Heinz Langer...
# Fetching works for Walter Larcher...
# Fetching works for Hans Lassmann...
# Fetching works for Reinhard Lauer...
# Fetching works for Jacques Le Rider...
# Fetching works for Klaus Lechner...
# Fetching works for Joseph Theodoor Leerssen...
# Fetching works for Gustav Adolf Lehmann...
# Fetching works for Marianne Johanna Lehmkuhl...
# Fetching works for Ursula Lehr...
# Fetching works for Helga Leitner...
# Fetching works for Mikhail Lemeshko...
# Fetching works for Alexandra N. Lenz...
# Fetching works for Silke Leopold...
# Fetching works for Johannes A. Lercher...
# Fetching works for Willem J. M. Levelt...
# Fetching works for Gary Libben...
# Fetching works for Elliott Lieb...
# Fetching works for Gene Elden Likens...
# Fetching works for Mandana E. Limbert...
# Fetching works for Andrea Lindmayr-Brandl...
# Fetching works for Thomas Lindner...
# Fetching works for Karl Lintner...
# Fetching works for Benjamin List...
# Fetching works for Birgit Lodes...
# Fetching works for Michele Loporcaro...
# Fetching works for Hellmut Lorenz...
# Fetching works for Martin Löschnigg...
# Fetching works for Peter Lucas...
# Fetching works for Monika Ludwig...
# Fetching works for Gerhard Luf...
# Fetching works for Thomas Luger...
# Fetching works for Helmut Lukesch...
# Fetching works for Reimar Lüst...
# Fetching works for Christina Lutter...
# Fetching works for Wolfgang Lutz...
# Fetching works for Marc Luy...
# Fetching works for Séamus Mac Mathúna...
# Fetching works for Thomas Magauer...
# Fetching works for Astrid Mager...
# Fetching works for Claudio Magris...
# Fetching works for Christian Mair...
# Fetching works for Melanie Malzahn...
# Fetching works for Herbert Mang...
# Fetching works for Wolfgang Mantl...
# Fetching works for Joseph Maran...
# Fetching works for Michael Marberger...
# Fetching works for Raimund Margreiter...
# Fetching works for Peter Markowich...
# Fetching works for James H. Marrow...
# Fetching works for Alberto Martino...
# Fetching works for Herbert Matis...
# Fetching works for Aleksandar Matković...
# Fetching works for Franz Matscher...
# Fetching works for Richard Viktor Mattessich...
# Fetching works for Hartmut  Matthäus...
# Fetching works for Paolo Matthiae...
# Fetching works for Marjori Ann Matzke...
# Fetching works for Nuno Maulide...
# Fetching works for Bernd Mayer...
# Fetching works for Henry M. R. E. Mayr-Harting...
# Fetching works for Paul Heinz Mayrhofer...
# Fetching works for Otto Mayrhofer-Krammel...
# Fetching works for Brigitte Mazohl...
# Fetching works for Rosamond McKitterick...
# Fetching works for Peter McMullen...
# Fetching works for Wolfgang F. G. Mecklenbräuker...
# Fetching works for Wolfgang Meid...
# Fetching works for Anne Sophie Meincke...
# Fetching works for Igor Mel'čuk...
# Fetching works for Fritz Melchers...
# Fetching works for Sarah Melzer...
# Fetching works for Günther Meschke...
# Fetching works for Bruno Messerli...
# Fetching works for Michael Metzeltin...
# Fetching works for Carola Metzner-Nebelsick...
# Fetching works for Ronald Micura...
# Fetching works for Gero Miesenböck...
# Fetching works for Hanno Millesi...
# Fetching works for Nina Mirnig...
# Fetching works for Diana Mishkova...
# Fetching works for Jürgen Mittelstraß...
# Fetching works for Christian  Mitterer...
# Fetching works for Fritz Mitthof...
# Fetching works for Kimberly Modic...
# Fetching works for Stephan Moebius...
# Fetching works for Helmuth Möhwald...
# Fetching works for Andreas F. Molisch...
# Fetching works for Hans Mommsen...
# Fetching works for Alessandro Montanari...
# Fetching works for Helmut Moritz...
# Fetching works for Cécile Morrisson...
# Fetching works for Gina E. Moseley...
# Fetching works for Helfried Mostler...
# Fetching works for Gérard A. Mourou...
# Fetching works for Nicolette Mout...
# Fetching works for Dennis C. Mueller...
# Fetching works for Wolfgang Mueller...
# Fetching works for Ivan I. Mueller...
# Fetching works for Sandra Müller...
# Fetching works for Ulrike Müller-Böker...
# Fetching works for Johann Mulzer...
# Fetching works for Ulrike Müßig...
# Fetching works for Karol Myśliwiec...
# Fetching works for Herta Nagl-Docekal...
# Fetching works for Norman M. Naimark...
# Fetching works for Rumi Nakamura...
# Fetching works for George (Gia) Sch. Nakhutsrishvili...
# Fetching works for Kim A. Nasmyth...
# Fetching works for David Natal Villazala...
# Fetching works for Adolf Neckel...
# Fetching works for Robert Nedoma...
# Fetching works for Wolfgang  Neubauer...
# Fetching works for Christine Neugebauer-Maresch...
# Fetching works for Winfried L. Neuhuber...
# Fetching works for Walter Neupert...
# Fetching works for Gerhard Neweklowsky...
# Fetching works for Stefan Michael Newerkla...
# Fetching works for Harald Niederreiter...
# Fetching works for Christian Roland Noe...
# Fetching works for Magnus Nordborg...
# Fetching works for Dieter Nörr...
# Fetching works for Marie-Louise Nosch...
# Fetching works for Sir Gustav Joseph Victor Nossal...
# Fetching works for Heinrich Nöth...
# Fetching works for Martin A. Nowak...
# Fetching works for Helga Nowotny...
# Fetching works for Onora O'Neill...
# Fetching works for Anna Christina Obenauf...
# Fetching works for Paul Oberhammer...
# Fetching works for Gerhard Oberhammer...
# Fetching works for Dieter Oesterhelt...
# Fetching works for Werner Ogris...
# Fetching works for Oskar Friedrich Olaj...
# Fetching works for Thomas Olechowski...
# Fetching works for Gerhard Opelz...
# Fetching works for Gherardo Ortalli...
# Fetching works for Marcus Ossiander...
# Fetching works for Jurij Sergejewitsch Ossipov...
# Fetching works for Jürgen Osterhammel...
# Fetching works for Jörg A. Ott...
# Fetching works for Alfred E. von Overbeck...
# Fetching works for Peter Palese...
# Fetching works for Herbert Palme...
# Fetching works for Bernhard Palme...
# Fetching works for Jian-Wei Pan...
# Fetching works for Oswald Panagl...
# Fetching works for Lucy Y. Pao...
# Fetching works for Fritz Paschke...
# Fetching works for Gernot Patzelt...
# Fetching works for Josef Penninger...
# Fetching works for Ernst Pernicka...
# Fetching works for Peter Pernthaler...
# Fetching works for Anne Peters...
# Fetching works for Jan-Michael Peters...
# Fetching works for Jillian Petersen...
# Fetching works for Hellmuth Petsche...
# Fetching works for Johann Pfanzagl...
# Fetching works for Gerhard Pferschy...
# Fetching works for Otto Pfersmann...
# Fetching works for Jörg Pfleiderer...
# Fetching works for Gert Pfurtscheller...
# Fetching works for Philip Ivanov Philippov...
# Fetching works for Gernot Piccottini...
# Fetching works for Helmut Pichler...
# Fetching works for Hannes Pichler...
# Fetching works for Pierre Jean Pichot...
# Fetching works for Herbert Pietschmann...
# Fetching works for Werner E. Piller...
# Fetching works for Renate Johanna Pillinger...
# Fetching works for Rudolf Pischinger...
# Fetching works for Clemens Plaschka...
# Fetching works for Carolina Plescia...
# Fetching works for Walter L. Pohl...
# Fetching works for Walter Pohl...
# Fetching works for Hryhoriy Polshyn...
# Fetching works for Marianne Popp...
# Fetching works for Magdalena Pöschl...
# Fetching works for Barbara Prainsack...
# Fetching works for Rudolf Preimesberger...
# Fetching works for Anton Preisinger...
# Fetching works for Friedrich B. Prinz...
# Fetching works for Manfred Prisching...
# Fetching works for Stephan  Procházka...
# Fetching works for Paolo Prodi...
# Fetching works for Walter Puchner...
# Fetching works for Andreas Pülz...
# Fetching works for Denise Pumain...
# Fetching works for Sonja Puntscher Riekmann...
# Fetching works for Gernot Rabeder...
# Fetching works for Ljiljana Radonić...
# Fetching works for Piero Rafanelli...
# Fetching works for Andrej Rahten...
# Fetching works for Franz Rainer...
# Fetching works for Ekkehard Ramm...
# Fetching works for Franz G. Rammerstorfer...
# Fetching works for Friederike Range...
# Fetching works for Claudia Rapp...
# Fetching works for Armando Rastelli...
# Fetching works for Gudrun Rath...
# Fetching works for Isabelle Ratié...
# Fetching works for Helmut Rauch...
# Fetching works for Peter H. Raven...
# Fetching works for Karl M. A. Rawer...
# Fetching works for Katharina Rebay-Salisbury...
# Fetching works for Anton Rebhan...
# Fetching works for Ludwig Reich...
# Fetching works for Ingo Reiffenstein...
# Fetching works for Wolf Uwe Reimold...
# Fetching works for Susanne Reindl-Krauskopf...
# Fetching works for August Reinisch...
# Fetching works for André Reis...
# Fetching works for Elmar R. Reiter...
# Fetching works for Reinhold Remmert...
# Fetching works for Andrew Colin Renfrew...
# Fetching works for Andrea Rentmeister...
# Fetching works for Fritz Resinger...
# Fetching works for Georg Ress...
# Fetching works for Keywan Riahi...
# Fetching works for James R. Rice...
# Fetching works for Kurt R. Richter...
# Fetching works for Norbert G. Riedel...
# Fetching works for Willibald Riedler...
# Fetching works for Josef Riedmann...
# Fetching works for Wolfgang Riehle...
# Fetching works for Gert Riethmüller...
# Fetching works for Wolfgang Rindler...
# Fetching works for Zsigmond Ritoók...
# Fetching works for Monika Ritsch-Marte...
# Fetching works for Olivia Fiona Robinson...
# Fetching works for Alexandra Rodler-Rørbo...
# Fetching works for Teresa Rodríguez de las Heras Ballell...
# Fetching works for Juan Gualterio Roederer...
# Fetching works for Herbert Walter Roesky...
# Fetching works for Robert Rollinger...
# Fetching works for José Luis Romero...
# Fetching works for Maria Grazia Roncarolo...
# Fetching works for Artur Rosenauer...
# Fetching works for Leopold Rosenmayr...
# Fetching works for Michael Rössner...
# Fetching works for Mathias Walter Rotach...
# Fetching works for Carlo Rubbia...
# Fetching works for Helmut O. Rucker...
# Fetching works for Helmut Rumpler...
# Fetching works for Hans Georg Ruppe...
# Fetching works for Günther Rupprechter...
# Fetching works for Eda Sagarra...
# Fetching works for Richard Salomon...
# Fetching works for Roman Sandgruber...
# Fetching works for Friedrich Sandhofer...
# Fetching works for Birgit Sandkaulen...
# Fetching works for Niyazi Serdar Sariçiftçi...
# Fetching works for Michael Sarnthein-Lotichius...
# Fetching works for Pasqualina Maria Sarro...
# Fetching works for Paolo Sartori...
# Fetching works for Friedrich Schaller...
# Fetching works for Gottfried Schatz...
# Fetching works for Philipp  Scheibelreiter...
# Fetching works for Walter Scheidel...
# Fetching works for Eva Schernhammer...
# Fetching works for Rudolf Schieffer...
# Fetching works for Sabine Schindler...
# Fetching works for Philipp Schindler...
# Fetching works for Andrzej Schinzel...
# Fetching works for Wolfgang Schlager...
# Fetching works for Wolfgang P. Schleich...
# Fetching works for Christa Schleper...
# Fetching works for Hermann Schmalzried...
# Fetching works for Klaus Schmidt...
# Fetching works for Wolfgang Schmidt...
# Fetching works for Matthias  Schmidt...
# Fetching works for Johannes Schmidt...
# Fetching works for Alfred Schmidt...
# Fetching works for Arnold Schmidt...
# Fetching works for Ernst August Schmidt...
# Fetching works for Philipp Schmidt-Dengler...
# Fetching works for Ursula Schmidt-Erfurth...
# Fetching works for Sabine Schmidtke...
# Fetching works for Jörg Schmiedmayer...
# Fetching works for Lambert Schmithausen...
# Fetching works for Rüdiger Schmitt...
# Fetching works for Oliver Jens Schmitt...
# Fetching works for Kurt Schmoller...
# Fetching works for Isabel Schnabel...
# Fetching works for Wilhelm Schneider...
# Fetching works for Albrecht Schöne...
# Fetching works for Hans Peter Schönlaub...
# Fetching works for Peter Schönswetter...
# Fetching works for Carl E. Schorske...
# Fetching works for Peter Schreiner...
# Fetching works for Ulrich Schubert...
# Fetching works for Gerold Schuler...
# Fetching works for Rolf Schulte-Hermann...
# Fetching works for Birgitta Schultze-Bernhardt...
# Fetching works for Winfried Schulze...
# Fetching works for Josef Schurz...
# Fetching works for Peter Schuster...
# Fetching works for Gerhard Schütz...
# Fetching works for Sebastian Schütze...
# Fetching works for Hans Schwabl...
# Fetching works for Karlheinz Schwarz...
# Fetching works for Florian Schwarz...
# Fetching works for Hans Georg Schwarzacher...
# Fetching works for Walther Schwarzacher...
# Fetching works for Günter C. Schweiger...
# Fetching works for Fritz Schweiger...
# Fetching works for Michael Schweitzer...
# Fetching works for Dieter Schweizer...
# Fetching works for Hugo Schwendenwein...
# Fetching works for Martin Seger...
# Fetching works for Christian Seidl...
# Fetching works for Horst Seidler...
# Fetching works for Stephan Johannes Seidlmayer...
# Fetching works for Robert  Seiringer...
# Fetching works for Ali Mehmet Celâl Şengör...
# Fetching works for Veronika Sexl...
# Fetching works for Demetra Sfendoni-Mentzou...
# Fetching works for Francesco Sferra...
# Fetching works for Danuta Shanzer...
# Fetching works for M. Rahim Shayegan...
# Fetching works for Ethan M. Shevach...
# Fetching works for Maria Sibilia...
# Fetching works for Susanne Sievers...
# Fetching works for Karl Sigmund...
# Fetching works for Petra Sijpesteijn...
# Fetching works for Oleg Simakov...
# Fetching works for Barry Simon...
# Fetching works for Nicholas Sims-Williams...
# Fetching works for Hans-Werner Sinn...
# Fetching works for Peter Sitte...
# Fetching works for Quentin R. D. Skinner...
# Fetching works for Uwe B. Sleytr...
# Fetching works for John Victor Small...
# Fetching works for Kurt Smolak...
# Fetching works for Josef Smolen...
# Fetching works for Werner Sollors...
# Fetching works for Éva Somogyi...
# Fetching works for Vera T. Sós...
# Fetching works for Nicola Spaldin...
# Fetching works for Katta Spiel...
# Fetching works for Christoph Spötl...
# Fetching works for Hellmuth Stachel...
# Fetching works for Saskia Stachowitsch...
# Fetching works for Peter F. Stadler...
# Fetching works for Lawrence E. Stager...
# Fetching works for Sigrid Stagl...
# Fetching works for André Stahl...
# Fetching works for Maria A. Stassinopoulou...
# Fetching works for Paul Stefanovits...
# Fetching works for Florian  Steger...
# Fetching works for Erwin Stein...
# Fetching works for Sybille Steinbacher...
# Fetching works for Peter Steinhauser...
# Fetching works for Friedrich Franz Steininger...
# Fetching works for Ernst Steinkellner...
# Fetching works for Hans-Peter Steinrück...
# Fetching works for Barbara Stelzl-Marx...
# Fetching works for Günter Stemberger...
# Fetching works for Stig T. Stenholm...
# Fetching works for Nikolaus K. Stephanidis...
# Fetching works for Peter Štih...
# Fetching works for Georg Stingl...
# Fetching works for Gerold Stoll...
# Fetching works for Barbara Stollberg-Rilinger...
# Fetching works for Gerald Stourzh...
# Fetching works for Helmut Strasser...
# Fetching works for Erich Wolfgang Streissler...
# Fetching works for Jörg Striessnig...
# Fetching works for Josef Strobl...
# Fetching works for Arno Strohmeyer...
# Fetching works for Tod F. Stuessy...
# Fetching works for Christian Sturmbauer...
# Fetching works for Robert Samuel Summers...
# Fetching works for Hans Sünkel...
# Fetching works for Giulio Superti-Furga...
# Fetching works for Arnold Suppan...
# Fetching works for Ernst Christoph Suttner...
# Fetching works for Gustav Andreas Tammann...
# Fetching works for Elly Tanaka...
# Fetching works for Éva Tardos...
# Fetching works for Ulrich Technau...
# Fetching works for Jaroslav Tejral...
# Fetching works for Werner Telesko...
# Fetching works for Heinz-Elmar Tenorth...
# Fetching works for Erich Thenius...
# Fetching works for Udo Thiel...
# Fetching works for Gerhard Thür...
# Fetching works for Robert F. Tichy...
# Fetching works for Klement Tockner...
# Fetching works for Theodor Tomandl...
# Fetching works for Erich Trapp...
# Fetching works for Dirk Trauner...
# Fetching works for Michael Trauner...
# Fetching works for Marko Trogrlić...
# Fetching works for Hans Tuppy...
# Fetching works for Franz-Josef Ulm...
# Fetching works for Melanie Unseld...
# Fetching works for Miriam M. Unterlass...
# Fetching works for Gerald Urban...
# Fetching works for Otto Helmut Urban...
# Fetching works for Boris A. Uspenskij...
# Fetching works for Gerd W. Utermann...
# Fetching works for Alice Vadrot...
# Fetching works for Rudolf Valenta...
# Fetching works for Peter van Nieuwenhuizen...
# Fetching works for Mihai-Cristian Vasile...
# Fetching works for Michael Johannes Vellekoop...
# Fetching works for Beatriz Vicoso...
# Fetching works for Karl Vodrazka...
# Fetching works for Thomas Vogl...
# Fetching works for Arndt von Haeseler...
# Fetching works for Klaus von Klitzing...
# Fetching works for Alfred Wagenhofer...
# Fetching works for Horst Wagner...
# Fetching works for Andreas  Wagner...
# Fetching works for Günter P. Wagner...
# Fetching works for Karl Wagner...
# Fetching works for Sigurd Wagner...
# Fetching works for Erwin F. Wagner...
# Fetching works for Michael Wagner...
# Fetching works for Birgit Wagner...
# Fetching works for Scott Waitukaitis...
# Fetching works for Wolfgang A. Wall...
# Fetching works for Grete Walter-Klingenstein...
# Fetching works for Heinrich Wänke...
# Fetching works for Graham Warren...
# Fetching works for Peter Michael Warren...
# Fetching works for Andrea Weber...
# Fetching works for Harald Wolfgang Weber...
# Fetching works for Gerhard Wegner...
# Fetching works for Rüdiger Wehner...
# Fetching works for Susanne Weigelin-Schwiedrzik...
# Fetching works for Stefan Weinfurter...
# Fetching works for Astrid Weiss...
# Fetching works for Günter Weiss...
# Fetching works for Werner Welzig...
# Fetching works for Emo Welzl...
# Fetching works for Christiane Wendehorst...
# Fetching works for Samuel A. Werner...
# Fetching works for Diter von Wettstein...
# Fetching works for Manfred Wicke...
# Fetching works for Gerhard Widmer...
# Fetching works for Ewald Wiederin...
# Fetching works for Maria Katharina  Wiedlack...
# Fetching works for Malcolm Hewitt Wiener...
# Fetching works for Josef Wiesehöfer...
# Fetching works for Wolfgang Wieser...
# Fetching works for Heinz Gregor Wieser...
# Fetching works for Michaela Wiesinger...
# Fetching works for Peter Wiesinger...
# Fetching works for Luzius Wildhaber...
# Fetching works for Günther Wilke...
# Fetching works for F. Ludwig Wilke...
# Fetching works for Jürgen Wilke...
# Fetching works for Harco Willems...
# Fetching works for Anouk Willemsen...
# Fetching works for Michaela Windischgrätz...
# Fetching works for Verena Winiwarter...
# Fetching works for Thomas Winkelbauer...
# Fetching works for Hans Winkler...
# Fetching works for Georg Winter...
# Fetching works for Renée Winter...
# Fetching works for Erich Winter...
# Fetching works for Irene J. Winter...
# Fetching works for Gerhard Wirth...
# Fetching works for Norbert Richard Wolf...
# Fetching works for Alois Wolf...
# Fetching works for Eckhard Wolf...
# Fetching works for Werner Wolf...
# Fetching works for Ulrich Wolf...
# Fetching works for Klaus Wolff...
# Fetching works for Herwig Wolfram...
# Fetching works for Bernhard Woytek...
# Fetching works for Dagmar Wujastyk...
# Fetching works for Keizô Yamamoto...
# Fetching works for Yeong-Bin Yang...
# Fetching works for William Edgar Yates...
# Fetching works for Bilge Yıldız...
# Fetching works for Stephen G. Young...
# Fetching works for Waldemar Zacharasiewicz...
# Fetching works for Hans Georg Zachau...
# Fetching works for Anatoly G. Zagorodny...
# Fetching works for Kurt Zatloukal...
# Fetching works for Josef Zechner...
# Fetching works for Rudolf Zechner...
# Fetching works for Anton Zeilinger...
# Fetching works for Josef Zemann...
# Fetching works for Wolfgang Zenker...
# Fetching works for Michael Zgurovsky...
# Fetching works for Yong-de Zhang...
# Fetching works for Shuguang Zhang...
# Fetching works for Franz Ziegler...
# Fetching works for Peter V. Zima...
# Fetching works for Reinhard Zimmermann...
# Fetching works for Harald Volkmar Zimmermann...
# Fetching works for Michel Zink...
# Fetching works for Ernst K. Zinner...
# Fetching works for Natalia A. Zinovieva...
# Fetching works for Theodore J. Ziolkowski...
# Fetching works for Jan M. Ziolkowski...
# Fetching works for Peter Zoller...
# Fetching works for Alessandro Zuccari...
# Fetching works for Paul Michael Zulehner...
# Filtered works data saved to JSON: austrian_academy_works_filtered.json
# Filtered works data saved to CSV: austrian_academy_works_filtered.csv

# %%
import json

# Input and output file paths
input_file = "/content/austrian_academy_works_filtered.json"  # Replace with your distorted JSON file path
output_file = "/content/austrian_academy_works_filtered_restored.json"  # Restored output file

# Load the distorted JSON file
with open(input_file, "r", encoding="utf-8") as infile:
    data = json.load(infile)

# Decode Unicode escape sequences
def decode_unicode(data):
    if isinstance(data, dict):
        return {key: decode_unicode(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [decode_unicode(item) for item in data]
    elif isinstance(data, str):
        try:
            # Attempt to decode the string
            return data.encode('latin1').decode('utf-8')
        except (UnicodeEncodeError, UnicodeDecodeError):
            # Return the original string if decoding fails
            return data
    else:
        return data

restored_data = decode_unicode(data)

# Save the restored JSON file
with open(output_file, "w", encoding="utf-8") as outfile:
    json.dump(restored_data, outfile, ensure_ascii=False, indent=4)

print(f"Restored file saved to {output_file}")
# Out:
# Restored file saved to /content/austrian_academy_works_filtered_restored.json

# %%
import pandas as pd

# Input and output file paths
input_file = "/content/austrian_academy_works_filtered.csv"  # Replace with your distorted CSV file path
output_file = "austrian_academy_works_filtered_restored.csv"  # Restored output file

# Load the distorted CSV file
df = pd.read_csv(input_file)

# Decode Unicode escape sequences in strings
def decode_unicode_string(value):
    if isinstance(value, str):  # Ensure the value is a string before decoding
        try:
            return value.encode('latin1').decode('utf-8')
        except (UnicodeEncodeError, UnicodeDecodeError):
            return value  # Return the original value if decoding fails
    return value  # Return the value as-is if it's not a string

# Apply the Unicode decoding function to all string cells in the DataFrame
for col in df.columns:
    if df[col].dtype == 'object':  # Apply only to object (string) columns
        df[col] = df[col].apply(decode_unicode_string)

# Save the restored CSV file
df.to_csv(output_file, index=False)

print(f"Restored file saved to {output_file}")
# Out:
# Restored file saved to austrian_academy_works_filtered_restored.csv

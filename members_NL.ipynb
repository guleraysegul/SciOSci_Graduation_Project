# %%
pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)

# %%
import requests
from bs4 import BeautifulSoup
import json
import time

base_url = "https://www.knaw.nl/leden?page="
members = []

# Loop through all 26 pages
for page in range(1, 27):
    print(f"Processing page {page}...")
    response = requests.get(f"{base_url}{page}")

    if response.status_code != 200:
        print(f"Failed to retrieve page {page}")
        continue

    soup = BeautifulSoup(response.content, "html.parser")
    member_entries = soup.find_all("div", class_="sc-d4b23084-0 knUljo")  # Targeting individual member entries

    for entry in member_entries:
        name_tag = entry.find("h3")  # Extracting the name
        expertise_tag = entry.find("div", class_="expertises")  # Extracting the expertise

        # Extract name and expertise text
        name = name_tag.get_text(strip=True) if name_tag else "Unknown"
        expertise = expertise_tag.get_text(strip=True) if expertise_tag else "Unknown"

        members.append({"name": name, "expertise": expertise})

    time.sleep(1)  # Polite delay to avoid overloading the server

# Save to JSON file
with open("knaw_members.json", "w", encoding="utf-8") as f:
    json.dump(members, f, indent=4, ensure_ascii=False)

print("Scraping completed. Data saved to 'knaw_members.json'.")
# Out:
# Processing page 1...
# Processing page 2...
# Processing page 3...
# Processing page 4...
# Processing page 5...
# Processing page 6...
# Processing page 7...
# Processing page 8...
# Processing page 9...
# Processing page 10...
# Processing page 11...
# Processing page 12...
# Processing page 13...
# Processing page 14...
# Processing page 15...
# Processing page 16...
# Processing page 17...
# Processing page 18...
# Processing page 19...
# Processing page 20...
# Processing page 21...
# Processing page 22...
# Processing page 23...
# Processing page 24...
# Processing page 25...
# Processing page 26...
# Scraping completed. Data saved to 'knaw_members.json'.

# %%
import json

# Load the JSON file
with open('knaw_members.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Count members based on the structure
if isinstance(data, list):  # If the JSON is a list
    member_count = len(data)
elif isinstance(data, dict):  # If the JSON is a dictionary
    # Assuming the key 'members' contains the list of members
    member_count = len(data.get('members', []))
else:
    member_count = 0

print(f"Total number of members: {member_count}")
# Out:
# Total number of members: 624

# %%
import requests
import json
import time
import pandas as pd

# Input and output file paths
input_file_path = "/content/knaw_members.json"  # Replace with actual file path
output_file_path = "knaw_author_ids.json"

# Load KNAW members JSON
with open(input_file_path, 'r', encoding='utf-8') as file:
    knaw_members = json.load(file)

# OpenAlex API endpoint
openalex_base_url = "https://api.openalex.org/authors"

# Function to query OpenAlex
def get_openalex_author_id(name):
    try:
        response = requests.get(openalex_base_url, params={"search": name})
        response.raise_for_status()  # Raise an exception for HTTP errors
        results = response.json()

        if "results" in results and results["results"]:
            # Take the first match (or apply more filters if needed)
            first_result = results["results"][0]
            return {
                "author_id": first_result.get("id"),
                "name": first_result.get("display_name"),
                "works_count": first_result.get("works_count", 0),
                "cited_by_count": first_result.get("cited_by_count", 0),
            }
        else:
            return None  # No match found
    except Exception as e:
        print(f"Error fetching author ID for {name}: {e}")
        return None

# Process each member to fetch OpenAlex Author ID
results = []
for member in knaw_members:
    print(f"Fetching OpenAlex Author ID for {member['name']}...")
    author_data = get_openalex_author_id(member["name"])
    if author_data:
        results.append({
            "name": member["name"],
            "expertise": member["expertise"],
            "openalex_id": author_data["author_id"],
            "works_count": author_data["works_count"],
            "cited_by_count": author_data["cited_by_count"],
        })
    else:
        results.append({
            "name": member["name"],
            "expertise": member["expertise"],
            "openalex_id": None,
            "works_count": None,
            "cited_by_count": None,
        })
    # Respect API rate limits
    time.sleep(1)  # Adjust delay if needed

# Save the results to a JSON file
with open(output_file_path, 'w', encoding='utf-8') as file:
    json.dump(results, file, ensure_ascii=False, indent=4)

print(f"Author IDs saved to '{output_file_path}'.")

# Optionally, save to CSV for easier inspection
pd.DataFrame(results).to_csv("knaw_author_ids.csv", index=False)
print("Author IDs also saved to 'knaw_author_ids.csv'.")
# Out:
# Fetching OpenAlex Author ID for Wil van der Aalst...
# Fetching OpenAlex Author ID for Kees Aarts...
# Fetching OpenAlex Author ID for Gerard Acket...
# Fetching OpenAlex Author ID for Remieg Aerts...
# Fetching OpenAlex Author ID for Conny Aerts...
# Fetching OpenAlex Author ID for Reuven Agami...
# Fetching OpenAlex Author ID for Frits Agterberg...
# Fetching OpenAlex Author ID for Takuzo Aida...
# Fetching OpenAlex Author ID for Anna Akhmanova...
# Fetching OpenAlex Author ID for Barbara Aland...
# Fetching OpenAlex Author ID for Tjeerd van Albada...
# Fetching OpenAlex Author ID for André Aleman...
# Fetching OpenAlex Author ID for Keimpe Algra...
# Fetching OpenAlex Author ID for Maurits Allessie...
# Fetching OpenAlex Author ID for Sigurd Angenent...
# Fetching OpenAlex Author ID for Frank Ankersmit...
# Fetching OpenAlex Author ID for Isabel Arends...
# Fetching OpenAlex Author ID for Ad van der Avoird...
# Fetching OpenAlex Author ID for Hein de Baar...
# Fetching OpenAlex Author ID for Thomas Bäck...
# Fetching OpenAlex Author ID for Jan Baerends...
# Fetching OpenAlex Author ID for Marian Bakermans-Kranenburg...
# Fetching OpenAlex Author ID for Jan Albert Bakker...
# Fetching OpenAlex Author ID for Huib Bakker...
# Fetching OpenAlex Author ID for Egbert Bakker...
# Fetching OpenAlex Author ID for Erik Bakkers...
# Fetching OpenAlex Author ID for Henk Barendregt...
# Fetching OpenAlex Author ID for René Barents...
# Fetching OpenAlex Author ID for Renate Bartsch...
# Fetching OpenAlex Author ID for Jurjen Battjes...
# Fetching OpenAlex Author ID for Bas van Bavel...
# Fetching OpenAlex Author ID for Adriaan Bax...
# Fetching OpenAlex Author ID for Bram van de Beek...
# Fetching OpenAlex Author ID for Carlo Beenakker...
# Fetching OpenAlex Author ID for Jos Beijnen...
# Fetching OpenAlex Author ID for Harold Bekkering...
# Fetching OpenAlex Author ID for Wout van Bekkum...
# Fetching OpenAlex Author ID for Jan van Bemmel...
# Fetching OpenAlex Author ID for Zvi Ben-Avraham...
# Fetching OpenAlex Author ID for Jozien Bensing...
# Fetching OpenAlex Author ID for Johan van Benthem...
# Fetching OpenAlex Author ID for Albert van den Berg...
# Fetching OpenAlex Author ID for Leonard van den Berg...
# Fetching OpenAlex Author ID for Gerard van den Berg...
# Fetching OpenAlex Author ID for André Berger...
# Fetching OpenAlex Author ID for Jan Bergstra...
# Fetching OpenAlex Author ID for Piet Bergveld Em....
# Fetching OpenAlex Author ID for Maaike  van Berkel...
# Fetching OpenAlex Author ID for Klaas van Berkel...
# Fetching OpenAlex Author ID for Guus Berkhout...
# Fetching OpenAlex Author ID for René Bernards...
# Fetching OpenAlex Author ID for Ton Berns...
# Fetching OpenAlex Author ID for Michael Berry...
# Fetching OpenAlex Author ID for Connie Bezzina...
# Fetching OpenAlex Author ID for Peter Bickel...
# Fetching OpenAlex Author ID for Marc Bierkens...
# Fetching OpenAlex Author ID for Catrien Bijleveld...
# Fetching OpenAlex Author ID for Karin Bijsterveld...
# Fetching OpenAlex Author ID for Ton Bisseling...
# Fetching OpenAlex Author ID for Alfons van Blaaderen...
# Fetching OpenAlex Author ID for Johan Bleeker...
# Fetching OpenAlex Author ID for Clemens van Blitterswijk...
# Fetching OpenAlex Author ID for Wim Blockmans...
# Fetching OpenAlex Author ID for Bas Bloem...
# Fetching OpenAlex Author ID for Josine Blok...
# Fetching OpenAlex Author ID for Kees Blom...
# Fetching OpenAlex Author ID for Carel Blotkamp...
# Fetching OpenAlex Author ID for Rens Bod...
# Fetching OpenAlex Author ID for Geoffrey Bodenhausen...
# Fetching OpenAlex Author ID for Monique Boekaerts...
# Fetching OpenAlex Author ID for Ted de Boer...
# Fetching OpenAlex Author ID for Hans Boersma...
# Fetching OpenAlex Author ID for Klaas Bom...
# Fetching OpenAlex Author ID for John Bongaarts...
# Fetching OpenAlex Author ID for Daniel Bonn...
# Fetching OpenAlex Author ID for Marc Bonten...
# Fetching OpenAlex Author ID for Dorret Boomsma...
# Fetching OpenAlex Author ID for Arnoud Boot...
# Fetching OpenAlex Author ID for René de Borst...
# Fetching OpenAlex Author ID for Piet Borst CBE...
# Fetching OpenAlex Author ID for Kees  van den  Bos...
# Fetching OpenAlex Author ID for Hans Bos...
# Fetching OpenAlex Author ID for Antal van den Bosch...
# Fetching OpenAlex Author ID for Joop Bouma...
# Fetching OpenAlex Author ID for Johan Bouma...
# Fetching OpenAlex Author ID for Herman Bouma...
# Fetching OpenAlex Author ID for Teun  Bousema...
# Fetching OpenAlex Author ID for Carlijn Bouten...
# Fetching OpenAlex Author ID for Harro Bouwmeester...
# Fetching OpenAlex Author ID for Joke Bouwstra...
# Fetching OpenAlex Author ID for Lans Bovenberg...
# Fetching OpenAlex Author ID for Mark Bovens...
# Fetching OpenAlex Author ID for Henk Braakhuis...
# Fetching OpenAlex Author ID for Joseph Braat...
# Fetching OpenAlex Author ID for Paul Brakefield...
# Fetching OpenAlex Author ID for Annelien Bredenoord...
# Fetching OpenAlex Author ID for Ferry Breedveld...
# Fetching OpenAlex Author ID for Nico van Breemen...
# Fetching OpenAlex Author ID for Douwe Breimer...
# Fetching OpenAlex Author ID for Jan Breman...
# Fetching OpenAlex Author ID for Monique Breteler...
# Fetching OpenAlex Author ID for Marcel van den Brink...
# Fetching OpenAlex Author ID for Laurens Jan Brinkhorst...
# Fetching OpenAlex Author ID for Henk Brinkhuis...
# Fetching OpenAlex Author ID for Roel van den Broek...
# Fetching OpenAlex Author ID for Michiel van den Broeke...
# Fetching OpenAlex Author ID for Henk Broer...
# Fetching OpenAlex Author ID for Dick Broer...
# Fetching OpenAlex Author ID for Johannes Bronkhorst...
# Fetching OpenAlex Author ID for Bart Bronnenberg...
# Fetching OpenAlex Author ID for Peter Brown...
# Fetching OpenAlex Author ID for Thijn Brummelkamp...
# Fetching OpenAlex Author ID for Bert Brunekreef...
# Fetching OpenAlex Author ID for Han Brunner...
# Fetching OpenAlex Author ID for Lucas Brunsveld...
# Fetching OpenAlex Author ID for Kenneth Buesseler...
# Fetching OpenAlex Author ID for Harry Buhrman...
# Fetching OpenAlex Author ID for Willem Buiter...
# Fetching OpenAlex Author ID for Harry Büller...
# Fetching OpenAlex Author ID for Erwin Bulte...
# Fetching OpenAlex Author ID for Wiep van Bunge...
# Fetching OpenAlex Author ID for Joost Businger...
# Fetching OpenAlex Author ID for Harvey Butcher...
# Fetching OpenAlex Author ID for Bram Buunk...
# Fetching OpenAlex Author ID for Peter Carmeliet...
# Fetching OpenAlex Author ID for Ger Challa...
# Fetching OpenAlex Author ID for Lisa Cheng...
# Fetching OpenAlex Author ID for Herbert Clark...
# Fetching OpenAlex Author ID for Eve Clark...
# Fetching OpenAlex Author ID for Hans Clevers...
# Fetching OpenAlex Author ID for Sierd Cloetingh...
# Fetching OpenAlex Author ID for Reinder Coehoorn...
# Fetching OpenAlex Author ID for Martien Cohen Stuart...
# Fetching OpenAlex Author ID for Margaret Collinson...
# Fetching OpenAlex Author ID for Bernard Comrie...
# Fetching OpenAlex Author ID for Roshan Cools...
# Fetching OpenAlex Author ID for Marius Crainic...
# Fetching OpenAlex Author ID for Ronald Cramer...
# Fetching OpenAlex Author ID for Maghiel  van Crevel...
# Fetching OpenAlex Author ID for Roberta Croce...
# Fetching OpenAlex Author ID for Eveline Crone...
# Fetching OpenAlex Author ID for Pedro Crous...
# Fetching OpenAlex Author ID for Deirdre Curtin...
# Fetching OpenAlex Author ID for Hans Daiber...
# Fetching OpenAlex Author ID for Jan Dalhuisen...
# Fetching OpenAlex Author ID for Eric van Damme...
# Fetching OpenAlex Author ID for Jenny Dankelman...
# Fetching OpenAlex Author ID for Ingrid Daubechies...
# Fetching OpenAlex Author ID for George Davey Smith...
# Fetching OpenAlex Author ID for Karel Davids...
# Fetching OpenAlex Author ID for Nynke Dekker...
# Fetching OpenAlex Author ID for Cees Dekker...
# Fetching OpenAlex Author ID for Jan van Deth...
# Fetching OpenAlex Author ID for Arwen Deuss...
# Fetching OpenAlex Author ID for Wilfried Dewachter...
# Fetching OpenAlex Author ID for Patrick Dewilde...
# Fetching OpenAlex Author ID for Marcel Dicke...
# Fetching OpenAlex Author ID for Karel Dicke...
# Fetching OpenAlex Author ID for Dennis Dieks...
# Fetching OpenAlex Author ID for José van Dijck...
# Fetching OpenAlex Author ID for Pieter van Dijk...
# Fetching OpenAlex Author ID for Peter ten Dijke...
# Fetching OpenAlex Author ID for Robbert Dijkgraaf...
# Fetching OpenAlex Author ID for Marjolein Dijkstra...
# Fetching OpenAlex Author ID for Henk Dijkstra...
# Fetching OpenAlex Author ID for Bauke Dijkstra...
# Fetching OpenAlex Author ID for Marcel den Dikken...
# Fetching OpenAlex Author ID for Charles Dinarello...
# Fetching OpenAlex Author ID for Ewine van Dishoeck...
# Fetching OpenAlex Author ID for Vishva M. Dixit...
# Fetching OpenAlex Author ID for Marileen Dogterom...
# Fetching OpenAlex Author ID for Eddy van Doorslaer...
# Fetching OpenAlex Author ID for Eite Drent...
# Fetching OpenAlex Author ID for Pieter Drenth...
# Fetching OpenAlex Author ID for Jan Drenth...
# Fetching OpenAlex Author ID for Carsten de Dreu...
# Fetching OpenAlex Author ID for Lou van den Dries...
# Fetching OpenAlex Author ID for Arnold Driessen...
# Fetching OpenAlex Author ID for Denis Duboule...
# Fetching OpenAlex Author ID for Cornelia van Duijn...
# Fetching OpenAlex Author ID for Catarina Dutilh Novaes...
# Fetching OpenAlex Author ID for Jan Willem Duyvendak...
# Fetching OpenAlex Author ID for Pearl Dykstra...
# Fetching OpenAlex Author ID for Lex van der Eb...
# Fetching OpenAlex Author ID for Mick Eekhout...
# Fetching OpenAlex Author ID for Jos Eggermont...
# Fetching OpenAlex Author ID for Philip van der Eijk...
# Fetching OpenAlex Author ID for Cees van der Eijk...
# Fetching OpenAlex Author ID for Ron Ekers...
# Fetching OpenAlex Author ID for Naomi Ellemers...
# Fetching OpenAlex Author ID for Bernet Elzinga...
# Fetching OpenAlex Author ID for Paul Emmelkamp...
# Fetching OpenAlex Author ID for Karl Enenkel...
# Fetching OpenAlex Author ID for Pierre van der Eng...
# Fetching OpenAlex Author ID for Godfried Engbersen...
# Fetching OpenAlex Author ID for Mirjam Ernestus...
# Fetching OpenAlex Author ID for Judith van Erp...
# Fetching OpenAlex Author ID for Wim van Es...
# Fetching OpenAlex Author ID for Thijs Ettema...
# Fetching OpenAlex Author ID for Andrea Evers...
# Fetching OpenAlex Author ID for Carel Faber...
# Fetching OpenAlex Author ID for Heino Falcke...
# Fetching OpenAlex Author ID for Reindert Falkenburg...
# Fetching OpenAlex Author ID for Martin Fase...
# Fetching OpenAlex Author ID for Michael Faure...
# Fetching OpenAlex Author ID for Bert Felling...
# Fetching OpenAlex Author ID for Ben Feringa...
# Fetching OpenAlex Author ID for Guillén Fernández...
# Fetching OpenAlex Author ID for Carl Figdor...
# Fetching OpenAlex Author ID for Manfred Fischer...
# Fetching OpenAlex Author ID for René Foqué...
# Fetching OpenAlex Author ID for Ron Fouchier...
# Fetching OpenAlex Author ID for James Fox...
# Fetching OpenAlex Author ID for Bas van Fraassen...
# Fetching OpenAlex Author ID for Barbara Franke...
# Fetching OpenAlex Author ID for Hans Franken...
# Fetching OpenAlex Author ID for Philip Hans Franses...
# Fetching OpenAlex Author ID for Marijn Franx...
# Fetching OpenAlex Author ID for Daan Frenkel...
# Fetching OpenAlex Author ID for Joost Frenken...
# Fetching OpenAlex Author ID for Louise Fresco...
# Fetching OpenAlex Author ID for Florentino Garcìa Martìnez...
# Fetching OpenAlex Author ID for Sara van de Geer...
# Fetching OpenAlex Author ID for Marc Geers...
# Fetching OpenAlex Author ID for Geert Jan van Gelder...
# Fetching OpenAlex Author ID for Guillaume van Gemert...
# Fetching OpenAlex Author ID for Janneke Gerards...
# Fetching OpenAlex Author ID for Klarita Gërxhani...
# Fetching OpenAlex Author ID for Peter Geschiere...
# Fetching OpenAlex Author ID for Hans Geuze...
# Fetching OpenAlex Author ID for Halleh Ghorashi...
# Fetching OpenAlex Author ID for Stan Gielen...
# Fetching OpenAlex Author ID for Jenny Gierveld...
# Fetching OpenAlex Author ID for Ivo Giesen...
# Fetching OpenAlex Author ID for Erik van der Giessen...
# Fetching OpenAlex Author ID for Jan van Gijn...
# Fetching OpenAlex Author ID for Richard Gill...
# Fetching OpenAlex Author ID for Willem Hendrik Gispen...
# Fetching OpenAlex Author ID for Rainer Goebel...
# Fetching OpenAlex Author ID for Marieke de Goede...
# Fetching OpenAlex Author ID for Jacob Goeree...
# Fetching OpenAlex Author ID for Jacqueline van Gorkom...
# Fetching OpenAlex Author ID for Beatrice de Graaf...
# Fetching OpenAlex Author ID for Maria Grever...
# Fetching OpenAlex Author ID for Rick Grobbee...
# Fetching OpenAlex Author ID for Kees Groeneboer...
# Fetching OpenAlex Author ID for Marc Groenhuijsen...
# Fetching OpenAlex Author ID for Rienk van Grondelle...
# Fetching OpenAlex Author ID for Piet Gros...
# Fetching OpenAlex Author ID for Frank Grosveld...
# Fetching OpenAlex Author ID for Maarten van de Guchte...
# Fetching OpenAlex Author ID for Jan Willem Gunning...
# Fetching OpenAlex Author ID for Wilfred van Gunsteren...
# Fetching OpenAlex Author ID for Herman van Gunsteren...
# Fetching OpenAlex Author ID for Holger Gzella...
# Fetching OpenAlex Author ID for Harm Habing...
# Fetching OpenAlex Author ID for Peter Hagoort...
# Fetching OpenAlex Author ID for Dick van Halsema...
# Fetching OpenAlex Author ID for Wouter Hanegraaff...
# Fetching OpenAlex Author ID for Ronald Hanson...
# Fetching OpenAlex Author ID for Annette Harder...
# Fetching OpenAlex Author ID for Anita Hardon...
# Fetching OpenAlex Author ID for Frank van Harmelen...
# Fetching OpenAlex Author ID for Paul 't Hart...
# Fetching OpenAlex Author ID for Joest 't Hart...
# Fetching OpenAlex Author ID for Arthur Hartkamp...
# Fetching OpenAlex Author ID for Joop Hartog...
# Fetching OpenAlex Author ID for Deanne den Hartog...
# Fetching OpenAlex Author ID for Trevor Hastie...
# Fetching OpenAlex Author ID for Henk ten Have...
# Fetching OpenAlex Author ID for Albert Heck...
# Fetching OpenAlex Author ID for Ron Heeren...
# Fetching OpenAlex Author ID for Martin van Hees...
# Fetching OpenAlex Author ID for Paul van der Heijden...
# Fetching OpenAlex Author ID for Sef Heijnen...
# Fetching OpenAlex Author ID for Gert Jan van Heijst...
# Fetching OpenAlex Author ID for Olivier Hekster...
# Fetching OpenAlex Author ID for Natali Helberger...
# Fetching OpenAlex Author ID for Lotte Hellinga-Querido...
# Fetching OpenAlex Author ID for Frans van der Helm...
# Fetching OpenAlex Author ID for Amina Helmi...
# Fetching OpenAlex Author ID for Coen Hemker...
# Fetching OpenAlex Author ID for Gotthilf Hempel...
# Fetching OpenAlex Author ID for Petra Hendriks...
# Fetching OpenAlex Author ID for Kees Hengeveld...
# Fetching OpenAlex Author ID for Paulien Herder...
# Fetching OpenAlex Author ID for Lambert Hesselink...
# Fetching OpenAlex Author ID for Jan van Hest...
# Fetching OpenAlex Author ID for Ed van den Heuvel...
# Fetching OpenAlex Author ID for Vincent van Heuven...
# Fetching OpenAlex Author ID for Frits Hilgen...
# Fetching OpenAlex Author ID for Thea Hilhorst...
# Fetching OpenAlex Author ID for Henk Hilhorst...
# Fetching OpenAlex Author ID for Henk Hillenaar...
# Fetching OpenAlex Author ID for Tadaki Hirose...
# Fetching OpenAlex Author ID for Ernst Hirsch Ballin...
# Fetching OpenAlex Author ID for Jan Hoeijmakers...
# Fetching OpenAlex Author ID for Wiel Hoekstra...
# Fetching OpenAlex Author ID for Bert Hofman...
# Fetching OpenAlex Author ID for Remco van der Hofstad...
# Fetching OpenAlex Author ID for Jan Hogendijk...
# Fetching OpenAlex Author ID for Pancras Hogendoorn...
# Fetching OpenAlex Author ID for Elly Hol...
# Fetching OpenAlex Author ID for Wim Hol...
# Fetching OpenAlex Author ID for Carla Hollak...
# Fetching OpenAlex Author ID for Frank den Hollander...
# Fetching OpenAlex Author ID for Cornelis Hollenberg...
# Fetching OpenAlex Author ID for Ewoud Hondius...
# Fetching OpenAlex Author ID for Henkjan Honing...
# Fetching OpenAlex Author ID for Jan van Hooff...
# Fetching OpenAlex Author ID for Gerard 't Hooft...
# Fetching OpenAlex Author ID for Serge Hoogendoorn...
# Fetching OpenAlex Author ID for Henry Hooghiemstra...
# Fetching OpenAlex Author ID for Adrianus de Hoop...
# Fetching OpenAlex Author ID for Paul Hooykaas...
# Fetching OpenAlex Author ID for Mary Horowitz...
# Fetching OpenAlex Author ID for Piet van der Horst...
# Fetching OpenAlex Author ID for Jeff de Hosson...
# Fetching OpenAlex Author ID for Theo van den Hout...
# Fetching OpenAlex Author ID for Jeanine Houwing-Duistermaat...
# Fetching OpenAlex Author ID for Lawrence Hubert...
# Fetching OpenAlex Author ID for Wilhelm Huck...
# Fetching OpenAlex Author ID for Nico Hugenholtz...
# Fetching OpenAlex Author ID for Suzanne Hulscher...
# Fetching OpenAlex Author ID for Piet Hut...
# Fetching OpenAlex Author ID for Francesco Iachello...
# Fetching OpenAlex Author ID for Wilt Idema...
# Fetching OpenAlex Author ID for Marinus van IJzendoorn dr. h.c....
# Fetching OpenAlex Author ID for Guido Imbens...
# Fetching OpenAlex Author ID for Jonathan Israel...
# Fetching OpenAlex Author ID for Bart Jacobs...
# Fetching OpenAlex Author ID for Vincent Jaddoe...
# Fetching OpenAlex Author ID for Anita Jansen...
# Fetching OpenAlex Author ID for Willy Jansen...
# Fetching OpenAlex Author ID for John Jansen...
# Fetching OpenAlex Author ID for Johan Jansonius...
# Fetching OpenAlex Author ID for Susanne Janssen...
# Fetching OpenAlex Author ID for René Janssen...
# Fetching OpenAlex Author ID for Erik Jayme...
# Fetching OpenAlex Author ID for Lotte Jensen...
# Fetching OpenAlex Author ID for Mike Jetten...
# Fetching OpenAlex Author ID for Jolanda Jetten...
# Fetching OpenAlex Author ID for Marian Joëls...
# Fetching OpenAlex Author ID for Aise de Jong...
# Fetching OpenAlex Author ID for Ab de Jong...
# Fetching OpenAlex Author ID for Irene de Jong...
# Fetching OpenAlex Author ID for Petra de Jongh...
# Fetching OpenAlex Author ID for Eddy de Jongh...
# Fetching OpenAlex Author ID for Joshua Jortner...
# Fetching OpenAlex Author ID for Dick van de Kaa...
# Fetching OpenAlex Author ID for René Kahn...
# Fetching OpenAlex Author ID for Matthijs Kalmijn...
# Fetching OpenAlex Author ID for Ab van Kammen...
# Fetching OpenAlex Author ID for Hans Kamp...
# Fetching OpenAlex Author ID for Roland Kanaar...
# Fetching OpenAlex Author ID for Hans Kaper...
# Fetching OpenAlex Author ID for Ernestine Kaper...
# Fetching OpenAlex Author ID for Rob Kaptein...
# Fetching OpenAlex Author ID for Arie Kapteyn...
# Fetching OpenAlex Author ID for Martin Karplus...
# Fetching OpenAlex Author ID for Martijn Katan...
# Fetching OpenAlex Author ID for Misha Katsnelson...
# Fetching OpenAlex Author ID for Mike Keane...
# Fetching OpenAlex Author ID for Peter van Kessel...
# Fetching OpenAlex Author ID for Sol Kimel...
# Fetching OpenAlex Author ID for Hanan Kisch...
# Fetching OpenAlex Author ID for Jan Kiviet...
# Fetching OpenAlex Author ID for Marian Klamer...
# Fetching OpenAlex Author ID for Caroline Klaver...
# Fetching OpenAlex Author ID for Pauline Kleingeld...
# Fetching OpenAlex Author ID for André Klip...
# Fetching OpenAlex Author ID for Michiel van der Klis...
# Fetching OpenAlex Author ID for Jeroen de Kloet...
# Fetching OpenAlex Author ID for Jan Willem Klop...
# Fetching OpenAlex Author ID for Theo van de Klundert...
# Fetching OpenAlex Author ID for Marjo van der Knaap...
# Fetching OpenAlex Author ID for Bert van der Knaap...
# Fetching OpenAlex Author ID for André Knottnerus...
# Fetching OpenAlex Author ID for Jan Koeman...
# Fetching OpenAlex Author ID for Gijsje Koenderink...
# Fetching OpenAlex Author ID for Jan Koenderink...
# Fetching OpenAlex Author ID for Johannes Konst...
# Fetching OpenAlex Author ID for Bas Kooijman...
# Fetching OpenAlex Author ID for Jelle Koopmans...
# Fetching OpenAlex Author ID for Marion Koopmans...
# Fetching OpenAlex Author ID for Maarten Koornneef...
# Fetching OpenAlex Author ID for Yvette van Kooyk...
# Fetching OpenAlex Author ID for Marc Koper...
# Fetching OpenAlex Author ID for Jaap Korevaar...
# Fetching OpenAlex Author ID for Frits Kortlandt...
# Fetching OpenAlex Author ID for Gerard van Koten...
# Fetching OpenAlex Author ID for Leo Kouwenhoven...
# Fetching OpenAlex Author ID for Xandra Kramer...
# Fetching OpenAlex Author ID for Jan Kramers...
# Fetching OpenAlex Author ID for Ben de Kruijff...
# Fetching OpenAlex Author ID for Remke Kruk...
# Fetching OpenAlex Author ID for Arno Kuijlaars...
# Fetching OpenAlex Author ID for Leonard van der Kuijp...
# Fetching OpenAlex Author ID for Simon Kuipers...
# Fetching OpenAlex Author ID for Oscar Kuipers...
# Fetching OpenAlex Author ID for Hans Kuipers...
# Fetching OpenAlex Author ID for Giselinde Kuipers...
# Fetching OpenAlex Author ID for Srinivas Kulkarni...
# Fetching OpenAlex Author ID for Max Kuperus...
# Fetching OpenAlex Author ID for Harry van der Laan...
# Fetching OpenAlex Author ID for Horst Lademacher...
# Fetching OpenAlex Author ID for Ad Lagendijk...
# Fetching OpenAlex Author ID for Inald Lagendijk...
# Fetching OpenAlex Author ID for Kurt Lambeck...
# Fetching OpenAlex Author ID for Hans Lambers...
# Fetching OpenAlex Author ID for Steven Lamberts...
# Fetching OpenAlex Author ID for Henny Lamers...
# Fetching OpenAlex Author ID for Klaas Landsman...
# Fetching OpenAlex Author ID for Titia de Lange...
# Fetching OpenAlex Author ID for Christian Lange...
# Fetching OpenAlex Author ID for Monique Laurent...
# Fetching OpenAlex Author ID for Richard Lauwaars...
# Fetching OpenAlex Author ID for Peter Leeflang...
# Fetching OpenAlex Author ID for Inger Leemans...
# Fetching OpenAlex Author ID for Joep Leerssen...
# Fetching OpenAlex Author ID for Jan  de Leeuw...
# Fetching OpenAlex Author ID for Sander van der Leeuw...
# Fetching OpenAlex Author ID for Jan de Leeuw...
# Fetching OpenAlex Author ID for Jean-Marie Lehn...
# Fetching OpenAlex Author ID for Henk Lekkerkerker...
# Fetching OpenAlex Author ID for Hendrik Lenstra...
# Fetching OpenAlex Author ID for Joop van Lenteren...
# Fetching OpenAlex Author ID for Ron Lesthaeghe...
# Fetching OpenAlex Author ID for Rob Leurs...
# Fetching OpenAlex Author ID for Pim Levelt...
# Fetching OpenAlex Author ID for Marcel Levi...
# Fetching OpenAlex Author ID for Robert de Levie...
# Fetching OpenAlex Author ID for Walter Lewin...
# Fetching OpenAlex Author ID for Aart Liefbroer...
# Fetching OpenAlex Author ID for Luuk de Ligt...
# Fetching OpenAlex Author ID for Arend Lijphart...
# Fetching OpenAlex Author ID for Frank Linde...
# Fetching OpenAlex Author ID for Siegwart Lindenberg...
# Fetching OpenAlex Author ID for Harry Lintsen...
# Fetching OpenAlex Author ID for Tanja van der Lippe...
# Fetching OpenAlex Author ID for Frank Lobbezoo...
# Fetching OpenAlex Author ID for Detlef Lohse...
# Fetching OpenAlex Author ID for Maria Antonietta Loi...
# Fetching OpenAlex Author ID for Renate Loll...
# Fetching OpenAlex Author ID for Eduard Looijenga...
# Fetching OpenAlex Author ID for Mark van Loosdrecht...
# Fetching OpenAlex Author ID for Leendert Louwe Kooijmans...
# Fetching OpenAlex Author ID for László Lovász...
# Fetching OpenAlex Author ID for Bob Löwenberg...
# Fetching OpenAlex Author ID for Sasha Lubotsky...
# Fetching OpenAlex Author ID for Leo Lucassen...
# Fetching OpenAlex Author ID for Jan Lucassen...
# Fetching OpenAlex Author ID for Christoph Lüthy...
# Fetching OpenAlex Author ID for Amade M’charek...
# Fetching OpenAlex Author ID for Eddy van der Maarel...
# Fetching OpenAlex Author ID for Ejan Mackaay...
# Fetching OpenAlex Author ID for Johan Mackenbach...
# Fetching OpenAlex Author ID for Roderick MacKinnon...
# Fetching OpenAlex Author ID for Vanessa Mak...
# Fetching OpenAlex Author ID for Kofi Makinwa...
# Fetching OpenAlex Author ID for Jaap Mansfeld...
# Fetching OpenAlex Author ID for Titti Mariani...
# Fetching OpenAlex Author ID for Sera  Markoff...
# Fetching OpenAlex Author ID for Siewert-Jan Marrink...
# Fetching OpenAlex Author ID for Eric Mazur...
# Fetching OpenAlex Author ID for Valentina Mazzucato...
# Fetching OpenAlex Author ID for René Medema...
# Fetching OpenAlex Author ID for Jos van der Meer...
# Fetching OpenAlex Author ID for Gerrit van Meer...
# Fetching OpenAlex Author ID for Gerard Meijer...
# Fetching OpenAlex Author ID for Bert Meijer...
# Fetching OpenAlex Author ID for Bert Meijer...
# Fetching OpenAlex Author ID for Eginhard Meijering...
# Fetching OpenAlex Author ID for Andries Meijerink...
# Fetching OpenAlex Author ID for Debora Meijers...
# Fetching OpenAlex Author ID for Kees Melief...
# Fetching OpenAlex Author ID for Walter Melion...
# Fetching OpenAlex Author ID for Julien Mendlewicz...
# Fetching OpenAlex Author ID for Steph Menken...
# Fetching OpenAlex Author ID for Albert Menkveld...
# Fetching OpenAlex Author ID for Stephen Mennell...
# Fetching OpenAlex Author ID for Harald Merckelbach...
# Fetching OpenAlex Author ID for Judi Mesman...
# Fetching OpenAlex Author ID for Alice ter Meulen...
# Fetching OpenAlex Author ID for Jacqueline Meulman...
# Fetching OpenAlex Author ID for Antje Meyer...
# Fetching OpenAlex Author ID for Birgit Meyer...
# Fetching OpenAlex Author ID for Hartmut Michel...
# Fetching OpenAlex Author ID for John Michon...
# Fetching OpenAlex Author ID for Jack Middelburg...
# Fetching OpenAlex Author ID for Wijnand Mijnhardt...
# Fetching OpenAlex Author ID for George Miley...
# Fetching OpenAlex Author ID for Ieke Moerdijk...
# Fetching OpenAlex Author ID for Keith Moffatt...
# Fetching OpenAlex Author ID for Joël Mokyr...
# Fetching OpenAlex Author ID for Annemarie Mol...
# Fetching OpenAlex Author ID for Laurens Molenkamp...
# Fetching OpenAlex Author ID for Hans Mooij...
# Fetching OpenAlex Author ID for Mary Morgan...
# Fetching OpenAlex Author ID for Maarten Mous...
# Fetching OpenAlex Author ID for Nicolette Mout...
# Fetching OpenAlex Author ID for Cas Mudde...
# Fetching OpenAlex Author ID for Clara Mulder...
# Fetching OpenAlex Author ID for Gerhard Müller...
# Fetching OpenAlex Author ID for Christine Mummery...
# Fetching OpenAlex Author ID for Heleen Murre-van den Berg...
# Fetching OpenAlex Author ID for John Mydosh...
# Fetching OpenAlex Author ID for Lodi Nauta...
# Fetching OpenAlex Author ID for Bram Nauta...
# Fetching OpenAlex Author ID for Jacques Neefjes...
# Fetching OpenAlex Author ID for Jan van Neerven...
# Fetching OpenAlex Author ID for John Nerbonne...
# Fetching OpenAlex Author ID for Nancy Nersessian...
# Fetching OpenAlex Author ID for Mihai Netea...
# Fetching OpenAlex Author ID for Bernard Nienhuis...
# Fetching OpenAlex Author ID for Wiro Niessen...
# Fetching OpenAlex Author ID for Peter van Nieuwenhuizen...
# Fetching OpenAlex Author ID for Emmie te Nijenhuis...
# Fetching OpenAlex Author ID for Peter Nijkamp...
# Fetching OpenAlex Author ID for Guust Nolet...
# Fetching OpenAlex Author ID for André Nollkaemper...
# Fetching OpenAlex Author ID for Julia Noordegraaf...
# Fetching OpenAlex Author ID for Ed Noort...
# Fetching OpenAlex Author ID for Bart Nooteboom...
# Fetching OpenAlex Author ID for Roel Nusse...
# Fetching OpenAlex Author ID for Theo Odijk...
# Fetching OpenAlex Author ID for Hans Oerlemans...
# Fetching OpenAlex Author ID for John van der Oost...
# Fetching OpenAlex Author ID for Frits van Oostrom...
# Fetching OpenAlex Author ID for Eric Opdam...
# Fetching OpenAlex Author ID for Hans Opschoor...
# Fetching OpenAlex Author ID for Gordon Orians...
# Fetching OpenAlex Author ID for Michel Orrit...
# Fetching OpenAlex Author ID for Jim van Os...
# Fetching OpenAlex Author ID for Henk van Os...
# Fetching OpenAlex Author ID for Ab Osterhaus...
# Fetching OpenAlex Author ID for Jeremiah Ostriker...
# Fetching OpenAlex Author ID for Koen Ottenheym...
# Fetching OpenAlex Author ID for Sijbren Otto...
# Fetching OpenAlex Author ID for Alexander van Oudenaarden...
# Fetching OpenAlex Author ID for Hermen Overkleeft...
# Fetching OpenAlex Author ID for René Pahud de Mortanges...
# Fetching OpenAlex Author ID for Franz Palm...
# Fetching OpenAlex Author ID for Thom Palstra...
# Fetching OpenAlex Author ID for Geoffrey Parker...
# Fetching OpenAlex Author ID for Barbara Partee...
# Fetching OpenAlex Author ID for Kiran Patel...
# Fetching OpenAlex Author ID for Herman Paul...
# Fetching OpenAlex Author ID for Peter Pearson...
# Fetching OpenAlex Author ID for Johannes Pennings...
# Fetching OpenAlex Author ID for Brenda Penninx...
# Fetching OpenAlex Author ID for Theunis Piersma...
# Fetching OpenAlex Author ID for Jean Pieters...
# Fetching OpenAlex Author ID for Corné Pieterse...
# Fetching OpenAlex Author ID for David Pinder...
# Fetching OpenAlex Author ID for Bob Pinedo...
# Fetching OpenAlex Author ID for Patricia Pisters...
# Fetching OpenAlex Author ID for Ronald Plasterk...
# Fetching OpenAlex Author ID for Henri Pleket...
# Fetching OpenAlex Author ID for Hans van der Plicht...
# Fetching OpenAlex Author ID for Rick van der Ploeg...
# Fetching OpenAlex Author ID for Hidde Ploegh...
# Fetching OpenAlex Author ID for Ibo van de Poel...
# Fetching OpenAlex Author ID for Tom van der Poll...
# Fetching OpenAlex Author ID for Judith Pollmann...
# Fetching OpenAlex Author ID for Albert Polman...
# Fetching OpenAlex Author ID for Bert Poolman...
# Fetching OpenAlex Author ID for Jacques Poot...
# Fetching OpenAlex Author ID for Mladen Popović...
# Fetching OpenAlex Author ID for Danielle Posthuma...
# Fetching OpenAlex Author ID for Dirkje Postma...
# Fetching OpenAlex Author ID for Mirjam van Praag...
# Fetching OpenAlex Author ID for Herman van Praag...
# Fetching OpenAlex Author ID for Bernard van Praag...
# Fetching OpenAlex Author ID for Maarten Prak...
# Fetching OpenAlex Author ID for Om Prakash...
# Fetching OpenAlex Author ID for Lucas Prakke...
# Fetching OpenAlex Author ID for Sacha Prechal...
# Fetching OpenAlex Author ID for Walter Prevenier...
# Fetching OpenAlex Author ID for Sally Price...
# Fetching OpenAlex Author ID for Roel Prins...
# Fetching OpenAlex Author ID for Corien Prins...
# Fetching OpenAlex Author ID for Jack Pronk...
# Fetching OpenAlex Author ID for Andrea Prosperetti...
# Fetching OpenAlex Author ID for Wim van der Putten...
# Fetching OpenAlex Author ID for Aad Quak...
# Fetching OpenAlex Author ID for Jos Raaijmakers...
# Fetching OpenAlex Author ID for Rudy Rabbinge...
# Fetching OpenAlex Author ID for Theo Rasing...
# Fetching OpenAlex Author ID for Jan Reedijk...
# Fetching OpenAlex Author ID for Joost Reek...
# Fetching OpenAlex Author ID for Martin Rees...
# Fetching OpenAlex Author ID for Manfred Reetz...
# Fetching OpenAlex Author ID for David Regan...
# Fetching OpenAlex Author ID for Hans Reiber...
# Fetching OpenAlex Author ID for David Reinhoudt...
# Fetching OpenAlex Author ID for Willem Remmelink...
# Fetching OpenAlex Author ID for Rob Reneman...
# Fetching OpenAlex Author ID for Geert Ridder...
# Fetching OpenAlex Author ID for Richard Ridderinkhof...
# Fetching OpenAlex Author ID for René de la Rie...
# Fetching OpenAlex Author ID for Ivonne Rietjens...
# Fetching OpenAlex Author ID for Ann Rigney...
# Fetching OpenAlex Author ID for Maarten de Rijke...
# Fetching OpenAlex Author ID for Avraham Rinat-Reiner...
# Fetching OpenAlex Author ID for Ingrid Robeyns...
# Fetching OpenAlex Author ID for George Robillard...
# Fetching OpenAlex Author ID for Wil Roebroeks...
# Fetching OpenAlex Author ID for Karin Roelofs...
# Fetching OpenAlex Author ID for Eelco Rohling...
# Fetching OpenAlex Author ID for Jana Roithová...
# Fetching OpenAlex Author ID for Lucas van Rompay...
# Fetching OpenAlex Author ID for Nico de Rooij...
# Fetching OpenAlex Author ID for Hilger Ropers...
# Fetching OpenAlex Author ID for Frits Rosendaal...
# Fetching OpenAlex Author ID for Judith  Rosmalen...
# Fetching OpenAlex Author ID for Maroeska Rovers...
# Fetching OpenAlex Author ID for Joost Ruitenberg...
# Fetching OpenAlex Author ID for Reiner Rummel...
# Fetching OpenAlex Author ID for Douwe Runia...
# Fetching OpenAlex Author ID for Floris Rutjes...
# Fetching OpenAlex Author ID for Wim van Saarloos...
# Fetching OpenAlex Author ID for Richard van de Sanden...
# Fetching OpenAlex Author ID for Andries Sanders...
# Author IDs saved to 'knaw_author_ids.json'.
# Author IDs also saved to 'knaw_author_ids.csv'.

# %%
import requests
import json
import time

# Input and output file paths
input_file = "/content/knaw_author_ids.json"  # Replace with your actual file path
output_file = "knaw_members_with_indices.json"  # File to save the updated data

# OpenAlex base API URL
openalex_base_url = "https://api.openalex.org"

# Function to fetch H-index and I10-index for an author
def fetch_author_metrics(author_id):
    url = f"{openalex_base_url}/authors/{author_id}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        h_index = data.get("summary_stats", {}).get("h_index", None)
        i10_index = data.get("summary_stats", {}).get("i10_index", None)
        return h_index, i10_index
    else:
        print(f"Error fetching data for author {author_id}: {response.status_code}")
        return None, None

# Load the existing JSON file
with open(input_file, "r") as infile:
    members = json.load(infile)

# Process each member and fetch H-index and I10-index
for member in members:
    openalex_ids = member.get("openalex_id")
    if isinstance(openalex_ids, list):
        # Initialize variables to aggregate metrics
        h_indices = []
        i10_indices = []
        for openalex_id in openalex_ids:
            author_id = openalex_id.split("/")[-1]  # Extract author ID
            h_index, i10_index = fetch_author_metrics(author_id)
            if h_index is not None:
                h_indices.append(h_index)
            if i10_index is not None:
                i10_indices.append(i10_index)
            time.sleep(1)  # Respect API rate limits

        # Aggregate indices (e.g., take maximum values)
        member["h_index"] = max(h_indices) if h_indices else None
        member["i10_index"] = max(i10_indices) if i10_indices else None

    elif isinstance(openalex_ids, str):
        author_id = openalex_ids.split("/")[-1]  # Extract author ID
        h_index, i10_index = fetch_author_metrics(author_id)
        member["h_index"] = h_index
        member["i10_index"] = i10_index
        time.sleep(1)  # Respect API rate limits
    else:
        print(f"No OpenAlex ID for {member['name']}. Skipping...")
        member["h_index"] = None
        member["i10_index"] = None

# Save the updated JSON with indices
with open(output_file, "w") as outfile:
    json.dump(members, outfile, indent=4)

print(f"H-index and I10-index added and saved to {output_file}")
# Out:
# No OpenAlex ID for Ernestine Kaper. Skipping...
# H-index and I10-index added and saved to knaw_members_with_indices.json

# %%
import requests
import json
import time

# Input and output file paths
input_file = "/content/knaw_members_with_indices.json"  # Replace with your actual file path
output_file = "knaw_works.json"  # File to save the detailed works data

# OpenAlex base API URL
openalex_base_url = "https://api.openalex.org"

# Function to fetch works for an author
def fetch_author_works(author_id):
    works = []
    page = 1
    while True:
        url = f"{openalex_base_url}/works?filter=author.id:{author_id}&per-page=200&page={page}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            for work in data["results"]:
                # Fetch detailed information for each work
                detailed_work_url = f"{openalex_base_url}/works/{work['id'].split('/')[-1]}"
                detailed_response = requests.get(detailed_work_url)
                if detailed_response.status_code == 200:
                    detailed_work = detailed_response.json()
                    # Remove the 'abstract' field
                    detailed_work.pop("abstract", None)
                    works.append(detailed_work)
                else:
                    print(f"Error fetching detailed work: {detailed_response.status_code}")
            if "next" not in data["meta"]:
                break
            page += 1
            time.sleep(1)  # Respect API rate limits
        else:
            print(f"Error fetching works for author {author_id}: {response.status_code}")
            break
    return works

# Load the existing JSON file
with open(input_file, "r") as infile:
    members = json.load(infile)

# Fetch works for each author
all_works = []
for member in members:
    openalex_ids = member.get("openalex_id")
    if isinstance(openalex_ids, list):
        for openalex_id in openalex_ids:
            author_id = openalex_id.split("/")[-1]  # Extract author ID
            works = fetch_author_works(author_id)
            all_works.extend(works)
    elif isinstance(openalex_ids, str):
        author_id = openalex_ids.split("/")[-1]  # Extract author ID
        works = fetch_author_works(author_id)
        all_works.extend(works)
    else:
        print(f"No OpenAlex ID for {member['name']}. Skipping...")

# Save the works data to a JSON file
with open(output_file, "w") as outfile:
    json.dump(all_works, outfile, indent=4)

print(f"Works data with full details saved to {output_file} without abstracts")

# %%
import requests
import json
import time
import os

# Input and output file paths
input_file = "/content/knaw_members_with_indices.json"  # Replace with your actual file path
output_file = "knaw_works.json"  # File to save the detailed works data
progress_file = "progress_log.json"  # Save progress to resume if interrupted

# OpenAlex base API URL
openalex_base_url = "https://api.openalex.org"

# Function to fetch works for an author
def fetch_author_works(author_id):
    works = []
    page = 1
    while True:
        try:
            url = f"{openalex_base_url}/works?filter=author.id:{author_id}&per-page=200&page={page}"
            response = requests.get(url, timeout=30)
            response.raise_for_status()  # Raise an exception for HTTP errors
            data = response.json()

            works.extend(data.get("results", []))
            if "next" not in data.get("meta", {}):
                break

            page += 1
            time.sleep(1)  # Respect API rate limits
        except requests.exceptions.RequestException as e:
            print(f"Error fetching works for author {author_id} on page {page}: {e}")
            break
    return works

# Resume or start fresh
if os.path.exists(progress_file):
    with open(progress_file, "r") as file:
        processed_authors = json.load(file)
else:
    processed_authors = {}

# Load the existing JSON file
with open(input_file, "r") as infile:
    members = json.load(infile)

# Fetch works for each author
all_works = []
for member in members:
    openalex_ids = member.get("openalex_id")
    if isinstance(openalex_ids, list):
        for openalex_id in openalex_ids:
            author_id = openalex_id.split("/")[-1]  # Extract author ID
            if author_id not in processed_authors:
                print(f"Fetching works for {member['name']} ({author_id})...")
                works = fetch_author_works(author_id)
                all_works.extend(works)
                processed_authors[author_id] = True
                # Save progress after each author
                with open(progress_file, "w") as file:
                    json.dump(processed_authors, file, indent=4)
    elif isinstance(openalex_ids, str):
        author_id = openalex_ids.split("/")[-1]  # Extract author ID
        if author_id not in processed_authors:
            print(f"Fetching works for {member['name']} ({author_id})...")
            works = fetch_author_works(author_id)
            all_works.extend(works)
            processed_authors[author_id] = True
            # Save progress after each author
            with open(progress_file, "w") as file:
                json.dump(processed_authors, file, indent=4)
    else:
        print(f"No OpenAlex ID for {member['name']}. Skipping...")

# Save the works data to a JSON file
with open(output_file, "w") as outfile:
    json.dump(all_works, outfile, indent=4)

print(f"Works data with full details saved to {output_file}.")

# Clean up the progress log file if processing is complete
if len(processed_authors) == len(members):
    os.remove(progress_file)
# Out:
# Fetching works for Wil van der Aalst (A5069762894)...
# Fetching works for Kees Aarts (A5025713059)...
# Fetching works for Gerard Acket (A5046174111)...
# Fetching works for Remieg Aerts (A5026631020)...
# Fetching works for Conny Aerts (A5071357492)...
# Fetching works for Reuven Agami (A5079323488)...
# Fetching works for Frits Agterberg (A5083547574)...
# Fetching works for Takuzo Aida (A5063217261)...
# Fetching works for Anna Akhmanova (A5024109873)...
# Fetching works for Barbara Aland (A5007027058)...
# Fetching works for Tjeerd van Albada (A5068636900)...
# Fetching works for André Aleman (A5083885093)...
# Fetching works for Keimpe Algra (A5060721437)...
# Fetching works for Maurits Allessie (A5112166922)...
# Fetching works for Sigurd Angenent (A5068621385)...
# Fetching works for Frank Ankersmit (A5106131841)...
# Fetching works for Isabel Arends (A5028443868)...
# Fetching works for Ad van der Avoird (A5030928179)...
# Fetching works for Hein de Baar (A5085046864)...
# Fetching works for Thomas Bäck (A5062646838)...
# Fetching works for Jan Baerends (A5029676676)...
# Fetching works for Marian Bakermans-Kranenburg (A5011041797)...
# Fetching works for Jan Albert Bakker (A5114070776)...
# Fetching works for Huib Bakker (A5050763048)...
# Fetching works for Egbert Bakker (A5048171390)...
# Fetching works for Erik Bakkers (A5041376320)...
# Fetching works for Henk Barendregt (A5016150987)...
# Fetching works for René Barents (A5090630251)...
# Fetching works for Renate Bartsch (A5002837237)...
# Fetching works for Jurjen Battjes (A5112762319)...
# Fetching works for Bas van Bavel (A5012992732)...
# Fetching works for Adriaan Bax (A5082289559)...
# Fetching works for Bram van de Beek (A5021997776)...
# Fetching works for Carlo Beenakker (A5072728378)...
# Fetching works for Jos Beijnen (A5062227574)...
# Fetching works for Harold Bekkering (A5110455146)...
# Fetching works for Wout van Bekkum (A5011336162)...
# Fetching works for Jan van Bemmel (A5112896560)...
# Fetching works for Zvi Ben-Avraham (A5071386500)...
# Fetching works for Jozien Bensing (A5110033685)...
# Fetching works for Johan van Benthem (A5083214023)...
# Fetching works for Albert van den Berg (A5012791912)...
# Fetching works for Leonard van den Berg (A5067571282)...
# Fetching works for Gerard van den Berg (A5001790127)...
# Fetching works for André Berger (A5103337249)...
# Fetching works for Jan Bergstra (A5032380170)...
# Fetching works for Piet Bergveld Em. (A5105296362)...
# Fetching works for Maaike  van Berkel (A5077890638)...
# Fetching works for Klaas van Berkel (A5112885139)...
# Fetching works for Guus Berkhout (A5022249214)...
# Fetching works for René Bernards (A5028266055)...
# Fetching works for Ton Berns (A5000887807)...
# Fetching works for Michael Berry (A5032503181)...
# Fetching works for Connie Bezzina (A5016023161)...
# Fetching works for Peter Bickel (A5025311999)...
# Fetching works for Marc Bierkens (A5080638739)...
# Fetching works for Catrien Bijleveld (A5057036253)...
# Fetching works for Karin Bijsterveld (A5075785069)...
# Fetching works for Ton Bisseling (A5077435743)...
# Fetching works for Alfons van Blaaderen (A5051859168)...
# Fetching works for Johan Bleeker (A5018206860)...
# Fetching works for Clemens van Blitterswijk (A5079436788)...
# Fetching works for Wim Blockmans (A5111951850)...
# Fetching works for Bas Bloem (A5109221179)...
# Fetching works for Josine Blok (A5065260257)...
# Fetching works for Kees Blom (A5054352176)...
# Fetching works for Carel Blotkamp (A5073311572)...
# Fetching works for Rens Bod (A5021400032)...
# Fetching works for Geoffrey Bodenhausen (A5054993004)...
# Fetching works for Monique Boekaerts (A5066638916)...
# Fetching works for Ted de Boer (A5085631342)...
# Fetching works for Hans Boersma (A5049850127)...
# Fetching works for Klaas Bom (A5008365574)...
# Fetching works for John Bongaarts (A5050111235)...
# Fetching works for Daniel Bonn (A5039921516)...
# Fetching works for Marc Bonten (A5055970684)...
# Fetching works for Dorret Boomsma (A5079752137)...
# Fetching works for Arnoud Boot (A5047273273)...
# Fetching works for René de Borst (A5089573819)...
# Fetching works for Piet Borst CBE (A5060054431)...
# Fetching works for Piet Borst CBE (A5110056321)...
# Fetching works for Kees  van den  Bos (A5004497466)...
# Fetching works for Hans Bos (A5003224348)...
# Fetching works for Antal van den Bosch (A5031562992)...
# Fetching works for Joop Bouma (A5053447527)...
# Fetching works for Johan Bouma (A5021866200)...
# Fetching works for Herman Bouma (A5108354377)...
# Fetching works for Teun  Bousema (A5036396443)...
# Fetching works for Carlijn Bouten (A5044939299)...
# Fetching works for Harro Bouwmeester (A5085437167)...
# Fetching works for Joke Bouwstra (A5072790675)...
# Fetching works for Lans Bovenberg (A5069552131)...
# Fetching works for Mark Bovens (A5049185993)...
# Fetching works for Henk Braakhuis (A5020188128)...
# Fetching works for Joseph Braat (A5109193412)...
# Fetching works for Paul Brakefield (A5082295183)...
# Fetching works for Annelien Bredenoord (A5044833174)...
# Fetching works for Ferry Breedveld (A5111692713)...
# Fetching works for Nico van Breemen (A5036248989)...
# Fetching works for Douwe Breimer (A5109127184)...
# Fetching works for Jan Breman (A5077394861)...
# Fetching works for Monique Breteler (A5070946697)...
# Fetching works for Marcel van den Brink (A5003503263)...
# Fetching works for Laurens Jan Brinkhorst (A5108346892)...
# Fetching works for Henk Brinkhuis (A5063324707)...
# Fetching works for Roel van den Broek (A5027570483)...
# Fetching works for Michiel van den Broeke (A5025794003)...
# Fetching works for Henk Broer (A5069925617)...
# Fetching works for Dick Broer (A5050911754)...
# Fetching works for Johannes Bronkhorst (A5006349948)...
# Fetching works for Bart Bronnenberg (A5081497740)...
# Fetching works for Peter Brown (A5087477752)...
# Fetching works for Thijn Brummelkamp (A5022409300)...
# Fetching works for Bert Brunekreef (A5025017022)...
# Fetching works for Han Brunner (A5030485933)...
# Fetching works for Lucas Brunsveld (A5082546186)...
# Fetching works for Kenneth Buesseler (A5012317636)...
# Fetching works for Harry Buhrman (A5083983355)...
# Fetching works for Willem Buiter (A5002338111)...
# Fetching works for Harry Büller (A5042290277)...
# Fetching works for Erwin Bulte (A5019516009)...
# Fetching works for Wiep van Bunge (A5085817427)...
# Fetching works for Joost Businger (A5090354469)...
# Fetching works for Harvey Butcher (A5075375452)...
# Fetching works for Bram Buunk (A5113506537)...
# Fetching works for Peter Carmeliet (A5047152113)...
# Fetching works for Ger Challa (A5108810452)...
# Fetching works for Lisa Cheng (A5088430839)...
# Fetching works for Herbert Clark (A5047363625)...
# Fetching works for Eve Clark (A5103117826)...
# Fetching works for Hans Clevers (A5062248785)...
# Fetching works for Sierd Cloetingh (A5034750019)...
# Fetching works for Reinder Coehoorn (A5072172184)...
# Fetching works for Martien Cohen Stuart (A5076719382)...
# Fetching works for Margaret Collinson (A5006997990)...
# Fetching works for Bernard Comrie (A5070791275)...
# Fetching works for Roshan Cools (A5072571980)...
# Fetching works for Marius Crainic (A5064361316)...
# Fetching works for Ronald Cramer (A5112681145)...
# Fetching works for Maghiel  van Crevel (A5006371825)...
# Fetching works for Roberta Croce (A5036165713)...
# Fetching works for Eveline Crone (A5064580768)...
# Fetching works for Pedro Crous (A5014452233)...
# Fetching works for Deirdre Curtin (A5108547021)...
# Fetching works for Hans Daiber (A5067723183)...
# Fetching works for Jan Dalhuisen (A5046468479)...
# Fetching works for Eric van Damme (A5005979958)...
# Fetching works for Jenny Dankelman (A5068143444)...
# Fetching works for Ingrid Daubechies (A5107519484)...
# Fetching works for George Davey Smith (A5013184354)...
# Fetching works for Karel Davids (A5105778690)...
# Fetching works for Nynke Dekker (A5066937642)...
# Fetching works for Cees Dekker (A5089996499)...
# Fetching works for Jan van Deth (A5047607822)...
# Fetching works for Arwen Deuss (A5071884555)...
# Fetching works for Wilfried Dewachter (A5019370929)...
# Fetching works for Patrick Dewilde (A5035921496)...
# Fetching works for Marcel Dicke (A5058286546)...
# Fetching works for Karel Dicke (A5110111395)...
# Fetching works for Dennis Dieks (A5052808639)...
# Fetching works for José van Dijck (A5031080224)...
# Fetching works for Pieter van Dijk (A5073629339)...
# Fetching works for Peter ten Dijke (A5046914597)...
# Fetching works for Robbert Dijkgraaf (A5027184820)...
# Fetching works for Marjolein Dijkstra (A5044673835)...
# Fetching works for Henk Dijkstra (A5030881656)...
# Fetching works for Bauke Dijkstra (A5066632471)...
# Fetching works for Marcel den Dikken (A5047183527)...
# Fetching works for Charles Dinarello (A5028234430)...
# Fetching works for Ewine van Dishoeck (A5048537056)...
# Fetching works for Vishva M. Dixit (A5084210146)...
# Fetching works for Marileen Dogterom (A5011932505)...
# Fetching works for Eddy van Doorslaer (A5056551664)...
# Fetching works for Eite Drent (A5071897698)...
# Fetching works for Pieter Drenth (A5072837175)...
# Fetching works for Carsten de Dreu (A5076545878)...
# Fetching works for Lou van den Dries (A5088052582)...
# Fetching works for Arnold Driessen (A5068549255)...
# Fetching works for Denis Duboule (A5036343790)...
# Fetching works for Cornelia van Duijn (A5017009749)...
# Fetching works for Catarina Dutilh Novaes (A5026914322)...
# Fetching works for Jan Willem Duyvendak (A5065718355)...
# Fetching works for Pearl Dykstra (A5023961667)...
# Fetching works for Lex van der Eb (A5110276364)...
# Fetching works for Mick Eekhout (A5032861987)...
# Fetching works for Jos Eggermont (A5112519356)...
# Fetching works for Philip van der Eijk (A5110391159)...
# Fetching works for Cees van der Eijk (A5020069172)...
# Fetching works for Ron Ekers (A5039716272)...
# Fetching works for Naomi Ellemers (A5067477814)...
# Fetching works for Bernet Elzinga (A5084976375)...
# Fetching works for Paul Emmelkamp (A5057350604)...
# Fetching works for Karl Enenkel (A5031996075)...
# Fetching works for Pierre van der Eng (A5066293729)...
# Fetching works for Godfried Engbersen (A5108824532)...
# Fetching works for Mirjam Ernestus (A5091677603)...
# Fetching works for Judith van Erp (A5089319801)...
# Fetching works for Wim van Es (A5088560819)...
# Fetching works for Thijs Ettema (A5086230550)...
# Fetching works for Andrea Evers (A5065164200)...
# Fetching works for Carel Faber (A5025699272)...
# Fetching works for Heino Falcke (A5050345412)...
# Fetching works for Reindert Falkenburg (A5058020822)...
# Fetching works for Martin Fase (A5112553741)...
# Fetching works for Michael Faure (A5086027798)...
# Fetching works for Bert Felling (A5062048773)...
# Fetching works for Ben Feringa (A5087713906)...
# Fetching works for Guillén Fernández (A5064429146)...
# Fetching works for Carl Figdor (A5052126051)...
# Fetching works for Manfred Fischer (A5037982517)...
# Fetching works for René Foqué (A5035286664)...
# Fetching works for Ron Fouchier (A5033922663)...
# Fetching works for James Fox (A5024428264)...
# Fetching works for Bas van Fraassen (A5005922054)...
# Fetching works for Barbara Franke (A5038874292)...
# Fetching works for Hans Franken (A5005485108)...
# Fetching works for Philip Hans Franses (A5064321959)...
# Fetching works for Marijn Franx (A5013271839)...
# Fetching works for Daan Frenkel (A5050049504)...
# Fetching works for Joost Frenken (A5025716936)...
# Fetching works for Louise Fresco (A5002418879)...
# Fetching works for Florentino Garcìa Martìnez (A5108437741)...
# Fetching works for Sara van de Geer (A5033661683)...
# Fetching works for Marc Geers (A5057263022)...
# Fetching works for Geert Jan van Gelder (A5080268394)...
# Fetching works for Guillaume van Gemert (A5086145315)...
# Fetching works for Janneke Gerards (A5004330525)...
# Fetching works for Klarita Gërxhani (A5008965781)...
# Fetching works for Peter Geschiere (A5007534832)...
# Fetching works for Hans Geuze (A5080897795)...
# Fetching works for Halleh Ghorashi (A5055560013)...
# Fetching works for Stan Gielen (A5108399880)...
# Fetching works for Jenny Gierveld (A5005676241)...
# Fetching works for Ivo Giesen (A5045509269)...
# Fetching works for Erik van der Giessen (A5047173595)...
# Fetching works for Jan van Gijn (A5066554954)...
# Fetching works for Richard Gill (A5042561088)...
# Fetching works for Willem Hendrik Gispen (A5110112204)...
# Fetching works for Rainer Goebel (A5026206233)...
# Fetching works for Marieke de Goede (A5042484381)...
# Fetching works for Jacob Goeree (A5070527085)...
# Fetching works for Jacqueline van Gorkom (A5109891895)...
# Fetching works for Beatrice de Graaf (A5076684481)...
# Fetching works for Maria Grever (A5063631584)...
# Fetching works for Rick Grobbee (A5112077285)...
# Fetching works for Kees Groeneboer (A5069737296)...
# Fetching works for Marc Groenhuijsen (A5045259352)...
# Fetching works for Rienk van Grondelle (A5050480031)...
# Fetching works for Piet Gros (A5045574506)...
# Fetching works for Frank Grosveld (A5056347519)...
# Fetching works for Maarten van de Guchte (A5102841266)...
# Fetching works for Jan Willem Gunning (A5007600056)...
# Fetching works for Wilfred van Gunsteren (A5063856246)...
# Fetching works for Herman van Gunsteren (A5049286062)...
# Fetching works for Holger Gzella (A5085015143)...
# Fetching works for Harm Habing (A5077701450)...
# Fetching works for Peter Hagoort (A5031285239)...
# Fetching works for Dick van Halsema (A5077869021)...
# Fetching works for Wouter Hanegraaff (A5058184692)...
# Fetching works for Ronald Hanson (A5039442806)...
# Fetching works for Annette Harder (A5034603956)...
# Fetching works for Anita Hardon (A5086338286)...
# Fetching works for Frank van Harmelen (A5029130731)...
# Fetching works for Paul 't Hart (A5066617319)...
# Fetching works for Joest 't Hart (A5013252508)...
# Fetching works for Arthur Hartkamp (A5061174995)...
# Fetching works for Joop Hartog (A5051905394)...
# Fetching works for Deanne den Hartog (A5017005488)...
# Fetching works for Trevor Hastie (A5045744709)...
# Fetching works for Henk ten Have (A5016797019)...
# Fetching works for Albert Heck (A5053603496)...
# Fetching works for Ron Heeren (A5057609112)...
# Fetching works for Martin van Hees (A5113779966)...
# Fetching works for Paul van der Heijden (A5108827485)...
# Fetching works for Sef Heijnen (A5109138305)...
# Fetching works for Gert Jan van Heijst (A5113598668)...
# Fetching works for Olivier Hekster (A5075994135)...
# Fetching works for Natali Helberger (A5053437341)...
# Fetching works for Lotte Hellinga-Querido (A5005246565)...
# Fetching works for Frans van der Helm (A5113760107)...
# Fetching works for Amina Helmi (A5073770015)...
# Fetching works for Coen Hemker (A5025201242)...
# Fetching works for Gotthilf Hempel (A5113989475)...
# Fetching works for Petra Hendriks (A5027258945)...
# Fetching works for Kees Hengeveld (A5110646564)...
# Fetching works for Paulien Herder (A5002593973)...
# Fetching works for Lambert Hesselink (A5110998886)...
# Fetching works for Lambert Hesselink (A5012890372)...
# Fetching works for Jan van Hest (A5016767643)...
# Fetching works for Ed van den Heuvel (A5004019464)...
# Fetching works for Vincent van Heuven (A5061764933)...
# Fetching works for Frits Hilgen (A5086776394)...
# Fetching works for Thea Hilhorst (A5032086874)...
# Fetching works for Henk Hilhorst (A5049717755)...
# Fetching works for Henk Hillenaar (A5052135462)...
# Fetching works for Tadaki Hirose (A5111599322)...
# Fetching works for Ernst Hirsch Ballin (A5009595518)...
# Fetching works for Jan Hoeijmakers (A5052209499)...
# Fetching works for Wiel Hoekstra (A5003393831)...
# Fetching works for Bert Hofman (A5108116354)...
# Fetching works for Remco van der Hofstad (A5034587660)...
# Fetching works for Jan Hogendijk (A5061336433)...
# Fetching works for Pancras Hogendoorn (A5003014435)...
# Fetching works for Elly Hol (A5013180706)...
# Fetching works for Wim Hol (A5108085252)...
# Fetching works for Carla Hollak (A5024669037)...
# Fetching works for Frank den Hollander (A5103224652)...
# Fetching works for Cornelis Hollenberg (A5111388006)...
# Fetching works for Ewoud Hondius (A5013216570)...
# Fetching works for Henkjan Honing (A5025728702)...
# Fetching works for Jan van Hooff (A5112733260)...
# Fetching works for Gerard 't Hooft (A5059474142)...
# Fetching works for Serge Hoogendoorn (A5077352940)...
# Fetching works for Henry Hooghiemstra (A5015451212)...
# Fetching works for Adrianus de Hoop (A5108528658)...
# Fetching works for Paul Hooykaas (A5074960830)...
# Fetching works for Mary Horowitz (A5091433944)...
# Fetching works for Piet van der Horst (A5051885491)...
# Fetching works for Jeff de Hosson (A5043868230)...
# Fetching works for Theo van den Hout (A5076995309)...
# Fetching works for Jeanine Houwing-Duistermaat (A5074193742)...
# Fetching works for Lawrence Hubert (A5113513665)...
# Fetching works for Wilhelm Huck (A5057058267)...
# Fetching works for Nico Hugenholtz (A5025156708)...
# Fetching works for Suzanne Hulscher (A5034759142)...
# Fetching works for Piet Hut (A5110618530)...
# Fetching works for Francesco Iachello (A5008909182)...
# Fetching works for Wilt Idema (A5067454662)...
# Fetching works for Marinus van IJzendoorn dr. h.c. (A5048314918)...
# Fetching works for Guido Imbens (A5052726702)...
# Fetching works for Jonathan Israel (A5109856261)...
# Fetching works for Bart Jacobs (A5084226578)...
# Fetching works for Vincent Jaddoe (A5012921360)...
# Fetching works for Anita Jansen (A5030179183)...
# Fetching works for Willy Jansen (A5022667936)...
# Fetching works for John Jansen (A5090135028)...
# Fetching works for Johan Jansonius (A5111423454)...
# Fetching works for Susanne Janssen (A5072483851)...
# Fetching works for René Janssen (A5038975929)...
# Fetching works for Erik Jayme (A5085467599)...
# Fetching works for Lotte Jensen (A5075665310)...
# Fetching works for Mike Jetten (A5036215557)...
# Fetching works for Jolanda Jetten (A5004337400)...
# Fetching works for Marian Joëls (A5069823044)...
# Fetching works for Aise de Jong (A5089160741)...
# Fetching works for Ab de Jong (A5012738054)...
# Fetching works for Irene de Jong (A5067467997)...
# Fetching works for Petra de Jongh (A5040096948)...
# Fetching works for Eddy de Jongh (A5113907934)...
# Fetching works for Joshua Jortner (A5111838551)...
# Fetching works for Dick van de Kaa (A5113482416)...
# Fetching works for René Kahn (A5031613969)...
# Fetching works for Matthijs Kalmijn (A5082048045)...
# Fetching works for Ab van Kammen (A5046751798)...
# Fetching works for Hans Kamp (A5109573358)...
# Fetching works for Roland Kanaar (A5038398625)...
# Fetching works for Hans Kaper (A5054755754)...
# No OpenAlex ID for Ernestine Kaper. Skipping...
# Fetching works for Rob Kaptein (A5111915979)...
# Fetching works for Arie Kapteyn (A5059397539)...
# Fetching works for Martin Karplus (A5076499540)...
# Fetching works for Martijn Katan (A5035572308)...
# Fetching works for Misha Katsnelson (A5005419486)...
# Fetching works for Mike Keane (A5000726249)...
# Fetching works for Peter van Kessel (A5011520905)...
# Fetching works for Sol Kimel (A5022930343)...
# Fetching works for Hanan Kisch (A5053846476)...
# Fetching works for Jan Kiviet (A5032724070)...
# Fetching works for Marian Klamer (A5037039029)...
# Fetching works for Caroline Klaver (A5029529953)...
# Fetching works for Pauline Kleingeld (A5003392945)...
# Fetching works for André Klip (A5082495058)...
# Fetching works for Michiel van der Klis (A5048157801)...
# Fetching works for Jeroen de Kloet (A5041131454)...
# Fetching works for Jan Willem Klop (A5110443113)...
# Fetching works for Theo van de Klundert (A5074370086)...
# Fetching works for Marjo van der Knaap (A5064045676)...
# Fetching works for Bert van der Knaap (A5005820831)...
# Fetching works for André Knottnerus (A5086562154)...
# Fetching works for Jan Koeman (A5008820116)...
# Fetching works for Gijsje Koenderink (A5083550174)...
# Fetching works for Jan Koenderink (A5054397668)...
# Fetching works for Johannes Konst (A5026546651)...
# Fetching works for Bas Kooijman (A5011546776)...
# Fetching works for Jelle Koopmans (A5002197154)...
# Fetching works for Marion Koopmans (A5008677339)...
# Fetching works for Maarten Koornneef (A5087379591)...
# Fetching works for Yvette van Kooyk (A5009217310)...
# Fetching works for Marc Koper (A5028485156)...
# Fetching works for Jaap Korevaar (A5108369385)...
# Fetching works for Frits Kortlandt (A5109714174)...
# Fetching works for Gerard van Koten (A5089521767)...
# Fetching works for Leo Kouwenhoven (A5103068314)...
# Fetching works for Xandra Kramer (A5085372272)...
# Fetching works for Jan Kramers (A5011245867)...
# Fetching works for Ben de Kruijff (A5030638118)...
# Fetching works for Remke Kruk (A5046849714)...
# Fetching works for Arno Kuijlaars (A5044081911)...
# Fetching works for Leonard van der Kuijp (A5022685947)...
# Fetching works for Simon Kuipers (A5113468194)...
# Fetching works for Oscar Kuipers (A5017781414)...
# Fetching works for Hans Kuipers (A5071048612)...
# Fetching works for Giselinde Kuipers (A5075600315)...
# Fetching works for Srinivas Kulkarni (A5112848197)...
# Fetching works for Max Kuperus (A5027599309)...
# Fetching works for Harry van der Laan (A5085582855)...
# Fetching works for Horst Lademacher (A5064520666)...
# Fetching works for Ad Lagendijk (A5054843956)...
# Fetching works for Inald Lagendijk (A5016853521)...
# Fetching works for Kurt Lambeck (A5049983897)...
# Fetching works for Hans Lambers (A5016389221)...
# Fetching works for Steven Lamberts (A5113453092)...
# Fetching works for Henny Lamers (A5042073722)...
# Fetching works for Klaas Landsman (A5111881134)...
# Fetching works for Titia de Lange (A5065113600)...
# Fetching works for Christian Lange (A5114374179)...
# Fetching works for Monique Laurent (A5047819350)...
# Fetching works for Richard Lauwaars (A5022717598)...
# Fetching works for Peter Leeflang (A5077152739)...
# Fetching works for Inger Leemans (A5090167566)...
# Fetching works for Joep Leerssen (A5003885020)...
# Fetching works for Jan  de Leeuw (A5057009278)...
# Fetching works for Sander van der Leeuw (A5014647084)...
# Fetching works for Jean-Marie Lehn (A5059296399)...
# Fetching works for Henk Lekkerkerker (A5038502536)...
# Fetching works for Hendrik Lenstra (A5109855871)...
# Fetching works for Joop van Lenteren (A5065428384)...
# Fetching works for Ron Lesthaeghe (A5005533367)...
# Fetching works for Rob Leurs (A5087896916)...
# Fetching works for Pim Levelt (A5109436410)...
# Fetching works for Marcel Levi (A5038678186)...
# Fetching works for Robert de Levie (A5046810886)...
# Fetching works for Walter Lewin (A5110725595)...
# Fetching works for Aart Liefbroer (A5035758817)...
# Fetching works for Luuk de Ligt (A5043894754)...
# Fetching works for Arend Lijphart (A5034708283)...
# Fetching works for Frank Linde (A5035367751)...
# Fetching works for Siegwart Lindenberg (A5068892781)...
# Fetching works for Harry Lintsen (A5108248699)...
# Fetching works for Tanja van der Lippe (A5042437033)...
# Fetching works for Frank Lobbezoo (A5033583933)...
# Fetching works for Detlef Lohse (A5066010665)...
# Fetching works for Maria Antonietta Loi (A5029707613)...
# Fetching works for Renate Loll (A5024443253)...
# Fetching works for Eduard Looijenga (A5012506697)...
# Fetching works for Mark van Loosdrecht (A5062101644)...
# Fetching works for Leendert Louwe Kooijmans (A5012683556)...
# Fetching works for László Lovász (A5067889485)...
# Fetching works for Bob Löwenberg (A5046775582)...
# Fetching works for Sasha Lubotsky (A5041028376)...
# Fetching works for Leo Lucassen (A5026579593)...
# Fetching works for Jan Lucassen (A5023229048)...
# Fetching works for Christoph Lüthy (A5011817938)...
# Fetching works for Amade M’charek (A5044269922)...
# Fetching works for Eddy van der Maarel (A5109554516)...
# Fetching works for Ejan Mackaay (A5090007650)...
# Fetching works for Johan Mackenbach (A5042474249)...
# Fetching works for Roderick MacKinnon (A5025045433)...
# Fetching works for Vanessa Mak (A5075264091)...
# Fetching works for Kofi Makinwa (A5029302924)...
# Fetching works for Jaap Mansfeld (A5077987498)...
# Fetching works for Titti Mariani (A5002175456)...
# Fetching works for Sera  Markoff (A5023792827)...
# Fetching works for Siewert-Jan Marrink (A5062095380)...
# Fetching works for Eric Mazur (A5091242412)...
# Fetching works for Valentina Mazzucato (A5049878471)...
# Fetching works for René Medema (A5074565662)...
# Fetching works for Jos van der Meer (A5008373339)...
# Fetching works for Gerrit van Meer (A5030256996)...
# Fetching works for Gerard Meijer (A5040038977)...
# Fetching works for Bert Meijer (A5077491842)...
# Fetching works for Eginhard Meijering (A5062368262)...
# Fetching works for Andries Meijerink (A5051420645)...
# Fetching works for Debora Meijers (A5058340610)...
# Fetching works for Kees Melief (A5034526361)...
# Fetching works for Walter Melion (A5026849474)...
# Fetching works for Julien Mendlewicz (A5017263126)...
# Fetching works for Steph Menken (A5076184651)...
# Fetching works for Albert Menkveld (A5046473475)...
# Fetching works for Stephen Mennell (A5029055845)...
# Fetching works for Harald Merckelbach (A5031330031)...
# Fetching works for Judi Mesman (A5086422376)...
# Fetching works for Alice ter Meulen (A5066920888)...
# Fetching works for Jacqueline Meulman (A5111647643)...
# Fetching works for Antje Meyer (A5091304551)...
# Fetching works for Birgit Meyer (A5027779972)...
# Fetching works for Hartmut Michel (A5065696174)...
# Fetching works for John Michon (A5047385666)...
# Fetching works for Jack Middelburg (A5043015956)...
# Fetching works for Wijnand Mijnhardt (A5072768033)...
# Fetching works for George Miley (A5007786170)...
# Fetching works for Ieke Moerdijk (A5015377052)...
# Fetching works for Keith Moffatt (A5063919952)...
# Fetching works for Joël Mokyr (A5110900731)...
# Fetching works for Annemarie Mol (A5046961212)...
# Fetching works for Laurens Molenkamp (A5085660056)...
# Fetching works for Hans Mooij (A5078587396)...
# Fetching works for Mary Morgan (A5008433860)...
# Fetching works for Maarten Mous (A5001739140)...
# Fetching works for Nicolette Mout (A5072756639)...
# Fetching works for Cas Mudde (A5081574124)...
# Fetching works for Clara Mulder (A5025953837)...
# Fetching works for Gerhard Müller (A5047665746)...
# Fetching works for Christine Mummery (A5085628953)...
# Fetching works for Heleen Murre-van den Berg (A5055367636)...
# Fetching works for John Mydosh (A5039748491)...
# Fetching works for Lodi Nauta (A5011701239)...
# Fetching works for Bram Nauta (A5035402438)...
# Fetching works for Jacques Neefjes (A5060457244)...
# Fetching works for Jan van Neerven (A5069563754)...
# Fetching works for John Nerbonne (A5065920740)...
# Fetching works for Nancy Nersessian (A5073390127)...
# Fetching works for Mihai Netea (A5027955775)...
# Fetching works for Bernard Nienhuis (A5039629784)...
# Fetching works for Wiro Niessen (A5038384386)...
# Fetching works for Peter van Nieuwenhuizen (A5002694782)...
# Fetching works for Emmie te Nijenhuis (A5070734072)...
# Fetching works for Peter Nijkamp (A5009404760)...
# Fetching works for Guust Nolet (A5084502405)...
# Fetching works for André Nollkaemper (A5049950975)...
# Fetching works for Julia Noordegraaf (A5033868045)...
# Fetching works for Ed Noort (A5057686290)...
# Fetching works for Bart Nooteboom (A5044940827)...
# Fetching works for Roel Nusse (A5048466506)...
# Fetching works for Theo Odijk (A5034539406)...
# Fetching works for Hans Oerlemans (A5065040600)...
# Fetching works for John van der Oost (A5010586842)...
# Fetching works for Frits van Oostrom (A5070910528)...
# Fetching works for Eric Opdam (A5009015751)...
# Fetching works for Hans Opschoor (A5066494352)...
# Fetching works for Gordon Orians (A5084855850)...
# Fetching works for Michel Orrit (A5065097100)...
# Fetching works for Jim van Os (A5024796415)...
# Fetching works for Henk van Os (A5105738008)...
# Fetching works for Ab Osterhaus (A5110227659)...
# Fetching works for Jeremiah Ostriker (A5045925716)...
# Fetching works for Koen Ottenheym (A5050931151)...
# Fetching works for Sijbren Otto (A5014310152)...
# Fetching works for Alexander van Oudenaarden (A5035202405)...
# Fetching works for Hermen Overkleeft (A5056673744)...
# Fetching works for René Pahud de Mortanges (A5086593700)...
# Fetching works for Franz Palm (A5009560383)...
# Fetching works for Thom Palstra (A5103524282)...
# Fetching works for Geoffrey Parker (A5009215153)...
# Fetching works for Barbara Partee (A5077409169)...
# Fetching works for Kiran Patel (A5111283735)...
# Fetching works for Herman Paul (A5050951546)...
# Fetching works for Peter Pearson (A5064509518)...
# Fetching works for Johannes Pennings (A5011277921)...
# Fetching works for Brenda Penninx (A5055183685)...
# Fetching works for Theunis Piersma (A5033978446)...
# Fetching works for Jean Pieters (A5044213528)...
# Fetching works for Corné Pieterse (A5038302656)...
# Fetching works for David Pinder (A5076520466)...
# Fetching works for Bob Pinedo (A5105878379)...
# Fetching works for Patricia Pisters (A5042768066)...
# Fetching works for Ronald Plasterk (A5052007480)...
# Fetching works for Henri Pleket (A5046867798)...
# Fetching works for Hans van der Plicht (A5087183374)...
# Fetching works for Rick van der Ploeg (A5021495373)...
# Fetching works for Hidde Ploegh (A5081514135)...
# Fetching works for Ibo van de Poel (A5113618730)...
# Fetching works for Tom van der Poll (A5048965254)...
# Fetching works for Judith Pollmann (A5070872015)...
# Fetching works for Albert Polman (A5060264337)...
# Fetching works for Bert Poolman (A5041070000)...
# Fetching works for Jacques Poot (A5061458455)...
# Fetching works for Mladen Popović (A5081174058)...
# Fetching works for Danielle Posthuma (A5052016436)...
# Fetching works for Dirkje Postma (A5030603878)...
# Fetching works for Mirjam van Praag (A5057217391)...
# Fetching works for Herman van Praag (A5109065522)...
# Fetching works for Bernard van Praag (A5011448760)...
# Fetching works for Maarten Prak (A5065470561)...
# Fetching works for Om Prakash (A5083380417)...
# Fetching works for Lucas Prakke (A5049523003)...
# Fetching works for Sacha Prechal (A5047308695)...
# Fetching works for Walter Prevenier (A5010682105)...
# Fetching works for Sally Price (A5003474186)...
# Fetching works for Roel Prins (A5081510450)...
# Fetching works for Corien Prins (A5065530656)...
# Fetching works for Jack Pronk (A5087000945)...
# Fetching works for Andrea Prosperetti (A5050089803)...
# Fetching works for Wim van der Putten (A5040240993)...
# Fetching works for Aad Quak (A5098643396)...
# Fetching works for Jos Raaijmakers (A5072260864)...
# Fetching works for Rudy Rabbinge (A5038265139)...
# Fetching works for Theo Rasing (A5033939277)...
# Fetching works for Jan Reedijk (A5086816309)...
# Fetching works for Joost Reek (A5013850715)...
# Fetching works for Martin Rees (A5110092412)...
# Fetching works for Manfred Reetz (A5112819763)...
# Fetching works for David Regan (A5101686963)...
# Fetching works for Hans Reiber (A5048516238)...
# Fetching works for David Reinhoudt (A5112298693)...
# Fetching works for Willem Remmelink (A5110027929)...
# Fetching works for Rob Reneman (A5111670546)...
# Fetching works for Geert Ridder (A5102733930)...
# Fetching works for Richard Ridderinkhof (A5064459907)...
# Fetching works for René de la Rie (A5023441661)...
# Fetching works for Ivonne Rietjens (A5032367534)...
# Fetching works for Ann Rigney (A5019293289)...
# Fetching works for Maarten de Rijke (A5031439294)...
# Fetching works for Avraham Rinat-Reiner (A5046267835)...
# Fetching works for Avraham Rinat-Reiner (A5080051550)...
# Fetching works for Avraham Rinat-Reiner (A5113804457)...
# Fetching works for Ingrid Robeyns (A5050270181)...
# Fetching works for George Robillard (A5105694788)...
# Fetching works for Wil Roebroeks (A5051515585)...
# Fetching works for Karin Roelofs (A5087340678)...
# Fetching works for Eelco Rohling (A5076761974)...
# Fetching works for Jana Roithová (A5021283178)...
# Fetching works for Lucas van Rompay (A5083579348)...
# Fetching works for Nico de Rooij (A5109170304)...
# Fetching works for Hilger Ropers (A5009225418)...
# Fetching works for Frits Rosendaal (A5031487360)...
# Fetching works for Judith  Rosmalen (A5005007108)...
# Fetching works for Maroeska Rovers (A5053996737)...
# Fetching works for Joost Ruitenberg (A5014407907)...
# Fetching works for Reiner Rummel (A5022246083)...
# Fetching works for Douwe Runia (A5112350821)...
# Fetching works for Floris Rutjes (A5067503330)...
# Fetching works for Wim van Saarloos (A5062482808)...
# Fetching works for Richard van de Sanden (A5078580218)...
# Fetching works for Andries Sanders (A5097400483)...
# Fetching works for Andries Sanders (A5015098320)...
# Works data with full details saved to knaw_works.json.

# %%
import json  # Make sure to import the json module

with open("knaw_works.json", "r") as file:
    data = json.load(file)
    print(data[:10])  # View the first 10 works

# %%
import json

input_file = "/content/knaw_works.json"
output_file = "knaw_works_subset.json"

# Open and load the full JSON file
with open(input_file, "r") as file:
    data = json.load(file)  # Load entire JSON file into memory

# Extract the first 1000 records (or fewer if the file has less than 1000)
subset = data[:1000]  # Adjust the number for your subset size

# Save the subset to a new JSON file
with open(output_file, "w") as output:
    json.dump(subset, output, indent=4)

print(f"Subset saved to {output_file}")
# Out:
# Subset saved to knaw_works_subset.json

# %%
import requests
import json
import time
import pandas as pd

# Input and output file paths
input_file = "knaw_members_with_indices.json"  # Replace with your actual file path
output_json_file = "knaw_works_filtered.json"  # JSON file output
output_csv_file = "knaw_works_filtered.csv"  # CSV file output
progress_log_file = "progress_log.json"  # Log file to track progress

# OpenAlex base API URL
openalex_base_url = "https://api.openalex.org"

# Function to fetch works for an author
def fetch_author_works(author_id):
    works = []
    page = 1
    while True:
        url = f"{openalex_base_url}/works?filter=author.id:{author_id}&per-page=200&page={page}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            for work in data["results"]:
                filtered_work = {
                    "id": work.get("id"),
                    "title": work.get("title"),
                    "doi": work.get("doi"),
                    "publication_year": work.get("publication_year"),
                    "cited_by_count": work.get("cited_by_count"),
                    "authorships": [
                        {
                            "author": {
                                "id": auth.get("author", {}).get("id"),
                                "display_name": auth.get("author", {}).get("display_name")
                            },
                            "institutions": [
                                {
                                    "id": inst.get("id"),
                                    "display_name": inst.get("display_name"),
                                    "country_code": inst.get("country_code")
                                }
                                for inst in auth.get("institutions", [])
                            ]
                        }
                        for auth in work.get("authorships", [])
                    ],
                    "topics": [
                        {
                            "display_name": topic.get("display_name"),
                            "score": topic.get("score")
                        }
                        for topic in work.get("concepts", [])
                    ],
                    "open_access": work.get("open_access"),
                    "referenced_works": work.get("referenced_works")
                }
                works.append(filtered_work)
            if "next" not in data["meta"]:
                break
            page += 1
            time.sleep(1)  # Respect API rate limits
        else:
            print(f"Error fetching works for author {author_id}: {response.status_code}")
            break
    return works

# Load the existing JSON file
with open(input_file, "r") as infile:
    members = json.load(infile)

# Load or initialize the progress log
try:
    with open(progress_log_file, "r") as log_file:
        progress_log = json.load(log_file)
except FileNotFoundError:
    progress_log = {}

# Fetch works for each author and organize them under authors
authors_with_works = []
for member in members:
    name = member["name"]
    openalex_ids = member.get("openalex_id")
    all_works = []

    if name in progress_log and progress_log[name]:
        print(f"Skipping {name}, already completed.")
        continue

    print(f"Fetching works for {name}...")

    try:
        if isinstance(openalex_ids, list):
            for openalex_id in openalex_ids:
                author_id = openalex_id.split("/")[-1]  # Extract author ID
                all_works.extend(fetch_author_works(author_id))
        elif isinstance(openalex_ids, str):
            author_id = openalex_ids.split("/")[-1]
            all_works.extend(fetch_author_works(author_id))

        authors_with_works.append({
            "name": name,
            "openalex_id": openalex_ids,
            "works": all_works
        })

        # Mark the author as successfully processed
        progress_log[name] = True

    except Exception as e:
        print(f"Error processing {name}: {e}")
        progress_log[name] = False  # Mark as failed

    # Save progress after each author
    with open(progress_log_file, "w") as log_file:
        json.dump(progress_log, log_file, indent=4)

# Save the filtered data to a JSON file
with open(output_json_file, "w") as outfile:
    json.dump(authors_with_works, outfile, indent=4)
print(f"Filtered works data saved to JSON: {output_json_file}")

# Convert to CSV for easier inspection
csv_data = []
for author in authors_with_works:
    for work in author["works"]:
        csv_data.append({
            "author_name": author["name"],
            "author_openalex_id": author["openalex_id"],
            "work_id": work["id"],
            "work_title": work["title"],
            "doi": work["doi"],
            "publication_year": work["publication_year"],
            "cited_by_count": work["cited_by_count"],
            "topics": ", ".join([topic["display_name"] for topic in work["topics"]]),
            "open_access_status": work["open_access"]["oa_status"] if work["open_access"] else None,
            "referenced_works_count": len(work["referenced_works"]) if work["referenced_works"] else 0
        })

pd.DataFrame(csv_data).to_csv(output_csv_file, index=False)
print(f"Filtered works data saved to CSV: {output_csv_file}")
# Out:
# Fetching works for Wil van der Aalst (https://openalex.org/A5069762894)...
# Fetching works for Kees Aarts (https://openalex.org/A5025713059)...
# Fetching works for Gerard Acket (https://openalex.org/A5046174111)...
# Fetching works for Remieg Aerts (https://openalex.org/A5026631020)...
# Fetching works for Conny Aerts (https://openalex.org/A5071357492)...
# Fetching works for Reuven Agami (https://openalex.org/A5079323488)...
# Fetching works for Frits Agterberg (https://openalex.org/A5083547574)...
# Fetching works for Takuzo Aida (https://openalex.org/A5063217261)...
# Fetching works for Anna Akhmanova (https://openalex.org/A5024109873)...
# Fetching works for Barbara Aland (https://openalex.org/A5007027058)...
# Fetching works for Tjeerd van Albada (https://openalex.org/A5068636900)...
# Fetching works for André Aleman (https://openalex.org/A5083885093)...
# Fetching works for Keimpe Algra (https://openalex.org/A5060721437)...
# Fetching works for Maurits Allessie (https://openalex.org/A5112166922)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-55688ad25279> in <cell line: 77>()
#      88         author_id = openalex_ids.split("/")[-1]
#      89         print(f"Fetching works for {member['name']} ({openalex_ids})...")
# ---> 90         all_works = fetch_author_works(author_id)
#      91         progress_log[openalex_ids] = True
#      92
#
# <ipython-input-11-55688ad25279> in fetch_author_works(author_id)
#      19     while True:
#      20         url = f"{openalex_base_url}/works?filter=author.id:{author_id}&per-page=200&page={page}"
# ---> 21         response = requests.get(url)
#      22         if response.status_code == 200:
#      23             data = response.json()
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787
#     788             # Make the request on the HTTPConnection object
# --> 789             response = self._make_request(
#     790                 conn,
#     791                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534         # Receive the response from the server
#     535         try:
# --> 536             response = conn.getresponse()
#     537         except (BaseSSLError, OSError) as e:
#     538             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     505
#     506         # Get the response from http.client.HTTPConnection
# --> 507         httplib_response = super().getresponse()
#     508
#     509         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import requests
import json
import time
import pandas as pd

# Input and output file paths
input_file = "/content/knaw_members_with_indices.json"  # Replace with your actual file path
output_json_file = "knaw_works_filtered.json"  # JSON file output
output_csv_file = "knaw_works_filtered.csv"  # CSV file output
progress_log_file = "progress_log.json"  # Log file to track progress

# OpenAlex base API URL
openalex_base_url = "https://api.openalex.org"

# Function to fetch works for an author
def fetch_author_works(author_id):
    works = []
    page = 1
    retries = 3  # Retry limit for failed requests

    while True:
        url = f"{openalex_base_url}/works?filter=author.id:{author_id}&per-page=200&page={page}"
        for attempt in range(retries):
            try:
                response = requests.get(url, timeout=10)
                response.raise_for_status()  # Raise error for bad status codes
                data = response.json()

                for work in data.get("results", []):
                    primary_topic = work.get("primary_topic") or {}
                    filtered_work = {
                        "id": work.get("id"),
                        "title": work.get("title", ""),
                        "doi": work.get("doi"),
                        "publication_year": work.get("publication_year"),
                        "cited_by_count": work.get("cited_by_count", 0),
                        "authorships": [
                            {
                                "author": {
                                    "id": auth.get("author", {}).get("id"),
                                    "display_name": auth.get("author", {}).get("display_name", "")
                                },
                                "institutions": [
                                    {
                                        "id": inst.get("id"),
                                        "display_name": inst.get("display_name", ""),
                                        "country_code": inst.get("country_code", "")
                                    }
                                    for inst in auth.get("institutions", []) if inst
                                ]
                            }
                            for auth in work.get("authorships", []) if auth
                        ],
                        "field": primary_topic.get("field", {}).get("display_name", ""),
                        "subfield": primary_topic.get("subfield", {}).get("display_name", ""),
                        "keywords": [
                            {
                                "id": keyword.get("id"),
                                "display_name": keyword.get("display_name", ""),
                                "score": keyword.get("score", 0)
                            }
                            for keyword in work.get("keywords", []) if keyword
                        ],
                        "open_access": work.get("open_access"),
                        "referenced_works": work.get("referenced_works", [])
                    }
                    works.append(filtered_work)

                if "next" not in data.get("meta", {}):
                    return works  # All pages fetched
                page += 1
                break  # Break out of the retry loop on success
            except requests.exceptions.RequestException as e:
                print(f"Error fetching page {page} for author {author_id}: {e}")
                time.sleep(2 ** attempt)  # Exponential backoff
                if attempt == retries - 1:
                    return works  # Return partial results if retries exhausted

    return works

# Load the existing JSON file
with open(input_file, "r") as infile:
    members = json.load(infile)

# Load or initialize the progress log
try:
    with open(progress_log_file, "r") as log_file:
        progress_log = json.load(log_file)
except FileNotFoundError:
    progress_log = {}

# Fetch works for each author and organize them under authors
authors_with_works = []
for member in members:
    name = member["name"]
    openalex_ids = member.get("openalex_id")
    all_works = []

    if name in progress_log and progress_log[name]:
        print(f"Skipping {name}, already completed.")
        continue

    print(f"Fetching works for {name}...")

    try:
        if isinstance(openalex_ids, list):
            for openalex_id in openalex_ids:
                if openalex_id:
                    author_id = openalex_id.split("/")[-1]  # Extract author ID
                    all_works.extend(fetch_author_works(author_id))
        elif isinstance(openalex_ids, str) and openalex_ids:
            author_id = openalex_ids.split("/")[-1]
            all_works.extend(fetch_author_works(author_id))

        authors_with_works.append({
            "name": name,
            "openalex_id": openalex_ids,
            "works": all_works
        })

        # Mark the author as successfully processed
        progress_log[name] = True

    except Exception as e:
        print(f"Error processing {name}: {e}")
        progress_log[name] = False  # Mark as failed

    # Save progress after each author
    with open(progress_log_file, "w") as log_file:
        json.dump(progress_log, log_file, indent=4)

# Save the filtered data to a JSON file
with open(output_json_file, "w") as outfile:
    json.dump(authors_with_works, outfile, indent=4)
print(f"Filtered works data saved to JSON: {output_json_file}")

# Convert to CSV for easier inspection
csv_data = []
for author in authors_with_works:
    for work in author["works"]:
        csv_data.append({
            "author_name": author["name"],
            "author_openalex_id": author["openalex_id"],
            "work_id": work["id"],
            "work_title": work["title"],
            "doi": work["doi"],
            "publication_year": work["publication_year"],
            "cited_by_count": work["cited_by_count"],
            "field": work["field"],
            "subfield": work["subfield"],
            "keywords": ", ".join([keyword["display_name"] for keyword in work["keywords"]]),
            "open_access_status": work["open_access"]["oa_status"] if work["open_access"] else None,
            "referenced_works_count": len(work["referenced_works"])
        })

pd.DataFrame(csv_data).to_csv(output_csv_file, index=False)
print(f"Filtered works data saved to CSV: {output_csv_file}")
# Out:
# Fetching works for Wil van der Aalst...
# Fetching works for Kees Aarts...
# Fetching works for Gerard Acket...
# Fetching works for Remieg Aerts...
# Fetching works for Conny Aerts...
# Fetching works for Reuven Agami...
# Fetching works for Frits Agterberg...
# Fetching works for Takuzo Aida...
# Fetching works for Anna Akhmanova...
# Fetching works for Barbara Aland...
# Fetching works for Tjeerd van Albada...
# Fetching works for André Aleman...
# Fetching works for Keimpe Algra...
# Fetching works for Maurits Allessie...
# Fetching works for Sigurd Angenent...
# Fetching works for Frank Ankersmit...
# Fetching works for Isabel Arends...
# Fetching works for Ad van der Avoird...
# Fetching works for Hein de Baar...
# Fetching works for Thomas Bäck...
# Fetching works for Jan Baerends...
# Fetching works for Marian Bakermans-Kranenburg...
# Fetching works for Jan Albert Bakker...
# Fetching works for Huib Bakker...
# Fetching works for Egbert Bakker...
# Fetching works for Erik Bakkers...
# Fetching works for Henk Barendregt...
# Fetching works for René Barents...
# Fetching works for Renate Bartsch...
# Fetching works for Jurjen Battjes...
# Fetching works for Bas van Bavel...
# Fetching works for Adriaan Bax...
# Fetching works for Bram van de Beek...
# Fetching works for Carlo Beenakker...
# Fetching works for Jos Beijnen...
# Fetching works for Harold Bekkering...
# Fetching works for Wout van Bekkum...
# Fetching works for Jan van Bemmel...
# Fetching works for Zvi Ben-Avraham...
# Fetching works for Jozien Bensing...
# Fetching works for Johan van Benthem...
# Fetching works for Albert van den Berg...
# Fetching works for Leonard van den Berg...
# Fetching works for Gerard van den Berg...
# Fetching works for André Berger...
# Fetching works for Jan Bergstra...
# Fetching works for Piet Bergveld Em....
# Fetching works for Maaike  van Berkel...
# Fetching works for Klaas van Berkel...
# Fetching works for Guus Berkhout...
# Fetching works for René Bernards...
# Fetching works for Ton Berns...
# Fetching works for Michael Berry...
# Fetching works for Connie Bezzina...
# Fetching works for Peter Bickel...
# Fetching works for Marc Bierkens...
# Fetching works for Catrien Bijleveld...
# Fetching works for Karin Bijsterveld...
# Fetching works for Ton Bisseling...
# Fetching works for Alfons van Blaaderen...
# Fetching works for Johan Bleeker...
# Fetching works for Clemens van Blitterswijk...
# Fetching works for Wim Blockmans...
# Fetching works for Bas Bloem...
# Fetching works for Josine Blok...
# Fetching works for Kees Blom...
# Fetching works for Carel Blotkamp...
# Fetching works for Rens Bod...
# Fetching works for Geoffrey Bodenhausen...
# Fetching works for Monique Boekaerts...
# Fetching works for Ted de Boer...
# Fetching works for Hans Boersma...
# Fetching works for Klaas Bom...
# Fetching works for John Bongaarts...
# Fetching works for Daniel Bonn...
# Fetching works for Marc Bonten...
# Fetching works for Dorret Boomsma...
# Fetching works for Arnoud Boot...
# Fetching works for René de Borst...
# Fetching works for Piet Borst CBE...
# Fetching works for Kees  van den  Bos...
# Fetching works for Hans Bos...
# Fetching works for Antal van den Bosch...
# Fetching works for Joop Bouma...
# Fetching works for Johan Bouma...
# Fetching works for Herman Bouma...
# Fetching works for Teun  Bousema...
# Fetching works for Carlijn Bouten...
# Fetching works for Harro Bouwmeester...
# Fetching works for Joke Bouwstra...
# Fetching works for Lans Bovenberg...
# Fetching works for Mark Bovens...
# Fetching works for Henk Braakhuis...
# Fetching works for Joseph Braat...
# Fetching works for Paul Brakefield...
# Fetching works for Annelien Bredenoord...
# Fetching works for Ferry Breedveld...
# Fetching works for Nico van Breemen...
# Fetching works for Douwe Breimer...
# Fetching works for Jan Breman...
# Fetching works for Monique Breteler...
# Fetching works for Marcel van den Brink...
# Fetching works for Laurens Jan Brinkhorst...
# Fetching works for Henk Brinkhuis...
# Fetching works for Roel van den Broek...
# Fetching works for Michiel van den Broeke...
# Fetching works for Henk Broer...
# Fetching works for Dick Broer...
# Fetching works for Johannes Bronkhorst...
# Fetching works for Bart Bronnenberg...
# Fetching works for Peter Brown...
# Fetching works for Thijn Brummelkamp...
# Fetching works for Bert Brunekreef...
# Fetching works for Han Brunner...
# Fetching works for Lucas Brunsveld...
# Fetching works for Kenneth Buesseler...
# Fetching works for Harry Buhrman...
# Fetching works for Willem Buiter...
# Fetching works for Harry Büller...
# Fetching works for Erwin Bulte...
# Fetching works for Wiep van Bunge...
# Fetching works for Joost Businger...
# Fetching works for Harvey Butcher...
# Fetching works for Bram Buunk...
# Fetching works for Peter Carmeliet...
# Fetching works for Ger Challa...
# Fetching works for Lisa Cheng...
# Fetching works for Herbert Clark...
# Fetching works for Eve Clark...
# Fetching works for Hans Clevers...
# Fetching works for Sierd Cloetingh...
# Fetching works for Reinder Coehoorn...
# Fetching works for Martien Cohen Stuart...
# Fetching works for Margaret Collinson...
# Fetching works for Bernard Comrie...
# Fetching works for Roshan Cools...
# Fetching works for Marius Crainic...
# Fetching works for Ronald Cramer...
# Fetching works for Maghiel  van Crevel...
# Fetching works for Roberta Croce...
# Fetching works for Eveline Crone...
# Fetching works for Pedro Crous...
# Fetching works for Deirdre Curtin...
# Fetching works for Hans Daiber...
# Fetching works for Jan Dalhuisen...
# Fetching works for Eric van Damme...
# Fetching works for Jenny Dankelman...
# Fetching works for Ingrid Daubechies...
# Fetching works for George Davey Smith...
# Fetching works for Karel Davids...
# Fetching works for Nynke Dekker...
# Fetching works for Cees Dekker...
# Fetching works for Jan van Deth...
# Fetching works for Arwen Deuss...
# Fetching works for Wilfried Dewachter...
# Fetching works for Patrick Dewilde...
# Fetching works for Marcel Dicke...
# Fetching works for Karel Dicke...
# Fetching works for Dennis Dieks...
# Fetching works for José van Dijck...
# Fetching works for Pieter van Dijk...
# Fetching works for Peter ten Dijke...
# Fetching works for Robbert Dijkgraaf...
# Fetching works for Marjolein Dijkstra...
# Fetching works for Henk Dijkstra...
# Fetching works for Bauke Dijkstra...
# Fetching works for Marcel den Dikken...
# Fetching works for Charles Dinarello...
# Fetching works for Ewine van Dishoeck...
# Fetching works for Vishva M. Dixit...
# Fetching works for Marileen Dogterom...
# Fetching works for Eddy van Doorslaer...
# Fetching works for Eite Drent...
# Fetching works for Pieter Drenth...
# Fetching works for Jan Drenth...
# Fetching works for Carsten de Dreu...
# Fetching works for Lou van den Dries...
# Fetching works for Arnold Driessen...
# Fetching works for Denis Duboule...
# Fetching works for Cornelia van Duijn...
# Fetching works for Catarina Dutilh Novaes...
# Fetching works for Jan Willem Duyvendak...
# Fetching works for Pearl Dykstra...
# Fetching works for Lex van der Eb...
# Fetching works for Mick Eekhout...
# Fetching works for Jos Eggermont...
# Fetching works for Philip van der Eijk...
# Fetching works for Cees van der Eijk...
# Fetching works for Ron Ekers...
# Fetching works for Naomi Ellemers...
# Fetching works for Bernet Elzinga...
# Fetching works for Paul Emmelkamp...
# Fetching works for Karl Enenkel...
# Fetching works for Pierre van der Eng...
# Fetching works for Godfried Engbersen...
# Fetching works for Mirjam Ernestus...
# Fetching works for Judith van Erp...
# Fetching works for Wim van Es...
# Fetching works for Thijs Ettema...
# Fetching works for Andrea Evers...
# Fetching works for Carel Faber...
# Fetching works for Heino Falcke...
# Fetching works for Reindert Falkenburg...
# Fetching works for Martin Fase...
# Fetching works for Michael Faure...
# Fetching works for Bert Felling...
# Fetching works for Ben Feringa...
# Fetching works for Guillén Fernández...
# Fetching works for Carl Figdor...
# Fetching works for Manfred Fischer...
# Fetching works for René Foqué...
# Fetching works for Ron Fouchier...
# Fetching works for James Fox...
# Fetching works for Bas van Fraassen...
# Fetching works for Barbara Franke...
# Fetching works for Hans Franken...
# Fetching works for Philip Hans Franses...
# Fetching works for Marijn Franx...
# Fetching works for Daan Frenkel...
# Fetching works for Joost Frenken...
# Fetching works for Louise Fresco...
# Fetching works for Florentino Garcìa Martìnez...
# Fetching works for Sara van de Geer...
# Fetching works for Marc Geers...
# Fetching works for Geert Jan van Gelder...
# Fetching works for Guillaume van Gemert...
# Fetching works for Janneke Gerards...
# Fetching works for Klarita Gërxhani...
# Fetching works for Peter Geschiere...
# Fetching works for Hans Geuze...
# Fetching works for Halleh Ghorashi...
# Fetching works for Stan Gielen...
# Fetching works for Jenny Gierveld...
# Fetching works for Ivo Giesen...
# Fetching works for Erik van der Giessen...
# Fetching works for Jan van Gijn...
# Fetching works for Richard Gill...
# Fetching works for Willem Hendrik Gispen...
# Fetching works for Rainer Goebel...
# Fetching works for Marieke de Goede...
# Fetching works for Jacob Goeree...
# Fetching works for Jacqueline van Gorkom...
# Fetching works for Beatrice de Graaf...
# Fetching works for Maria Grever...
# Fetching works for Rick Grobbee...
# Fetching works for Kees Groeneboer...
# Fetching works for Marc Groenhuijsen...
# Fetching works for Rienk van Grondelle...
# Fetching works for Piet Gros...
# Fetching works for Frank Grosveld...
# Fetching works for Maarten van de Guchte...
# Fetching works for Jan Willem Gunning...
# Fetching works for Wilfred van Gunsteren...
# Fetching works for Herman van Gunsteren...
# Fetching works for Holger Gzella...
# Fetching works for Harm Habing...
# Fetching works for Peter Hagoort...
# Fetching works for Dick van Halsema...
# Fetching works for Wouter Hanegraaff...
# Fetching works for Ronald Hanson...
# Fetching works for Annette Harder...
# Fetching works for Anita Hardon...
# Fetching works for Frank van Harmelen...
# Fetching works for Paul 't Hart...
# Fetching works for Joest 't Hart...
# Fetching works for Arthur Hartkamp...
# Fetching works for Joop Hartog...
# Fetching works for Deanne den Hartog...
# Fetching works for Trevor Hastie...
# Fetching works for Henk ten Have...
# Fetching works for Albert Heck...
# Fetching works for Ron Heeren...
# Fetching works for Martin van Hees...
# Fetching works for Paul van der Heijden...
# Fetching works for Sef Heijnen...
# Fetching works for Gert Jan van Heijst...
# Fetching works for Olivier Hekster...
# Fetching works for Natali Helberger...
# Fetching works for Lotte Hellinga-Querido...
# Fetching works for Frans van der Helm...
# Fetching works for Amina Helmi...
# Fetching works for Coen Hemker...
# Fetching works for Gotthilf Hempel...
# Fetching works for Petra Hendriks...
# Fetching works for Kees Hengeveld...
# Fetching works for Paulien Herder...
# Fetching works for Lambert Hesselink...
# Fetching works for Jan van Hest...
# Fetching works for Ed van den Heuvel...
# Fetching works for Vincent van Heuven...
# Fetching works for Frits Hilgen...
# Fetching works for Thea Hilhorst...
# Fetching works for Henk Hilhorst...
# Fetching works for Henk Hillenaar...
# Fetching works for Tadaki Hirose...
# Fetching works for Ernst Hirsch Ballin...
# Fetching works for Jan Hoeijmakers...
# Fetching works for Wiel Hoekstra...
# Fetching works for Bert Hofman...
# Fetching works for Remco van der Hofstad...
# Fetching works for Jan Hogendijk...
# Fetching works for Pancras Hogendoorn...
# Fetching works for Elly Hol...
# Fetching works for Wim Hol...
# Fetching works for Carla Hollak...
# Fetching works for Frank den Hollander...
# Fetching works for Cornelis Hollenberg...
# Fetching works for Ewoud Hondius...
# Fetching works for Henkjan Honing...
# Fetching works for Jan van Hooff...
# Fetching works for Gerard 't Hooft...
# Fetching works for Serge Hoogendoorn...
# Fetching works for Henry Hooghiemstra...
# Fetching works for Adrianus de Hoop...
# Fetching works for Paul Hooykaas...
# Fetching works for Mary Horowitz...
# Fetching works for Piet van der Horst...
# Fetching works for Jeff de Hosson...
# Fetching works for Theo van den Hout...
# Fetching works for Jeanine Houwing-Duistermaat...
# Fetching works for Lawrence Hubert...
# Fetching works for Wilhelm Huck...
# Fetching works for Nico Hugenholtz...
# Fetching works for Suzanne Hulscher...
# Fetching works for Piet Hut...
# Fetching works for Francesco Iachello...
# Fetching works for Wilt Idema...
# Fetching works for Marinus van IJzendoorn dr. h.c....
# Fetching works for Guido Imbens...
# Fetching works for Jonathan Israel...
# Fetching works for Bart Jacobs...
# Fetching works for Vincent Jaddoe...
# Fetching works for Anita Jansen...
# Fetching works for Willy Jansen...
# Fetching works for John Jansen...
# Fetching works for Johan Jansonius...
# Fetching works for Susanne Janssen...
# Fetching works for René Janssen...
# Fetching works for Erik Jayme...
# Fetching works for Lotte Jensen...
# Fetching works for Mike Jetten...
# Fetching works for Jolanda Jetten...
# Fetching works for Marian Joëls...
# Fetching works for Aise de Jong...
# Fetching works for Ab de Jong...
# Fetching works for Irene de Jong...
# Fetching works for Petra de Jongh...
# Fetching works for Eddy de Jongh...
# Fetching works for Joshua Jortner...
# Fetching works for Dick van de Kaa...
# Fetching works for René Kahn...
# Fetching works for Matthijs Kalmijn...
# Fetching works for Ab van Kammen...
# Fetching works for Hans Kamp...
# Fetching works for Roland Kanaar...
# Fetching works for Hans Kaper...
# Fetching works for Ernestine Kaper...
# Fetching works for Rob Kaptein...
# Fetching works for Arie Kapteyn...
# Fetching works for Martin Karplus...
# Fetching works for Martijn Katan...
# Fetching works for Misha Katsnelson...
# Fetching works for Mike Keane...
# Fetching works for Peter van Kessel...
# Fetching works for Sol Kimel...
# Fetching works for Hanan Kisch...
# Fetching works for Jan Kiviet...
# Fetching works for Marian Klamer...
# Fetching works for Caroline Klaver...
# Fetching works for Pauline Kleingeld...
# Fetching works for André Klip...
# Fetching works for Michiel van der Klis...
# Fetching works for Jeroen de Kloet...
# Fetching works for Jan Willem Klop...
# Fetching works for Theo van de Klundert...
# Fetching works for Marjo van der Knaap...
# Fetching works for Bert van der Knaap...
# Fetching works for André Knottnerus...
# Fetching works for Jan Koeman...
# Fetching works for Gijsje Koenderink...
# Fetching works for Jan Koenderink...
# Fetching works for Johannes Konst...
# Fetching works for Bas Kooijman...
# Fetching works for Jelle Koopmans...
# Fetching works for Marion Koopmans...
# Fetching works for Maarten Koornneef...
# Fetching works for Yvette van Kooyk...
# Fetching works for Marc Koper...
# Fetching works for Jaap Korevaar...
# Fetching works for Frits Kortlandt...
# Fetching works for Gerard van Koten...
# Fetching works for Leo Kouwenhoven...
# Fetching works for Xandra Kramer...
# Fetching works for Jan Kramers...
# Fetching works for Ben de Kruijff...
# Fetching works for Remke Kruk...
# Fetching works for Arno Kuijlaars...
# Fetching works for Leonard van der Kuijp...
# Fetching works for Simon Kuipers...
# Fetching works for Oscar Kuipers...
# Fetching works for Hans Kuipers...
# Fetching works for Giselinde Kuipers...
# Fetching works for Srinivas Kulkarni...
# Fetching works for Max Kuperus...
# Fetching works for Harry van der Laan...
# Fetching works for Horst Lademacher...
# Fetching works for Ad Lagendijk...
# Fetching works for Inald Lagendijk...
# Fetching works for Kurt Lambeck...
# Fetching works for Hans Lambers...
# Fetching works for Steven Lamberts...
# Fetching works for Henny Lamers...
# Fetching works for Klaas Landsman...
# Fetching works for Titia de Lange...
# Fetching works for Christian Lange...
# Fetching works for Monique Laurent...
# Fetching works for Richard Lauwaars...
# Fetching works for Peter Leeflang...
# Fetching works for Inger Leemans...
# Fetching works for Joep Leerssen...
# Fetching works for Jan  de Leeuw...
# Fetching works for Sander van der Leeuw...
# Fetching works for Jan de Leeuw...
# Fetching works for Jean-Marie Lehn...
# Fetching works for Henk Lekkerkerker...
# Fetching works for Hendrik Lenstra...
# Fetching works for Joop van Lenteren...
# Fetching works for Ron Lesthaeghe...
# Fetching works for Rob Leurs...
# Fetching works for Pim Levelt...
# Fetching works for Marcel Levi...
# Fetching works for Robert de Levie...
# Fetching works for Walter Lewin...
# Fetching works for Aart Liefbroer...
# Fetching works for Luuk de Ligt...
# Fetching works for Arend Lijphart...
# Fetching works for Frank Linde...
# Fetching works for Siegwart Lindenberg...
# Fetching works for Harry Lintsen...
# Fetching works for Tanja van der Lippe...
# Fetching works for Frank Lobbezoo...
# Fetching works for Detlef Lohse...
# Fetching works for Maria Antonietta Loi...
# Fetching works for Renate Loll...
# Fetching works for Eduard Looijenga...
# Fetching works for Mark van Loosdrecht...
# Fetching works for Leendert Louwe Kooijmans...
# Fetching works for László Lovász...
# Fetching works for Bob Löwenberg...
# Fetching works for Sasha Lubotsky...
# Fetching works for Leo Lucassen...
# Fetching works for Jan Lucassen...
# Fetching works for Christoph Lüthy...
# Fetching works for Amade M’charek...
# Fetching works for Eddy van der Maarel...
# Fetching works for Ejan Mackaay...
# Fetching works for Johan Mackenbach...
# Fetching works for Roderick MacKinnon...
# Fetching works for Vanessa Mak...
# Fetching works for Kofi Makinwa...
# Fetching works for Jaap Mansfeld...
# Fetching works for Titti Mariani...
# Fetching works for Sera  Markoff...
# Fetching works for Siewert-Jan Marrink...
# Fetching works for Eric Mazur...
# Fetching works for Valentina Mazzucato...
# Fetching works for René Medema...
# Fetching works for Jos van der Meer...
# Fetching works for Gerrit van Meer...
# Fetching works for Gerard Meijer...
# Fetching works for Bert Meijer...
# Skipping Bert Meijer, already completed.
# Fetching works for Eginhard Meijering...
# Fetching works for Andries Meijerink...
# Fetching works for Debora Meijers...
# Fetching works for Kees Melief...
# Fetching works for Walter Melion...
# Fetching works for Julien Mendlewicz...
# Fetching works for Steph Menken...
# Fetching works for Albert Menkveld...
# Fetching works for Stephen Mennell...
# Fetching works for Harald Merckelbach...
# Fetching works for Judi Mesman...
# Fetching works for Alice ter Meulen...
# Fetching works for Jacqueline Meulman...
# Fetching works for Antje Meyer...
# Fetching works for Birgit Meyer...
# Fetching works for Hartmut Michel...
# Fetching works for John Michon...
# Fetching works for Jack Middelburg...
# Fetching works for Wijnand Mijnhardt...
# Fetching works for George Miley...
# Fetching works for Ieke Moerdijk...
# Fetching works for Keith Moffatt...
# Fetching works for Joël Mokyr...
# Fetching works for Annemarie Mol...
# Fetching works for Laurens Molenkamp...
# Fetching works for Hans Mooij...
# Fetching works for Mary Morgan...
# Fetching works for Maarten Mous...
# Fetching works for Nicolette Mout...
# Fetching works for Cas Mudde...
# Fetching works for Clara Mulder...
# Fetching works for Gerhard Müller...
# Fetching works for Christine Mummery...
# Fetching works for Heleen Murre-van den Berg...
# Fetching works for John Mydosh...
# Fetching works for Lodi Nauta...
# Fetching works for Bram Nauta...
# Fetching works for Jacques Neefjes...
# Fetching works for Jan van Neerven...
# Fetching works for John Nerbonne...
# Fetching works for Nancy Nersessian...
# Fetching works for Mihai Netea...
# Fetching works for Bernard Nienhuis...
# Fetching works for Wiro Niessen...
# Fetching works for Peter van Nieuwenhuizen...
# Fetching works for Emmie te Nijenhuis...
# Fetching works for Peter Nijkamp...
# Fetching works for Guust Nolet...
# Fetching works for André Nollkaemper...
# Fetching works for Julia Noordegraaf...
# Fetching works for Ed Noort...
# Fetching works for Bart Nooteboom...
# Fetching works for Roel Nusse...
# Fetching works for Theo Odijk...
# Fetching works for Hans Oerlemans...
# Fetching works for John van der Oost...
# Fetching works for Frits van Oostrom...
# Fetching works for Eric Opdam...
# Fetching works for Hans Opschoor...
# Fetching works for Gordon Orians...
# Fetching works for Michel Orrit...
# Fetching works for Jim van Os...
# Fetching works for Henk van Os...
# Fetching works for Ab Osterhaus...
# Fetching works for Jeremiah Ostriker...
# Fetching works for Koen Ottenheym...
# Fetching works for Sijbren Otto...
# Fetching works for Alexander van Oudenaarden...
# Fetching works for Hermen Overkleeft...
# Fetching works for René Pahud de Mortanges...
# Fetching works for Franz Palm...
# Fetching works for Thom Palstra...
# Fetching works for Geoffrey Parker...
# Fetching works for Barbara Partee...
# Fetching works for Kiran Patel...
# Fetching works for Herman Paul...
# Fetching works for Peter Pearson...
# Fetching works for Johannes Pennings...
# Fetching works for Brenda Penninx...
# Fetching works for Theunis Piersma...
# Fetching works for Jean Pieters...
# Fetching works for Corné Pieterse...
# Fetching works for David Pinder...
# Fetching works for Bob Pinedo...
# Fetching works for Patricia Pisters...
# Fetching works for Ronald Plasterk...
# Fetching works for Henri Pleket...
# Fetching works for Hans van der Plicht...
# Fetching works for Rick van der Ploeg...
# Fetching works for Hidde Ploegh...
# Fetching works for Ibo van de Poel...
# Fetching works for Tom van der Poll...
# Fetching works for Judith Pollmann...
# Fetching works for Albert Polman...
# Fetching works for Bert Poolman...
# Fetching works for Jacques Poot...
# Fetching works for Mladen Popović...
# Fetching works for Danielle Posthuma...
# Fetching works for Dirkje Postma...
# Fetching works for Mirjam van Praag...
# Fetching works for Herman van Praag...
# Fetching works for Bernard van Praag...
# Fetching works for Maarten Prak...
# Fetching works for Om Prakash...
# Fetching works for Lucas Prakke...
# Fetching works for Sacha Prechal...
# Fetching works for Walter Prevenier...
# Fetching works for Sally Price...
# Fetching works for Roel Prins...
# Fetching works for Corien Prins...
# Fetching works for Jack Pronk...
# Fetching works for Andrea Prosperetti...
# Fetching works for Wim van der Putten...
# Fetching works for Aad Quak...
# Fetching works for Jos Raaijmakers...
# Fetching works for Rudy Rabbinge...
# Fetching works for Theo Rasing...
# Fetching works for Jan Reedijk...
# Fetching works for Joost Reek...
# Fetching works for Martin Rees...
# Fetching works for Manfred Reetz...
# Fetching works for David Regan...
# Fetching works for Hans Reiber...
# Fetching works for David Reinhoudt...
# Fetching works for Willem Remmelink...
# Fetching works for Rob Reneman...
# Fetching works for Geert Ridder...
# Fetching works for Richard Ridderinkhof...
# Fetching works for René de la Rie...
# Fetching works for Ivonne Rietjens...
# Fetching works for Ann Rigney...
# Fetching works for Maarten de Rijke...
# Fetching works for Avraham Rinat-Reiner...
# Fetching works for Ingrid Robeyns...
# Fetching works for George Robillard...
# Fetching works for Wil Roebroeks...
# Fetching works for Karin Roelofs...
# Fetching works for Eelco Rohling...
# Fetching works for Jana Roithová...
# Fetching works for Lucas van Rompay...
# Fetching works for Nico de Rooij...
# Fetching works for Hilger Ropers...
# Fetching works for Frits Rosendaal...
# Fetching works for Judith  Rosmalen...
# Fetching works for Maroeska Rovers...
# Fetching works for Joost Ruitenberg...
# Fetching works for Reiner Rummel...
# Fetching works for Douwe Runia...
# Fetching works for Floris Rutjes...
# Fetching works for Wim van Saarloos...
# Fetching works for Richard van de Sanden...
# Fetching works for Andries Sanders...
# Filtered works data saved to JSON: knaw_works_filtered.json
# Filtered works data saved to CSV: knaw_works_filtered.csv

# %%
import json

# Input and output file paths
input_file = "/content/knaw_members_with_indices.json"  # Replace with your distorted JSON file path
output_file = "knaw_members_with_indices_restored.json"  # Restored output file

# Load the distorted JSON file
with open(input_file, "r", encoding="utf-8") as infile:
    data = json.load(infile)

# Decode Unicode escape sequences
def decode_unicode(data):
    if isinstance(data, dict):
        return {key: decode_unicode(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [decode_unicode(item) for item in data]
    elif isinstance(data, str):
        try:
            # Attempt to decode the string
            return data.encode('latin1').decode('utf-8')
        except (UnicodeEncodeError, UnicodeDecodeError):
            # Return the original string if decoding fails
            return data
    else:
        return data

restored_data = decode_unicode(data)

# Save the restored JSON file
with open(output_file, "w", encoding="utf-8") as outfile:
    json.dump(restored_data, outfile, ensure_ascii=False, indent=4)

print(f"Restored file saved to {output_file}")
# Out:
# Restored file saved to knaw_members_with_indices_restored.json

# %%
import requests
import json
import time
import pandas as pd

# Input and output file paths
input_file = "/content/knaw_members_with_indices_restored.json"  # Replace with your actual file path
output_json_file = "knaw_works_filtered.json"  # JSON file output
output_csv_file = "knaw_works_filtered.csv"  # CSV file output
progress_log_file = "progress_log.json"  # Log file to track progress

# OpenAlex base API URL
openalex_base_url = "https://api.openalex.org"

# Function to fetch works for an author
def fetch_author_works(author_id):
    works = []
    page = 1
    while True:
        url = f"{openalex_base_url}/works?filter=author.id:{author_id}&per-page=200&page={page}"
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            for work in data.get("results", []):  # Handle missing 'results'
                filtered_work = {
                    "id": work.get("id", ""),
                    "title": work.get("title", ""),
                    "doi": work.get("doi", ""),
                    "publication_year": work.get("publication_year", ""),
                    "cited_by_count": work.get("cited_by_count", 0),
                    "authorships": [
                        {
                            "author": {
                                "id": auth.get("author", {}).get("id", ""),
                                "display_name": auth.get("author", {}).get("display_name", "")
                            },
                            "institutions": [
                                {
                                    "id": inst.get("id", ""),
                                    "display_name": inst.get("display_name", ""),
                                    "country_code": inst.get("country_code", ""),
                                    "type": inst.get("type", "")  # Safely handle missing type
                                }
                                for inst in auth.get("institutions", []) if inst
                            ]
                        }
                        for auth in work.get("authorships", []) if auth
                    ],
                    "primary_topic": {
                        "id": work.get("primary_topic", {}).get("id", ""),
                        "display_name": work.get("primary_topic", {}).get("display_name", ""),
                        "score": work.get("primary_topic", {}).get("score", 0),
                        "field": {
                            "id": work.get("primary_topic", {}).get("field", {}).get("id", ""),
                            "display_name": work.get("primary_topic", {}).get("field", {}).get("display_name", "")
                        } if work.get("primary_topic", {}).get("field") else {},
                        "subfield": {
                            "id": work.get("primary_topic", {}).get("subfield", {}).get("id", ""),
                            "display_name": work.get("primary_topic", {}).get("subfield", {}).get("display_name", "")
                        } if work.get("primary_topic", {}).get("subfield") else {},
                        "domain": {
                            "id": work.get("primary_topic", {}).get("domain", {}).get("id", ""),
                            "display_name": work.get("primary_topic", {}).get("domain", {}).get("display_name", "")
                        } if work.get("primary_topic", {}).get("domain") else {}
                    } if work.get("primary_topic") else {},  # Handle missing primary_topic
                    "concepts": [
                        {
                            "id": concept.get("id", ""),
                            "display_name": concept.get("display_name", ""),
                            "level": concept.get("level", 0),
                            "score": concept.get("score", 0)
                        }
                        for concept in work.get("concepts", []) if concept
                    ],
                    "open_access": work.get("open_access", {}),
                    "sustainable_development_goals": [
                        {
                            "id": sdg.get("id", ""),
                            "score": sdg.get("score", 0),
                            "display_name": sdg.get("display_name", "")
                        }
                        for sdg in work.get("sustainable_development_goals", []) if sdg
                    ],
                    "referenced_works": work.get("referenced_works", [])
                }
                works.append(filtered_work)
            if "next" not in data.get("meta", {}):  # Handle missing 'meta'
                break
            page += 1
            time.sleep(1)  # Respect API rate limits
        else:
            print(f"Error fetching works for author {author_id}: {response.status_code}")
            break
    return works

# Load the existing JSON file
with open(input_file, "r") as infile:
    members = json.load(infile)

# Load or initialize the progress log
try:
    with open(progress_log_file, "r") as log_file:
        progress_log = json.load(log_file)
except FileNotFoundError:
    progress_log = {}

# Fetch works for each author and organize them under authors
authors_with_works = []
for member in members:
    name = member["name"]
    openalex_ids = member.get("openalex_id")
    all_works = []

    if name in progress_log and progress_log[name]:
        print(f"Skipping {name}, already completed.")
        continue

    print(f"Fetching works for {name}...")

    try:
        if isinstance(openalex_ids, list):
            for openalex_id in openalex_ids:
                author_id = openalex_id.split("/")[-1]  # Extract author ID
                all_works.extend(fetch_author_works(author_id))
        elif isinstance(openalex_ids, str):
            author_id = openalex_ids.split("/")[-1]
            all_works.extend(fetch_author_works(author_id))

        authors_with_works.append({
            "name": name,
            "openalex_id": openalex_ids,
            "works": all_works
        })

        # Mark the author as successfully processed
        progress_log[name] = True

    except Exception as e:
        print(f"Error processing {name}: {e}")
        progress_log[name] = False  # Mark as failed

    # Save progress after each author
    with open(progress_log_file, "w") as log_file:
        json.dump(progress_log, log_file, indent=4)

# Save the filtered data to a JSON file
with open(output_json_file, "w") as outfile:
    json.dump(authors_with_works, outfile, indent=4)
print(f"Filtered works data saved to JSON: {output_json_file}")

# Convert to CSV for easier inspection
csv_data = []
for author in authors_with_works:
    for work in author["works"]:
        csv_data.append({
            "author_name": author["name"],
            "author_openalex_id": author["openalex_id"],
            "work_id": work["id"],
            "work_title": work["title"],
            "doi": work["doi"],
            "publication_year": work["publication_year"],
            "cited_by_count": work["cited_by_count"],
            "field": work["primary_topic"].get("field", {}).get("display_name", ""),
            "subfield": work["primary_topic"].get("subfield", {}).get("display_name", ""),
            "domain": work["primary_topic"].get("domain", {}).get("display_name", ""),
            "concepts": ", ".join([concept["display_name"] for concept in work["concepts"]]),
            "open_access_status": work.get("open_access", {}).get("oa_status", ""),
            "sustainable_development_goals": ", ".join([sdg["display_name"] for sdg in work.get("sustainable_development_goals", [])]),
            "referenced_works_count": len(work.get("referenced_works", []))
        })

pd.DataFrame(csv_data).to_csv(output_csv_file, index=False)
print(f"Filtered works data saved to CSV: {output_csv_file}")
# Out:
# Fetching works for Wil van der Aalst...
# Fetching works for Kees Aarts...
# Fetching works for Gerard Acket...
# Fetching works for Remieg Aerts...
# Fetching works for Conny Aerts...
# Fetching works for Reuven Agami...
# Fetching works for Frits Agterberg...
# Fetching works for Takuzo Aida...
# Fetching works for Anna Akhmanova...
# Fetching works for Barbara Aland...
# Fetching works for Tjeerd van Albada...
# Fetching works for André Aleman...
# Fetching works for Keimpe Algra...
# Fetching works for Maurits Allessie...
# Fetching works for Sigurd Angenent...
# Fetching works for Frank Ankersmit...
# Fetching works for Isabel Arends...
# Fetching works for Ad van der Avoird...
# Fetching works for Hein de Baar...
# Fetching works for Thomas Bäck...
# Fetching works for Jan Baerends...
# Fetching works for Marian Bakermans-Kranenburg...
# Fetching works for Jan Albert Bakker...
# Fetching works for Huib Bakker...
# Fetching works for Egbert Bakker...
# Fetching works for Erik Bakkers...
# Fetching works for Henk Barendregt...
# Fetching works for René Barents...
# Fetching works for Renate Bartsch...
# Fetching works for Jurjen Battjes...
# Fetching works for Bas van Bavel...
# Fetching works for Adriaan Bax...
# Fetching works for Bram van de Beek...
# Fetching works for Carlo Beenakker...
# Fetching works for Jos Beijnen...
# Fetching works for Harold Bekkering...
# Fetching works for Wout van Bekkum...
# Fetching works for Jan van Bemmel...
# Fetching works for Zvi Ben-Avraham...
# Fetching works for Jozien Bensing...
# Fetching works for Johan van Benthem...
# Fetching works for Albert van den Berg...
# Fetching works for Leonard van den Berg...
# Fetching works for Gerard van den Berg...
# Fetching works for André Berger...
# Fetching works for Jan Bergstra...
# Fetching works for Piet Bergveld Em....
# Fetching works for Maaike  van Berkel...
# Fetching works for Klaas van Berkel...
# Fetching works for Guus Berkhout...
# Fetching works for René Bernards...
# Fetching works for Ton Berns...
# Fetching works for Michael Berry...
# Fetching works for Connie Bezzina...
# Fetching works for Peter Bickel...
# Fetching works for Marc Bierkens...
# Fetching works for Catrien Bijleveld...
# Fetching works for Karin Bijsterveld...
# Fetching works for Ton Bisseling...
# Fetching works for Alfons van Blaaderen...
# Fetching works for Johan Bleeker...
# Fetching works for Clemens van Blitterswijk...
# Fetching works for Wim Blockmans...
# Fetching works for Bas Bloem...
# Fetching works for Josine Blok...
# Fetching works for Kees Blom...
# Fetching works for Carel Blotkamp...
# Fetching works for Rens Bod...
# Fetching works for Geoffrey Bodenhausen...
# Fetching works for Monique Boekaerts...
# Fetching works for Ted de Boer...
# Fetching works for Hans Boersma...
# Fetching works for Klaas Bom...
# Fetching works for John Bongaarts...
# Fetching works for Daniel Bonn...
# Fetching works for Marc Bonten...
# Fetching works for Dorret Boomsma...
# Fetching works for Arnoud Boot...
# Fetching works for René de Borst...
# Fetching works for Piet Borst CBE...
# Fetching works for Kees  van den  Bos...
# Fetching works for Hans Bos...
# Fetching works for Antal van den Bosch...
# Fetching works for Joop Bouma...
# Fetching works for Johan Bouma...
# Fetching works for Herman Bouma...
# Fetching works for Teun  Bousema...
# Fetching works for Carlijn Bouten...
# Fetching works for Harro Bouwmeester...
# Fetching works for Joke Bouwstra...
# Fetching works for Lans Bovenberg...
# Fetching works for Mark Bovens...
# Fetching works for Henk Braakhuis...
# Fetching works for Joseph Braat...
# Fetching works for Paul Brakefield...
# Fetching works for Annelien Bredenoord...
# Fetching works for Ferry Breedveld...
# Fetching works for Nico van Breemen...
# Fetching works for Douwe Breimer...
# Fetching works for Jan Breman...
# Fetching works for Monique Breteler...
# Fetching works for Marcel van den Brink...
# Fetching works for Laurens Jan Brinkhorst...
# Fetching works for Henk Brinkhuis...
# Fetching works for Roel van den Broek...
# Fetching works for Michiel van den Broeke...
# Fetching works for Henk Broer...
# Fetching works for Dick Broer...
# Fetching works for Johannes Bronkhorst...
# Fetching works for Bart Bronnenberg...
# Fetching works for Peter Brown...
# Fetching works for Thijn Brummelkamp...
# Fetching works for Bert Brunekreef...
# Fetching works for Han Brunner...
# Fetching works for Lucas Brunsveld...
# Fetching works for Kenneth Buesseler...
# Fetching works for Harry Buhrman...
# Fetching works for Willem Buiter...
# Fetching works for Harry Büller...
# Fetching works for Erwin Bulte...
# Fetching works for Wiep van Bunge...
# Fetching works for Joost Businger...
# Fetching works for Harvey Butcher...
# Fetching works for Bram Buunk...
# Fetching works for Peter Carmeliet...
# Fetching works for Ger Challa...
# Fetching works for Lisa Cheng...
# Fetching works for Herbert Clark...
# Fetching works for Eve Clark...
# Fetching works for Hans Clevers...
# Fetching works for Sierd Cloetingh...
# Fetching works for Reinder Coehoorn...
# Fetching works for Martien Cohen Stuart...
# Fetching works for Margaret Collinson...
# Fetching works for Bernard Comrie...
# Fetching works for Roshan Cools...
# Fetching works for Marius Crainic...
# Fetching works for Ronald Cramer...
# Fetching works for Maghiel  van Crevel...
# Fetching works for Roberta Croce...
# Fetching works for Eveline Crone...
# Fetching works for Pedro Crous...
# Fetching works for Deirdre Curtin...
# Fetching works for Hans Daiber...
# Fetching works for Jan Dalhuisen...
# Fetching works for Eric van Damme...
# Fetching works for Jenny Dankelman...
# Fetching works for Ingrid Daubechies...
# Fetching works for George Davey Smith...
# Fetching works for Karel Davids...
# Fetching works for Nynke Dekker...
# Fetching works for Cees Dekker...
# Fetching works for Jan van Deth...
# Fetching works for Arwen Deuss...
# Fetching works for Wilfried Dewachter...
# Fetching works for Patrick Dewilde...
# Fetching works for Marcel Dicke...
# Fetching works for Karel Dicke...
# Fetching works for Dennis Dieks...
# Fetching works for José van Dijck...
# Fetching works for Pieter van Dijk...
# Fetching works for Peter ten Dijke...
# Fetching works for Robbert Dijkgraaf...
# Fetching works for Marjolein Dijkstra...
# Fetching works for Henk Dijkstra...
# Fetching works for Bauke Dijkstra...
# Fetching works for Marcel den Dikken...
# Fetching works for Charles Dinarello...
# Fetching works for Ewine van Dishoeck...
# Fetching works for Vishva M. Dixit...
# Fetching works for Marileen Dogterom...
# Fetching works for Eddy van Doorslaer...
# Fetching works for Eite Drent...
# Fetching works for Pieter Drenth...
# Fetching works for Jan Drenth...
# Fetching works for Carsten de Dreu...
# Fetching works for Lou van den Dries...
# Fetching works for Arnold Driessen...
# Fetching works for Denis Duboule...
# Fetching works for Cornelia van Duijn...
# Fetching works for Catarina Dutilh Novaes...
# Fetching works for Jan Willem Duyvendak...
# Fetching works for Pearl Dykstra...
# Fetching works for Lex van der Eb...
# Fetching works for Mick Eekhout...
# Fetching works for Jos Eggermont...
# Fetching works for Philip van der Eijk...
# Fetching works for Cees van der Eijk...
# Fetching works for Ron Ekers...
# Fetching works for Naomi Ellemers...
# Fetching works for Bernet Elzinga...
# Fetching works for Paul Emmelkamp...
# Fetching works for Karl Enenkel...
# Fetching works for Pierre van der Eng...
# Fetching works for Godfried Engbersen...
# Fetching works for Mirjam Ernestus...
# Fetching works for Judith van Erp...
# Fetching works for Wim van Es...
# Fetching works for Thijs Ettema...
# Fetching works for Andrea Evers...
# Fetching works for Carel Faber...
# Fetching works for Heino Falcke...
# Fetching works for Reindert Falkenburg...
# Fetching works for Martin Fase...
# Fetching works for Michael Faure...
# Fetching works for Bert Felling...
# Fetching works for Ben Feringa...
# Fetching works for Guillén Fernández...
# Fetching works for Carl Figdor...
# Fetching works for Manfred Fischer...
# Fetching works for René Foqué...
# Fetching works for Ron Fouchier...
# Fetching works for James Fox...
# Fetching works for Bas van Fraassen...
# Fetching works for Barbara Franke...
# Fetching works for Hans Franken...
# Fetching works for Philip Hans Franses...
# Fetching works for Marijn Franx...
# Fetching works for Daan Frenkel...
# Fetching works for Joost Frenken...
# Fetching works for Louise Fresco...
# Fetching works for Florentino Garcìa Martìnez...
# Fetching works for Sara van de Geer...
# Fetching works for Marc Geers...
# Fetching works for Geert Jan van Gelder...
# Fetching works for Guillaume van Gemert...
# Fetching works for Janneke Gerards...
# Fetching works for Klarita Gërxhani...
# Fetching works for Peter Geschiere...
# Fetching works for Hans Geuze...
# Fetching works for Halleh Ghorashi...
# Fetching works for Stan Gielen...
# Fetching works for Jenny Gierveld...
# Fetching works for Ivo Giesen...
# Fetching works for Erik van der Giessen...
# Fetching works for Jan van Gijn...
# Fetching works for Richard Gill...
# Fetching works for Willem Hendrik Gispen...
# Fetching works for Rainer Goebel...
# Fetching works for Marieke de Goede...
# Fetching works for Jacob Goeree...
# Fetching works for Jacqueline van Gorkom...
# Fetching works for Beatrice de Graaf...
# Fetching works for Maria Grever...
# Fetching works for Rick Grobbee...
# Fetching works for Kees Groeneboer...
# Fetching works for Marc Groenhuijsen...
# Fetching works for Rienk van Grondelle...
# Fetching works for Piet Gros...
# Fetching works for Frank Grosveld...
# Fetching works for Maarten van de Guchte...
# Fetching works for Jan Willem Gunning...
# Fetching works for Wilfred van Gunsteren...
# Fetching works for Herman van Gunsteren...
# Fetching works for Holger Gzella...
# Fetching works for Harm Habing...
# Fetching works for Peter Hagoort...
# Fetching works for Dick van Halsema...
# Fetching works for Wouter Hanegraaff...
# Fetching works for Ronald Hanson...
# Fetching works for Annette Harder...
# Fetching works for Anita Hardon...
# Fetching works for Frank van Harmelen...
# Fetching works for Paul 't Hart...
# Fetching works for Joest 't Hart...
# Fetching works for Arthur Hartkamp...
# Fetching works for Joop Hartog...
# Fetching works for Deanne den Hartog...
# Fetching works for Trevor Hastie...
# Fetching works for Henk ten Have...
# Fetching works for Albert Heck...
# Fetching works for Ron Heeren...
# Fetching works for Martin van Hees...
# Fetching works for Paul van der Heijden...
# Fetching works for Sef Heijnen...
# Fetching works for Gert Jan van Heijst...
# Fetching works for Olivier Hekster...
# Fetching works for Natali Helberger...
# Fetching works for Lotte Hellinga-Querido...
# Fetching works for Frans van der Helm...
# Fetching works for Amina Helmi...
# Fetching works for Coen Hemker...
# Fetching works for Gotthilf Hempel...
# Fetching works for Petra Hendriks...
# Fetching works for Kees Hengeveld...
# Fetching works for Paulien Herder...
# Fetching works for Lambert Hesselink...
# Fetching works for Jan van Hest...
# Fetching works for Ed van den Heuvel...
# Fetching works for Vincent van Heuven...
# Fetching works for Frits Hilgen...
# Fetching works for Thea Hilhorst...
# Fetching works for Henk Hilhorst...
# Fetching works for Henk Hillenaar...
# Fetching works for Tadaki Hirose...
# Fetching works for Ernst Hirsch Ballin...
# Fetching works for Jan Hoeijmakers...
# Fetching works for Wiel Hoekstra...
# Fetching works for Bert Hofman...
# Fetching works for Remco van der Hofstad...
# Fetching works for Jan Hogendijk...
# Fetching works for Pancras Hogendoorn...
# Fetching works for Elly Hol...
# Fetching works for Wim Hol...
# Fetching works for Carla Hollak...
# Fetching works for Frank den Hollander...
# Fetching works for Cornelis Hollenberg...
# Fetching works for Ewoud Hondius...
# Fetching works for Henkjan Honing...
# Fetching works for Jan van Hooff...
# Fetching works for Gerard 't Hooft...
# Fetching works for Serge Hoogendoorn...
# Fetching works for Henry Hooghiemstra...
# Fetching works for Adrianus de Hoop...
# Fetching works for Paul Hooykaas...
# Fetching works for Mary Horowitz...
# Fetching works for Piet van der Horst...
# Fetching works for Jeff de Hosson...
# Fetching works for Theo van den Hout...
# Fetching works for Jeanine Houwing-Duistermaat...
# Fetching works for Lawrence Hubert...
# Fetching works for Wilhelm Huck...
# Fetching works for Nico Hugenholtz...
# Fetching works for Suzanne Hulscher...
# Fetching works for Piet Hut...
# Fetching works for Francesco Iachello...
# Fetching works for Wilt Idema...
# Fetching works for Marinus van IJzendoorn dr. h.c....
# Fetching works for Guido Imbens...
# Fetching works for Jonathan Israel...
# Fetching works for Bart Jacobs...
# Fetching works for Vincent Jaddoe...
# Fetching works for Anita Jansen...
# Fetching works for Willy Jansen...
# Fetching works for John Jansen...
# Fetching works for Johan Jansonius...
# Fetching works for Susanne Janssen...
# Fetching works for René Janssen...
# Fetching works for Erik Jayme...
# Fetching works for Lotte Jensen...
# Fetching works for Mike Jetten...
# Fetching works for Jolanda Jetten...
# Fetching works for Marian Joëls...
# Fetching works for Aise de Jong...
# Fetching works for Ab de Jong...
# Fetching works for Irene de Jong...
# Fetching works for Petra de Jongh...
# Fetching works for Eddy de Jongh...
# Fetching works for Joshua Jortner...
# Fetching works for Dick van de Kaa...
# Fetching works for René Kahn...
# Fetching works for Matthijs Kalmijn...
# Fetching works for Ab van Kammen...
# Fetching works for Hans Kamp...
# Fetching works for Roland Kanaar...
# Fetching works for Hans Kaper...
# Fetching works for Ernestine Kaper...
# Fetching works for Rob Kaptein...
# Fetching works for Arie Kapteyn...
# Fetching works for Martin Karplus...
# Fetching works for Martijn Katan...
# Fetching works for Misha Katsnelson...
# Fetching works for Mike Keane...
# Fetching works for Peter van Kessel...
# Fetching works for Sol Kimel...
# Fetching works for Hanan Kisch...
# Fetching works for Jan Kiviet...
# Fetching works for Marian Klamer...
# Fetching works for Caroline Klaver...
# Fetching works for Pauline Kleingeld...
# Fetching works for André Klip...
# Fetching works for Michiel van der Klis...
# Fetching works for Jeroen de Kloet...
# Fetching works for Jan Willem Klop...
# Fetching works for Theo van de Klundert...
# Fetching works for Marjo van der Knaap...
# Fetching works for Bert van der Knaap...
# Fetching works for André Knottnerus...
# Fetching works for Jan Koeman...
# Fetching works for Gijsje Koenderink...
# Fetching works for Jan Koenderink...
# Fetching works for Johannes Konst...
# Fetching works for Bas Kooijman...
# Fetching works for Jelle Koopmans...
# Fetching works for Marion Koopmans...
# Fetching works for Maarten Koornneef...
# Fetching works for Yvette van Kooyk...
# Fetching works for Marc Koper...
# Fetching works for Jaap Korevaar...
# Fetching works for Frits Kortlandt...
# Fetching works for Gerard van Koten...
# Fetching works for Leo Kouwenhoven...
# Fetching works for Xandra Kramer...
# Fetching works for Jan Kramers...
# Fetching works for Ben de Kruijff...
# Fetching works for Remke Kruk...
# Fetching works for Arno Kuijlaars...
# Fetching works for Leonard van der Kuijp...
# Fetching works for Simon Kuipers...
# Fetching works for Oscar Kuipers...
# Fetching works for Hans Kuipers...
# Fetching works for Giselinde Kuipers...
# Fetching works for Srinivas Kulkarni...
# Fetching works for Max Kuperus...
# Fetching works for Harry van der Laan...
# Fetching works for Horst Lademacher...
# Fetching works for Ad Lagendijk...
# Fetching works for Inald Lagendijk...
# Fetching works for Kurt Lambeck...
# Fetching works for Hans Lambers...
# Fetching works for Steven Lamberts...
# Fetching works for Henny Lamers...
# Fetching works for Klaas Landsman...
# Fetching works for Titia de Lange...
# Fetching works for Christian Lange...
# Fetching works for Monique Laurent...
# Fetching works for Richard Lauwaars...
# Fetching works for Peter Leeflang...
# Fetching works for Inger Leemans...
# Fetching works for Joep Leerssen...
# Fetching works for Jan  de Leeuw...
# Fetching works for Sander van der Leeuw...
# Fetching works for Jan de Leeuw...
# Fetching works for Jean-Marie Lehn...
# Fetching works for Henk Lekkerkerker...
# Fetching works for Hendrik Lenstra...
# Fetching works for Joop van Lenteren...
# Fetching works for Ron Lesthaeghe...
# Fetching works for Rob Leurs...
# Fetching works for Pim Levelt...
# Fetching works for Marcel Levi...
# Fetching works for Robert de Levie...
# Fetching works for Walter Lewin...
# Fetching works for Aart Liefbroer...
# Fetching works for Luuk de Ligt...
# Fetching works for Arend Lijphart...
# Fetching works for Frank Linde...
# Fetching works for Siegwart Lindenberg...
# Fetching works for Harry Lintsen...
# Fetching works for Tanja van der Lippe...
# Fetching works for Frank Lobbezoo...
# Fetching works for Detlef Lohse...
# Fetching works for Maria Antonietta Loi...
# Fetching works for Renate Loll...
# Fetching works for Eduard Looijenga...
# Fetching works for Mark van Loosdrecht...
# Fetching works for Leendert Louwe Kooijmans...
# Fetching works for László Lovász...
# Fetching works for Bob Löwenberg...
# Fetching works for Sasha Lubotsky...
# Fetching works for Leo Lucassen...
# Fetching works for Jan Lucassen...
# Fetching works for Christoph Lüthy...
# Fetching works for Amade M’charek...
# Fetching works for Eddy van der Maarel...
# Fetching works for Ejan Mackaay...
# Fetching works for Johan Mackenbach...
# Fetching works for Roderick MacKinnon...
# Fetching works for Vanessa Mak...
# Fetching works for Kofi Makinwa...
# Fetching works for Jaap Mansfeld...
# Fetching works for Titti Mariani...
# Fetching works for Sera  Markoff...
# Fetching works for Siewert-Jan Marrink...
# Fetching works for Eric Mazur...
# Fetching works for Valentina Mazzucato...
# Fetching works for René Medema...
# Fetching works for Jos van der Meer...
# Fetching works for Gerrit van Meer...
# Fetching works for Gerard Meijer...
# Fetching works for Bert Meijer...
# Skipping Bert Meijer, already completed.
# Fetching works for Eginhard Meijering...
# Fetching works for Andries Meijerink...
# Fetching works for Debora Meijers...
# Fetching works for Kees Melief...
# Fetching works for Walter Melion...
# Fetching works for Julien Mendlewicz...
# Fetching works for Steph Menken...
# Fetching works for Albert Menkveld...
# Fetching works for Stephen Mennell...
# Fetching works for Harald Merckelbach...
# Fetching works for Judi Mesman...
# Fetching works for Alice ter Meulen...
# Fetching works for Jacqueline Meulman...
# Fetching works for Antje Meyer...
# Fetching works for Birgit Meyer...
# Fetching works for Hartmut Michel...
# Fetching works for John Michon...
# Fetching works for Jack Middelburg...
# Fetching works for Wijnand Mijnhardt...
# Fetching works for George Miley...
# Fetching works for Ieke Moerdijk...
# Fetching works for Keith Moffatt...
# Fetching works for Joël Mokyr...
# Fetching works for Annemarie Mol...
# Fetching works for Laurens Molenkamp...
# Fetching works for Hans Mooij...
# Fetching works for Mary Morgan...
# Fetching works for Maarten Mous...
# Fetching works for Nicolette Mout...
# Fetching works for Cas Mudde...
# Fetching works for Clara Mulder...
# Fetching works for Gerhard Müller...
# Fetching works for Christine Mummery...
# Fetching works for Heleen Murre-van den Berg...
# Fetching works for John Mydosh...
# Fetching works for Lodi Nauta...
# Fetching works for Bram Nauta...
# Fetching works for Jacques Neefjes...
# Fetching works for Jan van Neerven...
# Fetching works for John Nerbonne...
# Fetching works for Nancy Nersessian...
# Fetching works for Mihai Netea...
# Fetching works for Bernard Nienhuis...
# Fetching works for Wiro Niessen...
# Fetching works for Peter van Nieuwenhuizen...
# Fetching works for Emmie te Nijenhuis...
# Fetching works for Peter Nijkamp...
# Fetching works for Guust Nolet...
# Fetching works for André Nollkaemper...
# Fetching works for Julia Noordegraaf...
# Fetching works for Ed Noort...
# Fetching works for Bart Nooteboom...
# Fetching works for Roel Nusse...
# Fetching works for Theo Odijk...
# Fetching works for Hans Oerlemans...
# Fetching works for John van der Oost...
# Fetching works for Frits van Oostrom...
# Fetching works for Eric Opdam...
# Fetching works for Hans Opschoor...
# Fetching works for Gordon Orians...
# Fetching works for Michel Orrit...
# Fetching works for Jim van Os...
# Fetching works for Henk van Os...
# Fetching works for Ab Osterhaus...
# Fetching works for Jeremiah Ostriker...
# Fetching works for Koen Ottenheym...
# Fetching works for Sijbren Otto...
# Fetching works for Alexander van Oudenaarden...
# Fetching works for Hermen Overkleeft...
# Fetching works for René Pahud de Mortanges...
# Fetching works for Franz Palm...
# Fetching works for Thom Palstra...
# Fetching works for Geoffrey Parker...
# Fetching works for Barbara Partee...
# Fetching works for Kiran Patel...
# Fetching works for Herman Paul...
# Fetching works for Peter Pearson...
# Fetching works for Johannes Pennings...
# Fetching works for Brenda Penninx...
# Fetching works for Theunis Piersma...
# Fetching works for Jean Pieters...
# Fetching works for Corné Pieterse...
# Fetching works for David Pinder...
# Fetching works for Bob Pinedo...
# Fetching works for Patricia Pisters...
# Fetching works for Ronald Plasterk...
# Fetching works for Henri Pleket...
# Fetching works for Hans van der Plicht...
# Fetching works for Rick van der Ploeg...
# Fetching works for Hidde Ploegh...
# Fetching works for Ibo van de Poel...
# Fetching works for Tom van der Poll...
# Fetching works for Judith Pollmann...
# Fetching works for Albert Polman...
# Fetching works for Bert Poolman...
# Fetching works for Jacques Poot...
# Fetching works for Mladen Popović...
# Fetching works for Danielle Posthuma...
# Fetching works for Dirkje Postma...
# Fetching works for Mirjam van Praag...
# Fetching works for Herman van Praag...
# Fetching works for Bernard van Praag...
# Fetching works for Maarten Prak...
# Fetching works for Om Prakash...
# Fetching works for Lucas Prakke...
# Fetching works for Sacha Prechal...
# Fetching works for Walter Prevenier...
# Fetching works for Sally Price...
# Fetching works for Roel Prins...
# Fetching works for Corien Prins...
# Fetching works for Jack Pronk...
# Fetching works for Andrea Prosperetti...
# Fetching works for Wim van der Putten...
# Fetching works for Aad Quak...
# Fetching works for Jos Raaijmakers...
# Fetching works for Rudy Rabbinge...
# Fetching works for Theo Rasing...
# Fetching works for Jan Reedijk...
# Fetching works for Joost Reek...
# Fetching works for Martin Rees...
# Fetching works for Manfred Reetz...
# Fetching works for David Regan...
# Fetching works for Hans Reiber...
# Fetching works for David Reinhoudt...
# Fetching works for Willem Remmelink...
# Fetching works for Rob Reneman...
# Fetching works for Geert Ridder...
# Fetching works for Richard Ridderinkhof...
# Fetching works for René de la Rie...
# Fetching works for Ivonne Rietjens...
# Fetching works for Ann Rigney...
# Fetching works for Maarten de Rijke...
# Fetching works for Avraham Rinat-Reiner...
# Fetching works for Ingrid Robeyns...
# Fetching works for George Robillard...
# Fetching works for Wil Roebroeks...
# Fetching works for Karin Roelofs...
# Fetching works for Eelco Rohling...
# Fetching works for Jana Roithová...
# Fetching works for Lucas van Rompay...
# Fetching works for Nico de Rooij...
# Fetching works for Hilger Ropers...
# Fetching works for Frits Rosendaal...
# Fetching works for Judith  Rosmalen...
# Fetching works for Maroeska Rovers...
# Fetching works for Joost Ruitenberg...
# Fetching works for Reiner Rummel...
# Fetching works for Douwe Runia...
# Fetching works for Floris Rutjes...
# Fetching works for Wim van Saarloos...
# Fetching works for Richard van de Sanden...
# Fetching works for Andries Sanders...
# Filtered works data saved to JSON: knaw_works_filtered.json
# Filtered works data saved to CSV: knaw_works_filtered.csv

# %%
import json

# Input and output file paths
input_file = "/content/knaw_works_filtered.json"  # Replace with your distorted JSON file path
output_file = "knaw_works_filtered_restored.json"  # Restored output file

# Load the distorted JSON file
with open(input_file, "r", encoding="utf-8") as infile:
    data = json.load(infile)

# Decode Unicode escape sequences
def decode_unicode(data):
    if isinstance(data, dict):
        return {key: decode_unicode(value) for key, value in data.items()}
    elif isinstance(data, list):
        return [decode_unicode(item) for item in data]
    elif isinstance(data, str):
        try:
            # Attempt to decode the string
            return data.encode('latin1').decode('utf-8')
        except (UnicodeEncodeError, UnicodeDecodeError):
            # Return the original string if decoding fails
            return data
    else:
        return data

restored_data = decode_unicode(data)

# Save the restored JSON file
with open(output_file, "w", encoding="utf-8") as outfile:
    json.dump(restored_data, outfile, ensure_ascii=False, indent=4)

print(f"Restored file saved to {output_file}")
# Out:
# Restored file saved to knaw_works_filtered_restored.json

# %%
import pandas as pd

# Input and output file paths
input_file = "/content/knaw_works_filtered.csv"  # Replace with your distorted CSV file path
output_file = "knaw_works_filtered_restored.csv"  # Restored output file

# Load the distorted CSV file
df = pd.read_csv(input_file)

# Decode Unicode escape sequences in strings
def decode_unicode_string(value):
    if isinstance(value, str):  # Ensure the value is a string before decoding
        try:
            return value.encode('latin1').decode('utf-8')
        except (UnicodeEncodeError, UnicodeDecodeError):
            return value  # Return the original value if decoding fails
    return value  # Return the value as-is if it's not a string

# Apply the Unicode decoding function to all string cells in the DataFrame
for col in df.columns:
    if df[col].dtype == 'object':  # Apply only to object (string) columns
        df[col] = df[col].apply(decode_unicode_string)

# Save the restored CSV file
df.to_csv(output_file, index=False)

print(f"Restored file saved to {output_file}")
# Out:
# Restored file saved to knaw_works_filtered_restored.csv
